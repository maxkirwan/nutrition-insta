# %% [markdown]
# # Using a subscription based service for ingredient parsing
#
# Zestful is a subscription based service which uses a prebuilt NER model to parse ingredients. It offers the parsing of 30 ingredients for free per day.
#
# However, it only intakes single lines of text relating to one ingredient:
#
#        - 3 red peppers, finely chopped
#        - 200 ml vegetable stock
#        - 1 tin of baked beans
#
# Therefore, this service will only be of use if singular ingredient lines can be retrieved from the text descriptions. This is a difficult task, as the posts come in a variety of formats. Here I shall focus on the most common formats of ingredient lists from the posts, i.e. those which are preceded by the word `ingredients` and are seperated by `\n` characters:
#
#         ingredients:
#         2 large onions, chopped
#         3 celery stalks, sliced
#         500g boneless chicken

# %%
import sys
sys.path.append("/Users/maxkirwan/Desktop/Uni/Data Science MSc/Data Science Project/nutrition-insta")
import functions

import numpy as np
import pandas as pd
import re

# %%
posts1 = pd.read_csv("/Users/maxkirwan/Desktop/Uni/Data Science MSc/Data Science Project/nutrition-insta/Instagram Data Scraping/Phantom Buster/recipe_posts.csv")
posts2 = pd.read_csv("/Users/maxkirwan/Desktop/Uni/Data Science MSc/Data Science Project/nutrition-insta/Instagram Data Scraping/Phantom Buster/recipe_posts_2.csv")
posts3 = pd.read_csv("/Users/maxkirwan/Desktop/Uni/Data Science MSc/Data Science Project/nutrition-insta/Instagram Data Scraping/Phantom Buster/recipe_posts_3.csv")

posts = pd.concat([posts1,posts2,posts3])

# %%
# Removing duplicate posts
posts = functions.remove_duplicates(posts)

# %%
# Getting english posts
posts = functions.get_english_posts(posts)
# Out:
# Detecting language of each post...
# Language detection complete.
# Time taken: 0:10:13.917597

# %%
# Preprocessing text descriptions
posts['description_preprocessed'] = posts['description'].apply(functions.preprocess_text)

# %%
def includes_ingredient_list(text):
    
    text_str = str(text)
    if ("ingredients:" in text or "ingredients :" in text) and text_str.count('\n') > 8:
        return True
        
    else:
        return False

# %%
posts['includes_ingredient_list'] = posts['description_preprocessed'].apply(includes_ingredient_list)
posts = posts[posts['includes_ingredient_list']]

# %% [markdown]
# ## Function to get ingredient lines

# %%
def get_ingredient_lines(text):
    
    '''
    Function to get list of ingredient lines.
    Only works if ingredient lines are preceded by "ingredients:" and are followed by a blank line
    '''
    
    # Split post description by new line
    text_list = text.split("\n")
    
    # The idea is to only take the part of the list between "ingredients:" and "\n"
    # as the ingredient list items will usually be in new lines after "ingredients:"
    # seperated by a blank line at the end before further text
    

    # Find index of first case of "ingredients:"
    for line in text_list:
        if 'ingredients:' in line or 'ingredients :' in line:
            start_index = text_list.index(line)
            break
    
    # Assume no end index to begin with (as ingredient list might come at end of post)
    end_index = None
    # Find index of first case of new line break after "ingredients:"
    # Skip out first ingredient in case its a new line (which we want to miss)
    rest_of_text_list = text_list[start_index+2:]
    for line in rest_of_text_list[2:]:
        if len(line) < 3:
            end_index = rest_of_text_list.index(line)
            break

    if end_index == None:
        ingredient_lines = text_list[start_index+1 : ]
    else:
        ingredient_lines = text_list[start_index+1 : start_index+end_index+2]
    
    if len(ingredient_lines[0]) < 2:
        ingredient_lines.pop(0)
        
    return ingredient_lines

# %%
for i in range(len(post_list)):
    print(i)
    print(get_ingredient_lines(post_list[i]))
# Out:
# 0
# ['1/2 cup instant oats', '1/2 cup milk', '1/2 cup water', '1 scoop chocolate protein powder', '1 teaspoon brown sugar']
# 1
# ['1 chicken breast⠀', '1 ball mozarella cheese ⠀', '2 tomatoes ⠀', 'small handful of basil ⠀', 'pesto ⠀', 'balsamic glaze ⠀']
# 2
# ['2 pound bok choy, small ', '1 tbs ginger, fresh, minced', ' 1/4 cup scallions, thinly sliced ', '1 1 /2 tbs olive oil, divided 6 tbs tamari sauce ', '1 tbs hemp seeds ']
# 3
# ['200 gram swiss brown mushrooms, chopped ', '220 gram all purpose flour', '20 gram sugar', '6 gram baking powder', '1/2 teaspoon salt', '1 teaspoon ', '55 gram cold butter, cut into small cubes', '25 gram beaten egg', 'approx. 100 ml milk ']
# 4
# ['curd - 1/2 cup', 'roasted gram flour - 1.5 tablespoon', 'carom seeds/ajwain - 1/4 teaspoon', 'ginger garlic paste - 1 tablespoon', 'kashmiri red mirch - 1 tablespoon', 'cumin powder - 1/2 teaspoon', 'black pepper powder - 1/2 teaspoon', 'turmeric powder - 1/2 teaspoon', 'salt as per taste', 'chaat masala - 1 teaspoon', 'garam masala - 1 teaspoon', 'lemon juice - 1 teaspoon', 'kasuri methi', 'hot mustard oil - 1.5 tablespoon', 'diced paneer - 200 grams', 'diced capsicum + onion + tomato(1 each)']
# 5
# ['*1 litre milk ', '*1/2 teaspoon oregano', '*1/2 teaspoon chili flakes', '*1/2 teaspoon jeera powder', '*salt as per taste', '*chat masala']
# 6
# ['serve it with butter and achaar, enjoy!']
# 7
# ['chia seeds - 1/2 cup', 'flax seeds - 1 cup ', 'coriander seeds /dhaniya - 1 tablespoon', 'urad dal -1 tablespoon', 'chana dal- 1 tablespoon', 'sesame seeds-1 tablespoon', 'dry coconut - 1 bowl', 'jeera / cumin seeds - 1 tablespoon', 'dried red chilies - 10-12 ', 'groundnuts - 1/2 cup', 'tamarind - one big lemon size', 'garlic clove - 10 ', 'salt - as per taste', 'jaggery -optional']
# 8
# ['8 ounce any mushrooms you can find', '5-7 slice of prosciutto', '1/3 cup sun dried tomato', '1/4 cup white wine', '2-3 sprig of thyme', '1 cup heavy cream', '3 clove garlic', '2 tablespoon parsley', '1 tablespoon butter', '1/2 cup parmesan', '12 ounce pasta of choice', 'optional: chili flakes to your liking']
# 9
# ['* 1 pound thinly sliced chicken thighs ', '* 1 jar maesri red curry paste', '* 2 tablespoon lemongrass paste plus a teaspoon of fresh minced lemongrass ', '* 1-2 diced shallots ', '* 2 minced garlic clove', '* about an inch of minced ginger', '*2 thinly sliced bell peppers ', '* 1 can coconut milk', '* 1 can coconut cream ', '* 1 tablespoon fish sauce (optional)', '* a few kaffir lime leaves ', '* 2 tablespoon brown sugar ', '* 2 minced thai chilies ', '* 1/2 - 1 juiced lime', '* 1/4 cup chopped thai basil', '*1/4 cup toasted cashews']
# 10
# ['16 ounce fettuccine pasta', '1-2 pound chicken breast thin sliced', 'less sodium montreal steak seasoning', 'olive oil', '1 stick (8 tablespoon) unsalted butter', '5 minced garlic clove', '3 tablespoon all purpose flour', '3 cup heavy cream', '1 cup pasta water', '1 cup shredded parmesan cheese( not the one in a bottle)', '1 cup white cheesy cheese', '1/2 teaspoon garlic powder', '1/2 teaspoon italian seasoning', '1 teaspoon black pepper', 'salt ', '1 serving of love']
# 11
# ['1/2 cup oats', '1 teaspoon chia seeds', '1 egg white ', '1 heap tablespoon vanilla protein powder', '1/2 banana mashed', '1 cup water']
# 12
# ['zucchini ']
# 13
# ['-\xa0\xa0vegan buffalo jack wings', '- chopped romaine lettuce', '- diced tomato', '- shredded carrots', '- diced cucumber', '- diced celery', '- sliced red onion']
# 14
# ['4 ounce whole cream cheese, softened to room temp', '2 tb chopped fresh dill', 'zest and juice of half a large lemon', 'salted butter, softened for spreading on bread slice', 'kosher salt', 'freshly ground black pepper', '6 slice high quality white or whole grain bread', '1/2 large cucumber, seeded and thinly sliced, thoroughly dried with paper towels']
# 15
# ['crust\u2060', '600 gram chocolate graham cracker crumb\u2060', '1/2 cup butter, melted\u2060', '1/2 teaspoon salt, to taste\u2060']
# 16
# ['- 400 gram new potatoes, preferably charlotte', '- 20 gram hazelnuts, blanched', '- 200 gram purple sprouting broccoli, trimmed of its thick stalk', '- 1/2 red onion, thinly sliced (approx. 75 g)', '- 20 gram parmigiano reggiano', '- 20 gram flat leaf parsley, leaves picked from the stalk (big handful)', '- 6 basil leaves (2.5 g)', '- 1 tarragon sprig, leaves picked (1 g)', '- 1 small clove garlic', '- 2 anchovy fillet, from a tin (optional)', '- 1/2 teaspoon dijon mustard', '- 1/2 lemon, juiced, the rest kept for garnish']
# 17
# ['1/2 pound farfalle', '1 medium yellow onion, finely chopped', '1 teaspoon olive oil', '3 large garlic clove, minced', '4 plant based sausages (396 g)', '1 teaspoon kosher salt', '1/2 teaspoon black pepper', '1 teaspoon dried parsley', '1/2 teaspoon dried oregano', '1 cup (packed) baby spinach', '1 cup canned crushed tomatoes', '1 cup dairy free heavy cream']
# 18
# ['cucumber ', 'eggs', 'canned corn', 'garlic', 'sour cream ', 'black pepper ', 'salt', 'optional: parsley garnish ']
# 19
# ['∙ 2 medium zucchini (about 11/2 lb.), halved lengthwise', '∙ about 1 pound adagio eggplants , cut into 1 " wedges', '∙ 3/4 cup extra-virgin olive oil, divided', '∙ 21/2 teaspoon. kosher salt, divided', '∙ 1 teaspoon. freshly ground black pepper, divided', '∙ 10 ounce penne or casarecce pasta', '∙ 1 large or 2 medium heirloom or virtuoso beefsteak tomatoes (about 1 lb.), cut into 1 " piece', '∙ 8 ounce ciliegini (mini fresh mozzarella balls), drained, halved', '∙ 2 tablespoon. white balsamic or white wine vinegar', '∙ 1 tablespoon. thyme leaves', '∙ 1 cup basil leaves']
# 20
# ['> soyabeans', '>salt', '> chilli powder , chat powder, onions, tomatoes, capsicum , coriander and mint leaves ', 'you can also mix variety of vegetables as you wish to have ']
# 21
# ['▢gluten-free nonstick cooking spray', '▢1 (30 -ounce) package of frozen gluten-free hash browns', '▢1 onion, diced', '▢1 red bell pepper, seeded, deveined, and diced', '▢8 ounce sliced mushrooms, baby bellas (cremini), or white', '▢2 cup chopped kale or spinach', '▢11/2 jars potato queso, mild or spicy', '▢smoked paprika', 'us customary - metric']
# 22
# ['-maida - 1 1 /3 cup', '-cocoa powder - 4 tablespoon', '-baking powder - 2 teaspoon', '-sugar - 3 tablespoon', '-chocolate chip - 2 tablespoon', '-salt - 1/4 teaspoon', '-egg - 1 no.', '-milk - 1 cup', '-melted butter - 1/4 cup', '-vanilla essence - 1/4 teaspoon', '-milk - 1/4 cup', '-butter']
# 23
# ['- 1.5 cup oats', '- 2 scoops unflavoured or vanilla protein powder', '- 1/2 teaspoon cinnamon', '- 1.5 -2 cup milk of choice (i use ) ', '- 2/3 cup greek yoghurt', '- 2 tablespoon chia seeds', '- maple syrup to taste (i used about 1 tablespoon)', '- 1 teaspoon vanilla essence (omit if using vanilla protein)', '- 1/4 cup dark chocolate chips']
# 24
# ['2 aubergines ', '2 minced garlic clove ', '2 tablespoon lemon juice ', '1/4 cup tahini ', '1/3 cup olive oil ', '2 tablespoon chopped flat leaf parsley', '1/4 teaspoon cumin ', 'salt n peps ', 'sprinkle of paprika ']
# 25
# ['• yogurt -1/2 cup ', '• papaya ripe - 1/2 ', '• banana\xa0 ripe - 2 ', '• raw turmeric\xa0 - 1/4 tablespoon ', '• ginger\xa0 - 1/2 tablespoon ', '• chia seeds\xa0 - 1 tablespoon ', '• pumpkin seeds - 1 tablespoon ', '• pomegranate kernels - 2 tablespoon ']
# 26
# ['1/2 cup oil/butter melted and cooled\u2060', '3/4 cup granulated sugar\u2060', '2 eggs, room temperature\u2060', '1 teaspoon vanilla extract\u2060', 'zest of one small lemon\u2060', '1 3 /4 cup of gf flour\u2060', '1/2 teaspoon salt\u2060', '2 teaspoon baking powder\u2060', '1/2 cup df milk\u2060', '1 1 /2 cup fresh/frozen blueberries\u2060']
# 27
# ['1.5 cup iceberg lettuce', '3 tablespoon mayonnaise', '2 tablespoon red wine vinegar', '1/4 cup banana peppers', 'banana pepper juice (optional)', 'oregano (to taste)', '1 clove minced garlic', 'red pepper flakes (to taste)', 'salt & pepper (to taste)', '1/2 cup sliced red onion']
# 28
# ['16 aero chocolate melts - 8 melts per person at 1/2 syn per melt (4 syns per portion)', '80 gram oats (40 gram = 1 hexb)', '60 ml semi skimmed milk (1/4 hexa)', '1/3 cup zero calorie sweetener (free)', '2 eggs (free)', '2 teaspoon vanilla essence (free)', '1 teaspoon baking powder ']
# 29
# ['chopped lettuce, sliced jalapeños, extra coriander chopped tomatoes and cucumber, cheese of choice. ', '', 'assemble and serve. ', '—————————————————————-']
# 30
# ['gochu chamchi (spicy tuna) 1 can ', '1/2 c diced onion', '1/2 t garlic minced', '2 t scallion, chopped', '3/4 buchim garoo (korean pancake mix)', 'pinch black pepper']
# 31
# ['whipped ff cream cheese, 80 g', 'salsa verde, 60 gram (1/4 cup)', '1 tbs lime juice', '1 teaspoon chili powder', '1/2 teaspoon cumin', '1/2 teaspoon onion powder', '1/2 teaspoon garlic powder', '1/3 cup cilantro', 'green onions, as much as desired', '2 cup shredded chicken (any kind you want! great if you have leftovers from a different night. in this photo, i used an heb rotisserie chicken!)', '10 extra thin mission corn tortillas', '1 can red enchilada sauce', '3 ounce lite mexican cheese']
# 32
# ['2 ripe bananas, mashed ', '1/3 cup olive oil ', '1/2 cup maple syrup ', '2 eggs ', '1/2 teaspoon vanilla ']
# 33
# ['- ⅔ cup rolled oats', '- ⅔ cup milk, of your choice', '- 1/2 cup vanilla greek yogurt', '- 1/2 teaspoon vanilla extract', '- 1 teaspoon chia seed, optional', '- 1/2 teaspoon cinnamon', '- 2 teaspoon of something sweet like honey, berry jam, or maple syrup', '- handful of fresh blueberries']
# 34
# ['chopped lettuce, sliced jalapeños, extra coriander chopped tomatoes and cucumber, cheese of choice. ', '', 'assemble and serve. ', '—————————————————————-']
# 35
# ['chopped lettuce, sliced jalapeños, extra coriander chopped tomatoes and cucumber, cheese of choice. ', '', 'assemble and serve. ', '—————————————————————-']
# 36
# ['• 4 medium ripe bananas', '• 1/4 cup vegetable oil', '• 1/4 cup unsweetened nondairy milk', '• 1/2 cup light brown sugar', '• 2 teaspoon pure vanilla extract', '• 2 cup unbleached all-purpose flour', '• 1 teaspoon cinnamon', '• 1 teaspoon baking soda', '• 1/2 teaspoon salt', '• sliced bananas, for topping']
# 37
# ['sourdough bread', 'pesto', 'large tomatoes ', 'mozzarella ', 'roasted red peppers']
# 38
# ['sourdough bread', 'pesto', 'large tomatoes ', 'mozzarella ', 'roasted red peppers']
# 39
# ['- 2 whole pepperoni sausages, casings removed and finely chopped in a food processor', '- 1 bunch flat-leaf parsley chopped', '- 75 gram harissa (we are big fans of rose harissa)', '- juice of 2 lemons', '- 500 gram pasta (we used pappardelle)', '- 280 gram thick greek-style yoghurt']
# 40
# ['100 gram butter- ', '1 tablespoon sugar free syrup*- ', '80 gram golden blond choc spread- ', '230 gram oreos- ', '80 gram raisins and cranberries- ', '150 gram white chocolate- ', '120 gram cookies and cream spread- ']
# 41
# ['4 oranges (peeled & cut) ', '2 carrots (peeled & cut) ', 'ginger (half thumb or 1/4 teaspoon ginger powder) ', 'turmeric (half thumb or 1/4 teaspoon turmeric powder) ', 'pinch of pepper ', '2 tablespoon fres aloe (gel, optional)', 'water (1/4 - 1/2 cup) ']
# 42
# ['170 gram “leivadiotis” raw almonds', '120 gram whole oats', '120 gram all-purpose flour', '1/2 teaspoon baking powder', '1/4 teaspoon salt', '125 gram unsalted butter', '120 gram soft brown sugar', '1 large egg', '1 teaspoon vanilla extract', 'about 24 whole almonds to garnish']
# 43
# ['- 425 gram ayam brand baked beans - vegetarian ', '- 1/4 zucchini (cut into small cubes)', '- 4 big cherry tomato (sliced)', '- 2 tablespoon parmesan cheese', '- few dash black pepper', '- few dash italian herbs']
# 44
# ['150 gram frozen mixed berries ', '80 gram yoghurt (i used yopro)', '15 gram vanilla protein powder ', '40 ml unsweetened almond milk ']
# 45
# ['1 . good quality cream. i used organic cream from . 3 tablespoon ', '2 . lighter, high protein cream cheese. x 2 165 gram tubs', '3 . 2 eggs, i used organic eggs', '4 . 3 tablespoon self raising flour ', '5 . honey, i used english blossom honey from ', '6 . 2 very ripe bananas ', '7 . vanilla extract/ paste, a drop ', '8 . zest of a lemon ', '9 . jaggery, to sprinkle on top if you please ', '10 . raspberry compote: raspberries, honey. microwave for a couple of minutes, sweeten to your taste using honey. chill overnight. ']
# 46
# ['2 cup wild rice blend (such as lundgren’s)', 'regular strength chicken or vegetable broth (enough to use instead of water, for cooking rice according to package instructions)', '1/4 cup salted butter, sliced', '1 large onion, chopped', '1 cup thinly sliced baby carrots', '2 cup freshly shaved brussels sprouts', '4 garlic clove, minced', '1 teaspoon dry italian seasoning', '1/4 teaspoon freshly ground black pepper']
# 47
# ['• 1 15 -ounce can chickpeas, drained and rinsed', '• 1/4 cup tahini ', '• 1/4 cup italian parsley', '• 1 cup super greens of choice (a packed cup of raw greens) such as kale, arugula, and/or spinach.', '• 1/4 cup chives or green onion, chopped', '• 1/4 cup lemon juice, fresh-squeezed', '• 1/4 cup olive oil', '• 1-2 clove fresh garlic (peeled) – depending on your affinity for garlic', '• 1/4 teaspoon cumin', '• 1/2 teaspoon sea salt ', '• dash of black pepper', '• 1 scp of creamy vanilla superfood protein', '• possibly a small splash of water during blending']
# 48
# ['• 72 gram self raising flour ', '• 1 light babybel ', '• 85 gram greek yoghurt (fat free / pizza)', '• 10 gram tomato & basil sauce ', '• 14 gram mozzarella ', '• 0.5 teaspoon spicy pizza seasoning ', '• 1 teaspoon herb dip seasoning ', '• 25 gram fat free greek yoghurt ']
# 49
# ['• 1 large onion ', '• 2 clove of garlic ', '• 500 ml heavy cream ', '• 300 ml water ', '• 1/4 teaspoon chili flakes ', '• 4 can of chopped tomatoes ', '• 3 tablespoon brown sugar', '• 1/2 teaspoon dried oregano ', '• 1/2 teaspoon dried thyme ', '• 2 chicken stock cubes or vegetable ', '• 25 gram of butter ', '• 1 tablespoon olive oil ', '• 2 large fresh basil leaves ', '• a good amount of freshly grounded black pepper', '• salt to taste', '• 3 tablespoon ketchup', '• 1 tablespoon tomato paste ', '• 1 teaspoon onion powder ']
# 50
# ['-spare ribs (2 x packs)', '-sausages (1 x pack)', '-chorizo (1 x)', '-olive oil', '-onion (3 x)', '-celery (3 ×)', '-carrot (3 x)', '-tomatos (3 x packs cherry/plum) ', '-passata', '-tomato paste', '-garlic (3 x clove)', '-red wine (200-250 ml)', '-basil (1 x pack)', '-bay leaf (6 x)', '-salt and pepper', '-rigatoni ', '-pasta water', '-parmesan ']
# 51
# ['3 can sweet corn rinsed and drained ', '3 tablespoon salted butter ', '3/4 teaspoon cumin ', '3/4 teaspoon chili powder ', '1/2 teaspoon pepper ', '1/2 teaspoon salt ', '1/2 large red onion, chopped ', '1 jalapeño, chopped ', '3/4 cup cotija cheese, crumbled (more for garnish) ', '2 tablespoon cilantro (more for garnish) ', 'lime wedges to garnish ']
# 52
# ['*boneless chicken (with bones also fine )', '*bell peppers ', '*onions ', '*garlic ', '*soya sauce', '*orange juice ', '*salt ', '*pepper ', '*fish sauce ', '*oyster sauce', '*lemon juice ', '*ketchup (optional)', '*sugar (optional or as per need)', '*lemon grass (optional)', '*sesame seeds (optional)']
# 53
# ['- half kg chicken minced', '- 1 medium sized onion finely chopped ', '- 3-4 medium sized tomatoes (paste)', '- ginger garlic paste 2 tb spoon (because i loveee)', '- salt (as per taste)', '- paprika powder, 1 tb spoon (or as per your taste)', '- oregano (half tea spoon)', '- mixed herms (as per your liking)', '- soya sauce 1 tb spoon', '- chilli sauce 1 tb spoon', '- chilli garlic ketchup (3-4 tb spoons )']
# 54
# ['1 glass milk', '2 banana', '1/4 cup oats', '1/2 teaspoon cardamom powder', 'pinch of cinnamon powder', 'dry fruits(almonds, walnuts, cashew) ', '1 tablespoon sugar / honey', '4 ice cubes']
# 55
# ['1 . wash and drain 200 gram of rice with a mesh sieve. ', '2 . heat 1 tablespoon of olive oil in a frying pan. toss a finely chopped onion, 1/2 a diced bell pepper, garlic, and a diced jalapeño in it, and give it a quick sauté. simmer for 10 minutes or until the onions become translucent.', '3 . toss in the rice and sauté for 2 minutes, or until it’s toasted and golden brown. add 1/2 a teaspoon of cumin, salt, pepper, 400 gram chopped tomatoes, and 250 ml broth to it. if you’re using ketchup instead of tomatoes, add it to the mixture. stir everything together.', '4 . bring the mixture to a boil and cover it with a lid. reduce the heat and simmer for 15 minutes or until the rice is thoroughly cooked.', '5 . garnish with chopped cilantro or lime wedges. ']
# 56
# ['caprese chicken sausage', 'protein pasta', 'cherry tomatoes', 'mozzarella pearls', 'olive oil/balsamic vinegar ', 'seasonings ', '(add basil lol)']
# 57
# ['• arugula', '• red grapefruit', '• red onion', '• fennel', '• boquerones', '• garlic', '• olive oil', '• red grapefruit juice', '• salt']
# 58
# ['cooked rice - 1.5 cup ', 'curd - 1 cup ', 'salt - as per taste ', 'mustard seeds - 1 teaspoon ', 'red chillies ', 'urad dal - 1 teaspoon ', 'hing - a pinch ', 'green chilly - 2/3 ', 'curry leaves - 10/15 ', 'coriander - for garnishing ']
# 59
# ['- 200 gram spaghetti', '- diced garlic', '- 1 tablespoon of chilli flakes (i used dried chillis)', '- 2 tablespoon soy sauce', '- 1 tablespoon oyster sauce', '- 1 tablespoon chilli oil', '- 3 tablespoon olive oil', '- 2 tablespoon butter']
# 60
# [' 250 gram plain flour ', '100 gram dairy free butter', ' 100 gram caster sugar', ' 1 egg ', ' 1 teaspoon vanilla extract ']
# 61
# ['1 medium sized onion - diced', '4 garlic clove - chopped ', '1/2 inch of ginger - sliced ', '1 tomato- cubes', '1 red chilli- julienne', '120 ml of coconut cream', '200 ml of water (or as required)', '1 tbs of oil ', 'a pinch of carom (ajwain) seeds', '1/2 teaspoon of turmeric powder', '1 bay leaf', '1 tbs of chopped coriander', 'salt to taste', '1/4 teaspoon of crushed black pepper ', '1/2 teaspoon paprika ', '200 gram of chicken (or any meat of choice)']
# 62
# ['4 large eggs ', '1 cup castor sugar', '1 cup oil', '1 cup fresh orange juice', 'zest of oranges used (reserve half for glaze) ', '2 cup self-raising flour', '2 teaspoon baking powder']
# 63
# ['250 gram diced extra firm tofu', '1 teaspoon oil', '1 finely sliced red onion', '1/2 inch ginger juliennes', '1 finely chopped spring onion', '1/2 cup thinly sliced peppers', '1-2 teaspoon white sesame seeds']
# 64
# ['butter ', 'tomato purée ', 'schezwan sauce ', 'tomato ketchup ', 'oregano ', 'chilly flakes ', 'rice paper roll ', 'cheese ', 'sesame seeds ', 'mint leaves ']
# 65
# ['for barista/fried onion - oil + finely sliced onion', 'fry it till turns golden and take it out']
# 66
# ['peanut oil, for frying', '1 1 /2 cup all-purpose flour', '1/2 cup cornstarch', '1/2 teaspoon baking powder', 'kosher salt', '1 cup buttermilk', '2 teaspoon hot sauce', '1 large egg', '4 boneless, skinless chicken thighs, patted dry', '4 tablespoon nashville hot chicken seasoning', '1 teaspoon garlic powder', '1 teaspoon smoked paprika', 'lettuce', 'mayonnaise']
# 67
# ['- minced pork 250 g', '- garlic 3 clove', '- chilli padi 2 pcs', '- sweet basil leaf 5 g', '- oyster sauce 1 teaspoon', '- rice wine 1 tablespoon', '- light soy sauce 1 1 /2 tablespoon', '- anchovy powder 1/2 teaspoon', '- dark soy sauce 1 teaspoon', '- sugar 1/2 teaspoon']
# 68
# ['1 cup oats, rolled', '500 ml milk, any', '1 tablespoon chia seeds', '1/2 teaspoon cardamom seeds', '20 gram pistachios, chopped']
# 69
# ['2 chicken breasts', 'salt and pepper', 'garlic granules', '200 ml single cream', '3 teaspoon wholegrain mustard', 'mash or rice to serve']
# 70
# ['3 chicken fillet (can use whole chicken piece too)', '⅓ cup oil or ghee for cooking ', '1 heaped teaspoon ground ginger ', '1 heaped teaspoon ground garlic ', '1 level teaspoon ground green chillies ', '1 teaspoon kashmiri red chilli powder ', '1 teaspoon ground cumin ', '1 teaspoon ground coriander powder ', 'salt and pepper to taste ', '3-4 large tomatoes (chopped)', '2 tablespoon thick plain yogurt ', 'freshly chopped coriander, lemon wedges and ginger julienne for garnish ']
# 71
# ['100 gram self-raising flour', '100 gram self-raising wholemeal flour ', '1 teaspoon baking powder', '70 gram fruit & seed mix ', '50 gram butter', '100 ml milk ', '1 egg ']
# 72
# [' 2 1 /4 cup plain flour\u2060', ' 1 teaspoon salt\u2060', ' 1/2 teaspoon bi carb soda\u2060', ' 3/4 cup vegan butter, melted\u2060', ' 1 cup sugar\u2060', ' 3/4 cup brown sugar\u2060', " 2 flax 'eggs' (to make 1 flax egg combine 1 tablespoon ground flaxseed and 3 tablespoon)\u2060", ' 1 teaspoon vanilla extract\u2060', ' 1 1 /2 cup oreos, crumbled \u2060']
# 73
# ['4 handfuls mixed tomatoes, roughly chopped\u2060', '1 jar of artichokes, drained but reserving 2 tablespoon oil \u2060', '2 clove garlic\u2060', '4 tablespoon capers and juices\u2060', 'juice of 1 lemon\u2060', '1 tablespoon tomato purée\u2060', '1 tablespoon olive oil\u2060', '1 tablespoon oregano\u2060', '1 teaspoon chilli flakes\u2060', '1/2 teaspoon salt\u2060', '1 teaspoon pepper\u2060']
# 74
# ['for the paste -', '1.5 tablespoon oil', '2 whole cardamom/elichee', '4 clove ', '3 black pepper', '1 bay leaf', 'small piece of cinnamon ', '2 slit green chillies ', '3 sliced onions ', '1 teaspoon ginger garlic paste ', '3 chopped tomatoes ', '2/3 teaspoon salt ']
# 75
# ['ghee - 3 tablespoon', 'chopped dry fruits', 'raisins/kishmish', 'seviyan/vermicelli - 1 cup', 'milk - 1 litre', 'sugar - 3/4 cup', 'saffron strands', 'cardamom powder - 1/2 teaspoon', 'custard mixture - 2 tablespoon custard powder + milk']
# 76
# ['milk 10 kg ', '1 large vanilla custard packet ', '1 packet of jelly ', 'half kg sugar (you can adjust according to your taste) ', 'few drops of vanilla essence ', '4-5 plain cakes ', 'fruits (apple and banana)']
# 77
# ['• 300 gram potatoes (use as much as you want)', '• one can of chickpeas', '• paprika & cumin ', '• baked carrots', '• tomatoes', '• 1/2 avocado ', '• 1 tbs tahini ', 'lettuce']
# 78
# ['nectarine ', ' vanilla whole milk greek yogurt ', ' pumpkin pie granola', ' kirklands peanut butter ', 'cinnamon ', 'banana ']
# 79
# ['sandwich thins', 'butter ', ' plain cream cheese ', 'carrots (shredded) ', 'avocado ', ' everything but the bagel seasoning ']
# 80
# ['- 3 cup long-grained rice (i’m using basmati), washed and rinsed until clear', '- 5 tablespoon unsalted butter', '- 1 medium onion, minced', '- 6 clove garlic, minced', '- 4 1 /2 c water', '- 1 chicken cube', '- 1 teaspoon ground cumin', '- 1 teaspoon ground turmeric', '- 1 cinnamon stick', '- 2 teaspoon salt', '- 1/2 teaspoon pepper', '- 1/2 cup dried cranberries', '- 1/2 cup pepitas']
# 81
# ['- 1 pound ground beef', '- 1/2 cup white onion diced', '- 1 package taco seasoning mix 1 oz', '- 1/2 cup water', '- 1 cup shredded cheddar cheese', '- 2 crescent-style dinner rolls 8 ounce can']
# 82
# ['1 . 5 -a-day components: 1 . courgette, 160 gram. sliced. 2 . chard, 160 gram 3 . cabbage, 160 gram 4 . baby broad beans (i used frozen), 160 gram 5 . beetroot, spring onions, 160 gram', '2 . garlic, 4 clove, finely sliced ', '3 . chilli, 1 , finely chopped ', '4 . olive oil ', '5 . zest and juice of 2 lemons', '6 . honey (optional) ', '7 . parsley ', '8 . wholewheat spaghetti, 160 gram cooked in a big pot of salted hot water', '9 . mozzarella (optional) ']
# 83
# ['• 6 full size chocolate bars', '• 1 bag of marshmallows ', '• assorted dippers, such as graham crackers, strawberries, pretzels, etc.']
# 84
# ['1 quart strawberries, washed and drained (plus extra for garnish)', '1 package cream cheese at room temperature, 8 oz.', '2 containers whipped topping 8 ounce each (divided)', '1 package vanilla wafers', '1 package instant vanilla pudding', '2 1 ⁄2 cup milk- enough for pudding recipe.']
# 85
# ['1 egg', '1/3 cup oil', '1 teaspoon vanilla ', '1/3 cup sugar', '3 tablespoon brown sugar', '1 teaspoon salt', '1 teaspoon baking soda', '1 package of sesame powder', '1/4 cup oil ', 'sesame seeds']
# 86
# [' 1-2 tablespoon of honey', ' 2-3 tablespoon of fresh-squeezed lemon juice from 2 lemons', ' 2 small garlic gloves, finally chopped', ' 2 teaspoon whole grain, old style mustard (optional)', ' 1/2 teaspoon sea salt', ' freshly ground pepper', '1/3 cup extra-virgin olive oil', ' 1/3 cup extra-virgin olive oiltional)']
# 87
# ['1/2 pound farfalle', '1 medium yellow onion, finely chopped', '1 teaspoon olive oil', '3 large garlic clove, minced', '4 plant based sausages (396 g)', '1 teaspoon kosher salt', '1/2 teaspoon black pepper', '1 teaspoon dried parsley', '1/2 teaspoon dried oregano', '1 cup (packed) baby spinach', '1 cup canned crushed tomatoes', '1 cup dairy free heavy cream']
# 88
# ['3-4 boneless skinless, chicken breasts (about 2 ibs)', '1/4 teaspoon salt', '1/4 teaspoon pepper', '1/4 teaspoon garlic powder', '1 medium zucchini', '1 medium yellow squash (i used butternut cause it’s all i had in my garden)', '1/2 medium sweet yellow onion', '1/2 cup pesto prepared ', '4 ounce parmesan cheese', '4 ounce mozzarella', 'instructions:', '1 . preheat the oven to 375 °f.', '2 . chop the zucchini, squash, and onion and combine', '3 . in a large casserole dish, lay the chicken in a flat single layer and season it with the salt, pepper and', 'garlic powder. next layer the veggies on and then dollop the pesto over the veggies, then top with the', 'cheeses.', '4 . bake on the middle rack for 35-45 minutes or until chicken is cooked through, 165 f internal temp. if it', 'starts to brown more than desired, loosely cover with foil until it is done cooking', '5 . serve hot and enjoy!']
# 89
# [' 1 teaspoon baking powder']
# 90
# ['-3 roma tomatoes seeds removed, diced\u2028-⅓ cup red onion diced', '-15 ounce black beans rinsed and drained', '-15 ounce black eyed peas rinsed and drained', '-1 1 /2 cup frozen sweet corn thawed ', '-1 bell pepper diced \u2028-1 jalapeño pepper seeds removed']
# 91
# ['- 200 gram tofu\u2063', '- 1.5 frozen bananas\u2063', '- 2 tablespoon cocoa + 2 tablespoon chocolate protein\u2063', '- 1 handful of cauliflower\u2063', '- 1 handful of frozen berries\u2063', '- 1 teaspoon of maca powder\u2063', '- 1 splash of plant-based milk"\u2063']
# 92
# ['shitake mushrooms', '4 tablespoon olive oil', '1 tablespoon white wine vinegar', '3 tablespoon garlic powder (or more if you want more taste)', '2 tablespoon minced garlic', '1 tablespoon salt', 'handful of chopped basil or parsley']
# 93
# ['4 medium-sized zucchini, spiralized', '2 eggs, lightly beaten ', '2 cup shredded mozzarella, divided', '⅓ cup grated parmesan', '1/4 cup all-purpose flour', '2 t. cornmeal', '8 ounce pizza sauce', '1/2 cup pepperoni (optional for vegetarian style)', '1 1 /2 t. kosher salt', '2 t. fresh basil for topping (optional)']
# 94
# ['- everything bagel', '- 2 tablespoon hommus ', '- 2 tablespoon low sodium peanut butter ', '- 1/2 banana ', '- cayenne pepper']
# 95
# ['• 1-2 peaches ', '• 1-2 plums ', '• dark grade 100 % pure maple syrup \U0001fad7', '• honey ', '• pistachios ', '• everything but the elote seasoning ']
# 96
# ['organic broccoli florets ', ' organic white beans ', 'pasta ', 'lemon juice ', 'optional: bacon, parmesan cheese ']
# 97
# ['cut crumb mixture ingredients together with a fork until crumbles form. sprinkle crumb mixture on top. bake at 350 for 10-11 minutes. ', '', 'in a small saucepan, melt syrup and butter together. once melted, remove from heat and whisk in cinnamon, salt, and powdered sugar. let it rest for a few minutes before drizzling on top of donuts.']
# 98
# ['・5 potatoes', '・3 deli ham, chopped', '・cheese', '・olive oil', '・salt', '・pepper', '・parsley']
# 99
# ['1-2 teaspoon matcha powder (more or less, your preference) ', 'milk of choice ', '2 tablespoon boiling water', 'sweetener of choice: stevia, maple syrup, manuka honey', '1 cup of ice']
# 100
# ['• 200 gram frozen banana', '• 100 gram frozen zucchini', '• 35 gram peanut flour', '• 200 gram silken tofu']
# 101
# ['1 pound chicken thighs or breast ', '1 garlic clove', '1 tablespoon butter', '1/3 cup honey ', '1/4 cup soy sauce ', '2 tablespoon rice vinegar ', '1 teaspoon chili flakes ', 'salt & pepper to taste', 'flour for dredging ', 'oil for frying ', 'scallions & parsley for garnish!']
# 102
# ['•250 gram strawberry', '•2 guavas', '•5 bananas •2 tablespoon of nevella', '•1 tablespoon honey', '•0.5 litre of low fat milk', '•almonds, pistachios, and cream for toppings', 'directions:', 'wash the fruits and cut them into halves', 'place them in the etectric blednder', 'pour milk, nevella and honey and blend them together', 'add your topping with ice cubes and cream', 'bon appétit ']
# 103
# ['- 1 tablespoon minced ginger ', '- juice of half a lemon', '- 1 tablespoon raw honey', '- throat coat tea ', '- 1 cup of hot water', '- 1/2 teaspoon turmeric ']
# 104
# ['5 persian cucumbers, peeled & sliced round ', '1/4 cup sour cream', '21/2 tablespoon yuzu hot sauce ', 'chives, finely chopped', 'flaky salt']
# 105
# ['- yogurt ', '- cashew spread ( use my discount code marie-10 to save some money on your order) ', '- banana', '- red currants', '- kiwi', '- blueberries', '- raspberries', '- pecan', '- chia seeds', '- dark chocolate']
# 106
# ['1 cup red split lentils \u2060', '1/2 med onion thinly sliced\u2060', '2/3 tablespoon. ghee (or 1/2 veg oil + butter) to fry onions \u2060', '1 teaspoon. turmeric \u2060', '1 teaspoon. paprika \u2060', '2 tablespoon. garlic and ginger paste\u2060', '1 1 /2 teaspoon ground coriander \u2060', 'salt to taste\u2060', 'green chillies, 2 small ones chopped (optional)\u2060', 'fresh coriander to garnish\u2060']
# 107
# ['• sesame bread (or any kind of bread you like)', '• kashi honey almond granola cereal', '• kraft smooth peanut butter ', '• (if you want to add something sweet, you can add berries or drizzle some honey on top) ']
# 108
# ['- 2 boxes of rigatoni noodles', '- 1 container of ricotta, whole milk', '- 1 block of mozzarella cheese, freshly grated', '- 1 roll of regular (or spicy) sausage', '- 2 jars of tomato basil sauce (using here)', '- 1/2 tablespoon of dried basil', '- 1/2 tablespoon of garlic powder', '- 1/2 tablespoon of italian seasoning ']
# 109
# ['sugar', 'instant coffee', 'ice cubes', 'whole milk']
# 110
# ['sweet corn ‘salsa’', '-1 can sweet corn ', '-1/3 red onion (chopped)', '-paprika powder ', '-chili powder', '-salt & pepper ', '-lime juice', ' (add as many spices and herbs as you like)']
# 111
# ['pepperoni', 'mozzarella', 'marinara sauce', 'low carb tortilla', 'seasonings of your choice ']
# 112
# ['1 tablespoon olive oil', '1 leek, finely sliced', '1/2 fennel bulb, thinly sliced', '3 garlic clove, crushed', '1/2 teaspoon fennel seeds', '6 sprig oregano, or 1 1 /2 teaspoon dried leaves', '1 parmesan rind (such a genius way of adding flavour without the fat and calories of cheese)', '4 cup chicken or veg stock', '500 gram chicken breast, cut into large piece', '400 gram cannellini beans, drained', '1 zucchini, diced', '2 stick celery, chopped', '1/2 bunch silverbeet']
# 113
# [' 450 gram 5 % beef mince ', ' 1 taco seasoning () ', ' 2 tablespoon honey ', ' 2 bell peppers chopped ', ' 4 brioche wraps ', ' 60 gram red leicestershire ', ' 60 gram mozzarella ', ' 1 tablespoon soured cream (per two portions) ', ' 1 tablespoon smashed avo & lime (per two portions) ', ' few baby plum tomatoes, chopped ']
# 114
# ['- 250 gram sour cream', '- 100 gram mayonnaise (min. 50 % fat)', '- 100 gram cream cheese', '- 50 gram yogurt 3.2 %', '- 1/2 teaspoon smoked paprika powder', '- 1/2 teaspoon chili cayenne', '- 1 teaspoon ground cumin', '- 1/2 teaspoon garlic powder', '- 1 tablespoon dried oregano', '- juice of 1/4 lime', '- salt & pepper']
# 115
# ['- 16 ounce mild italian sausage', '- 2 cup mushroom (sliced)', '- 1 small red onion (diced)', '- 1 clove minced garlic', '- 4 cup spinach', '- 1 cup brie cheese (cubed)', '- 10 eggs', '- 1/2 cup milk', '- 1 1 /2 teaspoon garlic powder', '- 1 1 /2 teaspoon onion powder', '- 1 teaspoon green goddess seasoning (can omit)', '- salt', '- pepper', '- 1 can crescent roll']
# 116
# ['rice cakes (i used 4 )']
# 117
# ['☆ boiled eggs ', '☆ oil to fry ', '☆ besan 1/2 cup', '☆ salt to taste', '☆ ajwain 1/2 teaspoon', '☆ jeera 1/2 teaspoon ', '☆ turmeric a pinch ', '☆ red chilli powder', '☆ coriender ', '☆ water', '☆ chat masala ']
# 118
# ['•2 pound ground beef (we use 85/15 )', '•2 medium zucchini (sliced & quartered)', '•elbow pasta (8 ounce - i use because it’s gluten free -plus it adds more fiber & protein!)', '•tomato sauce (8 oz)', '•chicken broth (4 cup)', '•shredded cheddar cheese (1 cup)', '•mustard (2 t)', '•hamburger seasoning (1 t)', '•tobasco (optional - to taste)', '•salt + pepper (to taste)']
# 119
# ['-1 1 /2 cup lentils', '-1.5 pound of ground beef', '-1 onion ', '-1 large carrot', '-2 large celery stick', '-1/2 teaspoon curry', '-1/4 teaspoon turmeric', '-1 teaspoon aleppo pepper', '-2 1 /2 teaspoon dry dill', '-1/4 teaspoon garlic powder', '-1 1 /2 tablespoon tomato paste', '-1 egg', '-salt and pepper to taste']
# 120
# ['2 large onions, chopped', '4 spring onions, sliced (be sure to also add the root ends to the soup -- they are extra healing)', '2 large carrots, peeled and sliced', '3 celery stalk, sliced', '12 large garlic clove, smashed', '4 large stick of wakame seaweed (this can be left out, or replaced with spinach)', '1/4 cup chicken bone broth (this can be substituted with chicken stock)', '3 cup water', '500 gram boneless chicken thighs, cut into 1 -inch piece', 'salt and pepper, to taste', '1 cup small pasta']
# 121
# ['4 raspberries', '3 blackberries ', '3 fresh mint leaves ', '2 small strawberries, hulled and sliced in half ', '2 teaspoon granulated sugar ', '2 ounce silver rum ', '2 ounce seltzer water ', ' in a pint or large glass, combine the raspberries, blackberries, lime wedges, mint leaves, strawberries and sugar and muddle with a muddler or wooden spoon. add the rum and mix with a spoon. fill the glass with ice, top off with the seltzer and stir. garnish with the mint ']
# 122
# ['2 cup coconut milk', '1/2 cup maple syrup', '1/3 cup peanut butter', '1 teaspoon vanilla', '2 cup rolled oats', '1/4 cup cocoa', '1 teaspoon baking powder', '1 tablespoon flax', 'pinch of salt', '1/3 cup chocolate chips', 'pan is 6 x 9 ']
# 123
# ['2 tablespoon butter ', '1 tablespoon olive oil ', 'meat of 6 sausages, removed from the skin', '1 onion, diced ', '1 bell pepper, diced ', '1/2 teaspoon chili flakes ', '1 teaspoon italian herbs ', '2 garlic clove, minced ', '250 gram cauliflower rice ', '100 gram frozen peas ', '150 gram grated mozzarella cheese ']
# 124
# ['2 skinless chicken breasts', '1 tablespoon olive oil', '1 tablespoon italian seasoning', '1 teaspoon garlic powder', '1/2 teaspoon paprika', 'salt and pepper', 'optional: vegetables (brussel sprouts, carrots, green beans)']
# 125
# ['dressing']
# 126
# ['• 1 x pack of super noods ', '• handful of frozen veg ', '• seasoning packet ', '• hot chilli powder (a lot) ', '• red pepper flakes ', '• mayo (too cool down the spiciness) ', '• ketchup (trust me - only a lil bit tho)', '• cheese', '• egg ', '• drizzle of soy sauce']
# 127
# ['- 50 gram butter', '- 6 spring onions, sliced', '- 200 gram jumbo oats', '- 150 gram grated carrot', '- 50 gram almonds, roughly chopped', '- 3 tablespoon mixed seeds, divided', '- 150 gram dubliner lighter, grated', '- 2 eggs, beaten', '- 1/2 teaspoon salt flakes', '- 1/4 teaspoon black pepper']
# 128
# ['paneer 250 gram', 'onion 1 medium chopped', 'garlic 3-4 clove chopped', 'cashews 15 pcs', 'mawa 100 gram grated (50 + 50 ) ', 'cardamom 2 pc whole', 'cinnamon stick 1 ', 'clove 2 ', 'pepper corns 7-8 pcs', 'cumin seeds 1 teaspoon', 'tej patta 1 ', 'milk 1/2 cup', 'yogurt 1 tablespoon', 'garam masala 1 teaspoon (or kitchen king masala)', 'salt to taste', 'fresh cream 2 tablespoon', 'oil', 'ghee']
# 129
# ['1 . white bread 2 pcs\r', '2 . warm milk 2 cup \r', '3 . cooking oil 4 tablespoon \r', '4 . ghee/clarified butter 2 tablespoon\r', '5 . bay leaf 1 \r', '6 . cinnamon stick 1 \r', '7 . cardamom 4 \r', '8 . clove 4 \r', '9 . onion paste 1 cup\r', '10 . garlic paste 1 tablespoon\r', '11 . ginger paste 1 tablespoon\r', '12 . coriander powder 1 teaspoon \r', '13 . cumin powder 1 teaspoon\r', '14 . chicken 300 gram\r', '15 . cashew paste 4 tablespoon\r', '16 . salt to taste\r', '17 . green chili 8-10 pcs \r', '18 . water 1.5 cup\r']
# 130
# ['2 bananas (mashed)', '1 egg', '1/2 c honey or sweetener of choice', '1/2 c natural peanut butter', '1 teaspoon vanilla extract', '1 c oat flour (just blend oats until they make a flour)', '1/3 c cacao powder', '1 teaspoon baking powder', 'handful of dark choc chips']
# 131
# ['* 1 (13.5 ounce) can full-fat coconut milk\u2060', '* 1 tablespoon gelatin powder\u2060', '* 3 tablespoon honey\u2060', '* 2 teaspoon almond extract\u2060', '* 1 cup canned mandarin orange segments (in juice)\u2060', '* 1 cup canned peach slice (in fruit juice)\u2060', '* 1 cup mixed berries']
# 132
# ['2 skinless chicken breasts, diced', '450 gram fettuccine noodles', '2-1 /2 cup all purpose cream/whipping cream', '5 clove garlic, minced', '1 sm onion, chopped', '1 cup champignons/canned mushrooms, optional', '1-1 /2 cup shredded parmessan cheese', '2 tbs butter', 'salt and white pepper to taste', '1/2 teaspoon ground nutmeg, optional', '1 tbs oregano', 'method:', 'cook fettucine according to package instructions and set aside.', 'in a large skillet, saute chicken in 1-1 /2 tbs cooking oil.', 'cook until no longer pink and juices run clear.', 'remove and keep warm.', 'in the same skillet, saute garlic and onions until tender.', 'add the champignons/mushrooms and cook for 3-5 minutes.', 'add butter, salt and pepper, all purpose cream and cheese.', 'return chicken to the pan; heat through and until the cheese is melted.', 'serve alfredo sauce over prepared noodles.', 'garnished with freshly grated parmesan and parsley if desired.', ' enjoy']
# 133
# ['jus rol or any brand of pre rolled puff pastry ', '250 gram double or whipping cream', '200 gram ready made custard', 'icing sugar', 'strawberries halved']
# 134
# ['4 tablespoon olive oil divided ', '2 tablespoon freshly squeezed lemon juice ', '1 tablespoon lemon zest (optional)', '1 teaspoon paprika', '2 teaspoon dried oregano', '2 teaspoon dried basil', '1 teaspoon dried thyme', '3 clove garlic minced', '1 shallot minced', 'sea salt and freshly ground black pepper ', '2 pound boneless and skinless chicken thighs cut into one inch chunks', '1 red onion', '1 red pepper', '10 cherry tomatoes halved']
# 135
# ['.', '.']
# 136
# ['600 gram mutton or lamb chops (about 8 chops)', '6 green chillies', '4 red chillies', '3 slice ginger (each 1 cm or in thick)', '5 clove garlic', '2 tablespoon plain yoghurt or juice of 1 lime', '2 tablespoon coriander (ketumbar) powder', '1 tablespoon chilli powder', '2 onions-chop', '4 tomatoes - chop', '6 stalk coriander leaves - chop', 'salt to taste']
# 137
# ['-onion, garlic', '-tomatoes', '-zucchini ', '-bell peppers ', '-fresh herbs and dried spices: thyme, basil, oregano, rosemary, parsley ']
# 138
# ['for burrito bowl:', '1 pound chicken thighs, boneless skinless', '2 tablespoons homemade taco seasoning', '2 cup cooked quinoa', '2 tablespoon olive oil, or avocado oil, divided', '2 bell peppers', '1 red onion', '1 ripe avocado, chopped', '1/4 cup crumbled cotija cheese, or other crumbly cheese', 'fresh cilantro, to garnish']
# 139
# ['chicken 400 g', 'garlic powder 1 teaspoon', 'pepper 3/4 teaspoon', 'salt 1 1 /4 teaspoon', 'all-purpose flour 1/2 cup', 'cornflour 1/2 cup', 'chilli powder 1 teaspoon', 'turmeric 1/4 teaspoon', 'beer 3/4 cup']
# 140
# ['1 egg', '500 gram potatoes (fresh, peeled)', '150 gram mushrooms (champignons)', ' 40 gram flour (i use corn flour)', ' 40 gram onion green feather', ' 90 gram processed cheese (3 x 30 g)', ' 8 gram oil', ' salt, pepper']
# 141
# ['iceberg lettuce chopped ', 'baby cucumber chopped ', 'german salami chopped', 'shredded mozzarella cheese ', 'chickpeas - roasted in olive oil, salt n peps and mixed herbs ', 'sundried tomatoes chopped ', 'artichokes chopped ']
# 142
# [' \r', '1 . piyali fish 200 gram\r', '2 . cooking oil 3 tablespoon\r', '3 . onion 1 cup\r', '4 . coconut paste 1/4 cup\r', '5 . red chili 1 teaspoon \r', '6 . turmeric 1 teaspoon \r', '7 . coriander 1 teaspoon \r', '8 . salt to taste\r', '9 . 2 lime leaves\r', '10 . 5 green chilies \r', '11 . fresh coriander 1 tablespoon\r']
# 143
# ['2 ounce cream cheese, softened', '2 teaspoon kitcheneez taco seasoning', '6 ounce shredded mexican-blend cheese (1 1 /2 cup), divided', '1 (15 oz) can black beans, drained and rinsed', '1 (15 oz) can corn kernels, drained', '1 (14.5 oz) can diced tomatoes, drained or 2 ripe tomatoes, chopped', '1 (4 -ounce) can chopped green chiles', 'topping options: diced tomatoes, diced avocado, sour cream, fresh or pickled jalapeños, fresh cilantro leaves', 'tortilla chips, for serving']
# 144
# ['pie crust (i had some in my freezer that i’d made earlier)', '1 cup ricotta cheese', '6 eggs', '1 large yam, peeled cubed', '1/2 cup sliced cherry tomatoes', 'goat cheese, broken into piece to sprinkle on top', 'sage leaves, to sprinkle on top', 'salt and pepper']
# 145
# ['1 cup quinoa, rinsed\xa0\u2063', '1 capsicum, sliced\xa0\u2063', '1/2 cucumber, chopped\xa0\u2063', '1 punnet cherry tomatoes, halved\xa0\u2063', '1 can organic chickpeas, rinsed and drained\xa0\u2063', '1 small red onion, sliced finely\xa0\u2063', '1 spring onion, sliced\xa0small bunch of parsley, chopped\u2063', '1/2 block of feta, crumbled\xa0\u2063']
# 146
# ['1 tablespoon olive oil or extra virgin olive oil, plus more for drizzling', '1 medium-sized onion, diced', '2 garlic clove, chopped', '1 ground turmeric (optional)*', '2 can (15 oz-450 gram each) chickpeas, rinsed and drained', '2 cup (250 gram) squash, cubed', '1 (150 gram) medium-sized potato, cubed', '3 cup (720 ml) vegetable broth or chicken broth ', '1 sprig fresh rosemary (or 1/4 teaspoon of dried rosemary)', '1/2 teaspoon salt, or according to your taste', 'freshly ground black pepper ']
# 147
# ['add 1 tablespoon of olive oil, the greek yogurt and salt to taste.', 'mix well and let the chicken marinate in the refrigerator (at least 1 hour or longer).']
# 148
# ['- 40 gram oats', '- 150 ml cashew milk', '- a few chopped cashews ', '- 1 tablespoon yogurt', '- 1 teaspoon cinnamon', '- 1 tablespoon cashew spread (use my code marie-10 to save 10 %)']
# 149
# ['california walnuts : 8-10 piece', 'onion: 1 sliced', 'dried cranberry : 1 tablespoon ', 'ghee - 1 tablespoon', 'pre cooked rice : 1 cup ', 'spices salt, turmeric, red chilli powder , black pepper powder . ', 'spring onion greens ', 'lemon juice ']
# 150
# ['2 cup coconut milk', '1/2 cup maple syrup', '1/3 cup peanut butter', '1 teaspoon vanilla', '2 cup rolled oats', '1/4 cup cocoa', '1 teaspoon baking powder', '1 tablespoon flax ', 'pinch of salt ', '1/3 cup chocolate chips', 'pan is 6 x 9 ']
# 151
# ['-1 red capsicum chopped ', '- 1 italian sausage (spicy or mild) cut into bite sized piece ', '- 2 fresh tomatoes diced', '- 1 bunch of basil', '- 1 small bunch of broccoli florets ', '- 4 garlic clove finely chopped', '- 1 red onion chopped', '- 1 jar of red wine and garlic pasta sauce', '- italian herbs mix']
# 152
# ['butter - 1 tablespoon', 'pav - 4 nos', 'onion (finely chopped) - 1/4 cup + 1/2 cup', 'coriander leaves (finely chopped) - 2 tablespoon + 2 tablespoon', 'grated cheese', 'lemon wedges - 2 nos (for serving)']
# 153
# ['160 gram wholemeal cous cous\u2060', '50 ml olive oil\u2060', '100 gram pistachio piece\u2060', '100 gram pomegranate seeds\u2060', '70 gram dried cranberries\u2060', '1 teaspoon ground coriander\u2060', '1 teaspoon ground cumin\u2060', '1⁄2 teaspoon ground ginger\u2060', '1⁄2 teaspoon chilli flakes (optional)\u2060', '1⁄2 teaspoon ground black pepper\u2060']
# 154
# ['1/2 pound dry elbow macaroni', '1/4 cup onion, minced', '2 tb shredded carrots', '1 cup real, whole mayo', '1/4 cup green onion, thinly sliced', '1/2 teaspoon white pepper', '1 teaspoon kosher salt', 'optional: freshly chopped parsley for garnish']
# 155
# ['1 package cheese ravioli', '2 pint wild harvest organic grape tomatoes', '3 clove garlic, minced', '2 tablespoon wild harvest organic olive oil', '3-4 tablespoon wild harvest organic basil, sliced into ribbons', '1 teaspoon salt', '1 teaspoon pepper']
# 156
# [' 1 large zucchini (+1 pp) \u2063', ' 1/2 cup fat free pizza sauce (1 pp) \u2063', ' 1/2 ounce turkey pepperoni (1 pp) \u2063', ' 1 ounce trader joe’s light mozzarella (1 pp)\u2063']
# 157
# ['3 eggs, scrambled', '4 slice bread, toasted', '120 gram smoked salmon', '114 gram tomato, sliced', '60 gram feta, crumbled', 'chilli flakes']
# 158
# ['2 pound boneless skinless chicken breast, cooked and cubed', '4 cup zucchini “noodles” or spaghetti squash', '4 slice lean turkey bacon, cooked and chopped up', '3 clove garlic, minced', '1 cup unsweetened almond or cashew milk', '3/4 cup reduced-fat ranch dressing', '2 cup reduced-fat mexican cheese blend', '1 , 4 ounce can green chilies']
# 159
# ['• 1 cup apple pie filling (look for no sugar added pie filling)', '• 1/4 cup unsweetened cashew milk (or almond)', '• 1 teaspoon powdered stevia, or to preferred taste', '• 1 1 /2 teaspoon ground cinnamon, or to preferred taste', '• 3/4 cup vanilla protein powder', '• 1/4 cup instant oats']
# 160
# ['1 cup pancake waffle mix original iswari', '1 cup almond plant-based milk', 'zest of 1 orange', '1 teaspoon of cinnamon', '2 teaspoon poppy seeds']
# 161
# ['- 1 pound shrimp, peeled and deveined', '- 1 onion, diced', '- 1 red bell pepper, diced', '- 1 tablespoon olive oil', '- 2 clove garlic, minced', '- 1 teaspoon chili powder', '- 1/2 teaspoon cumin', '- 1/2 teaspoon smoked paprika', '- 1/2 teaspoon salt']
# 162
# ['corn tortillas', '10 squash blossoms', 'avocado', 'salsa', 'salt & pepper']
# 163
# ['200 gram orzo, uncooked ', '2 chorizo styles sausage (asda), sliced', '1 white onion, diced', '2 garlic clove, crushed ', 'tinned tomatoes ', '1 tablespoon tomato purée', '1 teaspoon oregano ', '1 teaspoon basil', '30 gram feta cheese to top', 'salt and pepper to taste ']
# 164
# ['* 250 gram ripe banana', '* 100 gram peanut butter ', '* 100 gram 0 % greek yoghurt ', '* 150 gram blueberry & banana porridge oats (kg10 for 10 % off)', '* 80 gram vanilla protein powder ', '* 20 gram maple syrup ', '* 1 teaspoon baking powder ']
# 165
# [' 24 avocados, chopped', ' 1 small tomato, seeded and finely chopped', ' 2 jalapeno peppers (remove seeds for less heat), finely chopped', ' 2 garlic clove, finely grated', ' 1/2 cup fresh cilantro, chopped', ' 1/4 small red onion, finely chopped', ' 1/4 teaspoon sea salt', ' celery stick to dip ']
# 166
# ['- 2 (200 g) package shirataki noodles', '- 1 pound pastured chicken breast, cut into bite size piece', '- 1 tablespoon\xa0mct oil\xa0or other cooking oil', '- 1 large clove organic garlic, minced', '- 1/2 teaspoon dried oregano or 1 teaspoon minced fresh oregano (leaves only)', '- 1/2 teaspoon himalayan pink salt', '- 1 large lemon, zested and juiced (keep zest separate from juice)', '- 2 tablespoon grass-fed butter or ghee', '- 1 tablespoon\xa0collagelatin,\xa0or other grass-fed gelatin', '- 1-2 tablespoon fresh oregano to finish (leaves only)']
# 167
# ['1 small head cauliflower, wash & cut into florets\u2063', '1 small green bell pepper, cubed\u2063', '1/2 small red onion, cubed & 2 clove garlic - sliced\u2063', '1/4 cup dry roasted cashews\u2063', '4 dried thai chilis/red chilis\u2063', 'oil for frying and cooking\u2063']
# 168
# ['1/2 cup oats']
# 169
# ['- 2 skinless salmon fillet (always go for good quality and not farm one)', '- 200 gr thai jasmine rice', '- chilli flakes, to taste', '- ginger powder, to taste', '- 1 garlic clove, crushed', '- 2 tablespoon miso paste', '- 2 tablespoon fish sauce', '- 150 gr shiitake mushrooms, sliced', '- 250 gr pak choi', '- 100 gr fresh leaf spinach', '- 1 lime', '- sesame oil.']
# 170
# ['pure honey , almonds, walnuts, pistachios ,dried figs,chilgoza ,raisins,dry dates,black raisins.']
# 171
# ['4 ripe bananas (mashed)', '1 cup fresh or frozen blueberries', '1/2 cup extra virgin olive oil ', '2 eggs ', '1/4 cup brown sugar ', '1 teaspoon bicarb soda', '1 1 /2 teaspoon baking powder ', '2 teaspoon cinnamon ', '1/3 cup plain natural yoghurt ', '1 1 /2 cup plain wholemeal flour ', '1/3 cup self-raising flour']
# 172
# ['2 eggs ', '8 ml rice flour ', '250 ml soya or almond milk ', '20 gram honey ', '2 peaches ']
# 173
# ...
# 215
# [' 2 corn tortillas']
# 216
# [' 5 small carrots', ' 2 beaten eggs', ' 100 gr of turkey ham', ' 50 gram of wheat flour', ' 1 cup of', ' ground bread', ' oil for frying', ' preparation', ' wash and peel carrot, grate into fine strip, mix with diced turkey ham and 1/4 cup breadcrumbs.']
# 217
# [' 4 clear', ' 4 yolks', ' 4 tablespoon grated mozzarella cheese', ' 1 tablespoon finely chopped coriander', ' 1 small onion, finely chopped', ' 1 sweet bell pepper finely chopped (substitute 1/4 jalapeño if you want them hot)', ' 2 tablespoon of breadcrumbs', ' 2 tablespoon all-purpose flour', ' pepper to taste', ' salt to taste shell the corn and cook in a pot with 2 cup of water, about 10 minutes or until soft.', 'in a bowl, beat the egg whites until letter point is reached. then, incorporate the yolks, beat with your electric device for 30 seconds so that they are well integrated. place the cheese, onion, breadcrumbs, flour, cilantro and paprika in a large bowl, stir a little and season with salt and pepper to taste.', 'drain the corn kernels in a colander, add them to the bowl, stir well until the ingredients are evenly distributed and free of lumps.', 'add the beaten eggs, stir once more, using a spatula with smooth and enveloping movements so that the eggs retain the air they have acquired.', 'in a non-stick frying pan, heat a splash of oil, trying to cover the entire surface. add 2 tablespoon of the preparation per pancake (this is just a suggestion, add the amount depending on the size you want the corn pancakes), give it a circular shape.', 'let cook for approximately 2 minutes over medium heat, turn and fry for another 2 additional minutes on the other side.', 'line a container with kitchen paper, place the corn and cheese pancakes on top to remove excess oil. serve hot accompanied by hot sauce or other dressing of your choice.']
# 218
# ['• 12 eggs ', '• 3 tablespoon of mayonnaise ', '• 1 tablespoon of spicy brown mustard', '• ground black pepper to taste', '• sprinkle of paprika ', 'instructions:', 'boiled a dozen eggs for 20 minutes in a large pan and then transfer them to an ice bath. allow them to cool for 15 minutes. cut your eggs in half and scoop the yellow portion out into a medium sized bowl. then add mayonnaise, mustard, and ground black pepper to the bowl. with a fork mix up the ingredients until creamy. top your eggs off with paprika. i find it easiest to sprinkle it on with my fingers.']
# 219
# ['2 spring onions ', '30 gram dry roasted peanuts ', '100 gram sugar snap peas', '250 gram diced chicken breast (or meat free alternative) ', '1 clove garlic', '1 small piece of ginger ', '2 wholewheat noodle nests ']
# 220
# ['2-4 salmon piece ', '1 medium butternut squash (cubed)', '1 medium sweet potato (cubes)', 'kale (shredded/chopped - i just bought a bag that was already shredded )', '1 tablespoon rice bran oil (or oil of your choice)', '1 teaspoon cajun', '1 teaspoon paprika', '1 teaspoon garlic powder', '1/2 teaspoon turmeric ', '1/2 teaspoon himalayan salt', '1/2 teaspoon black ground pepper', '1/4 teaspoon rosemary (for the salmon) ']
# 221
# ['1 cup almond milk (or milk of choice)\u2060', '1 teaspoon vanilla extract\u2060', '1 teaspoon cinnamon\u2060', '2 teaspoon flax seeds\u2060', '2 tablespoon cornstarch\u2060', '1/2 teaspoon baking powder\u2060', '1 tablespoon maple syrup\u2060', 'sourdough bread\u2060', 'fruit\u2060']
# 222
# ['• puff pastry ', '• 2 tablespoon peach jam ', '• 1/3 cup cream cheese ', '• 1 peach, sliced ', '• 1 egg ', '• brown sugar & cinnamon to taste', '⠀⠀⠀⠀⠀⠀⠀⠀⠀', 'directions:', '• lightly flour a work surface and rest 1 puff pastry sheet on top to bring to room temperature. ', '• sprinkle top of puff pastry sheet with flour and roll out. use a pizza cutter or knife to cut puff pastry into 6 even squares/rectangles. use a sharp knife to draw lines ~1 inch from the edges of the puff pastry piece. ', '• mix together jam and cream cheese and spread onto puff pastry inside lines. layer peach on top of cream cheese mixture. ', '• make egg wash by lightly mixing egg with a fork or whisk. brush onto edges of pastry. ', '• sprinkle desired amount of brown sugar and cinnamon over pastries and bake in oven @ 400 for 15-17 mins.', '⠀⠀⠀⠀⠀⠀⠀⠀⠀']
# 223
# ['quinoa: 1 cup', 'cherry tomatoes: 300 gram cut in halves ', 'small red onion: 1 sliced ', 'large avocado: 1 cut into chunks ', 'parsley: 30 gram chopped ', 'rocket leaves : 40 gram ', 'feta: 40 gram ( skip if vegan)', 'dressing ingredients: ', 'extra virgin olive oil: 3 tablespoon ', 'rice wine vinegar: 1 tablespoon ', 'chipotle chilli flakes : 1/2 teaspoon ', 'tinned chickpeas: 1 ( optional for extra protein) ', 'salt & pepper ']
# 224
# ['1 tablespoon butter', '2 clove garlic', '1 and 1/2 cup long grain white rice', '2 teaspoon dried italian herbs', '1/2 teaspoon fine sea salt', '1/4 teaspoon black pepper', '2 and 3/4 cup water', '1/4 cup lemon juice', '1 pound shrimp', '1 cup frozen peas']
# 225
# ['- everything bagel', '- 2 tablespoon hummus ', '- 2 tablespoon low sodium peanut butter', '- 1/2 banana', '- cayenne pepper']
# 226
# ['- 5 dates', '- 50 gram cashew nuts', '- coconut flour ']
# 227
# ['7 egg whites', '1/4 cup splenda', '1 teaspoon. vanilla', '1 package sugar-free strawberry jello', 'preheat oven to 350 degrees f. line cookie sheet with parchment paper', 'beat egg whites until fluffy. gradually add splenda, jello, and vanilla. continue beating until soft peaks form.', 'drop a teaspoon onto a covered cookie sheet', 'bake for 10 min( do not let them brown)', 'turn off heat and leave cookies in the closed oven until cookies are dry, generally at least 4 hours or overnight.']
# 228
# ['baisan ', 'boiled potatoes', 'red chilli powder', 'turmeric powder ', 'salt', 'soda', 'bread', 'coriander']
# 229
# ['1 pound turkey, ground', '1 packet taco seasoning', '20 ounce enchilada sauce', '1 onion', '1 can corn', '1 can black beans', '1 can rotel', '6 pea protein tortillas', '1 c mexican shredded cheese']
# 230
# ['serves 2 ', '2 pork loins, fat removed and diced', '1 onion cut into chunks', '1 yellow pepper cut into chunks', '200 ml tomato passata ', '2 teaspoon paprika ', 'dash worcestershire sauce', '300 gram carrots diced', '300 gram parsnips diced', 'bit of fresh parsley chopped']
# 231
# ['- 1 red onion', '-1 clove of garlic', '-2 tomatoes (medium size)', '-1-2 hot peppers (depending on how hot they are)', '-6 tablespoon of beans (canned)', '-1/3 teaspoon ground colorful pepper', '-1/3 teaspoon cumin', '-1/2 teaspoon of sweet smoked paprika', '-2 tortillas', '-4 eggs', '-a little crumbled feta cheese (optional)', '-salt (amount as desired)', '-lard (for baking)']
# 232
# ['5 cup watermelon, cubed', '1 1 /2 cup yellow grape or cherry tomatoes, halved', '1 small red onion, chopped', '1/2 cup freshly torn basil leaves', '1/4 cup freshly squeezed lime juice', '2 tb pure honey', 'freshly ground black pepper to taste']
# 233
# ['- 1 cup couscous', '- 1 1 /4 teaspoon salt', '- 1 tablespoon olive oil', '- 1 lemon', '- 2 garlic clove', '- 3 tablespoon butter', '- 1 pound raw shrimp, peeled', '- 2 tablespoon chopped parsley ']
# 234
# ['1 cup (3.66 oz) raw cucumber, with peel', '1 cup (5.26 oz) raw peppers, red ', '1 cup (6.34 oz) raw tomatoes ', '8 olives olives, black ', '18.2 ounce chicken, breast, boneless, skinless (raw) ~should yield 12 ounce cooked', '1 teaspoon oil, olive ', '2 tablespoon dried parsley ', '1 clove garlic, clove ', '4 teaspoon lemon or lime juice ', '2 tablespoon raw onion ']
# 235
# ['- 1 tablespoon salted butter', '- 2 1 /2 cup milk chocolate', '- 16 ounce mini marshmallows', '- graham crackers for serving']
# 236
# ['1 large head of broccoli, cut into small florets ', '1 tablespoon salted butter ', '50 gram onion, diced ', '250 gram cauliflower rice', '1 celery stalk, sliced ', '600 gram chicken breast, cut into cubes ', '1/2 teaspoon garlic powder ', '50 gram cream cheese ', '125 ml single cream', '50 gram blue cheese', '1/2 cup buffalo sauce ', '150 gram low moisture mozzarella ', 'salt and pepper to taste ']
# 237
# ['basil coconut sauce:', '-1/2 cup full-fat coconut milk', '1/4 cup basil', '-1 tablespoon cashew butter', '-1 tablespoon lime juice', '-1/4 jalapeño, optional', '-1/2 clove garlic', '-1/2 teaspoon fresh ginger', '-1/4 teaspoon sea salt']
# 238
# ['serves 2 ', '200 gram dried pasta', '1 tablespoon salt', '70 gram crusty bread', '2 tablespoon olive oil', '30 gram butter', '70 gram hazelnuts', '1 garlic clove cracked open', '150 gram asparagus', '150 gram taleggio cheese', '1 handful of parsley chopped']
# 239
# ['handful of mint leaves\u2063\u2063\u2063\u2063', '1 sliced cucumber\u2063\u2063\u2063\u2063', '1 lime — juice and 2-3 slice \u2063\u2063\u2063\u2063', '3 cup of sparkling water from your hydrotap\u2063\u2063\u2063\u2063', '\u2063\u2063\u2063\u2063', 'directions\u2063\u2063\u2063\u2063', '1 . muddle or tear the mint leaves to release flavor and add to serving jug. \u2063\u2063\u2063\u2063', '2 . add the remaining ingredients to 3 cup of sparkling water and stir well.\u2063\u2063\u2063\u2063', '3 . serve over ice and enjoy!']
# 240
# ['cooking spray', '3 tablespoon salted butter, melted', '1 10 ounce bag mini marshmallows, divided', '5 cup golden grahams cereal', '1 cup chocolate chips + 1 small handful']
# 241
# ['for the mash: ', '- 1.5 kg maris piper potatoes, peeled and cut into cubes', '- whole milk x 125 ml', '- double cream x 4 tablespoon', '- unsalted butter x 4 tablespoon', '- salt and pepper to taste ']
# 242
# ['margarine 125 g', 'sugar 125 g', 'eggs 2 ', 'durian 1 1 /2 cup', 'vanilla 2 teaspoon', 'flour 125 g', 'baking soda 1/2 teaspoon']
# 243
# ['- 1/2 cup rolled oats', '- 1/2 mashed ripe banana ', '- 3/4 tablespoon chia seeds ', '- 1 tablespoon sunflower seeds ', '- teaspoon honey ', '- 1/2 cup oat milk ', 'mix together those ingredients and leave in the fridge overnight ']
# 244
# [' 1/2 jar quality marmalade, warmed in the microwave for 30 seconds ', ' 1/2 cup flaked almonds', ' 2 whole oranges, boiled 1.5 hours, drained and processed', ' 1.5 cup sugar', ' 5 eggs, whisked', ' 2.5 cup almond meal ', ' 1.5 teaspoon baking powder']
# 245
# ['-50 gr frozen pineapple ', '-50 gr coconut flakes ', '-1 tablespoon maple syrup', '-1 teaspoon lime juice', '-a pinch of salt ']
# 246
# ['for the dressing:', '1 teaspoon orange zest', '1 clove garlic minced', '1 tablespoon whole grain dijon mustard', '1 1 /2 tablespoon cider vinegar', '2 tablespoon honey preferably a citrus honey', '3 tablespoon olive oil', '1/2 teaspoon kosher salt', '1/4 teaspoon black pepper']
# 247
# ['coriander seeds, red chillies, toor dal, bengal gram dal, cumin seeds, pepper, fenugreek, boiled rice, asafoetida']
# 248
# ['coriander seeds, toor dal, bengal gram, pepper, red chillies, cumin seeds, turmeric powder']
# 249
# ['- 1 1 /2 cup alce nero organic plum jam', '- 1 cup all-purpose flour', '- 1 tablespoon white sugar', '- 1 tablespoon baking powder', '- 1/2 cup butter- cold, cut into cubes', '- 2 tablespoon heavy cream', '- 1 egg', '- 1 cup plums, pitted and sliced ', '- 1/2 teaspoon cinnamon', '- 1/4 teaspoon ground ginger', '- 1/4 teaspoon ground nutmeg']
# 250
# ['1 chicken breast (300 g/ 11 oz)', '1 japanese green onion (chives or corianders)', '2 tablespoon organic miso white', 'pinch of black pepper', '2 tablespoon cooking sake', '200 ml (6.8 fl oz) water', '1 piece ginger', '[a]', '1 tablespoon sesame oil', '1/4 teaspoon salt', 'pinch of black pepper']
# 251
# ['2 cup of chopped up rotisserie chicken ( are use the pre-packed pulled apart chicken from costco) ']
# 252
# ['2 eggplants', '2 tomatoes ', '1 large onion', '2 clove of garlic, crushed', '1/4 cup fresh mint, chopped ', '1/4 cup fresh parsley, chopped ', '2 1 /2 tablespoon fresh lemon juice', '1 1 /2 tablespoon pomegranate molasses ', '1/4 cup extra virgin olive oil', 'sea salt and pepper']
# 253
# ['1.5 cup greek yogurt', '1.5 scoops of level 1 protein powder (either milk chocolate, ice cream sandwich or caramel latte)', '1/2 cup 1 st phorm nut butter', '2 tablespoon unsweetened almond milk', '2 tablespoon sugar free maple syrup', '1/2 cup dark chocolate chips', '1 teaspoon coconut oil']
# 254
# ["2 cup nunweiler's flour spelt flour\u2060", '1 cup honey \u2060', '1 1 /2 teaspoon baking soda\u2060', '1 1 /2 teaspoon cinnamon\u2060', '1 teaspoon salt\u2060', '1/2 teaspoon pumpkin pie spice\u2060', '2 1 /2 cup carrots grated\u2060', '1 cup of grated zucchini \u2060', '3 eggs\u2060', '3/4 cup avocado oil\u2060', '1/4 cup coconut milk\u2060', '1 teaspoon vanilla\u2060', '3/4 cup walnuts chopped\u2060']
# 255
# ['- 2 salmon filets', '- 2 tablespoon dijon mustard', '- 2 tablespoon maple syrup (or sub honey)', '- 1 tablespoon chopped fresh rosemary', '- zest of a lemon ', '- 1/2 teaspoon of salt and pepper ']
# 256
# ['-eggplants: 2-3 , peeled, add some salt, let it sit for at least 1 hour, rinse them, and then sauté them in some oil.', '-onions: 2-3 medium size, chopped finely and sauté them for 20 minutes on low heat until golden brown. ', '-dried mint: 1/2 teaspoon to add to the eggplants and 1/2 tablespoon to be heated lightly with some oil for garnish ', '-whey ( kashk) : a few tablespoon , you can substitute whey with a thick yogurt or you may buy them from a persian store. i usually boil whey with some water for 20 minutes on low heat before using it.', 'cooking direction :', 'after sautéing the eggplants put them in a pot, add one cup water, a few dash of turmeric, and 1/2 teaspoon dried mint, and cook it for 25 minutes. remove some of the oil from the pot and smash the eggplants well with a wooden spoon. for the garnish we use lightly heated dried mint with some oil, sautéed onions, and some whey ( or thick yogurt). enjoy ']
# 257
# ['- 2 cup old fashioned rolled oats', '- 1 cup unsalted nuts (walnuts, almonds, pecan or hazelnuts)', '- 1/2 cup celly salt roasted pepitas', '- 1/2 cup vanilla pea protein powder', '- 1/4 cup hulled unsalted sunflower seeds', '- 1/4 cup flaxseed meal', '- 2 teaspoon ground cinnamon', '- 1/2 teaspoon celly salt original', '- 1/3 cup maple syrup', '- 1/3 cup coconut oil']
# 258
# ['1 x tin of pink salmon (or you can use fresh salmon if you aren’t lazy like me)', '150 gram carisma potatoes (can also use rice!)', '15 gram fat-reduced feta', '50 gram grape tomatoes', '50 gram spinach leaves', '15 gram pine nuts', '100 gram roasted pumpkin', '30 gram red onion', '15 ml balsamic glaze or dressing']
# 259
# ['4 cup (14.08 oz) cauliflower florets (8 greens)', '2 tablespoon heavy cream (2 condiments)', '2 tablespoon butter (4 healthy fat)', '1/2 cup (2 oz) shredded low fat sharp cheddar cheese (1/2 lean)', '7 egg whites (1/2 leanest)', '1/2 teaspoon pepper (1 condiment)', '1/4 teaspoon salt (1 condiment)', '10 sprays non-stick spray (1 condiment)']
# 260
# ['6 -8 peaches', '2 tablespoon of chia seeds', '1 piece of fresh ginger grated ', '4 tablespoon of honey ', '1 lemon']
# 261
# ['4 cup (14.08 oz) cauliflower florets (8 greens)', '2 tablespoon heavy cream (2 condiments)', '2 tablespoon butter (4 healthy fat)', '1/2 cup (2 oz) shredded low fat sharp cheddar cheese (1/2 lean)', '7 egg whites (1/2 leanest)', '1/2 teaspoon pepper (1 condiment)', '1/4 teaspoon salt (1 condiment)', '10 sprays non-stick spray (1 condiment)']
# 262
# ['2 clove garlic, finely diced', '1 pound (500 g) shrimp (or prawns) -- tails on or off', '1/2 cup diced green onions', '.25 ounce sundried tomatoes (just dried; not packed in oil)', '1 1 /2 cup half and half (can use 1 1 /2 cup unsweetened almond or cashew milk; this would result in 0 healthy fats per serving ; to keep condiments to 3 , reduce parmesan cheese to 2 tablespoon if using the milk)', '1/4 teaspoon each- salt and pepper', '4 cup baby spinach leaves', '1/4 cup fresh grated parmesan cheese (do not include for dairy free option)', '1/2 teaspoon dried italian herbs', '1 tablespoon fresh parsley, chopped']
# 263
# ['1/4 cup shredded cheddar cheese']
# 264
# ['1/4 cup shredded cheddar cheese']

# %% [markdown]
# # Now ready to get ingredient lines for each post and add it to the dataframe...
# ## Then will be ready to try out zestful on it

# %%
posts['ingredient_lines'] = posts['description_preprocessed'].apply(get_ingredient_lines)
# Out:
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_73487/168222658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   posts['ingredient_lines'] = posts['description_preprocessed'].apply(get_ingredient_lines)

# %%
for lines in posts['ingredient_lines'][0:4]:
    print(lines)
    print(len(lines))
# Out:
# ['1/2 cup instant oats', '1/2 cup milk', '1/2 cup water', '1 scoop chocolate protein powder', '1 teaspoon brown sugar']
# 5
# ['1 chicken breast⠀', '1 ball mozarella cheese ⠀', '2 tomatoes ⠀', 'small handful of basil ⠀', 'pesto ⠀', 'balsamic glaze ⠀']
# 6
# ['2 pound bok choy, small ', '1 tbs ginger, fresh, minced', ' 1/4 cup scallions, thinly sliced ', '1 1 /2 tbs olive oil, divided 6 tbs tamari sauce ', '1 tbs hemp seeds ']
# 5
# ['200 gram swiss brown mushrooms, chopped ', '220 gram all purpose flour', '20 gram sugar', '6 gram baking powder', '1/2 teaspoon salt', '1 teaspoon ', '55 gram cold butter, cut into small cubes', '25 gram beaten egg', 'approx. 100 ml milk ']
# 9

# %%
# Zestful can only parse up to 30 ingredients a day, so for now lets just use the first 4 posts (<30 ingredients)
posts_sample = posts.iloc[0:4,:]

# %%
# zestful ingredient parser
import parse_ingredient

def get_ingredients_dict(ingredient_lines):
    
    ingredients = parse_ingredient.parse_multiple(ingredient_lines)
    
    return ingredients.as_dict()

# %%
posts_sample['ingredients_dict'] = posts_sample['ingredient_lines'].apply(get_ingredients_dict)
# Out:
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_73487/3117765326.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   posts_sample['ingredients_dict'] = posts_sample['ingredient_lines'].apply(get_ingredients_dict)

# %%
print(posts_sample['description_preprocessed'].iloc[2])
# Out:
# looking for a fast recipe to make for lunch? this dish is light and can be made in only 25 minutes!
#
# bok choy with tamari sauce
#
# ingredients:
# 2 pound bok choy, small
# 1 tbs ginger, fresh, minced
#  1/4 cup scallions, thinly sliced
# 1 1 /2 tbs olive oil, divided 6 tbs tamari sauce
# 1 tbs hemp seeds
#
# directions:
# prep :
# 1 . trim bok choy bottoms and cut in half lengthwise.
# 2 . mince ginger.
# 3 . slice scallions.
#
# make :
# 1 . coat bottom of pan with 1 1 /2 teaspoon oil, over medium-high heat. when hot, lay bok choy in single layer, cut side down (do not overcrowd). add 2 tablespoon water and cover about 2 minutes.
#
# 2 . lift out of pan, drain, and place on platter. remove water from pan and repeat with remaining bok choy. leave residual water in pan.
#
# 3 . add 1 tablespoon oil and ginger to pan and cook, stirring over high
# heat until ginger is browned. remove from heat and add tamari sauce.
#
# 4 . pour sauce over bok choy, sprinkle with scallions and hemp seeds.
#
# for more healthy recipes, click the link in bio
# .
# .
# .
# .
# .
# .
# .
# .

# %%
posts_sample['ingredient_lines'].iloc[2]
# Out:
# ['2 pound bok choy, small ',
#  '1 tbs ginger, fresh, minced',
#  ' 1/4 cup scallions, thinly sliced ',
#  '1 1 /2 tbs olive oil, divided 6 tbs tamari sauce ',
#  '1 tbs hemp seeds ']

# %%
posts_sample['ingredients_dict'].iloc[2]
# Out:
# [{'error': None,
#   'raw': '2 pound bok choy, small ',
#   'parsed': {'confidence': 0.8712382,
#    'product': 'bok choy',
#    'productSizeModifier': None,
#    'quantity': 2.0,
#    'unit': 'pound',
#    'preparationNotes': None,
#    'usda_info': {'category': 'Vegetables and Vegetable Products',
#     'description': 'Cabbage, chinese (pak-choi), raw',
#     'fdcId': '170390',
#     'matchMethod': 'exact'}}},
#  {'error': None,
#   'raw': '1 tbs ginger, fresh, minced',
#   'parsed': {'confidence': 0.8276143,
#    'product': 'ginger',
#    'productSizeModifier': None,
#    'quantity': 1.0,
#    'unit': 'tablespoon',
#    'preparationNotes': 'fresh, minced',
#    'usda_info': {'category': 'Vegetables and Vegetable Products',
#     'description': 'Ginger root, raw',
#     'fdcId': '169231',
#     'matchMethod': 'exact'}}},
#  {'error': None,
#   'raw': ' 1/4 cup scallions, thinly sliced ',
#   'parsed': {'confidence': 0.9478576,
#    'product': 'scallions',
#    'productSizeModifier': None,
#    'quantity': 0.25,
#    'unit': 'cup',
#    'preparationNotes': 'thinly sliced',
#    'usda_info': {'category': 'Vegetables and Vegetable Products',
#     'description': 'Onions, spring or scallions (includes tops and bulb), raw',
#     'fdcId': '170005',
#     'matchMethod': 'exact'}}},
#  {'error': None,
#   'raw': '1 1 /2 tbs olive oil, divided 6 tbs tamari sauce ',
#   'parsed': {'confidence': 0.8384716,
#    'product': 'olive oil',
#    'productSizeModifier': None,
#    'quantity': 0.5,
#    'unit': 'tablespoon',
#    'preparationNotes': None,
#    'usda_info': {'category': 'Fats and Oils',
#     'description': 'Oil, olive, salad or cooking',
#     'fdcId': '171413',
#     'matchMethod': 'exact'}}},
#  {'error': None,
#   'raw': '1 tbs hemp seeds ',
#   'parsed': {'confidence': 0.944166,
#    'product': 'hemp seeds',
#    'productSizeModifier': None,
#    'quantity': 1.0,
#    'unit': 'tablespoon',
#    'preparationNotes': None,
#    'usda_info': None}}]

# %%
num_ingredients = 0
for lines in posts['ingredient_lines']:
    num_ingredients += len(lines)
num_ingredients
print(f"Zestful charge £0.02 per ingredient, so the cost of parsing all ingredients would be £{num_ingredients*0.02}.")
# Out:
# Zestful charge £0.02 per ingredient, so the cost of parsing all ingredients would be £43.28.

# %% [markdown]
# ### Using free trial each day to include another few posts

# %%
posts_sample.to_csv("posts_with_ingredients.csv")

# %%
posts.to_csv("posts_preprocessed.csv")

# %%
def add_new_posts(posts_file_path, posts_sample_file_path):
    
    posts = pd.read_csv(posts_file_path)
    posts_sample = pd.read_csv(posts_sample_file_path)

# %%
for index, row in posts.iterrows():

# %%
posts['ingredient_lines'].iloc[0]
# Out:
# ['1/2 cup instant oats',
#  '1/2 cup milk',
#  '1/2 cup water',
#  '1 scoop chocolate protein powder',
#  '1 teaspoon brown sugar']

# %%
posts_sample['ingredients_dict'].iloc[0]
# Out:
# [{'error': None,
#   'raw': '1/2 cup instant oats',
#   'parsed': {'confidence': 0.976161,
#    'product': 'instant oats',
#    'productSizeModifier': None,
#    'quantity': 0.5,
#    'unit': 'cup',
#    'preparationNotes': None,
#    'usda_info': None}},
#  {'error': None,
#   'raw': '1/2 cup milk',
#   'parsed': {'confidence': 0.9959719,
#    'product': 'milk',
#    'productSizeModifier': None,
#    'quantity': 0.5,
#    'unit': 'cup',
#    'preparationNotes': None,
#    'usda_info': {'category': 'Dairy and Egg Products',
#     'description': 'Milk, fluid, 1% fat, without added vitamin A and vitamin D',
#     'fdcId': '173441',
#     'matchMethod': 'closestUnbranded'}}},
#  {'error': None,
#   'raw': '1/2 cup water',
#   'parsed': {'confidence': 0.9923842,
#    'product': 'water',
#    'productSizeModifier': None,
#    'quantity': 0.5,
#    'unit': 'cup',
#    'preparationNotes': None,
#    'usda_info': {'category': 'Beverages',
#     'description': 'Beverages, water, tap, drinking',
#     'fdcId': '173647',
#     'matchMethod': 'exact'}}},
#  {'error': None,
#   'raw': '1 scoop chocolate protein powder',
#   'parsed': {'confidence': 0.948583,
#    'product': 'chocolate protein powder',
#    'productSizeModifier': None,
#    'quantity': 1.0,
#    'unit': 'scoop',
#    'preparationNotes': None,
#    'usda_info': None}},
#  {'error': None,
#   'raw': '1 teaspoon brown sugar',
#   'parsed': {'confidence': 0.9937513,
#    'product': 'brown sugar',
#    'productSizeModifier': None,
#    'quantity': 1.0,
#    'unit': 'teaspoon',
#    'preparationNotes': None,
#    'usda_info': {'category': 'Sweets',
#     'description': 'Sugars, brown',
#     'fdcId': '168833',
#     'matchMethod': 'exact'}}}]
