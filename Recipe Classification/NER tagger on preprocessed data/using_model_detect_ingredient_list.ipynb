# %% [markdown]
# # Using model to detect ingredient list section from post
#
# Applying NER model to posts and then using heuristics to identify the ingredients list section from the post.

# %%
import pandas as pd
import numpy as np
import spacy

import sys
sys.path.append("/Users/maxkirwan/Desktop/Uni/Data Science MSc/Data Science Project/nutrition-insta")
import functions

# %%
posts1 = pd.read_csv("/Users/maxkirwan/Desktop/Uni/Data Science MSc/Data Science Project/nutrition-insta/Instagram Data Scraping/Phantom Buster/recipe_posts.csv")
posts2 = pd.read_csv("/Users/maxkirwan/Desktop/Uni/Data Science MSc/Data Science Project/nutrition-insta/Instagram Data Scraping/Phantom Buster/recipe_posts_2.csv")
posts3 = pd.read_csv("/Users/maxkirwan/Desktop/Uni/Data Science MSc/Data Science Project/nutrition-insta/Instagram Data Scraping/Phantom Buster/recipe_posts_3.csv")

posts = pd.concat([posts1,posts2,posts3])

# %%
# Getting english posts
posts = functions.get_english_posts(posts)
# Out:
# Detecting language of each post...
# Language detection complete.
# Time taken: 0:07:40.709580

# %%
# Preprocessing text descriptions
posts['description_preprocessed'] = posts['description'].apply(functions.preprocess_text)

# %%
def includes_ingredient_list(text):
    
    text_str = str(text)
    if ("ingredients:" in text or "ingredients :" in text) and text_str.count('\n') > 8:
        return True
        
    else:
        return False
    
# Adding includes_ingredient_list binary column
posts['includes_ingredient_list'] = posts['description_preprocessed'].apply(includes_ingredient_list)
# Keeping only posts with ingredient_list
posts = posts[posts['includes_ingredient_list']]

# %%
posts = pd.read_csv('preprocessed_descriptions.csv')

# %%
nlp = spacy.load("./model-best")

# Merging entities into single tokens
nlp.add_pipe("merge_entities")
# Out:
# <function spacy.pipeline.functions.merge_entities(doc: spacy.tokens.doc.Doc)>

# %%
doc = nlp(posts['description_preprocessed'][3])
colors = {
    "MEASUREMENT": "#bfeeb7",
    "INGREDIENT": "#feca74",
    "QUANTITY": "#e4e7d2"
}
options = {"ents": list(colors), "colors": colors}
spacy.displacy.render(doc, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     banana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  breadrecipe, save it for later</br>follow .ltd </br>.</br>ingredients</br>.</br>ingredients:</br>.</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  medium ripe bananas</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  vegetable
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  unsweetened nondairy
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     milk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  light brown
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sugar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  pure
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vanilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  extract</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  unbleached all-purpose
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     flour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cinnamon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     baking soda
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="e

# %%
def get_ingredient_triplets(text):
    
    '''
    Function to identify entity triplets which relate to unique ingredients.
    These triplets come in the form consecutive QUANTITY, MEASUREMENT, INGREDIENT entities.
    '''
    
    doc = nlp(text)
    ingredient_triplets = []
    
    for i in range(len(doc)-10):
        
        if doc[i].ent_type_ == 'QUANTITY' and doc[i+1].ent_type_ == 'MEASUREMENT':
            
            quantity_index = i
            measurement_index = i+1
                
            for j in range(i+1,i+8):

                if doc[j].ent_type_ == 'INGREDIENT':

                    ingredient_index = j
                    ingredient_triplets.append((quantity_index,measurement_index,ingredient_index))
                    break
                    
                    
    def ingredient_triplets_to_list(triplets):

        dict_list = []

        for i, j, k in triplets:

            ing_dict = {}

            ing_dict['ingredient'] = doc[k]
            ing_dict['quantity'] = doc[i]
            ing_dict['measurement'] = doc[j]

            dict_list.append(ing_dict)

        return dict_list
        
    return ingredient_triplets_to_list(ingredient_triplets)

# %%
get_ingredient_triplets(doc)
# Out:
# [{'ingredient': oil, 'quantity': 1/4, 'measurement': cup},
#  {'ingredient': milk, 'quantity': 1/4, 'measurement': cup},
#  {'ingredient': sugar, 'quantity': 1/2, 'measurement': cup},
#  {'ingredient': vanilla, 'quantity': 2, 'measurement': teaspoon},
#  {'ingredient': flour, 'quantity': 2, 'measurement': cup},
#  {'ingredient': cinnamon, 'quantity': 1, 'measurement': teaspoon},
#  {'ingredient': baking soda, 'quantity': 1, 'measurement': teaspoon},
#  {'ingredient': salt, 'quantity': 1/2, 'measurement': teaspoon}]

# %%
# Getting ingredient triplets for all posts
posts['ingredient_list'] = posts['description_preprocessed'].apply(get_ingredient_triplets)
# Out:
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_24132/1270949432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   posts['ingredient_list'] = posts['description_preprocessed'].apply(get_ingredient_triplets)

# %%
for i in posts['ingredient_list'][0:5]:
    print(i,"\n\n")
# Out:
# [{'ingredient': oats, 'quantity': 1/2, 'measurement': cup}, {'ingredient': milk, 'quantity': 1/2, 'measurement': cup}, {'ingredient': water, 'quantity': 1/2, 'measurement': cup}, {'ingredient': sugar, 'quantity': 1, 'measurement': teaspoon}, {'ingredient': peanut butter, 'quantity': 1, 'measurement': tablespoon}, {'ingredient': banana, 'quantity': 1, 'measurement': tablespoon}]
#
#
# [{'ingredient': pesto, 'quantity': 2, 'measurement': teaspoon}]
#
#
# [{'ingredient': ginger, 'quantity': 1, 'measurement': tablespoon}, {'ingredient': tamari, 'quantity': 6, 'measurement': tablespoon}, {'ingredient': hemp seeds, 'quantity': 1, 'measurement': tablespoon}, {'ingredient': water, 'quantity': 2, 'measurement': tablespoon}, {'ingredient': oil, 'quantity': 1, 'measurement': tablespoon}]
#
#
# [{'ingredient': mushrooms, 'quantity': 200, 'measurement': gram}, {'ingredient': sugar, 'quantity': 20, 'measurement': gram}, {'ingredient': baking powder, 'quantity': 6, 'measurement': gram}, {'ingredient': salt, 'quantity': 1/2, 'measurement': teaspoon}, {'ingredient': butter, 'quantity': 1, 'measurement': teaspoon}, {'ingredient': butter, 'quantity': 55, 'measurement': gram}, {'ingredient': egg, 'quantity': 25, 'measurement': gram}]
#
#
# [{'ingredient': flour, 'quantity': 1/2, 'measurement': cup}, {'ingredient': carom seeds, 'quantity': 1.5, 'measurement': tablespoon}, {'ingredient': ginger, 'quantity': 1/4, 'measurement': teaspoon}, {'ingredient': red mirch, 'quantity': 1, 'measurement': tablespoon}, {'ingredient': cumin powder, 'quantity': 1, 'measurement': tablespoon}, {'ingredient': black pepper powder, 'quantity': 1/2, 'measurement': teaspoon}, {'ingredient': turmeric, 'quantity': 1/2, 'measurement': teaspoon}, {'ingredient': salt, 'quantity': 1/2, 'measurement': teaspoon}, {'ingredient': garam masala, 'quantity': 1, 'measurement': teaspoon}, {'ingredient': lemon juice, 'quantity': 1, 'measurement': teaspoon}, {'ingredient': paneer, 'quantity': 1.5, 'measurement': tablespoon}]

# %%
# Average length of ingredient list
np.mean([len(ing_list) for ing_list in list(posts['ingredient_list'])])
# Out:
# 4.017964071856287

# %%
# Number of empty ingredient lists
[len(ing_list) for ing_list in list(posts['ingredient_list'])].count(0)
# Out:
# 59

# %% [markdown]
# ### Getting list of ingredients

# %%
def get_ingredients(ing_list):
    return [ing['ingredient'] for ing in ing_list]

# %%
# Get list of ingredients for all posts
posts['ingredients'] = posts['ingredient_list'].apply(get_ingredients)

# %%
posts
# Out:
#                                        postUrl  \
# 81    https://www.instagram.com/p/Cgd_iR_vT2d/
# 104   https://www.instagram.com/p/Cgd8bLXDaCq/
# 169   https://www.instagram.com/p/CgdylqtOy9s/
# 172   https://www.instagram.com/p/CgdyENyLgmv/
# 226   https://www.instagram.com/p/CgdpvTNvrWt/
# ...                                        ...
# 3208  https://www.instagram.com/p/CgCX2p_DSsu/
# 3389  https://www.instagram.com/p/ChFyI8OLgWy/
# 3463  https://www.instagram.com/p/ChFdeY_P89I/
# 3556  https://www.instagram.com/p/ChFKUXyoR-t/
# 3558  https://www.instagram.com/p/ChFJ79eoSMG/
#
#                                           profileUrl              username  \
# 81          https://www.instagram.com/all.about.oats        all.about.oats
# 104               https://www.instagram.com/a_m_eats              a_m_eats
# 169        https://www.instagram.com/hescottwellness       hescottwellness
# 172          https://www.instagram.com/rainbowpiatto         rainbowpiatto
# 226      https://www.instagram.com/foodiesfood_court     foodiesfood_court
# ...                                              ...                   ...
# 3208  https://www.instagram.com/alwayshungryinlondon  alwayshungryinlondon
# 3389  https://www.instagram.com/everyday_homecooking  everyday_homecooking
# 3463         https://www.instagram.com/masterclassuk         masterclassuk
# 3556           https://www.instagram.com/ketoguide24           ketoguide24
# 3558         https://www.instagram.com/ketorecipesin         ketorecipesin
#
#                         fullName  commentCount  likeCount  \
# 81                 Anushka Lodhi             0          2
# 104                Alice & Meg 🍴             3         12
# 169    Natasha Hescott, RDN, CDN             0          1
# 172               Rainbow Piatto             1         14
# 226           Foodies Food Court            43       1819
# ...                          ...           ...        ...
# 3208                   𝐇𝐚𝐧𝐧𝐚𝐡 𝐃𝐉           111       6861
# 3389       JESS WHARTON | FOODIE             2         23
# 3463                 MasterClass             1         11
# 3556       keto diet | meal plan             2         21
# 3558  Keto Recipes | Weight Loss             2         39
#
#                        pubDate  \
# 81    2022-07-26T08:23:14.000Z
# 104   2022-07-26T07:56:03.000Z
# 169   2022-07-26T06:30:06.000Z
# 172   2022-07-26T06:25:32.000Z
# 226   2022-07-26T05:12:47.000Z
# ...                        ...
# 3208  2022-07-15T14:57:00.000Z
# 3389  2022-08-10T19:15:48.000Z
# 3463  2022-08-10T16:15:14.000Z
# 3556  2022-08-10T13:27:50.000Z
# 3558  2022-08-10T13:24:31.000Z
#
#                                             description  \
# 81    Chocolate fudge protein oatmeal🤎 💪\nIngredient...
# 104   ⁣Caprese Chicken with Pesto 🌿🍅⠀\n⠀\nThis dish ...
# 169   Looking for a fast recipe to make for lunch? T...
# 172   Sweet & Savoury Mushroom Scones~🍄 This easy an...
# 226   Paneer Tikka Recipe😍\nSave it to try later♥️\n...
# ...                                                 ...
# 3208  Prawn Taco Bowl\n—————————————————————-\nPerfe...
# 3389  SALMON, BUTTERNUT SQUASH, SWEET POTATO AND KAL...
# 3463  Are you feeling lazy? We have just the recipe ...
# 3556  🍽 Servings: 1\n⠀ ⠀\nIngredients:\n⠀\n1/4 cup s...
# 3558  🍽 Servings: 1\n⠀ ⠀\nIngredients:\n⠀\n1/4 cup s...
#
#                                        location  \
# 81                             Ghaziabad, India
# 104                     Glasgow, United Kingdom
# 169                                         NaN
# 172   Singapore / Singapura / 新加坡 / சிங்கப்பூர்
# 226                                       Bihar
# ...                                         ...
# 3208                     London, United Kingdom
# 3389                                        NaN
# 3463                                        NaN
# 3556                                        USA
# 3558                   United States of America
#
#                                                  imgUrl  ...  isSidecar  \
# 81    https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...       True
# 104   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...       True
# 169   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...      False
# 172   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...      False
# 226   https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...       True
# ...                                                 ...  ...        ...
# 3208  https://scontent-cdg2-1.cdninstagram.com/v/t51...  ...      False
# 3389  https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...      False
# 3463  https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...      False
# 3556  https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...      False
# 3558  https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...      False
#
#       sidecarMedias videoUrl viewCount language     score  \
# 81              3.0      NaN       NaN       en  0.999996
# 104             3.0      NaN       NaN       en  0.999997
# 169             NaN      NaN       NaN       en  0.999996
# 172             NaN      NaN       NaN       en  0.999998
# 226             2.0      NaN       NaN       en  0.999996
# ...             ...      ...       ...      ...       ...
# 3208            NaN      NaN       NaN       en  0.999997
# 3389            NaN      NaN       NaN       en  0.999995
# 3463            NaN      NaN       NaN       en  0.999995
# 3556            NaN      NaN       NaN       en  0.999998
# 3558            NaN      NaN       NaN       en  0.999997
#
#                                description_preprocessed  \
# 81    chocolate fudge protein oatmeal \ningredients:...
# 104   ⁣caprese chicken with pesto ⠀\n⠀\nthis dish is...
# 169   looking for a fast recipe to make for lunch? t...
# 172   sweet & savoury mushroom scones~ this easy and...
# 226   paneer tikka recipe\nsave it to try later\n\ni...
# ...                                                 ...
# 3208  prawn taco bowl\n—————————————————————-\nperfe...
# 3389  salmon, butternut squash, sweet potato and kal...
# 3463  are you feeling lazy? we have just the recipe ...
# 3556  servings: 1 \n⠀ ⠀\ningredients:\n⠀\n1/4 cup sh...
# 3558  servings: 1 \n⠀ ⠀\ningredients:\n⠀\n1/4 cup sh...
#
#      includes_ingredient_list  \
# 81                       True
# 104                      True
# 169                      True
# 172                      True
# 226                      True
# ...                       ...
# 3208                     True
# 3389                     True
# 3463                     True
# 3556                     True
# 3558                     True
#
#                                         ingredient_list  \
# 81    [{'ingredient': oats, 'quantity': 1/2, 'measur...
# 104   [{'ingredient': pesto, 'quantity': 2, 'measure...
# 169   [{'ingredient': ginger, 'quantity': 1, 'measur...
# 172   [{'ingredient': mushrooms, 'quantity': 200, 'm...
# 226   [{'ingredient': flour, 'quantity': 1/2, 'measu...
# ...                                                 ...
# 3208  [{'ingredient': prawns, 'quantity': 90, 'measu...
# 3389  [{'ingredient': rice, 'quantity': 1, 'measurem...
# 3463  [{'ingredient': pasta, 'quantity': 200, 'measu...
# 3556  [{'ingredient': cheddar, 'quantity': 1/4, 'mea...
# 3558  [{'ingredient': cheddar, 'quantity': 1/4, 'mea...
#
#                                             ingredients
# 81    [oats, milk, water, sugar, peanut butter, banana]
# 104                                             [pesto]
# 169            [ginger, tamari, hemp seeds, water, oil]
# 172   [mushrooms, sugar, baking powder, salt, butter...
# 226   [flour, carom seeds, ginger, red mirch, cumin ...
# ...                                                 ...
# 3208  [prawns, garlic powder, chilli, coriander, ric...
# 3389  [rice, paprika, paprika, garlic powder, turmer...
# 3463  [pasta, salt, bread, olive, butter, hazelnuts,...
# 3556                                   [cheddar, flour]
# 3558                                   [cheddar, flour]
#
# [334 rows x 25 columns]

# %% [markdown]
# ## Using USDA API

# %%
import requests

headers = {
    # Already added when you pass json= but not when you pass data=
    # 'Content-Type': 'application/json',
}

params = {
    'api_key': 'XBZBkznaG3lFCfED92u489nCZFlm9zdBNdH6lCEZ',
}

json_data = {
    'query': 'Cheddar cheese',
    'dataType': [
        'Branded',
    ],
    'sortBy': 'fdcId',
    'sortOrder': 'desc',
}

response = requests.post('https://api.nal.usda.gov/fdc/v1/foods/list', params=params, headers=headers, json=json_data)

# %%
json_data = {
    'query': 'oats',
    'dataType': [
        'Foundation',
        'SR Legacy'
    ],
    'pageSize' : 1,
    'pageNumber' : 1,
    'sortBy': 'fdcId',
    'sortOrder': 'desc',
}

response = requests.post('https://api.nal.usda.gov/fdc/v1/foods/list', params=params, headers=headers, json=json_data)

# %%
print(len([nutrient['name'] for nutrient in response.json()[0]['foodNutrients']]))
[nutrient['name'] for nutrient in response.json()[0]['foodNutrients']]
# Out:
# 58
# ['Thiamin',
#  'Riboflavin',
#  'Niacin',
#  'Vitamin B-6',
#  'Biotin',
#  'Folate, total',
#  'Vitamin B-12',
#  'Water',
#  'Galactose',
#  'Fiber, total dietary',
#  'Tryptophan',
#  'Threonine',
#  'Isoleucine',
#  'Leucine',
#  'Lysine',
#  'Methionine',
#  'Calcium, Ca',
#  'Iron, Fe',
#  'Phenylalanine',
#  'Tyrosine',
#  'Magnesium, Mg',
#  'Valine',
#  'Phosphorus, P',
#  'Arginine',
#  'Potassium, K',
#  'Histidine',
#  'Sodium, Na',
#  'Alanine',
#  'Zinc, Zn',
#  'Aspartic acid',
#  'Glutamic acid',
#  'Glycine',
#  'Copper, Cu',
#  'Proline',
#  'Serine',
#  'Hydroxyproline',
#  'Manganese, Mn',
#  'Molybdenum, Mo',
#  'Selenium, Se',
#  'Cysteine',
#  'Retinol',
#  'Vitamin D2 (ergocalciferol)',
#  'Vitamin D3 (cholecalciferol)',
#  'Nitrogen',
#  'Total lipid (fat)',
#  'Ash',
#  'Sucrose',
#  'Glucose',
#  'Fructose',
#  'Lactose',
#  'Maltose',
#  'Protein',
#  'Carbohydrate, by difference',
#  'Vitamin A',
#  'Vitamin D (D2 + D3)',
#  'Energy (Atwater General Factors)',
#  'Vitamin D (D2 + D3), International Units',
#  'Sugars, Total NLEA']

# %%
def get_usda_info_json(ingredient):
    
    headers = {}
    params = {'api_key': 'XBZBkznaG3lFCfED92u489nCZFlm9zdBNdH6lCEZ'}
    
    json_data = {
        'query': ingredient,
        'dataType': [
            'Foundation',
            'SR Legacy'
        ],
        'pageSize' : 1,
        'pageNumber' : 1,
        'sortBy': 'dataType.keyword',
        'sortOrder': 'asc',
    }

    response = requests.post('https://api.nal.usda.gov/fdc/v1/foods/list', params=params, headers=headers, json=json_data)
    
    return response.json()

# %%
get_usda_info_json('peanut butter')
# Out:
# {'fdcId': 2262072,
#  'description': 'Peanut butter, creamy',
#  'dataType': 'Foundation',
#  'publicationDate': '2022-04-28',
#  'ndbNumber': '16098',
#  'foodNutrients': [{'number': '717',
#    'name': 'Daidzin',
#    'amount': 0.649,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '718',
#    'name': 'Genistin',
#    'amount': 1.93,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '719',
#    'name': 'Glycitin',
#    'amount': 0.412,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '645',
#    'name': 'Fatty acids, total monounsaturated',
#    'amount': 30.7,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '646',
#    'name': 'Fatty acids, total polyunsaturated',
#    'amount': 9.78,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '404',
#    'name': 'Thiamin',
#    'amount': 0.121,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '406',
#    'name': 'Niacin',
#    'amount': 17.2,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '654',
#    'name': 'SFA 24:0',
#    'amount': 0.824,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '415',
#    'name': 'Vitamin B-6',
#    'amount': 0.38,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '416',
#    'name': 'Biotin',
#    'amount': 87.8,
#    'unitName': 'UG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '417',
#    'name': 'Folate, total',
#    'amount': 97.3,
#    'unitName': 'UG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '255',
#    'name': 'Water',
#    'amount': 1.1,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '674',
#    'name': 'MUFA 18:1 c',
#    'amount': 29.8,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '675',
#    'name': 'PUFA 18:2 n-6 c,c',
#    'amount': 9.73,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '291',
#    'name': 'Fiber, total dietary',
#    'amount': 6.32,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '501',
#    'name': 'Tryptophan',
#    'amount': 0.229,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '502',
#    'name': 'Threonine',
#    'amount': 0.806,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '710',
#    'name': 'Daidzein',
#    'amount': 11.5,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '503',
#    'name': 'Isoleucine',
#    'amount': 0.92,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '711',
#    'name': 'Genistein',
#    'amount': 0.0,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '504',
#    'name': 'Leucine',
#    'amount': 1.88,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '505',
#    'name': 'Lysine',
#    'amount': 0.951,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '301',
#    'name': 'Calcium, Ca',
#    'amount': 49.8,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '506',
#    'name': 'Methionine',
#    'amount': 0.29,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '303',
#    'name': 'Iron, Fe',
#    'amount': 1.85,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '508',
#    'name': 'Phenylalanine',
#    'amount': 1.5,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '304',
#    'name': 'Magnesium, Mg',
#    'amount': 193,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '509',
#    'name': 'Tyrosine',
#    'amount': 1.06,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '305',
#    'name': 'Phosphorus, P',
#    'amount': 393,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '510',
#    'name': 'Valine',
#    'amount': 1.12,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '511',
#    'name': 'Arginine',
#    'amount': 3.32,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '306',
#    'name': 'Potassium, K',
#    'amount': 654,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '512',
#    'name': 'Histidine',
#    'amount': 0.676,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '307',
#    'name': 'Sodium, Na',
#    'amount': 221,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '513',
#    'name': 'Alanine',
#    'amount': 1.16,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '514',
#    'name': 'Aspartic acid',
#    'amount': 3.42,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '309',
#    'name': 'Zinc, Zn',
#    'amount': 3.06,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '515',
#    'name': 'Glutamic acid',
#    'amount': 5.82,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '516',
#    'name': 'Glycine',
#    'amount': 1.69,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '312',
#    'name': 'Copper, Cu',
#    'amount': 0.54,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '517',
#    'name': 'Proline',
#    'amount': 1.24,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '518',
#    'name': 'Serine',
#    'amount': 1.42,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '521',
#    'name': 'Hydroxyproline',
#    'amount': 0.162,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '315',
#    'name': 'Manganese, Mn',
#    'amount': 1.68,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '317',
#    'name': 'Selenium, Se',
#    'amount': 20.2,
#    'unitName': 'UG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '526',
#    'name': 'Cysteine',
#    'amount': 0.514,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '323',
#    'name': 'Vitamin E (alpha-tocopherol)',
#    'amount': 5.41,
#    'unitName': 'MG',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '829',
#    'name': 'MUFA 20:1 c',
#    'amount': 0.801,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '676.1',
#    'name': 'MUFA 22:1 n-9',
#    'amount': 0.132,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '202',
#    'name': 'Nitrogen',
#    'amount': 4.39,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '606',
#    'name': 'Fatty acids, total saturated',
#    'amount': 8.42,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '204',
#    'name': 'Total lipid (fat)',
#    'amount': 49.4,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '207',
#    'name': 'Ash',
#    'amount': 2.77,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '613',
#    'name': 'SFA 16:0',
#    'amount': 4.11,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '614',
#    'name': 'SFA 18:0',
#    'amount': 1.29,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '615',
#    'name': 'SFA 20:0',
#    'amount': 0.683,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '624',
#    'name': 'SFA 22:0',
#    'amount': 1.42,
#    'unitName': 'G',
#    'derivationCode': 'A',
#    'derivationDescription': 'Analytical'},
#   {'number': '203',
#    'name': 'Protein',
#    'amount': 24.0,
#    'unitName': 'G',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'},
#   {'number': '205',
#    'name': 'Carbohydrate, by difference',
#    'amount': 22.7,
#    'unitName': 'G',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'},
#   {'number': '957',
#    'name': 'Energy (Atwater General Factors)',
#    'amount': 632,
#    'unitName': 'KCAL',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'},
#   {'number': '958',
#    'name': 'Energy (Atwater Specific Factors)',
#    'amount': 589,
#    'unitName': 'KCAL',
#    'derivationCode': 'NC',
#    'derivationDescription': 'Calculated'}]}

# %%
get_usda_info_json('banana')['foodNutrients']
# Out:
# [{'number': '322',
#   'name': 'Carotene, alpha',
#   'amount': 8.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '335',
#   'name': 'Cryptoxanthin, alpha',
#   'amount': 0.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '334',
#   'name': 'Cryptoxanthin, beta',
#   'amount': 0.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '321.1',
#   'name': 'cis-beta-Carotene',
#   'amount': 1.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '338.3',
#   'name': 'cis-Lutein/Zeaxanthin',
#   'amount': 0.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '337.1',
#   'name': 'cis-Lycopene',
#   'amount': 0.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '321',
#   'name': 'Carotene, beta',
#   'amount': 10.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '321.2',
#   'name': 'trans-beta-Carotene',
#   'amount': 9.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '337.2',
#   'name': 'trans-Lycopene',
#   'amount': 0.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '207',
#   'name': 'Ash',
#   'amount': 0.67,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '204',
#   'name': 'Total lipid (fat)',
#   'amount': 0.22,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '202',
#   'name': 'Nitrogen',
#   'amount': 0.12,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '416',
#   'name': 'Biotin',
#   'amount': 0.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '406',
#   'name': 'Niacin',
#   'amount': 0.57,
#   'unitName': 'MG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '405',
#   'name': 'Riboflavin',
#   'amount': 0.0,
#   'unitName': 'MG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '404',
#   'name': 'Thiamin',
#   'amount': 0.04,
#   'unitName': 'MG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '417',
#   'name': 'Folate, total',
#   'amount': 25.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '415',
#   'name': 'Vitamin B-6',
#   'amount': 0.234,
#   'unitName': 'MG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '255',
#   'name': 'Water',
#   'amount': 78.3,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '401',
#   'name': 'Vitamin C, total ascorbic acid',
#   'amount': 9.7,
#   'unitName': 'MG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '428',
#   'name': 'Vitamin K (Menaquinone-4)',
#   'amount': 0.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '430',
#   'name': 'Vitamin K (phylloquinone)',
#   'amount': 0.2,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '429',
#   'name': 'Vitamin K (Dihydrophylloquinone)',
#   'amount': 0.0,
#   'unitName': 'UG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '291',
#   'name': 'Fiber, total dietary',
#   'amount': 1.7,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '236',
#   'name': 'Citric acid',
#   'amount': 279,
#   'unitName': 'MG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '243',
#   'name': 'Malic acid',
#   'amount': 290,
#   'unitName': 'MG',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '293',
#   'name': 'Total dietary fiber (AOAC 2011.25)',
#   'amount': 2.02,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '203',
#   'name': 'Protein',
#   'amount': 0.73,
#   'unitName': 'G',
#   'derivationCode': 'NC',
#   'derivationDescription': 'Calculated'},
#  {'number': '205',
#   'name': 'Carbohydrate, by difference',
#   'amount': 20.1,
#   'unitName': 'G',
#   'derivationCode': 'NC',
#   'derivationDescription': 'Calculated'},
#  {'number': '320',
#   'name': 'Vitamin A, RAE',
#   'amount': 1.0,
#   'unitName': 'UG',
#   'derivationCode': 'NC',
#   'derivationDescription': 'Calculated'},
#  {'number': '208',
#   'name': 'Energy',
#   'amount': 85.0,
#   'unitName': 'KCAL',
#   'derivationCode': 'NC',
#   'derivationDescription': 'Calculated'},
#  {'number': '268',
#   'name': 'Energy',
#   'amount': 357,
#   'unitName': 'kJ',
#   'derivationCode': 'NC',
#   'derivationDescription': 'Calculated'},
#  {'number': '212',
#   'name': 'Fructose',
#   'amount': 6.7,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '211',
#   'name': 'Glucose',
#   'amount': 7.0,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '213',
#   'name': 'Lactose',
#   'amount': 0.0,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '214',
#   'name': 'Maltose',
#   'amount': 0.0,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '210',
#   'name': 'Sucrose',
#   'amount': 2.1,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '209',
#   'name': 'Starch',
#   'amount': 0.41,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '287',
#   'name': 'Galactose',
#   'amount': 0.0,
#   'unitName': 'G',
#   'derivationCode': 'A',
#   'derivationDescription': 'Analytical'},
#  {'number': '269.3',
#   'name': 'Sugars, Total NLEA',
#   'amount': 15.8,
#   'unitName': 'G',
#   'derivationCode': 'AS',
#   'derivationDescription': 'Summed'},
#  {'number': '205.2',
#   'name': 'Carbohydrate, by summation',
#   'amount': 18.0,
#   'unitName': 'G',
#   'derivationCode': 'AS',
#   'derivationDescription': 'Summed'}]

# %%
def calc_nutrient_levels_recipe(ing_list):
    '''
    USDA food lookup for each ingredient in recipe.
    Then totals levels of required nutrients.
    To give total nutrient levels for whole recipe.
    '''
    
    energy = 0         # KCAL
    protein = 0        # G
    carbohydrates = 0  # G
    sugars = 0         # G
    sodium = 0         # MG
    fiber = 0          # G
    
    # Making sure we don't count dupliacte energy values
    energy_dup = 0
    
    for ing in ing_list:
        
        # Making sure we don't count duplicate energy values
        energy_dup = False
        
        # Query ingredient against FoodData Central database
        response = get_usda_info_json(str(ing))
        
        # If query returned a response
        if response:
        
            # Get list of nutrients
            nutrients = response[0]['foodNutrients']

            for nutrient in nutrients:

                if nutrient['name'] == 'Sugars, Total NLEA':
                    sugars += nutrient['amount']
                    print("added",ing,'//',nutrient['name'],nutrient['amount'])

                elif nutrient['name'] == 'Carbohydrate, by difference':
                    carbohydrates += nutrient['amount']
                    print("added",ing,'//',nutrient['name'],nutrient['amount'])

                elif nutrient['name'] == 'Sodium, Na':
                    sodium += nutrient['amount']
                    print("added",ing,'//',nutrient['name'],nutrient['amount'])

                elif nutrient['name'] == 'Protein':
                    protein += nutrient['amount']
                    print("added",ing,'//',nutrient['name'],nutrient['amount'])

                elif 'Energy' in nutrient['name'] and energy_dup==False:
                    energy += nutrient['amount']
                    energy_dup = True
                    print("added",ing,'//',nutrient['name'],nutrient['amount'])

                elif nutrient['name'] == 'Fiber, total dietary':
                    fiber += nutrient['amount']
                    print("added",ing,'//',nutrient['name'],nutrient['amount'])
                
                
    nutrient_levels = {'energy': energy,
                       'protein' : protein,
                       'carbohydrates' : carbohydrates,
                       'sugars' : sugars,
                       'sodium' : sodium,
                       'fiber' : fiber
                      }
    
    return nutrient_levels



def convert_dict_to_series_values(nutrient_levels_dict):
    
    return pd.Series(nutrient_levels_dict.values())

# %%
calc_nutrient_levels_recipe(posts['ingredients'].iloc[0])
# Out:
# added oats // Sodium, Na 3.62
# added oats // Fiber, total dietary 10.5
# added oats // Carbohydrate, by difference 69.9
# added oats // Protein 13.2
# added oats // Energy (Atwater General Factors) 389
# added milk // Protein 7.81
# added milk // Sodium, Na 105
# added milk // Energy 657
# added milk // Carbohydrate, by difference 6.86
# added water // Energy 90.0
# added water // Protein 19.0
# added water // Sodium, Na 219
# added water // Carbohydrate, by difference 0.08
# added water // Sugars, Total NLEA 0.0
# added sugar // Energy 1610.0
# added sugar // Protein 0.0
# added sugar // Sodium, Na 1.0
# added sugar // Carbohydrate, by difference 99.6
# added sugar // Sugars, Total NLEA 99.8
# added peanut butter // Fiber, total dietary 6.32
# added peanut butter // Sodium, Na 221
# added peanut butter // Protein 24.0
# added peanut butter // Carbohydrate, by difference 22.7
# added peanut butter // Energy (Atwater General Factors) 632
# added banana // Fiber, total dietary 1.7
# added banana // Protein 0.73
# added banana // Carbohydrate, by difference 20.1
# added banana // Energy 85.0
# added banana // Sugars, Total NLEA 15.8
# {'energy': 3463.0,
#  'protein': 64.74,
#  'carbohydrates': 219.23999999999998,
#  'sugars': 115.6,
#  'sodium': 549.62,
#  'fiber': 18.52}

# %% [markdown]
# ### Adding nutrient levels to (a slice of) the dataframe

# %%
small_posts = posts.head(50)

# %%
nutrient_cols = ['energy','protein','carbohydrates','sugars','sodium','fiber']

small_posts[nutrient_cols] = small_posts['ingredients'].apply(calc_nutrient_levels_recipe).apply(convert_dict_to_series)
# Out:
# added oats // Sodium, Na 3.62
# added oats // Fiber, total dietary 10.5
# added oats // Carbohydrate, by difference 69.9
# added oats // Protein 13.2
# added oats // Energy (Atwater General Factors) 389
# added milk // Protein 7.81
# added milk // Sodium, Na 105
# added milk // Energy 657
# added milk // Carbohydrate, by difference 6.86
# added water // Energy 90.0
# added water // Protein 19.0
# added water // Sodium, Na 219
# added water // Carbohydrate, by difference 0.08
# added water // Sugars, Total NLEA 0.0
# added sugar // Energy 1610.0
# added sugar // Protein 0.0
# added sugar // Sodium, Na 1.0
# added sugar // Carbohydrate, by difference 99.6
# added sugar // Sugars, Total NLEA 99.8
# added peanut butter // Fiber, total dietary 6.32
# added peanut butter // Sodium, Na 221
# added peanut butter // Protein 24.0
# added peanut butter // Carbohydrate, by difference 22.7
# added peanut butter // Energy (Atwater General Factors) 632
# added banana // Fiber, total dietary 1.7
# added banana // Protein 0.73
# added banana // Carbohydrate, by difference 20.1
# added banana // Energy 85.0
# added banana // Sugars, Total NLEA 15.8
# added pesto // Protein 4.16
# added pesto // Energy 1560.0
# added pesto // Fiber, total dietary 2.1
# added pesto // Sodium, Na 1030.0
# added pesto // Carbohydrate, by difference 6.93
# added ginger // Sodium, Na 13.0
# added ginger // Energy 333
# added ginger // Protein 1.82
# added ginger // Carbohydrate, by difference 17.8
# added ginger // Fiber, total dietary 2.0
# added tamari // Carbohydrate, by difference 5.57
# added tamari // Energy 60.0
# added tamari // Protein 10.5
# added tamari // Fiber, total dietary 0.8
# added tamari // Sodium, Na 5590.0
# added hemp seeds // Fiber, total dietary 10.3
# added hemp seeds // Sodium, Na 532
# added hemp seeds // Carbohydrate, by difference 17.1
# added hemp seeds // Energy 612
# added hemp seeds // Protein 21.0
# added hemp seeds // Sugars, Total NLEA 3.14
# added water // Energy 90.0
# added water // Protein 19.0
# added water // Sodium, Na 219
# added water // Carbohydrate, by difference 0.08
# added water // Sugars, Total NLEA 0.0
# added mushrooms // Sodium, Na 0.891
# added mushrooms // Protein 2.18
# added mushrooms // Carbohydrate, by difference 6.76
# added mushrooms // Energy (Atwater General Factors) 39.8
# added sugar // Energy 1610.0
# added sugar // Protein 0.0
# added sugar // Sodium, Na 1.0
# added sugar // Carbohydrate, by difference 99.6
# added sugar // Sugars, Total NLEA 99.8
# added baking powder // Fiber, total dietary 2.3
# added baking powder // Carbohydrate, by difference 49.2
# added baking powder // Energy 270
# added baking powder // Protein 9.43
# added baking powder // Sodium, Na 477
# added baking powder // Sugars, Total NLEA 5.34
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added butter // Fiber, total dietary 9.72
# added butter // Sodium, Na 0.996
# added butter // Carbohydrate, by difference 21.2
# added butter // Protein 20.8
# added butter // Energy (Atwater General Factors) 645
# added butter // Fiber, total dietary 9.72
# added butter // Sodium, Na 0.996
# added butter // Carbohydrate, by difference 21.2
# added butter // Protein 20.8
# added butter // Energy (Atwater General Factors) 645
# added egg // Protein 10.7
# added egg // Energy 231
# added egg // Carbohydrate, by difference 2.36
# added flour // Sodium, Na 0.0
# added flour // Fiber, total dietary 2.66
# added flour // Protein 11.4
# added flour // Carbohydrate, by difference 74.4
# added flour // Energy (Atwater General Factors) 357
# added carom seeds // Fiber, total dietary 10.3
# added carom seeds // Sodium, Na 532
# added carom seeds // Carbohydrate, by difference 17.1
# added carom seeds // Energy 612
# added carom seeds // Protein 21.0
# added carom seeds // Sugars, Total NLEA 3.14
# added ginger // Sodium, Na 13.0
# added ginger // Energy 333
# added ginger // Protein 1.82
# added ginger // Carbohydrate, by difference 17.8
# added ginger // Fiber, total dietary 2.0
# added red mirch // Fiber, total dietary 2.2
# added red mirch // Sodium, Na 1.0
# added red mirch // Protein 0.94
# added red mirch // Sugars, Total NLEA 5.76
# added red mirch // Carbohydrate, by difference 9.93
# added red mirch // Energy 44.0
# added cumin powder // Protein 17.8
# added cumin powder // Fiber, total dietary 10.5
# added cumin powder // Sodium, Na 168
# added cumin powder // Carbohydrate, by difference 44.2
# added cumin powder // Energy 375
# added black pepper powder // Sodium, Na 0.0
# added black pepper powder // Fiber, total dietary 0.942
# added black pepper powder // Protein 0.715
# added black pepper powder // Carbohydrate, by difference 4.78
# added black pepper powder // Energy (Atwater General Factors) 22.9
# added turmeric // Carbohydrate, by difference 67.1
# added turmeric // Energy 312
# added turmeric // Protein 9.68
# added turmeric // Fiber, total dietary 22.7
# added turmeric // Sodium, Na 27.0
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added garam masala // Carbohydrate, by difference 10.5
# added garam masala // Energy 57.0
# added garam masala // Protein 3.3
# added garam masala // Fiber, total dietary 2.6
# added garam masala // Sodium, Na 92.0
# added lemon juice // Protein 0.55
# added lemon juice // Energy 157
# added lemon juice // Fiber, total dietary 0.2
# added lemon juice // Sodium, Na 1.0
# added lemon juice // Carbohydrate, by difference 7.59
# added lemon juice // Sugars, Total NLEA 7.72
# added milk // Protein 7.81
# added milk // Sodium, Na 105
# added milk // Energy 657
# added milk // Carbohydrate, by difference 6.86
# added oregano // Carbohydrate, by difference 68.9
# added oregano // Energy 265
# added oregano // Fiber, total dietary 42.5
# added oregano // Sodium, Na 25.0
# added oregano // Protein 9.0
# added chili flakes // Energy 349
# added chili flakes // Carbohydrate, by difference 83.3
# added chili flakes // Protein 8.95
# added chili flakes // Fiber, total dietary 9.2
# added chili flakes // Sodium, Na 21.0
# added jeera powder // Carbohydrate, by difference 79.6
# added jeera powder // Energy 250
# added jeera powder // Protein 3.69
# added jeera powder // Fiber, total dietary 44.5
# added jeera powder // Sodium, Na 10.0
# added flax seeds // Fiber, total dietary 10.3
# added flax seeds // Sodium, Na 532
# added flax seeds // Carbohydrate, by difference 17.1
# added flax seeds // Energy 612
# added flax seeds // Protein 21.0
# added flax seeds // Sugars, Total NLEA 3.14
# added coriander // Carbohydrate, by difference 55.0
# added coriander // Energy 298
# added coriander // Sodium, Na 35.0
# added coriander // Protein 12.4
# added coriander // Fiber, total dietary 41.9
# added sesame // Fiber, total dietary 8.37
# added sesame // Sodium, Na 63.6
# added sesame // Carbohydrate, by difference 14.2
# added sesame // Protein 19.7
# added sesame // Energy (Atwater General Factors) 697
# added red chilies // Fiber, total dietary 2.2
# added red chilies // Sodium, Na 1.0
# added red chilies // Protein 0.94
# added red chilies // Sugars, Total NLEA 5.76
# added red chilies // Carbohydrate, by difference 9.93
# added red chilies // Energy 44.0
# added mustard seeds // Protein 4.25
# added mustard seeds // Energy 254
# added mustard seeds // Fiber, total dietary 4.3
# added mustard seeds // Sodium, Na 1100.0
# added mustard seeds // Carbohydrate, by difference 5.3
# added mustard seeds // Sugars, Total NLEA 1.42
# added tomato // Sodium, Na 0.0
# added tomato // Fiber, total dietary 0.971
# added tomato // Protein 0.696
# added tomato // Carbohydrate, by difference 3.84
# added tomato // Energy (Atwater General Factors) 22.0
# added cream // Protein 2.96
# added cream // Sodium, Na 72.0
# added cream // Carbohydrate, by difference 3.66
# added cream // Energy 195
# added cream // Fiber, total dietary 0.0
# added garlic // Fiber, total dietary 2.7
# added garlic // Protein 6.62
# added garlic // Carbohydrate, by difference 28.2
# added garlic // Energy 143
# added parsley // Carbohydrate, by difference 6.33
# added parsley // Energy 36.0
# added parsley // Protein 2.97
# added parsley // Fiber, total dietary 3.3
# added parsley // Sodium, Na 56.0
# added butter // Fiber, total dietary 9.72
# added butter // Sodium, Na 0.996
# added butter // Carbohydrate, by difference 21.2
# added butter // Protein 20.8
# added butter // Energy (Atwater General Factors) 645
# added parmesan // Carbohydrate, by difference 12.4
# added parmesan // Energy 421
# added parmesan // Protein 29.6
# added parmesan // Sodium, Na 1750.0
# added parmesan // Sugars, Total NLEA 0.07
# added pasta // Fiber, total dietary 1.8
# added pasta // Carbohydrate, by difference 8.05
# added pasta // Energy 45.0
# added pasta // Sodium, Na 419
# added pasta // Protein 1.41
# added pasta // Sugars, Total NLEA 5.5
# added sugar // Energy 1610.0
# added sugar // Protein 0.0
# added sugar // Sodium, Na 1.0
# added sugar // Carbohydrate, by difference 99.6
# added sugar // Sugars, Total NLEA 99.8
# added basil // Carbohydrate, by difference 2.65
# added basil // Energy 23.0
# added basil // Fiber, total dietary 1.6
# added basil // Sodium, Na 4.0
# added basil // Protein 3.15
# added cashews // Protein 18.2
# added cashews // Sodium, Na 12.0
# added cashews // Energy 2310.0
# added cashews // Carbohydrate, by difference 30.2
# added cashews // Fiber, total dietary 3.3
# added pasta // Fiber, total dietary 1.8
# added pasta // Carbohydrate, by difference 8.05
# added pasta // Energy 45.0
# added pasta // Sodium, Na 419
# added pasta // Protein 1.41
# added pasta // Sugars, Total NLEA 5.5
# added butter // Fiber, total dietary 9.72
# added butter // Sodium, Na 0.996
# added butter // Carbohydrate, by difference 21.2
# added butter // Protein 20.8
# added butter // Energy (Atwater General Factors) 645
# added flour // Sodium, Na 0.0
# added flour // Fiber, total dietary 2.66
# added flour // Protein 11.4
# added flour // Carbohydrate, by difference 74.4
# added flour // Energy (Atwater General Factors) 357
# added cream // Protein 2.96
# added cream // Sodium, Na 72.0
# added cream // Carbohydrate, by difference 3.66
# added cream // Energy 195
# added cream // Fiber, total dietary 0.0
# added pasta // Fiber, total dietary 1.8
# added pasta // Carbohydrate, by difference 8.05
# added pasta // Energy 45.0
# added pasta // Sodium, Na 419
# added pasta // Protein 1.41
# added pasta // Sugars, Total NLEA 5.5
# added parmesan // Carbohydrate, by difference 12.4
# added parmesan // Energy 421
# added parmesan // Protein 29.6
# added parmesan // Sodium, Na 1750.0
# added parmesan // Sugars, Total NLEA 0.07
# added cheese // Carbohydrate, by difference 2.44
# added cheese // Energy 408
# added cheese // Protein 23.3
# added cheese // Sodium, Na 654
# added cheese // Sugars, Total NLEA 0.33
# added garlic powder // Fiber, total dietary 2.7
# added garlic powder // Protein 6.62
# added garlic powder // Carbohydrate, by difference 28.2
# added garlic powder // Energy 143
# added black pepper // Sodium, Na 0.0
# added black pepper // Fiber, total dietary 0.942
# added black pepper // Protein 0.715
# added black pepper // Carbohydrate, by difference 4.78
# added black pepper // Energy (Atwater General Factors) 22.9
# added oats // Sodium, Na 3.62
# added oats // Fiber, total dietary 10.5
# added oats // Carbohydrate, by difference 69.9
# added oats // Protein 13.2
# added oats // Energy (Atwater General Factors) 389
# added chia seeds // Fiber, total dietary 10.3
# added chia seeds // Sodium, Na 532
# added chia seeds // Carbohydrate, by difference 17.1
# added chia seeds // Energy 612
# added chia seeds // Protein 21.0
# added chia seeds // Sugars, Total NLEA 3.14
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added water // Energy 90.0
# added water // Protein 19.0
# added water // Sodium, Na 219
# added water // Carbohydrate, by difference 0.08
# added water // Sugars, Total NLEA 0.0
# added zucchini // Fiber, total dietary 1.1
# added zucchini // Energy 88.0
# added zucchini // Carbohydrate, by difference 3.11
# added zucchini // Protein 2.71
# added zucchini // Sodium, Na 3.0
# added cashews // Protein 18.2
# added cashews // Sodium, Na 12.0
# added cashews // Energy 2310.0
# added cashews // Carbohydrate, by difference 30.2
# added cashews // Fiber, total dietary 3.3
# added garlic powder // Fiber, total dietary 2.7
# added garlic powder // Protein 6.62
# added garlic powder // Carbohydrate, by difference 28.2
# added garlic powder // Energy 143
# added garlic powder // Fiber, total dietary 2.7
# added garlic powder // Protein 6.62
# added garlic powder // Carbohydrate, by difference 28.2
# added garlic powder // Energy 143
# added onion // Fiber, total dietary 2.2
# added onion // Sodium, Na 1.0
# added onion // Protein 0.94
# added onion // Sugars, Total NLEA 5.76
# added onion // Carbohydrate, by difference 9.93
# added onion // Energy 44.0
# added lemon juice // Protein 0.55
# added lemon juice // Energy 157
# added lemon juice // Fiber, total dietary 0.2
# added lemon juice // Sodium, Na 1.0
# added lemon juice // Carbohydrate, by difference 7.59
# added lemon juice // Sugars, Total NLEA 7.72
# added lemon juice // Protein 0.55
# added lemon juice // Energy 157
# added lemon juice // Fiber, total dietary 0.2
# added lemon juice // Sodium, Na 1.0
# added lemon juice // Carbohydrate, by difference 7.59
# added lemon juice // Sugars, Total NLEA 7.72
# added water // Energy 90.0
# added water // Protein 19.0
# added water // Sodium, Na 219
# added water // Carbohydrate, by difference 0.08
# added water // Sugars, Total NLEA 0.0
# added cream // Protein 2.96
# added cream // Sodium, Na 72.0
# added cream // Carbohydrate, by difference 3.66
# added cream // Energy 195
# added cream // Fiber, total dietary 0.0
# added butter // Fiber, total dietary 9.72
# added butter // Sodium, Na 0.996
# added butter // Carbohydrate, by difference 21.2
# added butter // Protein 20.8
# added butter // Energy (Atwater General Factors) 645
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added cream // Protein 2.96
# added cream // Sodium, Na 72.0
# added cream // Carbohydrate, by difference 3.66
# added cream // Energy 195
# added cream // Fiber, total dietary 0.0
# added tahini // Energy 2480.0
# added tahini // Protein 17.4
# added tahini // Fiber, total dietary 4.7
# added tahini // Sodium, Na 35.0
# added tahini // Carbohydrate, by difference 21.5
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added potatoes // Sodium, Na 47.7
# added potatoes // Fiber, total dietary 5.4
# added potatoes // Carbohydrate, by difference 79.9
# added potatoes // Protein 8.11
# added potatoes // Energy (Atwater General Factors) 361
# added purple // Sodium, Na 4.02
# added purple // Protein 0.258
# added purple // Carbohydrate, by difference 15.6
# added purple // Energy (Atwater General Factors) 66.1
# added purple // Sugars, Total NLEA 14.0
# added parsley // Carbohydrate, by difference 6.33
# added parsley // Energy 36.0
# added parsley // Protein 2.97
# added parsley // Fiber, total dietary 3.3
# added parsley // Sodium, Na 56.0
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added black pepper // Sodium, Na 0.0
# added black pepper // Fiber, total dietary 0.942
# added black pepper // Protein 0.715
# added black pepper // Carbohydrate, by difference 4.78
# added black pepper // Energy (Atwater General Factors) 22.9
# added parsley // Carbohydrate, by difference 6.33
# added parsley // Energy 36.0
# added parsley // Protein 2.97
# added parsley // Fiber, total dietary 3.3
# added parsley // Sodium, Na 56.0
# added oregano // Carbohydrate, by difference 68.9
# added oregano // Energy 265
# added oregano // Fiber, total dietary 42.5
# added oregano // Sodium, Na 25.0
# added oregano // Protein 9.0
# added tomatoes // Sodium, Na 0.0
# added tomatoes // Fiber, total dietary 0.971
# added tomatoes // Protein 0.696
# added tomatoes // Carbohydrate, by difference 3.84
# added tomatoes // Energy (Atwater General Factors) 22.0
# added cream // Protein 2.96
# added cream // Sodium, Na 72.0
# added cream // Carbohydrate, by difference 3.66
# added cream // Energy 195
# added cream // Fiber, total dietary 0.0
# added water // Energy 90.0
# added water // Protein 19.0
# added water // Sodium, Na 219
# added water // Carbohydrate, by difference 0.08
# added water // Sugars, Total NLEA 0.0
# added water // Energy 90.0
# added water // Protein 19.0
# added water // Sodium, Na 219
# added water // Carbohydrate, by difference 0.08
# added water // Sugars, Total NLEA 0.0
# added black pepper // Sodium, Na 0.0
# added black pepper // Fiber, total dietary 0.942
# added black pepper // Protein 0.715
# added black pepper // Carbohydrate, by difference 4.78
# added black pepper // Energy (Atwater General Factors) 22.9
# added pasta // Fiber, total dietary 1.8
# added pasta // Carbohydrate, by difference 8.05
# added pasta // Energy 45.0
# added pasta // Sodium, Na 419
# added pasta // Protein 1.41
# added pasta // Sugars, Total NLEA 5.5
# added basil // Carbohydrate, by difference 2.65
# added basil // Energy 23.0
# added basil // Fiber, total dietary 1.6
# added basil // Sodium, Na 4.0
# added basil // Protein 3.15
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added pepper // Sodium, Na 0.0
# added pepper // Fiber, total dietary 0.942
# added pepper // Protein 0.715
# added pepper // Carbohydrate, by difference 4.78
# added pepper // Energy (Atwater General Factors) 22.9
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added pepper // Sodium, Na 0.0
# added pepper // Fiber, total dietary 0.942
# added pepper // Protein 0.715
# added pepper // Carbohydrate, by difference 4.78
# added pepper // Energy (Atwater General Factors) 22.9
# added mushrooms // Sodium, Na 0.891
# added mushrooms // Protein 2.18
# added mushrooms // Carbohydrate, by difference 6.76
# added mushrooms // Energy (Atwater General Factors) 39.8
# added potato // Sodium, Na 47.7
# added potato // Fiber, total dietary 5.4
# added potato // Carbohydrate, by difference 79.9
# added potato // Protein 8.11
# added potato // Energy (Atwater General Factors) 361
# added powder // Carbohydrate, by difference 79.6
# added powder // Energy 250
# added powder // Protein 3.69
# added powder // Fiber, total dietary 44.5
# added powder // Sodium, Na 10.0
# added -sugar // Fiber, total dietary 9.72
# added -sugar // Sodium, Na 0.996
# added -sugar // Carbohydrate, by difference 21.2
# added -sugar // Protein 20.8
# added -sugar // Energy (Atwater General Factors) 645
# added -salt // Fiber, total dietary 9.72
# added -salt // Sodium, Na 0.996
# added -salt // Carbohydrate, by difference 21.2
# added -salt // Protein 20.8
# added -salt // Energy (Atwater General Factors) 645
# added -egg // Fiber, total dietary 9.72
# added -egg // Sodium, Na 0.996
# added -egg // Carbohydrate, by difference 21.2
# added -egg // Protein 20.8
# added -egg // Energy (Atwater General Factors) 645
# added butter // Fiber, total dietary 9.72
# added butter // Sodium, Na 0.996
# added butter // Carbohydrate, by difference 21.2
# added butter // Protein 20.8
# added butter // Energy (Atwater General Factors) 645
# added -vanilla // Fiber, total dietary 9.72
# added -vanilla // Sodium, Na 0.996
# added -vanilla // Carbohydrate, by difference 21.2
# added -vanilla // Protein 20.8
# added -vanilla // Energy (Atwater General Factors) 645
# added -milk // Fiber, total dietary 9.72
# added -milk // Sodium, Na 0.996
# added -milk // Carbohydrate, by difference 21.2
# added -milk // Protein 20.8
# added -milk // Energy (Atwater General Factors) 645
# added -butter // Fiber, total dietary 0.0
# added -butter // Sodium, Na 59.2
# added -butter // Protein 0.656
# added -butter // Carbohydrate, by difference 0.671
# added -butter // Energy (Atwater General Factors) 19.3
# added -milk // Fiber, total dietary 9.72
# added -milk // Sodium, Na 0.996
# added -milk // Carbohydrate, by difference 21.2
# added -milk // Protein 20.8
# added -milk // Energy (Atwater General Factors) 645
# added -semi // Fiber, total dietary 9.72
# added -semi // Sodium, Na 0.996
# added -semi // Carbohydrate, by difference 21.2
# added -semi // Protein 20.8
# added -semi // Energy (Atwater General Factors) 645
# added oats // Sodium, Na 3.62
# added oats // Fiber, total dietary 10.5
# added oats // Carbohydrate, by difference 69.9
# added oats // Protein 13.2
# added oats // Energy (Atwater General Factors) 389
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added cinnamon // Carbohydrate, by difference 44.4
# added cinnamon // Energy 253
# added cinnamon // Protein 7.05
# added cinnamon // Fiber, total dietary 3.5
# added cinnamon // Sodium, Na 388
# added chia seeds // Fiber, total dietary 10.3
# added chia seeds // Sodium, Na 532
# added chia seeds // Carbohydrate, by difference 17.1
# added chia seeds // Energy 612
# added chia seeds // Protein 21.0
# added chia seeds // Sugars, Total NLEA 3.14
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added lemon juice // Protein 0.55
# added lemon juice // Energy 157
# added lemon juice // Fiber, total dietary 0.2
# added lemon juice // Sodium, Na 1.0
# added lemon juice // Carbohydrate, by difference 7.59
# added lemon juice // Sugars, Total NLEA 7.72
# added tahini // Energy 2480.0
# added tahini // Protein 17.4
# added tahini // Fiber, total dietary 4.7
# added tahini // Sodium, Na 35.0
# added tahini // Carbohydrate, by difference 21.5
# added parsley // Carbohydrate, by difference 6.33
# added parsley // Energy 36.0
# added parsley // Protein 2.97
# added parsley // Fiber, total dietary 3.3
# added parsley // Sodium, Na 56.0
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added ginger // Sodium, Na 13.0
# added ginger // Energy 333
# added ginger // Protein 1.82
# added ginger // Carbohydrate, by difference 17.8
# added ginger // Fiber, total dietary 2.0
# added chia seeds // Fiber, total dietary 10.3
# added chia seeds // Sodium, Na 532
# added chia seeds // Carbohydrate, by difference 17.1
# added chia seeds // Energy 612
# added chia seeds // Protein 21.0
# added chia seeds // Sugars, Total NLEA 3.14
# added pumpkin seeds // Fiber, total dietary 10.3
# added pumpkin seeds // Sodium, Na 532
# added pumpkin seeds // Carbohydrate, by difference 17.1
# added pumpkin seeds // Energy 612
# added pumpkin seeds // Protein 21.0
# added pumpkin seeds // Sugars, Total NLEA 3.14
# added butter // Fiber, total dietary 9.72
# added butter // Sodium, Na 0.996
# added butter // Carbohydrate, by difference 21.2
# added butter // Protein 20.8
# added butter // Energy (Atwater General Factors) 645
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added baking powder // Fiber, total dietary 2.3
# added baking powder // Carbohydrate, by difference 49.2
# added baking powder // Energy 270
# added baking powder // Protein 9.43
# added baking powder // Sodium, Na 477
# added baking powder // Sugars, Total NLEA 5.34
# added milk // Protein 7.81
# added milk // Sodium, Na 105
# added milk // Energy 657
# added milk // Carbohydrate, by difference 6.86
# added lettuce // Carbohydrate, by difference 3.24
# added lettuce // Energy 17.0
# added lettuce // Fiber, total dietary 1.8
# added lettuce // Protein 1.24
# added lettuce // Sugars, Total NLEA 1.19
# added red wine // Fiber, total dietary 2.2
# added red wine // Sodium, Na 1.0
# added red wine // Protein 0.94
# added red wine // Sugars, Total NLEA 5.76
# added red wine // Carbohydrate, by difference 9.93
# added red wine // Energy 44.0
# added red wine // Fiber, total dietary 2.2
# added red wine // Sodium, Na 1.0
# added red wine // Protein 0.94
# added red wine // Sugars, Total NLEA 5.76
# added red wine // Carbohydrate, by difference 9.93
# added red wine // Energy 44.0
# added banana // Fiber, total dietary 1.7
# added banana // Protein 0.73
# added banana // Carbohydrate, by difference 20.1
# added banana // Energy 85.0
# added banana // Sugars, Total NLEA 15.8
# added garlic // Fiber, total dietary 2.7
# added garlic // Protein 6.62
# added garlic // Carbohydrate, by difference 28.2
# added garlic // Energy 143
# added red onion // Fiber, total dietary 2.2
# added red onion // Sodium, Na 1.0
# added red onion // Protein 0.94
# added red onion // Sugars, Total NLEA 5.76
# added red onion // Carbohydrate, by difference 9.93
# added red onion // Energy 44.0
# added cheese // Carbohydrate, by difference 2.44
# added cheese // Energy 408
# added cheese // Protein 23.3
# added cheese // Sodium, Na 654
# added cheese // Sugars, Total NLEA 0.33
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added baking powder // Fiber, total dietary 2.3
# added baking powder // Carbohydrate, by difference 49.2
# added baking powder // Energy 270
# added baking powder // Protein 9.43
# added baking powder // Sodium, Na 477
# added baking powder // Sugars, Total NLEA 5.34
# added baking powder // Fiber, total dietary 2.3
# added baking powder // Carbohydrate, by difference 49.2
# added baking powder // Energy 270
# added baking powder // Protein 9.43
# added baking powder // Sodium, Na 477
# added baking powder // Sugars, Total NLEA 5.34
# added baking powder // Fiber, total dietary 2.3
# added baking powder // Carbohydrate, by difference 49.2
# added baking powder // Energy 270
# added baking powder // Protein 9.43
# added baking powder // Sodium, Na 477
# added baking powder // Sugars, Total NLEA 5.34
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added ginger // Sodium, Na 13.0
# added ginger // Energy 333
# added ginger // Protein 1.82
# added ginger // Carbohydrate, by difference 17.8
# added ginger // Fiber, total dietary 2.0
# added tamari // Carbohydrate, by difference 5.57
# added tamari // Energy 60.0
# added tamari // Protein 10.5
# added tamari // Fiber, total dietary 0.8
# added tamari // Sodium, Na 5590.0
# added hemp seeds // Fiber, total dietary 10.3
# added hemp seeds // Sodium, Na 532
# added hemp seeds // Carbohydrate, by difference 17.1
# added hemp seeds // Energy 612
# added hemp seeds // Protein 21.0
# added hemp seeds // Sugars, Total NLEA 3.14
# added water // Energy 90.0
# added water // Protein 19.0
# added water // Sodium, Na 219
# added water // Carbohydrate, by difference 0.08
# added water // Sugars, Total NLEA 0.0
# added garlic powder // Fiber, total dietary 2.7
# added garlic powder // Protein 6.62
# added garlic powder // Carbohydrate, by difference 28.2
# added garlic powder // Energy 143
# added coriander // Carbohydrate, by difference 55.0
# added coriander // Energy 298
# added coriander // Sodium, Na 35.0
# added coriander // Protein 12.4
# added coriander // Fiber, total dietary 41.9
# added rice // Energy 1580.0
# added rice // Sodium, Na 1.0
# added rice // Protein 7.19
# added rice // Carbohydrate, by difference 75.5
# added coriander // Carbohydrate, by difference 55.0
# added coriander // Energy 298
# added coriander // Sodium, Na 35.0
# added coriander // Protein 12.4
# added coriander // Fiber, total dietary 41.9
# added lime juice // Protein 0.55
# added lime juice // Energy 157
# added lime juice // Fiber, total dietary 0.2
# added lime juice // Sodium, Na 1.0
# added lime juice // Carbohydrate, by difference 7.59
# added lime juice // Sugars, Total NLEA 7.72
# added lime juice // Protein 0.55
# added lime juice // Energy 157
# added lime juice // Fiber, total dietary 0.2
# added lime juice // Sodium, Na 1.0
# added lime juice // Carbohydrate, by difference 7.59
# added lime juice // Sugars, Total NLEA 7.72
# added chili powder // Sodium, Na 2870.0
# added chili powder // Carbohydrate, by difference 49.7
# added chili powder // Energy 282
# added chili powder // Protein 13.5
# added chili powder // Fiber, total dietary 34.8
# added onion // Fiber, total dietary 2.2
# added onion // Sodium, Na 1.0
# added onion // Protein 0.94
# added onion // Sugars, Total NLEA 5.76
# added onion // Carbohydrate, by difference 9.93
# added onion // Energy 44.0
# added onion // Fiber, total dietary 2.2
# added onion // Sodium, Na 1.0
# added onion // Protein 0.94
# added onion // Sugars, Total NLEA 5.76
# added onion // Carbohydrate, by difference 9.93
# added onion // Energy 44.0
# added garlic powder // Fiber, total dietary 2.7
# added garlic powder // Protein 6.62
# added garlic powder // Carbohydrate, by difference 28.2
# added garlic powder // Energy 143
# added cilantro // Energy 95.0
# added cilantro // Protein 2.13
# added cilantro // Carbohydrate, by difference 3.67
# added cilantro // Fiber, total dietary 2.8
# added cilantro // Sodium, Na 46.0
# added chicken // Protein 23.9
# added chicken // Energy 652
# added chicken // Sodium, Na 117
# added chicken // Carbohydrate, by difference 0.0
# added cheese // Carbohydrate, by difference 2.44
# added cheese // Energy 408
# added cheese // Protein 23.3
# added cheese // Sodium, Na 654
# added cheese // Sugars, Total NLEA 0.33
# added maple // Fiber, total dietary 0.0
# added maple // Sodium, Na 11.0
# added maple // Protein 0.1
# added maple // Carbohydrate, by difference 90.9
# added maple // Energy 354
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added flour // Sodium, Na 0.0
# added flour // Fiber, total dietary 2.66
# added flour // Protein 11.4
# added flour // Carbohydrate, by difference 74.4
# added flour // Energy (Atwater General Factors) 357
# added baking powder // Fiber, total dietary 2.3
# added baking powder // Carbohydrate, by difference 49.2
# added baking powder // Energy 270
# added baking powder // Protein 9.43
# added baking powder // Sodium, Na 477
# added baking powder // Sugars, Total NLEA 5.34
# added baking soda // Fiber, total dietary 2.3
# added baking soda // Carbohydrate, by difference 49.2
# added baking soda // Energy 270
# added baking soda // Protein 9.43
# added baking soda // Sodium, Na 477
# added baking soda // Sugars, Total NLEA 5.34
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added oats // Sodium, Na 3.62
# added oats // Fiber, total dietary 10.5
# added oats // Carbohydrate, by difference 69.9
# added oats // Protein 13.2
# added oats // Energy (Atwater General Factors) 389
# added milk // Protein 7.81
# added milk // Sodium, Na 105
# added milk // Energy 657
# added milk // Carbohydrate, by difference 6.86
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added seed // Fiber, total dietary 10.3
# added seed // Sodium, Na 532
# added seed // Carbohydrate, by difference 17.1
# added seed // Energy 612
# added seed // Protein 21.0
# added seed // Sugars, Total NLEA 3.14
# added cinnamon // Carbohydrate, by difference 44.4
# added cinnamon // Energy 253
# added cinnamon // Protein 7.05
# added cinnamon // Fiber, total dietary 3.5
# added cinnamon // Sodium, Na 388
# added garlic powder // Fiber, total dietary 2.7
# added garlic powder // Protein 6.62
# added garlic powder // Carbohydrate, by difference 28.2
# added garlic powder // Energy 143
# added coriander // Carbohydrate, by difference 55.0
# added coriander // Energy 298
# added coriander // Sodium, Na 35.0
# added coriander // Protein 12.4
# added coriander // Fiber, total dietary 41.9
# added rice // Energy 1580.0
# added rice // Sodium, Na 1.0
# added rice // Protein 7.19
# added rice // Carbohydrate, by difference 75.5
# added coriander // Carbohydrate, by difference 55.0
# added coriander // Energy 298
# added coriander // Sodium, Na 35.0
# added coriander // Protein 12.4
# added coriander // Fiber, total dietary 41.9
# added garlic powder // Fiber, total dietary 2.7
# added garlic powder // Protein 6.62
# added garlic powder // Carbohydrate, by difference 28.2
# added garlic powder // Energy 143
# added coriander // Carbohydrate, by difference 55.0
# added coriander // Energy 298
# added coriander // Sodium, Na 35.0
# added coriander // Protein 12.4
# added coriander // Fiber, total dietary 41.9
# added rice // Energy 1580.0
# added rice // Sodium, Na 1.0
# added rice // Protein 7.19
# added rice // Carbohydrate, by difference 75.5
# added coriander // Carbohydrate, by difference 55.0
# added coriander // Energy 298
# added coriander // Sodium, Na 35.0
# added coriander // Protein 12.4
# added coriander // Fiber, total dietary 41.9
# added milk // Protein 7.81
# added milk // Sodium, Na 105
# added milk // Energy 657
# added milk // Carbohydrate, by difference 6.86
# added sugar // Energy 1610.0
# added sugar // Protein 0.0
# added sugar // Sodium, Na 1.0
# added sugar // Carbohydrate, by difference 99.6
# added sugar // Sugars, Total NLEA 99.8
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added flour // Sodium, Na 0.0
# added flour // Fiber, total dietary 2.66
# added flour // Protein 11.4
# added flour // Carbohydrate, by difference 74.4
# added flour // Energy (Atwater General Factors) 357
# added cinnamon // Carbohydrate, by difference 44.4
# added cinnamon // Energy 253
# added cinnamon // Protein 7.05
# added cinnamon // Fiber, total dietary 3.5
# added cinnamon // Sodium, Na 388
# added baking soda // Fiber, total dietary 2.3
# added baking soda // Carbohydrate, by difference 49.2
# added baking soda // Energy 270
# added baking soda // Protein 9.43
# added baking soda // Sodium, Na 477
# added baking soda // Sugars, Total NLEA 5.34
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added parsley // Carbohydrate, by difference 6.33
# added parsley // Energy 36.0
# added parsley // Protein 2.97
# added parsley // Fiber, total dietary 3.3
# added parsley // Sodium, Na 56.0
# added pasta // Fiber, total dietary 1.8
# added pasta // Carbohydrate, by difference 8.05
# added pasta // Energy 45.0
# added pasta // Sodium, Na 419
# added pasta // Protein 1.41
# added pasta // Sugars, Total NLEA 5.5
# added ghee // Protein 0.0
# added ghee // Energy 3770.0
# added ghee // Fiber, total dietary 0.0
# added ghee // Sodium, Na 0.0
# added ghee // Carbohydrate, by difference 0.0
# added sugar // Energy 1610.0
# added sugar // Protein 0.0
# added sugar // Sodium, Na 1.0
# added sugar // Carbohydrate, by difference 99.6
# added sugar // Sugars, Total NLEA 99.8
# added rice // Energy 1580.0
# added rice // Sodium, Na 1.0
# added rice // Protein 7.19
# added rice // Carbohydrate, by difference 75.5
# added flour // Sodium, Na 0.0
# added flour // Fiber, total dietary 2.66
# added flour // Protein 11.4
# added flour // Carbohydrate, by difference 74.4
# added flour // Energy (Atwater General Factors) 357
# added flour // Sodium, Na 0.0
# added flour // Fiber, total dietary 2.66
# added flour // Protein 11.4
# added flour // Carbohydrate, by difference 74.4
# added flour // Energy (Atwater General Factors) 357
# added sugar // Energy 1610.0
# added sugar // Protein 0.0
# added sugar // Sodium, Na 1.0
# added sugar // Carbohydrate, by difference 99.6
# added sugar // Sugars, Total NLEA 99.8
# added sugar // Energy 1610.0
# added sugar // Protein 0.0
# added sugar // Sodium, Na 1.0
# added sugar // Carbohydrate, by difference 99.6
# added sugar // Sugars, Total NLEA 99.8
# added ginger // Sodium, Na 13.0
# added ginger // Energy 333
# added ginger // Protein 1.82
# added ginger // Carbohydrate, by difference 17.8
# added ginger // Fiber, total dietary 2.0
# added turmeric // Carbohydrate, by difference 67.1
# added turmeric // Energy 312
# added turmeric // Protein 9.68
# added turmeric // Fiber, total dietary 22.7
# added turmeric // Sodium, Na 27.0
# added milk // Protein 7.81
# added milk // Sodium, Na 105
# added milk // Energy 657
# added milk // Carbohydrate, by difference 6.86
# added sugar // Energy 1610.0
# added sugar // Protein 0.0
# added sugar // Sodium, Na 1.0
# added sugar // Carbohydrate, by difference 99.6
# added sugar // Sugars, Total NLEA 99.8
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added flour // Sodium, Na 0.0
# added flour // Fiber, total dietary 2.66
# added flour // Protein 11.4
# added flour // Carbohydrate, by difference 74.4
# added flour // Energy (Atwater General Factors) 357
# added cinnamon // Carbohydrate, by difference 44.4
# added cinnamon // Energy 253
# added cinnamon // Protein 7.05
# added cinnamon // Fiber, total dietary 3.5
# added cinnamon // Sodium, Na 388
# added baking soda // Fiber, total dietary 2.3
# added baking soda // Carbohydrate, by difference 49.2
# added baking soda // Energy 270
# added baking soda // Protein 9.43
# added baking soda // Sodium, Na 477
# added baking soda // Sugars, Total NLEA 5.34
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added baking powder // Fiber, total dietary 2.3
# added baking powder // Carbohydrate, by difference 49.2
# added baking powder // Energy 270
# added baking powder // Protein 9.43
# added baking powder // Sodium, Na 477
# added baking powder // Sugars, Total NLEA 5.34
# added salt // Sodium, Na 524
# added salt // Sugars, Total NLEA 0.58
# added butter // Fiber, total dietary 9.72
# added butter // Sodium, Na 0.996
# added butter // Carbohydrate, by difference 21.2
# added butter // Protein 20.8
# added butter // Energy (Atwater General Factors) 645
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added baked beans // Protein 24.4
# added baked beans // Fiber, total dietary 4.2
# added parmesan // Carbohydrate, by difference 12.4
# added parmesan // Energy 421
# added parmesan // Protein 29.6
# added parmesan // Sodium, Na 1750.0
# added parmesan // Sugars, Total NLEA 0.07
# added black pepper // Sodium, Na 0.0
# added black pepper // Fiber, total dietary 0.942
# added black pepper // Protein 0.715
# added black pepper // Carbohydrate, by difference 4.78
# added black pepper // Energy (Atwater General Factors) 22.9
# added herbs // Protein 4.25
# added herbs // Energy 254
# added herbs // Fiber, total dietary 4.3
# added herbs // Sodium, Na 1100.0
# added herbs // Carbohydrate, by difference 5.3
# added herbs // Sugars, Total NLEA 1.42
# added vanilla // Energy 1200.0
# added vanilla // Carbohydrate, by difference 12.6
# added vanilla // Protein 0.06
# added vanilla // Fiber, total dietary 0.0
# added vanilla // Sodium, Na 9.0
# added eggs // Protein 10.7
# added eggs // Energy 231
# added eggs // Carbohydrate, by difference 2.36
# added flour // Sodium, Na 0.0
# added flour // Fiber, total dietary 2.66
# added flour // Protein 11.4
# added flour // Carbohydrate, by difference 74.4
# added flour // Energy (Atwater General Factors) 357
# added rice // Energy 1580.0
# added rice // Sodium, Na 1.0
# added rice // Protein 7.19
# added rice // Carbohydrate, by difference 75.5
# added butter // Fiber, total dietary 9.72
# added butter // Sodium, Na 0.996
# added butter // Carbohydrate, by difference 21.2
# added butter // Protein 20.8
# added butter // Energy (Atwater General Factors) 645
# added carrots // Sodium, Na 62.7
# added carrots // Fiber, total dietary 2.69
# added carrots // Protein 0.805
# added carrots // Carbohydrate, by difference 9.08
# added carrots // Energy (Atwater General Factors) 40.8
# added brussels sprouts // Fiber, total dietary 3.8
# added brussels sprouts // Energy 179
# added brussels sprouts // Carbohydrate, by difference 8.95
# added brussels sprouts // Protein 3.38
# added brussels sprouts // Sodium, Na 25.0
# added black pepper // Sodium, Na 0.0
# added black pepper // Fiber, total dietary 0.942
# added black pepper // Protein 0.715
# added black pepper // Carbohydrate, by difference 4.78
# added black pepper // Energy (Atwater General Factors) 22.9
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_24132/3618714968.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_posts[nutrient_cols] = small_posts['ingredients'].apply(calc_nutrient_levels_recipe).apply(convert_dict_to_series)
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_24132/3618714968.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_posts[nutrient_cols] = small_posts['ingredients'].apply(calc_nutrient_levels_recipe).apply(convert_dict_to_series)
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_24132/3618714968.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_posts[nutrient_cols] = small_posts['ingredients'].apply(calc_nutrient_levels_recipe).apply(convert_dict_to_series)
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_24132/3618714968.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_posts[nutrient_cols] = small_posts['ingredients'].apply(calc_nutrient_levels_recipe).apply(convert_dict_to_series)
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_24132/3618714968.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_posts[nutrient_cols] = small_posts['ingredients'].apply(calc_nutrient_levels_recipe).apply(convert_dict_to_series)
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_24132/3618714968.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_posts[nutrient_cols] = small_posts['ingredients'].apply(calc_nutrient_levels_recipe).apply(convert_dict_to_series)

# %%
small_posts.to_csv("posts_with_nutritional_info.csv")

# %%
np.sum([len(ing) for ing in posts.head(100)['ingredients']])
# Out:
# 451

# %%
small_posts
# Out:
#                                        postUrl  \
# 81    https://www.instagram.com/p/Cgd_iR_vT2d/
# 104   https://www.instagram.com/p/Cgd8bLXDaCq/
# 169   https://www.instagram.com/p/CgdylqtOy9s/
# 172   https://www.instagram.com/p/CgdyENyLgmv/
# 226   https://www.instagram.com/p/CgdpvTNvrWt/
# 230   https://www.instagram.com/p/CgdmRS0DWm4/
# 251   https://www.instagram.com/p/Cgdl5Uehh6u/
# 278   https://www.instagram.com/p/CgdgJ2eA8Tl/
# 279   https://www.instagram.com/p/CgdfLOSrAUG/
# 291   https://www.instagram.com/p/CgddMjDMIQx/
# 322   https://www.instagram.com/p/CgdUufMllJ7/
# 334   https://www.instagram.com/p/CgdTlx_JNpJ/
# 362   https://www.instagram.com/p/CgdO-7IpAiI/
# 419   https://www.instagram.com/p/CgdMw-dBgjZ/
# 449   https://www.instagram.com/p/Cgc4OSqMQKW/
# 453   https://www.instagram.com/p/Cgc3XrXLd6s/
# 459   https://www.instagram.com/p/CgcxXFKv8lj/
# 487   https://www.instagram.com/p/Cgckat3Iui0/
# 512   https://www.instagram.com/p/CgcYwiNF_9n/
# 564   https://www.instagram.com/p/CgcHlYcsH0k/
# 577   https://www.instagram.com/p/CgcBFP4rE3j/
# 592   https://www.instagram.com/p/Cgb4QURp4j_/
# 615   https://www.instagram.com/p/CgbutKFlZZx/
# 627   https://www.instagram.com/p/CgboCcgDiXs/
# 635   https://www.instagram.com/p/Cgbk1gkj0Bj/
# 713   https://www.instagram.com/p/Cgd-PpwBf4c/
# 740   https://www.instagram.com/p/Cgd88KdLcaP/
# 781   https://www.instagram.com/p/Cgdw3BDKgw2/
# 833   https://www.instagram.com/p/Cgd4NfDKVWC/
# 926   https://www.instagram.com/p/CgdylqtOy9s/
# 971   https://www.instagram.com/p/CgCX2p_DSsu/
# 1072  https://www.instagram.com/p/CgdJgkEMPeN/
# 1089  https://www.instagram.com/p/CgdEtXGJ3ve/
# 1143  https://www.instagram.com/p/Cgcz3kkPsLI/
# 1174  https://www.instagram.com/p/Cgcp-jtOQGM/
# 1220  https://www.instagram.com/p/CgcdoMmPZu7/
# 1221  https://www.instagram.com/p/Cgcds0aP4j2/
# 3     https://www.instagram.com/p/ChEnnOzsxCs/
# 22    https://www.instagram.com/p/ChE7IgTK8CF/
# 23    https://www.instagram.com/p/ChE7H4Gossf/
# 30    https://www.instagram.com/p/ChE5qrGDhGb/
# 41    https://www.instagram.com/p/ChE3jp4qElr/
# 52    https://www.instagram.com/p/ChE1NB8KIYm/
# 85    https://www.instagram.com/p/ChEuCsWrbfM/
# 121   https://www.instagram.com/p/ChEnnOzsxCs/
# 183   https://www.instagram.com/p/ChEdXeWNG8K/
# 265   https://www.instagram.com/p/ChECk3_vGV4/
# 284   https://www.instagram.com/p/ChD7rylhNzc/
# 329   https://www.instagram.com/p/ChDe5x2MkOM/
# 339   https://www.instagram.com/p/ChDgJS_snt5/
#
#                                              profileUrl  \
# 81             https://www.instagram.com/all.about.oats
# 104                  https://www.instagram.com/a_m_eats
# 169           https://www.instagram.com/hescottwellness
# 172             https://www.instagram.com/rainbowpiatto
# 226         https://www.instagram.com/foodiesfood_court
# 230        https://www.instagram.com/corner_to_discover
# 251          https://www.instagram.com/mixin._.goodness
# 278   https://www.instagram.com/sri_vani_cooking_cha...
# 279                https://www.instagram.com/enzo_mapua
# 291                 https://www.instagram.com/chefproto
# 322       https://www.instagram.com/cooking_con_claudia
# 334       https://www.instagram.com/chloemoir_nutrition
# 362                   https://www.instagram.com/kiipfit
# 419           https://www.instagram.com/veganrecipes.io
# 449               https://www.instagram.com/chewoutloud
# 453                https://www.instagram.com/chefericak
# 459     https://www.instagram.com/parmigianoreggianoaus
# 487          https://www.instagram.com/keto_daily_meals
# 512           https://www.instagram.com/fullhappybelly_
# 564              https://www.instagram.com/windsetfarms
# 577           https://www.instagram.com/thewellbeingnet
# 592      https://www.instagram.com/glutenfreeandmoremag
# 615             https://www.instagram.com/trustfoods.in
# 627             https://www.instagram.com/thealmostcook
# 635            https://www.instagram.com/hangryinlondon
# 713             https://www.instagram.com/lets_eat_2021
# 740               https://www.instagram.com/imunihealth
# 781   https://www.instagram.com/ket_ofoodrecipesandtips
# 833              https://www.instagram.com/yuss_does_sw
# 926           https://www.instagram.com/hescottwellness
# 971      https://www.instagram.com/alwayshungryinlondon
# 1072            https://www.instagram.com/seasonedbyjin
# 1089    https://www.instagram.com/macrosmargsandpeloton
# 1143         https://www.instagram.com/eatswithaaliyahh
# 1174             https://www.instagram.com/landsbestcbd
# 1220           https://www.instagram.com/ketorecipes.hk
# 1221        https://www.instagram.com/weightlossplan.hk
# 3                     https://www.instagram.com/yum.ltd
# 22                https://www.instagram.com/_pjnfitness
# 23                  https://www.instagram.com/_emmanunn
# 30                  https://www.instagram.com/keevaeats
# 41               https://www.instagram.com/holisticmoon
# 52           https://www.instagram.com/kpfoodandfitness
# 85         https://www.instagram.com/fitqueens_wellness
# 121                   https://www.instagram.com/yum.ltd
# 183                https://www.instagram.com/cuisinovia
# 265               https://www.instagram.com/ayambrandsg
# 284            https://www.instagram.com/healthyeats.wb
# 329     https://www.instagram.com/vegfruitsandmushrooms
# 339               https://www.instagram.com/chewoutloud
#
#                       username  \
# 81              all.about.oats
# 104                   a_m_eats
# 169            hescottwellness
# 172              rainbowpiatto
# 226          foodiesfood_court
# 230         corner_to_discover
# 251           mixin._.goodness
# 278   sri_vani_cooking_channel
# 279                 enzo_mapua
# 291                  chefproto
# 322        cooking_con_claudia
# 334        chloemoir_nutrition
# 362                    kiipfit
# 419            veganrecipes.io
# 449                chewoutloud
# 453                 chefericak
# 459      parmigianoreggianoaus
# 487           keto_daily_meals
# 512            fullhappybelly_
# 564               windsetfarms
# 577            thewellbeingnet
# 592       glutenfreeandmoremag
# 615              trustfoods.in
# 627              thealmostcook
# 635             hangryinlondon
# 713              lets_eat_2021
# 740                imunihealth
# 781    ket_ofoodrecipesandtips
# 833               yuss_does_sw
# 926            hescottwellness
# 971       alwayshungryinlondon
# 1072             seasonedbyjin
# 1089     macrosmargsandpeloton
# 1143          eatswithaaliyahh
# 1174              landsbestcbd
# 1220            ketorecipes.hk
# 1221         weightlossplan.hk
# 3                      yum.ltd
# 22                 _pjnfitness
# 23                   _emmanunn
# 30                   keevaeats
# 41                holisticmoon
# 52            kpfoodandfitness
# 85          fitqueens_wellness
# 121                    yum.ltd
# 183                 cuisinovia
# 265                ayambrandsg
# 284             healthyeats.wb
# 329      vegfruitsandmushrooms
# 339                chewoutloud
#
#                                              fullName  commentCount  \
# 81                                      Anushka Lodhi             0
# 104                                     Alice & Meg 🍴             3
# 169                         Natasha Hescott, RDN, CDN             0
# 172                                    Rainbow Piatto             1
# 226                                Foodies Food Court            43
# 230                                    Shivangi Gupta             4
# 251                                           Sunaina             2
# 278                                 Srivani's Kitchen             1
# 279                                        enzo mapua             3
# 291                                        Zoya Ahmed             2
# 322                                           Claudia            26
# 334                    Nutritionist - Healthy Recipes             3
# 362                         Gunjan🥦Vegan Food Blogger             0
# 419                                   veganrecipes.io             1
# 449                            Recipes | Food Blogger             0
# 453                                   Erica Karbelnik            10
# 459                     Parmigiano Reggiano Australia             1
# 487                                  keto daily meals             1
# 512                                        Lily Leung             0
# 564                                     Windset Farms             0
# 577                                   thewellbeingnet             0
# 592                       Gluten Free & More Magazine             0
# 615                                 Trust Foods India             2
# 627                                             Mel 🍋             2
# 635                                Hangry in London 🌶             0
# 713                                      roy_debojani             1
# 740                      IMUNI Vitamins & Supplements             0
# 781                        Keto Food Recipes and Tips             1
# 833                                      Yousra Samir             2
# 926                         Natasha Hescott, RDN, CDN             0
# 971                                         𝐇𝐚𝐧𝐧𝐚𝐡 𝐃𝐉            97
# 1072                                  Seasoned By Jin             3
# 1089                               Macros and Peloton             2
# 1143                       aaliyahh | healthy recipes             2
# 1174                                      Land's Best             0
# 1220                           Weightloss | keto diet             2
# 1221                   weightloss | fatloss | healthy             0
# 3                                               🍧YUM🍧            12
# 22                                   Pete & Emma Nunn             0
# 23                Emma • Fitness Accountability Coach             0
# 30                                         Keeva Eats             3
# 41                      Mel 🪷 Wellness + Healthy food             0
# 52                      Kate | Food Recipes & Running             7
# 85    health | food | fitness | lifestyle | self-love             0
# 121                                             🍧YUM🍧            12
# 183                                Galatia Pamboridis             5
# 265                          Ayam Brand Singapore 🐟 🥥             1
# 284                            HEALTHY EATS WITH BREE             1
# 329                                       DP and Neil             1
# 339                            Recipes | Food Blogger             4
#
#       likeCount                   pubDate  \
# 81            2  2022-07-26T08:23:14.000Z
# 104          12  2022-07-26T07:56:03.000Z
# 169           1  2022-07-26T06:30:06.000Z
# 172          14  2022-07-26T06:25:32.000Z
# 226        1819  2022-07-26T05:12:47.000Z
# 230         102  2022-07-26T05:04:54.000Z
# 251          47  2022-07-26T04:39:12.000Z
# 278           9  2022-07-26T03:49:32.000Z
# 279          48  2022-07-26T03:40:28.000Z
# 291          30  2022-07-26T03:23:11.000Z
# 322        2087  2022-07-26T02:15:41.000Z
# 334          54  2022-07-26T01:59:14.000Z
# 362           8  2022-07-26T01:18:59.000Z
# 419           3  2022-07-26T01:00:21.000Z
# 449          24  2022-07-25T22:00:06.000Z
# 453          62  2022-07-25T21:52:39.000Z
# 459          10  2022-07-25T21:00:11.000Z
# 487          20  2022-07-25T19:07:02.000Z
# 512          15  2022-07-25T17:25:10.000Z
# 564          12  2022-07-25T14:55:09.000Z
# 577          30  2022-07-25T13:58:16.000Z
# 592          11  2022-07-25T12:41:08.000Z
# 615          17  2022-07-25T11:18:18.000Z
# 627          38  2022-07-25T10:19:26.000Z
# 635          16  2022-07-25T09:51:27.000Z
# 713           5  2022-07-26T08:11:58.000Z
# 740           1  2022-07-26T08:01:01.000Z
# 781           5  2022-07-26T06:18:07.000Z
# 833           7  2022-07-26T07:19:14.000Z
# 926           1  2022-07-26T06:30:06.000Z
# 971        6243  2022-07-15T14:57:00.000Z
# 1072         42  2022-07-26T00:31:09.000Z
# 1089          6  2022-07-25T23:49:12.000Z
# 1143          3  2022-07-25T21:22:03.000Z
# 1174         11  2022-07-25T19:55:37.000Z
# 1220         98  2022-07-25T18:07:43.000Z
# 1221        110  2022-07-25T18:08:21.000Z
# 3           208  2022-08-10T08:24:35.000Z
# 22            2  2022-08-10T11:15:09.000Z
# 23            0  2022-08-10T11:15:04.000Z
# 30           25  2022-08-10T11:02:20.000Z
# 41            8  2022-08-10T10:43:54.000Z
# 52           15  2022-08-10T10:23:20.000Z
# 85           11  2022-08-10T09:20:46.000Z
# 121         208  2022-08-10T08:24:35.000Z
# 183         170  2022-08-10T06:55:03.000Z
# 265          22  2022-08-10T03:01:13.000Z
# 284           3  2022-08-10T02:00:44.000Z
# 329          20  2022-08-09T21:49:14.000Z
# 339          97  2022-08-09T22:00:05.000Z
#
#                                             description  \
# 81    Chocolate fudge protein oatmeal🤎 💪\nIngredient...
# 104   ⁣Caprese Chicken with Pesto 🌿🍅⠀\n⠀\nThis dish ...
# 169   Looking for a fast recipe to make for lunch? T...
# 172   Sweet & Savoury Mushroom Scones~🍄 This easy an...
# 226   Paneer Tikka Recipe😍\nSave it to try later♥️\n...
# 230   MASALA PANEER 🥰\n\nTo set the paneer why to us...
# 251   Paneer Aaloo mix Paratha 👩‍🍳😃😋\n\nIngredients:...
# 278   Healthy chutney powder to serve with Idli, dos...
# 279   Boscaiola! @rumourhasit9 had cooked this for m...
# 291   Hi besties! I thought it was time I’d share on...
# 322   If you are a pasta lover like myself, you are ...
# 334   [ad] Porridge for a warm winter lunch ☺️\n\nIN...
# 362   Crispy and crunchy Air Fryer 🥒 Zucchini Fries ...
# 419   bookmark this VEGAN BUFFALO CHICKEN SALAD (wit...
# 449   These Creamy, Lemony Cucumber Sandwiches are p...
# 453   No-Bake Salted Chocolate Tahini Tart 🍫🥧⁠\n.⁠\n...
# 459   Warm salad of purple sprouting broccoli, new p...
# 487   .A Complete 5 week meal plan with Quick start ...
# 512   Delicious Summer SALAD in 5 minutes | I can ea...
# 564   If you are looking to bring a yummy pasta sala...
# 577   Roasted soyabeans salad 🥗  recipe in the capti...
# 592   Need an easy brunch recipe? This Plant-Based🌱 ...
# 615   This Chocolate Pancake  is a must try for all ...
# 627   overnight oats 🍯 if you’re wanting some easy a...
# 635   Finally got round to making baba ganoush! Not ...
# 713   Immunity-boosting Detox Smoothie Jar \n\n🍹🍹🍹🍹🍹...
# 740   Gluten Free | Dairy Free | Yields 12 medium-si...
# 781   👉Save this post for the recipe.\nFollow \n@ket...
# 833   CHOCOLATE BAKED OATS 😋 I love chocolate and I ...
# 926   Looking for a fast recipe to make for lunch? T...
# 971   Prawn Taco Bowl\n—————————————————————-\nPerfe...
# 1072  Spicy Tuna Pancake/Gochu-Chamchi Jeon!(고추참...
# 1089  Macro Friendly Chicken Enchiladas 🥑 \n\nIngred...
# 1143  HEALTHY & EASY BANANA BREAD MUFFINS🍌🧁\n\nI’ve ...
# 1174  I've been LOVING having overnight oats for bre...
# 1220  Prawn Taco Bowl\n\n❓Eating Keto is simple🥑🧀🥘⁠\...
# 1221  Prawn Taco Bowl\n\n❓Eating Keto is simple🥑🧀🥘⁠\...
# 3     🍌Banana Bread🍌recipe, save it for later🐵\nFoll...
# 22    • Lunch (or dinner) idea •\n\nThe most amazing...
# 23    • Lunch (or dinner) idea •\n\nThe most amazing...
# 30    RECIPE DROP: Pepperoni, Harissa & Yoghurt Past...
# 41    🇮🇹🇬🇧 STUFFED COOKIES 🍪👇\n.\n.\n.\n\nFollow  @h...
# 52    Oreo tiffin/traybake 🍫\n\nThis Oreo flavoured ...
# 85    Inflammation means when your body tries to def...
# 121   🍌Banana Bread🍌recipe, save it for later🐵\nFoll...
# 183   Irresistible almond-oat cookies – Can’t get en...
# 265   😉 Take a look at how @eatsimply02 put together...
# 284   mixed berry creamy protein smoothie bowl 💭🍓\n\...
# 329   Banana and vanilla cheesecake with raspberry c...
# 339   This wild rice pilaf recipe creates a side dis...
#
#                                        location  \
# 81                             Ghaziabad, India
# 104                     Glasgow, United Kingdom
# 169                                         NaN
# 172   Singapore / Singapura / 新加坡 / சிங்கப்பூர்
# 226                                       Bihar
# 230                                         NaN
# 251                                         NaN
# 278                                         NaN
# 279                                         NaN
# 291                                         NaN
# 322                                         NaN
# 334                                         NaN
# 362                         Seattle, Washington
# 419                                         NaN
# 449                                         NaN
# 453                                         NaN
# 459                                         NaN
# 487                                         NaN
# 512                                      @ Home
# 564                                         NaN
# 577                                         NaN
# 592                                         NaN
# 615                                         NaN
# 627                   London Borough of Hackney
# 635                                    Cornwall
# 713                                         NaN
# 740                                         NaN
# 781                                         NaN
# 833                                         NaN
# 926                                         NaN
# 971                      London, United Kingdom
# 1072                        Arlington, Virginia
# 1089                                        NaN
# 1143                                        NaN
# 1174                                        NaN
# 1220                                        USA
# 1221                                        USA
# 3                                           NaN
# 22                                          NaN
# 23                                          NaN
# 30                                      Belfast
# 41                                        Italy
# 52                                          NaN
# 85                FitQueens Wellness Sisterhood
# 121                                         NaN
# 183                                         NaN
# 265                                         NaN
# 284                                         NaN
# 329           Holy Island, Northumberland Coast
# 339                                         NaN
#
#                                                  imgUrl  ...  \
# 81    https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...
# 104   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 169   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 172   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 226   https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...
# 230                                                 NaN  ...
# 251   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 278                                                 NaN  ...
# 279   https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...
# 291   https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...
# 322                                                 NaN  ...
# 334   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 362   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 419                                                 NaN  ...
# 449   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 453   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 459   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 487   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 512   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 564   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 577   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 592   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 615                                                 NaN  ...
# 627   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 635   https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...
# 713   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 740   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 781                                                 NaN  ...
# 833   https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...
# 926   https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 971   https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...
# 1072  https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...
# 1089  https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 1143  https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 1174  https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 1220  https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...
# 1221  https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...
# 3     https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...
# 22    https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...
# 23    https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...
# 30    https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...
# 41    https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...
# 52    https://scontent-cdg2-1.cdninstagram.com/v/t51...  ...
# 85    https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...
# 121   https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...
# 183   https://scontent-cdg2-1.cdninstagram.com/v/t51...  ...
# 265                                                 NaN  ...
# 284   https://scontent-cdt1-1.cdninstagram.com/v/t51...  ...
# 329   https://scontent-cdg2-1.cdninstagram.com/v/t51...  ...
# 339   https://scontent-cdg2-1.cdninstagram.com/v/t51...  ...
#
#                                description_preprocessed  \
# 81    chocolate fudge protein oatmeal \ningredients:...
# 104   ⁣caprese chicken with pesto ⠀\n⠀\nthis dish is...
# 169   looking for a fast recipe to make for lunch? t...
# 172   sweet & savoury mushroom scones~ this easy and...
# 226   paneer tikka recipe\nsave it to try later\n\ni...
# 230   masala paneer \n\nto set the paneer why to use...
# 251   paneer aaloo mix paratha \n\ningredients: pane...
# 278   healthy chutney powder to serve with idli, dos...
# 279   boscaiola! had cooked this for my family and i...
# 291   hi besties! i thought it was time i’d share on...
# 322   if you are a pasta lover like myself, you are ...
# 334   [ad] porridge for a warm winter lunch \n\ningr...
# 362   crispy and crunchy air fryer zucchini fries ar...
# 419   bookmark this vegan buffalo chicken salad (wit...
# 449   these creamy, lemony cucumber sandwiches are p...
# 453   no-bake salted chocolate tahini tart \n.\na ri...
# 459   warm salad of purple sprouting broccoli, new p...
# 487   .a complete 5 week meal plan with quick start ...
# 512   delicious summer salad in 5 minutes | i can ea...
# 564   if you are looking to bring a yummy pasta sala...
# 577   roasted soyabeans salad recipe in the caption ...
# 592   need an easy brunch recipe? this plant-based b...
# 615   this chocolate pancake is a must try for all c...
# 627   overnight oats if you’re wanting some easy and...
# 635   finally got round to making baba ganoush! not ...
# 713   immunity-boosting detox smoothie jar \n\n\n\ns...
# 740   gluten free | dairy free | yields 12 medium-si...
# 781   save this post for the recipe.\nfollow \n  to ...
# 833   chocolate baked oats i love chocolate and i lo...
# 926   looking for a fast recipe to make for lunch? t...
# 971   prawn taco bowl\n—————————————————————-\nperfe...
# 1072  spicy tuna pancake/gochu-chamchi jeon!(고추참...
# 1089  macro friendly chicken enchiladas \n\ningredie...
# 1143  healthy & easy banana bread muffins\n\ni’ve re...
# 1174  i've been loving having overnight oats for bre...
# 1220  prawn taco bowl\n\neating keto is simple\n- le...
# 1221  prawn taco bowl\n\neating keto is simple\n- le...
# 3     banana breadrecipe, save it for later\nfollow ...
# 22    lunch (or dinner) idea \n\nthe most amazing to...
# 23    lunch (or dinner) idea \n\nthe most amazing to...
# 30    recipe drop: pepperoni, harissa & yoghurt past...
# 41    stuffed cookies \n.\n.\n.\n\nfollow \n.\n.\nsa...
# 52    oreo tiffin/traybake \n\nthis oreo flavoured n...
# 85    inflammation means when your body tries to def...
# 121   banana breadrecipe, save it for later\nfollow ...
# 183   irresistible almond-oat cookies – can’t get en...
# 265   take a look at how put together her ultimate c...
# 284   mixed berry creamy protein smoothie bowl \n\ns...
# 329   banana and vanilla cheesecake with raspberry c...
# 339   this wild rice pilaf recipe creates a side dis...
#
#       includes_ingredient_list  \
# 81                        True
# 104                       True
# 169                       True
# 172                       True
# 226                       True
# 230                       True
# 251                       True
# 278                       True
# 279                       True
# 291                       True
# 322                       True
# 334                       True
# 362                       True
# 419                       True
# 449                       True
# 453                       True
# 459                       True
# 487                       True
# 512                       True
# 564                       True
# 577                       True
# 592                       True
# 615                       True
# 627                       True
# 635                       True
# 713                       True
# 740                       True
# 781                       True
# 833                       True
# 926                       True
# 971                       True
# 1072                      True
# 1089                      True
# 1143                      True
# 1174                      True
# 1220                      True
# 1221                      True
# 3                         True
# 22                        True
# 23                        True
# 30                        True
# 41                        True
# 52                        True
# 85                        True
# 121                       True
# 183                       True
# 265                       True
# 284                       True
# 329                       True
# 339                       True
#
#                                         ingredient_list  \
# 81    [{'ingredient': oats, 'quantity': 1/2, 'measur...
# 104   [{'ingredient': pesto, 'quantity': 2, 'measure...
# 169   [{'ingredient': ginger, 'quantity': 1, 'measur...
# 172   [{'ingredient': mushrooms, 'quantity': 200, 'm...
# 226   [{'ingredient': flour, 'quantity': 1/2, 'measu...
# 230   [{'ingredient': milk, 'quantity': 1, 'measurem...
# 251                                                  []
# 278   [{'ingredient': flax seeds, 'quantity': 1/2, '...
# 279   [{'ingredient': tomato, 'quantity': 1/3, 'meas...
# 291   [{'ingredient': sugar, 'quantity': 2, 'measure...
# 322   [{'ingredient': pasta, 'quantity': 16, 'measur...
# 334   [{'ingredient': oats, 'quantity': 1/2, 'measur...
# 362   [{'ingredient': zucchini, 'quantity': 2, 'meas...
# 419   [{'ingredient': cashews, 'quantity': 1.5, 'mea...
# 449   [{'ingredient': cream, 'quantity': 4, 'measure...
# 453   [{'ingredient': butter, 'quantity': 1/2, 'meas...
# 459   [{'ingredient': potatoes, 'quantity': 400, 'me...
# 487   [{'ingredient': olive, 'quantity': 1, 'measure...
# 512                                                  []
# 564   [{'ingredient': black pepper, 'quantity': 1, '...
# 577                                                  []
# 592   [{'ingredient': mushrooms, 'quantity': 8, 'mea...
# 615   [{'ingredient': powder, 'quantity': 4, 'measur...
# 627   [{'ingredient': oats, 'quantity': 1.5, 'measur...
# 635   [{'ingredient': lemon juice, 'quantity': 2, 'm...
# 713   [{'ingredient': ginger, 'quantity': 1/4, 'meas...
# 740   [{'ingredient': butter, 'quantity': 1/2, 'meas...
# 781   [{'ingredient': lettuce, 'quantity': 1.5, 'mea...
# 833   [{'ingredient': vanilla, 'quantity': 2, 'measu...
# 926   [{'ingredient': ginger, 'quantity': 1, 'measur...
# 971   [{'ingredient': prawns, 'quantity': 90, 'measu...
# 1072                                                 []
# 1089  [{'ingredient': lime juice, 'quantity': 1/4, '...
# 1143  [{'ingredient': olive, 'quantity': 1/3, 'measu...
# 1174  [{'ingredient': oats, 'quantity': ⅔, 'measurem...
# 1220  [{'ingredient': prawns, 'quantity': 90, 'measu...
# 1221  [{'ingredient': prawns, 'quantity': 90, 'measu...
# 3     [{'ingredient': oil, 'quantity': 1/4, 'measure...
# 22                                                   []
# 23                                                   []
# 30    [{'ingredient': parsley, 'quantity': 1, 'measu...
# 41    [{'ingredient': ghee, 'quantity': 40, 'measure...
# 52    [{'ingredient': sugar, 'quantity': 100, 'measu...
# 85    [{'ingredient': ginger, 'quantity': 1/4, 'meas...
# 121   [{'ingredient': oil, 'quantity': 1/4, 'measure...
# 183   [{'ingredient': baking powder, 'quantity': 1/2...
# 265   [{'ingredient': baked beans, 'quantity': 425, ...
# 284   [{'ingredient': yoghurt, 'quantity': 80, 'meas...
# 329   [{'ingredient': lighter, 'quantity': 3, 'measu...
# 339   [{'ingredient': rice, 'quantity': 2, 'measurem...
#
#                                             ingredients  energy  protein  \
# 81    [oats, milk, water, sugar, peanut butter, banana]  3463.0   64.740
# 104                                             [pesto]  1560.0    4.160
# 169            [ginger, tamari, hemp seeds, water, oil]  1095.0   52.320
# 172   [mushrooms, sugar, baking powder, salt, butter...  3440.8   63.910
# 226   [flour, carom seeds, ginger, red mirch, cumin ...  2269.9   67.205
# 230         [milk, oregano, chili flakes, jeera powder]  1521.0   29.450
# 251                                                  []     0.0    0.000
# 278   [flax seeds, coriander, urad, sesame, red chil...  1905.0   58.290
# 279   [tomato, cream, garlic, parsley, butter, parme...  1507.0   65.056
# 291                             [sugar, basil, cashews]  3943.0   21.350
# 322   [pasta, butter, flour, cream, pasta, parmesan,...  2281.9   98.215
# 334                  [oats, chia seeds, vanilla, water]  2291.0   53.260
# 362                                          [zucchini]    88.0    2.710
# 419   [cashews, garlic powder, garlic powder, onion,...  3044.0   52.480
# 449                                             [cream]   195.0    2.960
# 453                 [butter, salt, cream, tahini, salt]  3320.0   41.160
# 459      [potatoes, purple, parmigiano, parsley, olive]   463.1   11.338
# 487   [olive, salt, black pepper, parsley, oregano, ...   720.9   54.341
# 512                                                  []     0.0    0.000
# 564   [black pepper, pasta, ciliegini, basil, oil, s...   136.7    6.705
# 577                                                  []     0.0    0.000
# 592                                 [mushrooms, potato]   400.8   10.290
# 615   [powder, -sugar, -salt, -egg, butter, -vanilla...  5429.3  170.746
# 627   [oats, vanilla, cinnamon, yoghurt, chia seeds,...  4854.0   41.430
# 635         [lemon juice, tahini, olive, parsley, salt]  2673.0   20.920
# 713                 [ginger, chia seeds, pumpkin seeds]  1557.0   43.820
# 740        [butter, vanilla, salt, baking powder, milk]  2772.0   38.100
# 781   [lettuce, red wine, red wine, banana, garlic, ...   785.0   34.710
# 833   [vanilla, baking powder, baking powder, baking...  3210.0   28.410
# 926            [ginger, tamari, hemp seeds, water, oil]  1095.0   52.320
# 971   [prawns, garlic powder, chilli, coriander, ric...  2319.0   38.610
# 1072                                                 []     0.0    0.000
# 1089  [lime juice, lime juice, chili powder, onion, ...  1982.0   72.430
# 1143  [olive, maple, vanilla, flour, baking powder, ...  2451.0   30.420
# 1174     [oats, milk, vanilla, vanilla, seed, cinnamon]  4311.0   49.180
# 1220  [prawns, garlic powder, chilli, coriander, ric...  2319.0   38.610
# 1221  [prawns, garlic powder, chilli, coriander, ric...  2319.0   38.610
# 3     [oil, milk, sugar, vanilla, flour, cinnamon, b...  4347.0   35.750
# 22                                                   []     0.0    0.000
# 23                                                   []     0.0    0.000
# 30                   [parsley, harissa, pasta, yoghurt]    81.0    4.380
# 41                    [ghee, sugar, rice, flour, flour]  7674.0   29.990
# 52                                       [sugar, sugar]  3220.0    0.000
# 85                                   [ginger, turmeric]   645.0   11.500
# 121   [oil, milk, sugar, vanilla, flour, cinnamon, b...  4347.0   35.750
# 183              [baking powder, salt, butter, vanilla]  2115.0   30.290
# 265        [baked beans, parmesan, black pepper, herbs]   697.9   58.965
# 284                                  [yoghurt, vanilla]  1200.0    0.060
# 329                              [lighter, eggs, flour]   588.0   22.100
# 339   [rice, butter, carrots, brussels sprouts, blac...  2467.7   32.890
#
#       carbohydrates  sugars    sodium    fiber
# 81          219.240  115.60   549.620   18.520
# 104           6.930    0.00  1030.000    2.100
# 169          40.550    3.14  6354.000   13.100
# 172         200.320  105.72  1004.883   21.740
# 226         253.400   17.20  1358.000   54.102
# 230         238.660    0.00   161.000   96.200
# 251           0.000    0.00     0.000    0.000
# 278         101.530   10.32  1731.600   67.070
# 279          83.680    5.57  2297.996   18.491
# 291         132.450   99.80    17.000    4.900
# 322         163.180   11.40  3314.996   19.622
# 334          99.680    3.14   763.620   20.800
# 362           3.110    0.00     3.000    1.100
# 419         111.790   21.20   234.000   11.300
# 449           3.660    0.00    72.000    0.000
# 453          46.360    1.16  1155.996   14.420
# 459         101.830   14.00   107.720    8.700
# 487          87.670    0.58  1115.000   47.713
# 512           0.000    0.00     0.000    0.000
# 564          25.040    6.66  1471.000    6.226
# 577           0.000    0.00     0.000    0.000
# 592          86.660    0.00    48.591    5.400
# 615         249.871    0.00    77.168  122.260
# 627         169.200    3.14   950.620   24.300
# 635          35.420    8.30   616.000    8.200
# 713          52.000    6.28  1077.000   22.600
# 740          89.860    5.92  1115.996   12.020
# 781          83.770   34.60   657.000   12.800
# 833         172.800   16.02  1449.000    6.900
# 926          40.550    3.14  6354.000   13.100
# 971         213.700    0.00    71.000   86.500
# 1072          0.000    0.00     0.000    0.000
# 1089        119.050   27.29  3691.000   45.100
# 1143        276.300   11.26  1498.000    7.260
# 1174        163.460    3.14  1046.620   24.300
# 1220        213.700    0.00    71.000   86.500
# 1221        213.700    0.00    71.000   86.500
# 3           287.060  105.72  1504.000    8.460
# 22            0.000    0.00     0.000    0.000
# 23            0.000    0.00     0.000    0.000
# 30           14.380    5.50   475.000    5.100
# 41          323.900   99.80     2.000    5.320
# 52          199.200  199.60     2.000    0.000
# 85           84.900    0.00    40.000   24.700
# 121         287.060  105.72  1504.000    8.460
# 183          83.000    5.92  1010.996   12.020
# 265          22.480    1.49  2850.000    9.442
# 284          12.600    0.00     9.000    0.000
# 329          76.760    0.00     0.000    2.660
# 339         119.510    0.00    89.696   17.152
#
# [50 rows x 31 columns]

# %%
small_posts[['fullName', 'commentCount', 'likeCount', 'description', 'ingredient_list', 'energy', 'protein', 'carbohydrates', 'sugars', 'sodium', 'fiber']].head(6)
# Out:
#                       fullName  commentCount  likeCount  \
# 81               Anushka Lodhi             0          2
# 104              Alice & Meg 🍴             3         12
# 169  Natasha Hescott, RDN, CDN             0          1
# 172             Rainbow Piatto             1         14
# 226         Foodies Food Court            43       1819
# 230             Shivangi Gupta             4        102
#
#                                            description  \
# 81   Chocolate fudge protein oatmeal🤎 💪\nIngredient...
# 104  ⁣Caprese Chicken with Pesto 🌿🍅⠀\n⠀\nThis dish ...
# 169  Looking for a fast recipe to make for lunch? T...
# 172  Sweet & Savoury Mushroom Scones~🍄 This easy an...
# 226  Paneer Tikka Recipe😍\nSave it to try later♥️\n...
# 230  MASALA PANEER 🥰\n\nTo set the paneer why to us...
#
#                                        ingredient_list  energy  protein  \
# 81   [{'ingredient': oats, 'quantity': 1/2, 'measur...  3463.0   64.740
# 104  [{'ingredient': pesto, 'quantity': 2, 'measure...  1560.0    4.160
# 169  [{'ingredient': ginger, 'quantity': 1, 'measur...  1095.0   52.320
# 172  [{'ingredient': mushrooms, 'quantity': 200, 'm...  3440.8   63.910
# 226  [{'ingredient': flour, 'quantity': 1/2, 'measu...  2269.9   67.205
# 230  [{'ingredient': milk, 'quantity': 1, 'measurem...  1521.0   29.450
#
#      carbohydrates  sugars    sodium   fiber
# 81          219.24  115.60   549.620  18.520
# 104           6.93    0.00  1030.000   2.100
# 169          40.55    3.14  6354.000  13.100
# 172         200.32  105.72  1004.883  21.740
# 226         253.40   17.20  1358.000  54.102
# 230         238.66    0.00   161.000  96.200
