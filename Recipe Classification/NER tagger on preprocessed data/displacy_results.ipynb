# %% [markdown]
# # Displacy results

# %%
import json
import random
import pandas as pd
import numpy as np

import spacy

# %%
nlp = spacy.load("./model-best")

# %%
# Function to load in json file from LightTag
def load_json_to_df(file):
    
    results = json.load(open(file))
    
    # Create list of only those posts which have been annotated
    annotated = []
    for example in results['examples']:
        if example['annotations'] != []:
            annotated.append(example)
            
    return pd.DataFrame(annotated)


# Function to convert data into spacy format
def convert_to_spacy_format(df):
    
    TRAIN_DATA = []
    
    for index, row in df.iterrows():
        
        sentence = row['content']
        annotations_input_list = row['annotations']
        
        annotations_output_list = []
        ing_dict = {}
        
        for annotation in annotations_input_list:
            
            annotations_output_list.append((annotation['start'], annotation['end'], annotation['tag']))
        
        ing_dict['entities'] = annotations_output_list
        TRAIN_DATA.append((sentence, ing_dict))
        
    return TRAIN_DATA

# %%
TRAIN_DATA = convert_to_spacy_format(load_json_to_df('ingredient-tagger_annotations.json'))

# %%
TEST_DATA = convert_to_spacy_format(load_json_to_df('ingredient-tagger_annotations_2.json'))

# %%
test_set = []
for post, entities in TEST_DATA:
    if post not in [TRAIN_DATA[i][0] for i in range(len(TRAIN_DATA))]:
        test_set.append((post, entities))

# %%
TRAIN_DATA
# Out:
# [('masala paneer \n\nto set the paneer why to use cotton / muslin cloth when you can easily set in nyra paneer mould \n\ntap on the link to buy the product: \n\n1 . buy nyra stainless steel round paneer mould maker with top press lid (set of 3 pcs) online at low prices in india - amazon.in\n2 . nyra stainless steel round paneer mould/ mould press set of 3 piece colander price in india - buy nyra stainless steel round paneer mould/ mould press set of 3 piece colander online at flipkart.com\n3 . nyra stainless steel glossy finish round paneer mould/ mould press set of 3 - jiomart\n4 . nyra stainless steel glossy finish round paneer mould/ mould press – set of 3 (nyrakitchenware.in)\n\n ingredients: \n*1 litre milk \n*1/2 teaspoon oregano\n*1/2 teaspoon chili flakes\n*1/2 teaspoon jeera powder\n*salt as per taste\n*chat masala\n\nfollow \nno repost without permission',
#   {'entities': [(744, 756, 'INGREDIENT'),
#     (619, 625, 'INGREDIENT'),
#     (709, 712, 'QUANTITY'),
#     (696, 701, 'MEASUREMENT'),
#     (27, 33, 'INGREDIENT'),
#     (484, 485, 'QUANTITY'),
#     (313, 319, 'INGREDIENT'),
#     (722, 729, 'INGREDIENT'),
#     (562, 563, 'QUANTITY'),
#     (758, 761, 'QUANTITY'),
#     (702, 706, 'INGREDIENT'),
#     (785, 789, 'INGREDIENT'),
#     (762, 770, 'MEASUREMENT'),
#     (529, 535, 'INGREDIENT'),
#     (735, 743, 'MEASUREMENT'),
#     (771, 783, 'INGREDIENT'),
#     (444, 445, 'QUANTITY'),
#     (233, 234, 'QUANTITY'),
#     (7, 13, 'INGREDIENT'),
#     (731, 734, 'QUANTITY'),
#     (654, 655, 'QUANTITY'),
#     (152, 153, 'QUANTITY'),
#     (574, 575, 'QUANTITY'),
#     (99, 105, 'INGREDIENT'),
#     (346, 347, 'QUANTITY'),
#     (187, 193, 'INGREDIENT'),
#     (694, 695, 'QUANTITY'),
#     (411, 417, 'INGREDIENT'),
#     (713, 721, 'MEASUREMENT'),
#     (282, 283, 'QUANTITY')]}),
#  ('warm salad of purple sprouting broccoli, new potatoes and \n\ningredients:\n- 400 gram new potatoes, preferably charlotte\n- 20 gram hazelnuts, blanched\n- 200 gram purple sprouting broccoli, trimmed of its thick stalk\n- 1/2 red onion, thinly sliced (approx. 75 g)\n- 20 gram parmigiano reggiano\n- 20 gram flat leaf parsley, leaves picked from the stalk (big handful)\n- 6 basil leaves (2.5 g)\n- 1 tarragon sprig, leaves picked (1 g)\n- 1 small clove garlic\n- 2 anchovy fillet, from a tin (optional)\n- 1/2 teaspoon dijon mustard\n- 1/2 lemon, juiced, the rest kept for garnish\n\nmethod:\n1 . boil the potatoes until cooked, approx. 15 minutes, then drain.\n2 . make a garlic paste by smashing it with salt with the back of your knife. add to the picked herbs and the anchovies and chop finely. put in a bowl and mix with the mustard, lemon juice, olive oil and black pepper.\n3 . toast the hazelnuts in a dry pan for a few minutes. use a pestle and mortar or similar to coarsely crush the hazelnuts.\n4 . heat 2 tablespoon olive oil in the same frying pan. add the broccoli and sliced onion and a splash of water. cover and sauté/steam until broccoli cooked al dente. remove lid and boil off any water left in pan. season and empty into large bowl.\n5 . thickly slice the potatoes and add to the pan, with a splash more olive oil if needed. fry for a couple of minutes to reheat. season well.\n6 . add the dressing to the bowl and coat everything.',
#   {'entities': [(353, 360, 'MEASUREMENT'),
#     (1235, 1236, 'QUANTITY'),
#     (494, 497, 'QUANTITY'),
#     (389, 390, 'QUANTITY'),
#     (998, 1008, 'MEASUREMENT'),
#     (822, 833, 'INGREDIENT'),
#     (429, 430, 'QUANTITY'),
#     (645, 646, 'QUANTITY'),
#     (422, 423, 'QUANTITY'),
#     (1071, 1076, 'INGREDIENT'),
#     (462, 468, 'MEASUREMENT'),
#     (1009, 1018, 'INGREDIENT'),
#     (391, 399, 'INGREDIENT'),
#     (863, 864, 'QUANTITY'),
#     (987, 988, 'QUANTITY'),
#     (1128, 1136, 'INGREDIENT'),
#     (689, 693, 'INGREDIENT'),
#     (849, 861, 'INGREDIENT'),
#     (216, 219, 'QUANTITY'),
#     (295, 299, 'MEASUREMENT'),
#     (527, 532, 'INGREDIENT'),
#     (31, 39, 'INGREDIENT'),
#     (443, 449, 'INGREDIENT'),
#     (155, 159, 'MEASUREMENT'),
#     (310, 317, 'INGREDIENT'),
#     (976, 985, 'INGREDIENT'),
#     (129, 138, 'INGREDIENT'),
#     (75, 78, 'QUANTITY'),
#     (507, 520, 'INGREDIENT'),
#     (364, 365, 'QUANTITY'),
#     (452, 453, 'QUANTITY'),
#     (656, 662, 'INGREDIENT'),
#     (262, 264, 'QUANTITY'),
#     (45, 53, 'INGREDIENT'),
#     (577, 578, 'QUANTITY'),
#     (366, 371, 'INGREDIENT'),
#     (1051, 1059, 'INGREDIENT'),
#     (437, 442, 'MEASUREMENT'),
#     (1093, 1098, 'INGREDIENT'),
#     (1257, 1265, 'INGREDIENT'),
#     (454, 461, 'INGREDIENT'),
#     (380, 383, 'QUANTITY'),
#     (998, 1008, 'QUANTITY'),
#     (877, 886, 'INGREDIENT'),
#     (124, 128, 'MEASUREMENT'),
#     (1182, 1187, 'INGREDIENT'),
#     (254, 256, 'QUANTITY'),
#     (996, 997, 'QUANTITY'),
#     (220, 229, 'INGREDIENT'),
#     (265, 269, 'MEASUREMENT'),
#     (590, 598, 'INGREDIENT'),
#     (835, 844, 'INGREDIENT'),
#     (177, 185, 'INGREDIENT'),
#     (121, 123, 'QUANTITY'),
#     (88, 96, 'INGREDIENT'),
#     (1305, 1314, 'INGREDIENT'),
#     (498, 506, 'MEASUREMENT'),
#     (270, 280, 'INGREDIENT'),
#     (523, 526, 'QUANTITY'),
#     (380, 381, 'QUANTITY'),
#     (79, 83, 'MEASUREMENT'),
#     (151, 154, 'QUANTITY'),
#     (292, 294, 'QUANTITY'),
#     (741, 746, 'INGREDIENT')]}),
#  ('if you are looking to bring a yummy pasta salad to the next outdoor summer bbq, try out this amazing grilled ratatouille pasta salad!\n\ningredients: \n\n∙ 2 medium zucchini (about 11/2 lb.), halved lengthwise\n∙ about 1 pound adagio eggplants , cut into 1 " wedges\n∙ 3/4 cup extra-virgin olive oil, divided\n∙ 21/2 teaspoon. kosher salt, divided\n∙ 1 teaspoon. freshly ground black pepper, divided\n∙ 10 ounce penne or casarecce pasta\n∙ 1 large or 2 medium heirloom or virtuoso beefsteak tomatoes (about 1 lb.), cut into 1 " piece\n∙ 8 ounce ciliegini (mini fresh mozzarella balls), drained, halved\n∙ 2 tablespoon. white balsamic or white wine vinegar\n∙ 1 tablespoon. thyme leaves\n∙ 1 cup basil leaves\n\ninstructions:\n\n1 . prepare a grill for medium heat. toss zucchini, eggplant, and 1/4 cup oil on a rimmed baking sheet; season with 1 teaspoon. salt and 1/2 teaspoon. pepper. grill, turning often, until steamy, tender, and charred all over, 8–12 minutes. return to the baking sheet and let cool.\n\n2 . cook pasta according to package directions.\n\n3 . slice grilled vegetables into bite-size piece and transfer to a large bowl. add tomato, cheese, vinegar, thyme, and 11/2 teaspoon. salt, 1/2 teaspoon. pepper, and 1/2 cup oil and mix to combine. drain pasta and immediately add to the bowl with vegetables. mix well to combine, then top with basil.\n\nthank you to for the fantastic recipe and beautiful image!\n\nlooking for more recipes? we are officially announcing that windset farms is now on tiktok! find our account via the link in our bio. head over to find more recipes!',
#   {'entities': [(595, 605, 'MEASUREMENT'),
#     (861, 867, 'INGREDIENT'),
#     (1140, 1147, 'INGREDIENT'),
#     (152, 153, 'QUANTITY'),
#     (121, 126, 'INGREDIENT'),
#     (752, 760, 'INGREDIENT'),
#     (343, 344, 'QUANTITY'),
#     (1000, 1005, 'INGREDIENT'),
#     (263, 264, 'QUANTITY'),
#     (1195, 1201, 'INGREDIENT'),
#     (1207, 1210, 'QUANTITY'),
#     (528, 533, 'MEASUREMENT'),
#     (177, 181, 'QUANTITY'),
#     (1245, 1250, 'INGREDIENT'),
#     (499, 501, 'MEASUREMENT'),
#     (593, 594, 'QUANTITY'),
#     (826, 827, 'QUANTITY'),
#     (556, 566, 'INGREDIENT'),
#     (625, 643, 'INGREDIENT'),
#     (660, 665, 'INGREDIENT'),
#     (310, 318, 'MEASUREMENT'),
#     (828, 836, 'MEASUREMENT'),
#     (284, 293, 'INGREDIENT'),
#     (265, 266, 'QUANTITY'),
#     (327, 331, 'INGREDIENT'),
#     (776, 779, 'QUANTITY'),
#     (422, 427, 'INGREDIENT'),
#     (1335, 1340, 'INGREDIENT'),
#     (1160, 1164, 'QUANTITY'),
#     (250, 251, 'QUANTITY'),
#     (1132, 1138, 'INGREDIENT'),
#     (36, 41, 'INGREDIENT'),
#     (1019, 1026, 'MEASUREMENT'),
#     (851, 859, 'MEASUREMENT'),
#     (345, 353, 'MEASUREMENT'),
#     (514, 515, 'QUANTITY'),
#     (1165, 1173, 'MEASUREMENT'),
#     (1124, 1130, 'INGREDIENT'),
#     (780, 783, 'MEASUREMENT'),
#     (1149, 1154, 'INGREDIENT'),
#     (397, 402, 'MEASUREMENT'),
#     (1211, 1214, 'MEASUREMENT'),
#     (762, 770, 'INGREDIENT'),
#     (1181, 1184, 'QUANTITY'),
#     (370, 382, 'INGREDIENT'),
#     (182, 184, 'MEASUREMENT'),
#     (677, 680, 'MEASUREMENT'),
#     (394, 396, 'QUANTITY'),
#     (648, 658, 'MEASUREMENT'),
#     (305, 309, 'QUANTITY'),
#     (710, 711, 'QUANTITY'),
#     (675, 676, 'QUANTITY'),
#     (991, 992, 'QUANTITY'),
#     (847, 850, 'QUANTITY'),
#     (214, 215, 'QUANTITY'),
#     (430, 431, 'QUANTITY'),
#     (1185, 1193, 'MEASUREMENT'),
#     (267, 270, 'MEASUREMENT'),
#     (161, 169, 'INGREDIENT'),
#     (481, 489, 'INGREDIENT'),
#     (441, 442, 'QUANTITY'),
#     (646, 647, 'QUANTITY'),
#     (838, 842, 'INGREDIENT'),
#     (497, 498, 'QUANTITY'),
#     (1040, 1041, 'QUANTITY'),
#     (681, 686, 'INGREDIENT'),
#     (1175, 1179, 'INGREDIENT'),
#     (308, 309, 'QUANTITY')]}),
#  ("need an easy brunch recipe? this plant-based breakfast casserole is so simple and so tasty! it’s a great vegan recipe for brunch and it feeds at least 8 people. and the key to this dish, is the savory kick from the plant-based loca foods potato queso! it is just such a delicious recipe! so whether or not your guests are vegetarian, vegan, or meat-eaters, they’ll enjoy this dish! \n\nget these ingredients, and try this recipe for your breakfast tomorrow, it won't disappoint!\n\ngluten-free plant-based breakfast casserole recipe:\ningredients:\n▢gluten-free nonstick cooking spray\n▢1 (30 -ounce) package of frozen gluten-free hash browns\n▢1 onion, diced\n▢1 red bell pepper, seeded, deveined, and diced\n▢8 ounce sliced mushrooms, baby bellas (cremini), or white\n▢2 cup chopped kale or spinach\n▢11/2 jars potato queso, mild or spicy\n▢smoked paprika\nus customary - metric\n\ninstructions:\n1 . preheat the oven to 350 degrees. spray a 9x12 -inch casserole dish with cooking spray.\n\n2 . in a large bowl, combine the hashbrowns with the onion, bell pepper, mushrooms, and kale. add the queso and mix well. pour into the prepared dish and sprinkle with paprika. bake for 30-40 minutes or until everything is hot.\n\nfind the full recipe on our gluten-free and allergen-friendly recipe blog at glutenfreeandmore.com in the link in our bio!\n-\n-\n-",
#   {'entities': [(1039, 1045, 'INGREDIENT'),
#     (703, 708, 'MEASUREMENT'),
#     (637, 638, 'QUANTITY'),
#     (791, 795, 'QUANTITY'),
#     (760, 761, 'QUANTITY'),
#     (701, 702, 'QUANTITY'),
#     (837, 844, 'INGREDIENT'),
#     (1163, 1165, 'QUANTITY'),
#     (774, 778, 'INGREDIENT'),
#     (639, 644, 'INGREDIENT'),
#     (906, 909, 'QUANTITY'),
#     (716, 725, 'INGREDIENT'),
#     (583, 585, 'QUANTITY'),
#     (594, 601, 'MEASUREMENT'),
#     (762, 765, 'MEASUREMENT'),
#     (653, 654, 'QUANTITY'),
#     (1062, 1066, 'INGREDIENT'),
#     (624, 635, 'INGREDIENT'),
#     (1047, 1056, 'INGREDIENT'),
#     (974, 975, 'QUANTITY'),
#     (782, 789, 'INGREDIENT'),
#     (587, 592, 'MEASUREMENT'),
#     (882, 883, 'QUANTITY'),
#     (664, 670, 'INGREDIENT'),
#     (1027, 1032, 'INGREDIENT'),
#     (796, 800, 'MEASUREMENT'),
#     (580, 581, 'QUANTITY'),
#     (1007, 1017, 'INGREDIENT'),
#     (1142, 1149, 'INGREDIENT'),
#     (801, 813, 'INGREDIENT'),
#     (1160, 1162, 'QUANTITY')]}),
#  ("spicy tuna pancake/gochu-chamchi jeon!(고추참치전) \n\nsharing another easy and tasty dish you can enjoy any day of the week! recently, you guys may have seen my story photos, i had received a wonderful box of korean products from . it included a nice variety of pantry items from korea: like roasted seaweed, canned tuna, seaweed crackers, nori sheets and more! thanks to them i was able to make this delicious jeon!! recipe below!\n\ningredients:\ngochu chamchi (spicy tuna) 1 can \n1/2 c diced onion\n1/2 t garlic minced\n2 t scallion, chopped\n3/4 buchim garoo (korean pancake mix)\npinch black pepper\n\n1 )open can and drain tuna for 5-10 min \n2 )combine all ingredients into a mixing bowl, without over mixing. \n3 )heat pan and cook jeon until golden brown on both sides, in med low heat. drop about 2 tablespoon for each jeon. makes about 9 pc. total. enjoy with favorite dipping sauce!! \n\nthese were super tasty and not fishy at all!! i didn't need to add any salt or seasoning since the canned tuna was already seasoned and had a nice savory kick to it! \n\nand look for these brands if you want to try some high quality korean seafood!!\n.\n.\n.",
#   {'entities': [(467, 468, 'QUANTITY'),
#     (498, 504, 'INGREDIENT'),
#     (790, 791, 'QUANTITY'),
#     (512, 513, 'QUANTITY'),
#     (440, 453, 'INGREDIENT'),
#     (534, 535, 'QUANTITY'),
#     (702, 703, 'QUANTITY'),
#     (492, 495, 'QUANTITY'),
#     (952, 956, 'INGREDIENT'),
#     (578, 590, 'INGREDIENT'),
#     (623, 624, 'QUANTITY'),
#     (486, 491, 'INGREDIENT'),
#     (633, 634, 'QUANTITY'),
#     (536, 537, 'QUANTITY'),
#     (516, 524, 'INGREDIENT'),
#     (474, 477, 'QUANTITY'),
#     (324, 332, 'INGREDIENT'),
#     (538, 550, 'INGREDIENT'),
#     (625, 627, 'QUANTITY'),
#     (792, 802, 'MEASUREMENT'),
#     (572, 577, 'MEASUREMENT'),
#     (461, 465, 'INGREDIENT'),
#     (469, 472, 'MEASUREMENT'),
#     (592, 593, 'QUANTITY')]}),
#  ('prawn taco bowl\n\neating keto is simple\u2060\n- less carbs\u2060\n- more healthy fats\u2060\n- easy and delicious recipes\u2060\n- happy and healthy lifestyle choice\u2060\n.\nif you don\'t know how to start ketodiet properly or do you want to lose possibly 5-10 pound in the first week alone with keto ?? join "custom keto diet". link in bio .hk\n\nperfect for a hot summer’s day, this is my spiced prawn bowl with lime rice and homemade guacamole. \n\nshrimp spices:\n90 gram raw king prawns \njuice of 1/2 lime \n1/2 teaspoon garlic powder \n1/2 teaspoon chilli powder \n1/2 teaspoon coriander powder \nfry for 2 minutes until pink. \n\nsimple guacamole:\n1/2 avocado \n1/4 red chilli, diced \nseason to taste with lime juice and salt\n\nlime rice: \n125 gram cooked long grain rice \nseasoned with a pinch of salt, juice of 1/2 lime and 2 teaspoon chopped coriander. \n\nother ingredients:\nchopped lettuce, sliced jalapeños, extra coriander chopped tomatoes and cucumber, cheese of choice. \n\nassemble and serve. \n—————————————————————-',
#   {'entities': [(537, 545, 'MEASUREMENT'),
#     (697, 701, 'INGREDIENT'),
#     (731, 735, 'INGREDIENT'),
#     (228, 230, 'QUANTITY'),
#     (618, 625, 'INGREDIENT'),
#     (572, 573, 'QUANTITY'),
#     (614, 617, 'QUANTITY'),
#     (509, 517, 'MEASUREMENT'),
#     (671, 681, 'INGREDIENT'),
#     (490, 503, 'INGREDIENT'),
#     (923, 929, 'INGREDIENT'),
#     (425, 431, 'INGREDIENT'),
#     (631, 641, 'INGREDIENT'),
#     (505, 508, 'QUANTITY'),
#     (226, 227, 'QUANTITY'),
#     (790, 791, 'QUANTITY'),
#     (686, 690, 'INGREDIENT'),
#     (546, 555, 'INGREDIENT'),
#     (849, 856, 'INGREDIENT'),
#     (753, 758, 'MEASUREMENT'),
#     (792, 800, 'MEASUREMENT'),
#     (762, 766, 'INGREDIENT'),
#     (467, 470, 'QUANTITY'),
#     (477, 480, 'QUANTITY'),
#     (533, 536, 'QUANTITY'),
#     (481, 489, 'MEASUREMENT'),
#     (433, 435, 'QUANTITY'),
#     (882, 891, 'INGREDIENT'),
#     (387, 391, 'INGREDIENT'),
#     (809, 818, 'INGREDIENT'),
#     (704, 707, 'QUANTITY'),
#     (777, 780, 'QUANTITY'),
#     (900, 908, 'INGREDIENT'),
#     (913, 921, 'INGREDIENT'),
#     (450, 456, 'INGREDIENT'),
#     (436, 440, 'MEASUREMENT'),
#     (708, 712, 'MEASUREMENT'),
#     (865, 874, 'INGREDIENT'),
#     (518, 524, 'INGREDIENT'),
#     (627, 630, 'QUANTITY')]}),
#  ('• lunch (or dinner) idea •\n\nthe most amazing toasted sarnie, yesterday i really didn’t fancy using the oven as it was so hot! so whipped up these tomato & mozzarella toasties instead and boy were they good \n\ningredients:\nsourdough bread\npesto\nlarge tomatoes \nmozzarella \nroasted red peppers\n\nmethod:\nspread pesto onto each slice of bread, add one slice of bread to your george foreman grill, top with tomatoes, mozzarella & peppers then add second slice of bread & close grill. leave for 2-3 mins until cheese has melted & tomatoes have softened.\n\ncalories per serving approx: 492 kcals\n\ni’d love to hear if you give this lunch idea a try and don’t forget to tag me in your foodie pictures \n\nemma',
#   {'entities': [(237, 242, 'INGREDIENT'),
#     (503, 509, 'INGREDIENT'),
#     (401, 409, 'INGREDIENT'),
#     (332, 337, 'INGREDIENT'),
#     (259, 269, 'INGREDIENT'),
#     (307, 312, 'INGREDIENT'),
#     (279, 290, 'INGREDIENT'),
#     (356, 361, 'INGREDIENT'),
#     (231, 236, 'INGREDIENT'),
#     (155, 165, 'INGREDIENT'),
#     (457, 462, 'INGREDIENT'),
#     (411, 421, 'INGREDIENT'),
#     (249, 257, 'INGREDIENT'),
#     (488, 489, 'QUANTITY'),
#     (146, 152, 'INGREDIENT'),
#     (490, 491, 'QUANTITY'),
#     (523, 531, 'INGREDIENT')]}),
#  ('this wild rice pilaf recipe creates a side dish that’s full of delicious flavor while being an easy and healthy! \n\nsave this post! full recipe below! \n\ningredients: \n\n2 cup wild rice blend (such as lundgren’s)\nregular strength chicken or vegetable broth (enough to use instead of water, for cooking rice according to package instructions)\n1/4 cup salted butter, sliced\n1 large onion, chopped\n1 cup thinly sliced baby carrots\n2 cup freshly shaved brussels sprouts\n4 garlic clove, minced\n1 teaspoon dry italian seasoning\n1/4 teaspoon freshly ground black pepper\n\ninstructions: \n\ncook rice according to package instructions, using the broth instead of water. when cook time is up, do not open lid; turn heat off and keep lid tightly covered for 10 minutes to allow continued steaming. if rice is still a bit too firm, mix in just enough extra broth to moisten all rice, cover, and simmer another 10 minutes.\nwhile rice is cooking, add butter to a large/deep skillet over medium high heat. once butter is melted and starting to bubble, add onion and carrots. stir to combine. cover and cook 5 minutes, stirring occasionally. add brussels sprouts, garlic, italian seasoning, and black pepper, stirring another 2 minutes until softened. \ncheck rice for doneness. fluff with fork and add to skillet with vegetable mixture, stirring to incorporate. taste and season with kosher salt and freshly ground black pepper as needed.',
#   {'entities': [(317, 324, 'MEASUREMENT'),
#     (893, 895, 'QUANTITY'),
#     (1238, 1242, 'INGREDIENT'),
#     (742, 744, 'QUANTITY'),
#     (861, 865, 'INGREDIENT'),
#     (1394, 1406, 'INGREDIENT'),
#     (991, 997, 'INGREDIENT'),
#     (427, 430, 'MEASUREMENT'),
#     (1046, 1053, 'INGREDIENT'),
#     (1125, 1141, 'INGREDIENT'),
#     (280, 285, 'INGREDIENT'),
#     (1143, 1149, 'INGREDIENT'),
#     (354, 360, 'INGREDIENT'),
#     (446, 462, 'INGREDIENT'),
#     (392, 393, 'QUANTITY'),
#     (465, 471, 'INGREDIENT'),
#     (600, 607, 'MEASUREMENT'),
#     (463, 464, 'QUANTITY'),
#     (10, 14, 'INGREDIENT'),
#     (167, 168, 'QUANTITY'),
#     (425, 426, 'QUANTITY'),
#     (417, 424, 'INGREDIENT'),
#     (1036, 1041, 'INGREDIENT'),
#     (339, 342, 'QUANTITY'),
#     (932, 938, 'INGREDIENT'),
#     (394, 397, 'MEASUREMENT'),
#     (227, 234, 'INGREDIENT'),
#     (547, 559, 'INGREDIENT'),
#     (1205, 1206, 'QUANTITY'),
#     (519, 522, 'QUANTITY'),
#     (911, 915, 'INGREDIENT'),
#     (649, 654, 'INGREDIENT'),
#     (785, 789, 'INGREDIENT'),
#     (178, 182, 'INGREDIENT'),
#     (343, 346, 'MEASUREMENT'),
#     (1087, 1088, 'QUANTITY'),
#     (369, 370, 'QUANTITY'),
#     (1370, 1374, 'INGREDIENT'),
#     (486, 487, 'QUANTITY'),
#     (488, 496, 'MEASUREMENT'),
#     (523, 531, 'MEASUREMENT'),
#     (582, 586, 'INGREDIENT'),
#     (169, 172, 'MEASUREMENT'),
#     (299, 303, 'INGREDIENT'),
#     (1174, 1186, 'INGREDIENT'),
#     (377, 382, 'INGREDIENT'),
#     (472, 477, 'MEASUREMENT')]}),
#  ('recipe time!!\n\nboil your lasagna for 5-7 minutes and run cold water over it once its boiled! keep it aside.\n\nchicken minced ingredients: \n\n- half kg chicken minced\n- 1 medium sized onion finely chopped \n- 3-4 medium sized tomatoes (paste)\n- ginger garlic paste 2 tb spoon (because i loveee)\n- salt (as per taste)\n- paprika powder, 1 tb spoon (or as per your taste)\n- oregano (half tea spoon)\n- mixed herms (as per your liking)\n- soya sauce 1 tb spoon\n- chilli sauce 1 tb spoon\n- chilli garlic ketchup (3-4 tb spoons )\n\nmethod: sauté your onion in half tb spoon oil, add ginger garlic paste and cook it until your onion becomes transparent, add chicken minced and sauté nicely for about 4-5 mins, add tomato paste, all the spices and sauces and let it cook for almost 20 mins or until the water dries up.\n\nwhite sauce ingredients:\n- butter (3-4 tb spoon)\n- maida- all purpose flour - (4-5 tb spoon)\n- milk around 1-1 .5 cup, depends on your consistency\n- black pepper (1 tea spoon)\n- salt (as per your liking)\n- white pepper (1 tea spoon)\n- oregano (half tea spoon)\n- mixed herbs (half tea spoon)\n\nmethod: add butter in your pan, once its melted, add flour and keep wisking, gradually add milk while mixing the mixture, add all your spices and herbs, make sure you’re continuously mixing so there’s no lumps in the sauce. once you get your desired consistency, turn off the flame. \n\npreparation: in a ovenproof dish, make a layer of your lasagna sheets, top it with your minced mixture, drop some white sauce on it, garnish with mushrooms and olives, put some (a lot) cheese, i used mozzarella and cheddar!\n\nkeep repeating the layers! make the last layer of lasagna sheet, mushrooms, olives, oregano and cheese.\nbake it for 20-25 mins, once its done, broil it for 5-7 mins or once the cheese is completely melted and the crust is nicely golden! \n\ntadaaa! done.\n\n.\n.\n.\n.\n.\n.\n.',
#   {'entities': [(241, 247, 'INGREDIENT'),
#     (968, 969, 'QUANTITY'),
#     (1672, 1681, 'INGREDIENT'),
#     (181, 186, 'INGREDIENT'),
#     (109, 116, 'INGREDIENT'),
#     (149, 156, 'INGREDIENT'),
#     (261, 262, 'QUANTITY'),
#     (847, 852, 'MEASUREMENT'),
#     (205, 206, 'QUANTITY'),
#     (1567, 1573, 'INGREDIENT'),
#     (1784, 1790, 'INGREDIENT'),
#     (912, 913, 'QUANTITY'),
#     (900, 904, 'INGREDIENT'),
#     (445, 450, 'MEASUREMENT'),
#     (207, 208, 'QUANTITY'),
#     (331, 332, 'QUANTITY'),
#     (570, 576, 'INGREDIENT'),
#     (577, 583, 'INGREDIENT'),
#     (367, 374, 'INGREDIENT'),
#     (1582, 1592, 'INGREDIENT'),
#     (1049, 1053, 'QUANTITY'),
#     (1691, 1698, 'INGREDIENT'),
#     (266, 271, 'MEASUREMENT'),
#     (700, 706, 'INGREDIENT'),
#     (832, 838, 'INGREDIENT'),
#     (385, 390, 'MEASUREMENT'),
#     (686, 687, 'QUANTITY'),
#     (486, 492, 'INGREDIENT'),
#     (453, 465, 'INGREDIENT'),
#     (336, 341, 'MEASUREMENT'),
#     (293, 297, 'INGREDIENT'),
#     (891, 896, 'MEASUREMENT'),
#     (954, 966, 'INGREDIENT'),
#     (1067, 1078, 'INGREDIENT'),
#     (1597, 1604, 'INGREDIENT'),
#     (914, 915, 'QUANTITY'),
#     (886, 887, 'QUANTITY'),
#     (788, 793, 'INGREDIENT'),
#     (914, 918, 'QUANTITY'),
#     (722, 728, 'INGREDIENT'),
#     (376, 380, 'QUANTITY'),
#     (429, 439, 'INGREDIENT'),
#     (840, 841, 'QUANTITY'),
#     (1703, 1709, 'INGREDIENT'),
#     (1528, 1537, 'INGREDIENT'),
#     (1232, 1238, 'INGREDIENT'),
#     (466, 467, 'QUANTITY'),
#     (842, 843, 'QUANTITY'),
#     (613, 618, 'INGREDIENT'),
#     (1031, 1036, 'MEASUREMENT'),
#     (1058, 1063, 'MEASUREMENT'),
#     (1188, 1192, 'INGREDIENT'),
#     (440, 441, 'QUANTITY'),
#     (538, 543, 'INGREDIENT'),
#     (248, 254, 'INGREDIENT'),
#     (547, 551, 'QUANTITY'),
#     (222, 230, 'INGREDIENT'),
#     (471, 476, 'MEASUREMENT'),
#     (1683, 1689, 'INGREDIENT'),
#     (919, 922, 'MEASUREMENT'),
#     (644, 651, 'INGREDIENT'),
#     (504, 505, 'QUANTITY'),
#     (166, 167, 'QUANTITY'),
#     (1089, 1094, 'MEASUREMENT'),
#     (141, 145, 'QUANTITY'),
#     (502, 503, 'QUANTITY'),
#     (1542, 1548, 'INGREDIENT'),
#     (555, 560, 'MEASUREMENT'),
#     (493, 500, 'INGREDIENT'),
#     (875, 880, 'INGREDIENT'),
#     (479, 485, 'INGREDIENT'),
#     (1243, 1248, 'INGREDIENT'),
#     (561, 564, 'INGREDIENT'),
#     (146, 148, 'MEASUREMENT'),
#     (1109, 1115, 'INGREDIENT'),
#     (1150, 1155, 'INGREDIENT'),
#     (1040, 1047, 'INGREDIENT'),
#     (1025, 1026, 'QUANTITY'),
#     (1017, 1023, 'INGREDIENT'),
#     (884, 885, 'QUANTITY'),
#     (1080, 1084, 'QUANTITY'),
#     (62, 67, 'INGREDIENT'),
#     (983, 987, 'INGREDIENT'),
#     (974, 979, 'MEASUREMENT'),
#     (315, 322, 'INGREDIENT')]}),
#  ('paneer matar pulao\nsave it to try later\n\ningredients :-\nfor barista/fried onion - oil + finely sliced onion\nfry it till turns golden and take it out\n\nfor pulao -\noil - 2 tablespoon\nghee - 2 tablespoon\nwhole spices\nchopped onion - 1 \nchopped green chillies\nginger garlic paste - 1 tablespoon\ngreen peas - 1 cup\nchopped carrot - half\nsalt as per taste\nturmeric powder - 1/2 teaspoon\nred chilli powder - 1 teaspoon\nbiryani masala - 1 tablespoon\nsoaked basmati rice - 1 cup\nwater - 1 & 1/2 cup\nfried paneer - 200 grams\nroasted dry fruits\nfried barista\nchopped coriander leaves\nmint leaves\nghee - 1 tablespoon\nsaffron water - 1 tablespoon\ncover the lid & cook over medium flame for 1 whistle.\nserve it with raita and enjoy.!!\n\nfollow for more instant and daily recipes \n\nsong copyright',
#   {'entities': [(280, 290, 'MEASUREMENT'),
#     (573, 577, 'INGREDIENT'),
#     (350, 358, 'INGREDIENT'),
#     (181, 185, 'INGREDIENT'),
#     (613, 618, 'INGREDIENT'),
#     (168, 169, 'QUANTITY'),
#     (241, 255, 'INGREDIENT'),
#     (466, 469, 'MEASUREMENT'),
#     (449, 461, 'INGREDIENT'),
#     (540, 547, 'INGREDIENT'),
#     (188, 189, 'QUANTITY'),
#     (207, 213, 'INGREDIENT'),
#     (372, 380, 'MEASUREMENT'),
#     (403, 411, 'MEASUREMENT'),
#     (170, 180, 'MEASUREMENT'),
#     (256, 262, 'INGREDIENT'),
#     (368, 371, 'QUANTITY'),
#     (429, 430, 'QUANTITY'),
#     (478, 479, 'QUANTITY'),
#     (102, 107, 'INGREDIENT'),
#     (74, 79, 'INGREDIENT'),
#     (486, 489, 'MEASUREMENT'),
#     (401, 402, 'QUANTITY'),
#     (482, 485, 'QUANTITY'),
#     (263, 269, 'INGREDIENT'),
#     (278, 279, 'QUANTITY'),
#     (594, 604, 'MEASUREMENT'),
#     (592, 593, 'QUANTITY'),
#     (222, 227, 'INGREDIENT'),
#     (621, 622, 'QUANTITY'),
#     (304, 305, 'QUANTITY'),
#     (431, 441, 'MEASUREMENT'),
#     (381, 398, 'INGREDIENT'),
#     (332, 336, 'INGREDIENT'),
#     (470, 475, 'INGREDIENT'),
#     (464, 465, 'QUANTITY'),
#     (556, 565, 'INGREDIENT'),
#     (306, 309, 'MEASUREMENT'),
#     (623, 633, 'MEASUREMENT'),
#     (496, 502, 'INGREDIENT'),
#     (677, 678, 'QUANTITY'),
#     (297, 301, 'INGREDIENT'),
#     (318, 324, 'INGREDIENT'),
#     (190, 200, 'MEASUREMENT'),
#     (412, 426, 'INGREDIENT'),
#     (585, 589, 'INGREDIENT'),
#     (327, 331, 'QUANTITY'),
#     (230, 231, 'QUANTITY'),
#     (162, 165, 'INGREDIENT')]}),
#  ('pan fried chicken with creamy mustard sauce recipe \n.\na super quick and easy dinner! we served ours with some fluffy spring onion mash but rice would work well as well! \n.\ningredients:\n2 chicken breasts\nsalt and pepper\ngarlic granules\n200 ml single cream\n3 teaspoon wholegrain mustard\nmash or rice to serve\n.\nseason both sides of the chicken breasts with salt, pepper and some garlic granules. \nheat a little oil in a griddle pan and fry the chicken breasts for 7-8 mins each side until fully cooked timing will vary depending on size and thickness of the chicken breast.\nremove the chicken from the pan and add the cream, mustard and a pinch of black pepper to the pan and mix well.\nslice the chicken and serve on top of rice or mash. \nonce the sauce is heated through pour over the chicken and enjoy! \n.\n.\n.\n.\n.',
#   {'entities': [(124, 129, 'INGREDIENT'),
#     (616, 621, 'INGREDIENT'),
#     (255, 256, 'QUANTITY'),
#     (334, 341, 'INGREDIENT'),
#     (784, 791, 'INGREDIENT'),
#     (293, 297, 'INGREDIENT'),
#     (187, 194, 'INGREDIENT'),
#     (185, 186, 'QUANTITY'),
#     (257, 265, 'MEASUREMENT'),
#     (242, 254, 'INGREDIENT'),
#     (235, 238, 'QUANTITY'),
#     (139, 143, 'INGREDIENT'),
#     (637, 642, 'MEASUREMENT'),
#     (583, 590, 'INGREDIENT'),
#     (117, 129, 'INGREDIENT'),
#     (239, 241, 'MEASUREMENT'),
#     (361, 367, 'INGREDIENT'),
#     (442, 449, 'INGREDIENT'),
#     (722, 726, 'INGREDIENT'),
#     (10, 17, 'INGREDIENT'),
#     (377, 383, 'INGREDIENT'),
#     (219, 225, 'INGREDIENT'),
#     (646, 658, 'INGREDIENT'),
#     (355, 359, 'INGREDIENT'),
#     (623, 630, 'INGREDIENT'),
#     (694, 701, 'INGREDIENT'),
#     (556, 570, 'INGREDIENT'),
#     (212, 218, 'INGREDIENT'),
#     (277, 284, 'INGREDIENT'),
#     (203, 207, 'INGREDIENT')]}),
#  ("oreo blondies recipe \u2060\n\u2060\nyou will thank me later once you try this recipe for yourself, but then later curse me because you easily demolished a whole tray! \u2060\n\u2060\noreos by themselves are a delicious treat, but this oreo blondie recipe takes them to a whole new level that you just have to try.\u2060\n\u2060\ningredients:\u2060\n\u2060\n 2 1 /4 cup plain flour\u2060\n 1 teaspoon salt\u2060\n 1/2 teaspoon bi carb soda\u2060\n 3/4 cup vegan butter, melted\u2060\n 1 cup sugar\u2060\n 3/4 cup brown sugar\u2060\n 2 flax 'eggs' (to make 1 flax egg combine 1 tablespoon ground flaxseed and 3 tablespoon)\u2060\n 1 teaspoon vanilla extract\u2060\n 1 1 /2 cup oreos, crumbled \u2060\n\u2060\nmethod\u2060\n\u2060\n preheat oven to 180 °. in a small bowl, mix together 2 tablespoon of ground flaxseed and 6 tablespoon of water. put aside and allow 'eggs' to thicken.\u2060\n\u2060\n in a mixing bowl, sift flour, salt and bi carb soda.\u2060\n\u2060\n in a separate mixing bowl, fork mix together melted butter, sugar, brown sugar, flax eggs and vanilla.\u2060\n\u2060\n add in flour mixture and mix together until well combined. fold in a cup of crushed oreos.\u2060\n\u2060\n in a prepared rectangle baking tray (baking paper/lightly greased), evenly spread in batter. top with the remaining oreos and bake in oven for about 25 minutes or until lightly golden.\u2060\n\u2060\n allow to cool in baking tray for a further 10 minutes, and then place on a baking rack until completely cooled before cutting.\u2060\n\u2060",
#   {'entities': [(937, 942, 'INGREDIENT'),
#     (576, 579, 'MEASUREMENT'),
#     (441, 446, 'INGREDIENT'),
#     (457, 461, 'INGREDIENT'),
#     (338, 346, 'MEASUREMENT'),
#     (664, 665, 'QUANTITY'),
#     (474, 478, 'INGREDIENT'),
#     (328, 333, 'INGREDIENT'),
#     (358, 366, 'MEASUREMENT'),
#     (415, 418, 'MEASUREMENT'),
#     (700, 701, 'QUANTITY'),
#     (666, 676, 'MEASUREMENT'),
#     (160, 165, 'INGREDIENT'),
#     (917, 924, 'INGREDIENT'),
#     (384, 385, 'QUANTITY'),
#     (367, 379, 'INGREDIENT'),
#     (427, 428, 'QUANTITY'),
#     (903, 907, 'INGREDIENT'),
#     (716, 721, 'INGREDIENT'),
#     (386, 389, 'MEASUREMENT'),
#     (744, 748, 'INGREDIENT'),
#     (396, 402, 'INGREDIENT'),
#     (313, 314, 'QUANTITY'),
#     (999, 1002, 'MEASUREMENT'),
#     (524, 525, 'QUANTITY'),
#     (0, 4, 'INGREDIENT'),
#     (431, 434, 'MEASUREMENT'),
#     (413, 414, 'QUANTITY'),
#     (627, 630, 'QUANTITY'),
#     (702, 712, 'MEASUREMENT'),
#     (580, 585, 'INGREDIENT'),
#     (212, 216, 'INGREDIENT'),
#     (316, 317, 'QUANTITY'),
#     (908, 912, 'INGREDIENT'),
#     (336, 337, 'QUANTITY'),
#     (687, 695, 'INGREDIENT'),
#     (540, 541, 'QUANTITY'),
#     (347, 351, 'INGREDIENT'),
#     (1014, 1019, 'INGREDIENT'),
#     (382, 383, 'QUANTITY'),
#     (493, 503, 'MEASUREMENT'),
#     (491, 492, 'QUANTITY'),
#     (526, 536, 'MEASUREMENT'),
#     (419, 424, 'INGREDIENT'),
#     (896, 901, 'INGREDIENT'),
#     (479, 482, 'INGREDIENT'),
#     (883, 888, 'INGREDIENT'),
#     (472, 473, 'QUANTITY'),
#     (551, 566, 'INGREDIENT'),
#     (1257, 1259, 'QUANTITY'),
#     (571, 575, 'QUANTITY'),
#     (796, 800, 'INGREDIENT'),
#     (449, 450, 'QUANTITY'),
#     (542, 550, 'MEASUREMENT'),
#     (311, 312, 'QUANTITY'),
#     (789, 794, 'INGREDIENT'),
#     (318, 321, 'MEASUREMENT'),
#     (429, 430, 'QUANTITY'),
#     (875, 881, 'INGREDIENT'),
#     (1174, 1176, 'QUANTITY'),
#     (569, 570, 'QUANTITY'),
#     (451, 455, 'INGREDIENT'),
#     (1141, 1146, 'INGREDIENT'),
#     (354, 357, 'QUANTITY')]}),
#  ('this looks absolutely amazing! what do you think? repost from \n•\ncrescent roll taco ring - a fun idea for taco tuesday! such an easy dinner idea and i’m already thinking about what else i can make inside a crescent dough wreath! \n\nserve with your favorite taco toppings! i used lettuce, sour cream, tomatoes and cheese! \n\ningredients:\n- 1 pound ground beef\n- 1/2 cup white onion diced\n- 1 package taco seasoning mix 1 oz\n- 1/2 cup water\n- 1 cup shredded cheddar cheese\n- 2 crescent-style dinner rolls 8 ounce can\n\ndirections:\n1 . preheat the oven to 375 degrees.\n2 . heat a large skillet over low-medium heat. cook the ground beef and onions until the beef is no longer pink. drain grease if needed, and return meat to the skillet.\n3 . add the water and taco seasoning. continue to cook until the mixture begins to thicken. remove from heat.\n4 . open both can of dough, unroll, and separate into triangles. using a large baking sheet or pizza pan lined with parchment paper, place the wide sides of the triangles in the center with the tips overlapping. the center should form a circle. the longer tips of the triangle will face outward, and the end result will look like a sunburst.\n5 . spoon the beef around the overlapping portions of the dough to form a large circle. top the beef with shredded cheese. \n6 . pick up the outer point of a triangle and lay it over the top of the meat and cheese. tuck the point underneath the inside of the circle of dough so the meat and cheese is covered. continue this around the circle until all the outer points are folded over and tucked into the center.\n8 . bake for 18 to 22 minutes or until the ring is golden brown. cut into slice and serve with your favorite toppings.\n\nrecipe by: myheavenlyrecipes.com',
#   {'entities': [(423, 426, 'QUANTITY'),
#     (292, 297, 'INGREDIENT'),
#     (337, 338, 'QUANTITY'),
#     (373, 378, 'INGREDIENT'),
#     (454, 461, 'INGREDIENT'),
#     (1474, 1480, 'INGREDIENT'),
#     (635, 641, 'INGREDIENT'),
#     (842, 843, 'QUANTITY'),
#     (1184, 1185, 'QUANTITY'),
#     (439, 440, 'QUANTITY'),
#     (732, 733, 'QUANTITY'),
#     (526, 527, 'QUANTITY'),
#     (503, 508, 'MEASUREMENT'),
#     (431, 436, 'INGREDIENT'),
#     (441, 444, 'MEASUREMENT'),
#     (1596, 1597, 'QUANTITY'),
#     (744, 749, 'INGREDIENT'),
#     (278, 285, 'INGREDIENT'),
#     (1188, 1193, 'MEASUREMENT'),
#     (74, 78, 'MEASUREMENT'),
#     (416, 417, 'QUANTITY'),
#     (299, 307, 'INGREDIENT'),
#     (1390, 1396, 'INGREDIENT'),
#     (427, 430, 'MEASUREMENT'),
#     (501, 502, 'QUANTITY'),
#     (1308, 1309, 'QUANTITY'),
#     (363, 366, 'MEASUREMENT'),
#     (312, 318, 'INGREDIENT'),
#     (389, 396, 'MEASUREMENT'),
#     (387, 388, 'QUANTITY'),
#     (462, 468, 'INGREDIENT'),
#     (471, 472, 'QUANTITY'),
#     (1299, 1305, 'INGREDIENT'),
#     (359, 362, 'QUANTITY'),
#     (563, 564, 'QUANTITY')]}),
#  ('easy baked ziti\n\ningredients:\n- 2 boxes of rigatoni noodles\n- 1 container of ricotta, whole milk\n- 1 block of mozzarella cheese, freshly grated\n- 1 roll of regular (or spicy) sausage\n- 2 jars of tomato basil sauce (using here)\n- 1/2 tablespoon of dried basil\n- 1/2 tablespoon of garlic powder\n- 1/2 tablespoon of italian seasoning \n\nsteps:\n1 . preheat oven to 400 degrees\n2 . in a medium to large pot cook your sausage throughly, add your sauce and seasonings and simmer for 20 minutes\n3 . in another large pot cook your pasta noodles, adding a decent amount of salt and oil while boiling \n4 . drain the noodles and combine with the sauce, stir \n5 . add ricotta cheese and stir well until everything is creamy and well combined\n6 . pour into a baking dish and top with mozzarella cheese \n7 . bake for 20 minutes or until cheese is bubbly',
#   {'entities': [(229, 232, 'QUANTITY'),
#     (99, 100, 'QUANTITY'),
#     (101, 106, 'MEASUREMENT'),
#     (654, 661, 'INGREDIENT'),
#     (780, 786, 'INGREDIENT'),
#     (821, 827, 'INGREDIENT'),
#     (562, 566, 'INGREDIENT'),
#     (728, 729, 'QUANTITY'),
#     (64, 73, 'MEASUREMENT'),
#     (92, 96, 'INGREDIENT'),
#     (372, 373, 'QUANTITY'),
#     (521, 526, 'INGREDIENT'),
#     (646, 647, 'QUANTITY'),
#     (801, 803, 'QUANTITY'),
#     (34, 39, 'MEASUREMENT'),
#     (52, 59, 'INGREDIENT'),
#     (148, 152, 'MEASUREMENT'),
#     (185, 186, 'QUANTITY'),
#     (279, 292, 'INGREDIENT'),
#     (662, 668, 'INGREDIENT'),
#     (146, 147, 'QUANTITY'),
#     (313, 330, 'INGREDIENT'),
#     (110, 120, 'INGREDIENT'),
#     (175, 182, 'INGREDIENT'),
#     (411, 418, 'INGREDIENT'),
#     (360, 363, 'QUANTITY'),
#     (299, 309, 'MEASUREMENT'),
#     (202, 207, 'INGREDIENT'),
#     (32, 33, 'QUANTITY'),
#     (187, 191, 'MEASUREMENT'),
#     (295, 298, 'QUANTITY'),
#     (590, 591, 'QUANTITY'),
#     (253, 258, 'INGREDIENT'),
#     (475, 477, 'QUANTITY'),
#     (261, 264, 'QUANTITY'),
#     (788, 789, 'QUANTITY'),
#     (340, 341, 'QUANTITY'),
#     (769, 779, 'INGREDIENT'),
#     (195, 201, 'INGREDIENT'),
#     (265, 275, 'MEASUREMENT'),
#     (77, 84, 'INGREDIENT'),
#     (62, 63, 'QUANTITY'),
#     (121, 127, 'INGREDIENT'),
#     (486, 487, 'QUANTITY'),
#     (233, 243, 'MEASUREMENT')]}),
#  ('comment "" if you want to try this!\n\nbookmark this vegan brownie baked oatmeal \nby \n.\nplease support & follow for more vegan recipe!!!\n.\n.\n.\ningredients:\n2 cup coconut milk\n1/2 cup maple syrup\n1/3 cup peanut butter\n1 teaspoon vanilla\n2 cup rolled oats\n1/4 cup cocoa\n1 teaspoon baking powder\n1 tablespoon flax\npinch of salt\n1/3 cup chocolate chips\npan is 6 x 9 \n\n1 . preheat oven to 350 f. add all wet ingredients to a bowl. then add dry ingredients. mix then add chocolate chips. mix.\n2 . pour into baking pan and bake for 40 minutes.\n3 . enjoy! store in fridge and reheat when you want to eat!',
#   {'entities': [(463, 478, 'INGREDIENT'),
#     (252, 255, 'QUANTITY'),
#     (523, 525, 'QUANTITY'),
#     (234, 235, 'QUANTITY'),
#     (323, 324, 'QUANTITY'),
#     (325, 326, 'QUANTITY'),
#     (277, 290, 'INGREDIENT'),
#     (160, 172, 'INGREDIENT'),
#     (217, 225, 'MEASUREMENT'),
#     (304, 308, 'INGREDIENT'),
#     (318, 322, 'INGREDIENT'),
#     (181, 192, 'INGREDIENT'),
#     (268, 276, 'MEASUREMENT'),
#     (156, 159, 'MEASUREMENT'),
#     (323, 326, 'QUANTITY'),
#     (293, 303, 'MEASUREMENT'),
#     (247, 251, 'INGREDIENT'),
#     (154, 155, 'QUANTITY'),
#     (291, 292, 'QUANTITY'),
#     (173, 176, 'QUANTITY'),
#     (226, 233, 'INGREDIENT'),
#     (362, 363, 'QUANTITY'),
#     (485, 486, 'QUANTITY'),
#     (309, 314, 'MEASUREMENT'),
#     (215, 216, 'QUANTITY'),
#     (266, 267, 'QUANTITY'),
#     (260, 265, 'INGREDIENT'),
#     (193, 194, 'QUANTITY'),
#     (201, 214, 'INGREDIENT'),
#     (168, 172, 'INGREDIENT'),
#     (195, 196, 'QUANTITY'),
#     (327, 330, 'MEASUREMENT'),
#     (193, 196, 'QUANTITY'),
#     (382, 385, 'QUANTITY'),
#     (177, 180, 'MEASUREMENT'),
#     (236, 239, 'MEASUREMENT'),
#     (331, 346, 'INGREDIENT'),
#     (535, 536, 'QUANTITY'),
#     (197, 200, 'MEASUREMENT'),
#     (208, 214, 'INGREDIENT'),
#     (256, 259, 'MEASUREMENT')]}),
#  ('we’ve turned international beer day into a weekend, and it calls for something more than cracking open a cold one.\n\nmake your boozy weekend a little more exciting, with aunty d’s crispy beer battered chicken recipe! it’s quick, simple and deliciously addictive!\n\ningredients:\n\nchicken 400 g\ngarlic powder 1 teaspoon\npepper 3/4 teaspoon\nsalt 1 1 /4 teaspoon\nall-purpose flour 1/2 cup\ncornflour 1/2 cup\nchilli powder 1 teaspoon\nturmeric 1/4 teaspoon\nbeer 3/4 cup\n\nmethod:\n\nto a bowl, add the prepped chicken cuts, garlic powder, pepper and salt, mix and let it marinate for 30 minutes.\n\ncombine all-purpose flour, cornflour, chilli powder, turmeric and beer in a separate bowl and whisk until it forms a smooth batter. \n\ndip the marinated chicken in the batter and fry them in oil until golden on all sides.\n\nserve while it’s hot!\n-\n-\n-',
#   {'entities': [(383, 392, 'INGREDIENT'),
#     (336, 340, 'INGREDIENT'),
#     (305, 306, 'QUANTITY'),
#     (327, 335, 'MEASUREMENT'),
#     (343, 344, 'QUANTITY'),
#     (455, 456, 'QUANTITY'),
#     (325, 326, 'QUANTITY'),
#     (605, 610, 'INGREDIENT'),
#     (307, 315, 'MEASUREMENT'),
#     (200, 207, 'INGREDIENT'),
#     (346, 347, 'QUANTITY'),
#     (426, 434, 'INGREDIENT'),
#     (435, 438, 'QUANTITY'),
#     (397, 400, 'MEASUREMENT'),
#     (341, 342, 'QUANTITY'),
#     (277, 284, 'INGREDIENT'),
#     (623, 629, 'INGREDIENT'),
#     (415, 416, 'QUANTITY'),
#     (348, 356, 'MEASUREMENT'),
#     (737, 744, 'INGREDIENT'),
#     (512, 525, 'INGREDIENT'),
#     (289, 290, 'MEASUREMENT'),
#     (453, 454, 'QUANTITY'),
#     (638, 646, 'INGREDIENT'),
#     (417, 425, 'MEASUREMENT'),
#     (538, 542, 'INGREDIENT'),
#     (316, 322, 'INGREDIENT'),
#     (457, 460, 'MEASUREMENT'),
#     (401, 407, 'INGREDIENT'),
#     (448, 452, 'INGREDIENT'),
#     (323, 324, 'QUANTITY'),
#     (527, 533, 'INGREDIENT'),
#     (369, 374, 'INGREDIENT'),
#     (291, 304, 'INGREDIENT'),
#     (498, 505, 'INGREDIENT'),
#     (375, 378, 'QUANTITY'),
#     (393, 396, 'QUANTITY'),
#     (572, 574, 'QUANTITY'),
#     (285, 288, 'QUANTITY'),
#     (775, 778, 'INGREDIENT'),
#     (439, 447, 'MEASUREMENT'),
#     (379, 382, 'MEASUREMENT')]}),
#  ('haven’t cooked a nice meal for myself at home in so long. it’s been busy and spending the afternoon in the kitchen just hasn’t been an option, or i just haven’t had the energy for it. honestly, we’ve done more in the last month then we’ve done in the last 3 year it seems! since coming back from our honeymoon, i’ve slowly been easing myself back to my daily routine and habits, like starting to go on some small runs again, seeing friends, doing the sauna, etc.\n\nchris is away for the weekend so i decided today was going to be all about me i spent my saturday at the market, the library, the beach and the kitchen, and now i’m just about to sit down and have a romantic dinner date with myself \n\nthis is a yam and cherry tomatoes tart with sage and goats cheese. i imagine you can change the produce with the seasons; pumpkin and broccoli for the fall sounds good!\n\ningredients:\npie crust (i had some in my freezer that i’d made earlier)\n1 cup ricotta cheese\n6 eggs\n1 large yam, peeled cubed\n1/2 cup sliced cherry tomatoes\ngoat cheese, broken into piece to sprinkle on top\nsage leaves, to sprinkle on top\nsalt and pepper\n\npreheat oven to 400 . roast your yams and bake your crust for 20 minutes or until golden. place eggs, ricotta, tomatoes and salt and pepper in a bowl, whisk to combine. remove the crust and yams from the oven, place the yams on the crust then pour mixture overtop. top egg mixture with goats cheese and sage. bake for another 25 minutes.\n.\n.\n.\n.\n.\n.',
#   {'entities': [(1220, 1224, 'INGREDIENT'),
#     (1116, 1122, 'INGREDIENT'),
#     (1235, 1243, 'INGREDIENT'),
#     (1416, 1422, 'INGREDIENT'),
#     (757, 763, 'INGREDIENT'),
#     (1393, 1396, 'INGREDIENT'),
#     (942, 945, 'MEASUREMENT'),
#     (820, 827, 'INGREDIENT'),
#     (963, 967, 'INGREDIENT'),
#     (1075, 1079, 'INGREDIENT'),
#     (968, 969, 'QUANTITY'),
#     (1257, 1263, 'INGREDIENT'),
#     (1226, 1233, 'INGREDIENT'),
#     (1248, 1252, 'INGREDIENT'),
#     (1186, 1188, 'QUANTITY'),
#     (1016, 1024, 'INGREDIENT'),
#     (961, 962, 'QUANTITY'),
#     (946, 953, 'INGREDIENT'),
#     (1140, 1143, 'QUANTITY'),
#     (954, 960, 'INGREDIENT'),
#     (832, 840, 'INGREDIENT'),
#     (940, 941, 'QUANTITY'),
#     (994, 997, 'QUANTITY'),
#     (998, 1001, 'MEASUREMENT'),
#     (723, 731, 'INGREDIENT'),
#     (256, 257, 'QUANTITY'),
#     (1030, 1036, 'INGREDIENT'),
#     (1450, 1452, 'QUANTITY'),
#     (1107, 1111, 'INGREDIENT'),
#     (976, 979, 'INGREDIENT')]}),
#  ('over 100 delicious vegan recipes. plant based recipes for muscle growth fat loss and a healthier lifestyle\nvisit my website in bio!!!\n\nsquash blossom vegan quesadillas! \n\nalexa from created this incredible dish! check out her recipe below:\n\nrecipe\ningredients:\ncorn tortillas\n10 squash blossoms\navocado\nsalsa\nsalt & pepper\n\n"tofu cheese"\n1 (14 ounce) container medium firm or extra firm tofu\n2 tablespoon olive oil\njuice of 1 lemon\n2 tablespoon any plant milk (i used oat milk)\n1/2 teaspoon salt\n4 tablespoon nutritional yeast (i like trader joe\'s brand)\n1/2 teaspoon garlic powder\n\ninstructions:\n1 . remove tofu from package and wrap tofu block in 2 paper towels. squeeze for 10 seconds then break apart tofu into your food processor. to the food processor add salt, 2 tablespoon olive oil, lemon juice, nutritional yeast and garlic powder, plant milk. pulse 6-10 times until you reach the consistency of ricotta cheese like consistency. taste and adjust salt and seasonings as needed.\n\n2 . clean off each squash blossom with a damp paper towel then trim the stems. in a pan over medium heat, add a tiny bit of oil and quickly cook the squash blossoms 10 seconds on each side. season with a little salt and pepper.\n\n3 . warm a cast-iron skillet or pan over medium heat. (optional tip my mama taught me... wait till pan is super hot then quickly dip tortilla in water and add to hot pan. if the pan doesn\'t sizzle then it\'s not ready!!!* flip the tortilla 10-15 seconds later...this makes your tortillas so soft and fresh tasting giving a dry tortilla the moisture it needs. *** only do this tip w/ corn tortillas not flour tortilla***\n\n4 . add a generous spoonful of tofu cheese on half the tortilla, then add squash blossom then fold over. let cook for 1 minute on both sides.\n\n5 . add sliced avocados and serve with salsa!',
#   {'entities': [(781, 790, 'INGREDIENT'),
#     (817, 822, 'INGREDIENT'),
#     (1683, 1687, 'QUANTITY'),
#     (309, 313, 'INGREDIENT'),
#     (279, 294, 'INGREDIENT'),
#     (1618, 1623, 'INGREDIENT'),
#     (325, 329, 'INGREDIENT'),
#     (330, 336, 'INGREDIENT'),
#     (1637, 1638, 'QUANTITY'),
#     (1795, 1803, 'INGREDIENT'),
#     (770, 780, 'MEASUREMENT'),
#     (768, 769, 'QUANTITY'),
#     (1199, 1203, 'INGREDIENT'),
#     (635, 639, 'INGREDIENT'),
#     (1755, 1756, 'QUANTITY'),
#     (424, 425, 'QUANTITY'),
#     (338, 339, 'QUANTITY'),
#     (1673, 1679, 'INGREDIENT'),
#     (472, 476, 'INGREDIENT'),
#     (405, 414, 'INGREDIENT'),
#     (597, 598, 'QUANTITY'),
#     (649, 650, 'QUANTITY'),
#     (860, 861, 'QUANTITY'),
#     (1459, 1461, 'QUANTITY'),
#     (762, 766, 'INGREDIENT'),
#     (303, 308, 'INGREDIENT'),
#     (827, 840, 'INGREDIENT'),
#     (1362, 1367, 'INGREDIENT'),
#     (341, 343, 'QUANTITY'),
#     (1208, 1214, 'INGREDIENT'),
#     (455, 459, 'INGREDIENT'),
#     (956, 960, 'INGREDIENT'),
#     (344, 349, 'MEASUREMENT'),
#     (906, 913, 'INGREDIENT'),
#     (608, 612, 'INGREDIENT'),
#     (478, 481, 'QUANTITY'),
#     (792, 803, 'INGREDIENT'),
#     (862, 864, 'QUANTITY'),
#     (394, 404, 'MEASUREMENT'),
#     (482, 490, 'MEASUREMENT'),
#     (491, 495, 'INGREDIENT'),
#     (555, 558, 'QUANTITY'),
#     (559, 567, 'MEASUREMENT'),
#     (705, 709, 'INGREDIENT'),
#     (392, 393, 'QUANTITY'),
#     (1456, 1458, 'QUANTITY'),
#     (496, 497, 'QUANTITY'),
#     (434, 444, 'MEASUREMENT'),
#     (295, 302, 'INGREDIENT'),
#     (498, 508, 'MEASUREMENT'),
#     (1153, 1155, 'QUANTITY'),
#     (387, 391, 'INGREDIENT'),
#     (677, 679, 'QUANTITY'),
#     (848, 852, 'INGREDIENT'),
#     (1599, 1613, 'INGREDIENT'),
#     (468, 476, 'INGREDIENT'),
#     (156, 167, 'INGREDIENT'),
#     (316, 322, 'INGREDIENT'),
#     (914, 920, 'INGREDIENT'),
#     (261, 275, 'INGREDIENT'),
#     (1217, 1218, 'QUANTITY'),
#     (988, 989, 'QUANTITY'),
#     (432, 433, 'QUANTITY'),
#     (1668, 1672, 'INGREDIENT'),
#     (521, 526, 'INGREDIENT'),
#     (426, 431, 'INGREDIENT'),
#     (568, 581, 'INGREDIENT')]}),
#  ('orzo pasta with chorizo style sausages and feta cheese 863 kcals - serves 4 \n\norzo pasta with chorizo style sausages and feta cheese 863 kcals - serves 4 \n\ningredients:\n200 gram orzo, uncooked \n2 chorizo styles sausage (asda), sliced\n1 white onion, diced\n2 garlic clove, crushed \ntinned tomatoes \n1 tablespoon tomato purée\n1 teaspoon oregano \n1 teaspoon basil\n30 gram feta cheese to top\nsalt and pepper to taste \n\nstart by cooking the orzo in a saucepan for 8 minutes. whilst this is cooking fry your sausages, onions and garlic. once browned add in your tinned tomatoes, tomato purée and herbs. let this simmer for a couple of minutes then added in your orzo and mix together. once mixed it is ready to serve. top with feta cheese, so quick and easy',
#   {'entities': [(55, 58, 'QUANTITY'),
#     (43, 47, 'INGREDIENT'),
#     (299, 309, 'MEASUREMENT'),
#     (368, 372, 'INGREDIENT'),
#     (373, 379, 'INGREDIENT'),
#     (178, 182, 'INGREDIENT'),
#     (169, 172, 'QUANTITY'),
#     (334, 341, 'INGREDIENT'),
#     (234, 235, 'QUANTITY'),
#     (255, 256, 'QUANTITY'),
#     (387, 391, 'INGREDIENT'),
#     (720, 724, 'INGREDIENT'),
#     (297, 298, 'QUANTITY'),
#     (325, 333, 'MEASUREMENT'),
#     (522, 528, 'INGREDIENT'),
#     (242, 247, 'INGREDIENT'),
#     (194, 195, 'QUANTITY'),
#     (323, 324, 'QUANTITY'),
#     (572, 578, 'INGREDIENT'),
#     (257, 263, 'INGREDIENT'),
# ...
#     (24, 31, 'INGREDIENT'),
#     (555, 562, 'INGREDIENT'),
#     (448, 452, 'MEASUREMENT'),
#     (952, 953, 'QUANTITY'),
#     (251, 252, 'QUANTITY'),
#     (764, 765, 'QUANTITY'),
#     (372, 374, 'QUANTITY'),
#     (13, 22, 'INGREDIENT')]}),
#  ('take a look at how put together her ultimate comfort dish - cheesy tomato fusilli recipe with her favourite ayam brand baked beans vegetarian amid the breathtaking scenery of cradle mountain. \n\n give this recipe a try and you are in for a treat. remember to tag your vegetarian friend too! \n\ningredients: \n- 425 gram ayam brand baked beans - vegetarian \n- 1/4 zucchini (cut into small cubes)\n- 4 big cherry tomato (sliced)\n- 2 tablespoon parmesan cheese\n- few dash black pepper\n- few dash italian herbs\n\npreparation: \n1 . add baked beans, zucchini and cherry tomatoes to the cooking pot. bring it to boil then simmer for 5 minutes. stir occasionally. (concurrently, cook fusilli according to instructions.)\n2 . stir in parmesan cheese, black pepper and italian herbs until cheese has melted into the sauce.\n3 . pour the sauce onto the fusilli. serve immediately.\n\n purchase any ayam brand baked beans for $5 now and redeem 1 limited edition plate at major fairprice outlets. \n\npromotion period: now - 31 st august 2022 \n*terms and conditions apply',
#   {'entities': [(67, 73, 'INGREDIENT'),
#     (480, 483, 'QUANTITY'),
#     (497, 502, 'INGREDIENT'),
#     (923, 924, 'QUANTITY'),
#     (328, 339, 'INGREDIENT'),
#     (807, 808, 'QUANTITY'),
#     (539, 547, 'INGREDIENT'),
#     (736, 748, 'INGREDIENT'),
#     (427, 437, 'MEASUREMENT'),
#     (728, 734, 'INGREDIENT'),
#     (773, 779, 'INGREDIENT'),
#     (312, 316, 'MEASUREMENT'),
#     (447, 453, 'INGREDIENT'),
#     (360, 368, 'INGREDIENT'),
#     (518, 519, 'QUANTITY'),
#     (407, 413, 'INGREDIENT'),
#     (761, 766, 'INGREDIENT'),
#     (425, 426, 'QUANTITY'),
#     (308, 311, 'QUANTITY'),
#     (559, 567, 'INGREDIENT'),
#     (394, 395, 'QUANTITY'),
#     (438, 446, 'INGREDIENT'),
#     (465, 477, 'INGREDIENT'),
#     (889, 900, 'INGREDIENT'),
#     (484, 488, 'MEASUREMENT'),
#     (707, 708, 'QUANTITY'),
#     (456, 459, 'QUANTITY'),
#     (460, 464, 'MEASUREMENT'),
#     (356, 359, 'QUANTITY')]}),
#  ('new york strip steak \nfollow \nfacebook homerecipes101 \n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\n-\ningredients:\n8 ounce sirloin steak\nfreshly cracked pepper \nkosher salt \n\ninstructions:\n1 . season strip steak 30 minutes prior to grilling, let it sit out until it comes to room temperature.\n2 . preheat your grill to medium-high heat.\n3 . grill steak turning at least twice, and remove just before desired doneness.\n4 . let the steak rest covered in tin foil for 5 minutes before serving. \n\n*the best indicator is an instant-read thermometer.\nfor rare – 120-130 °f internal temperature\nfor medium rare – 130-140 °f internal temperature\nfor medium – 140-150 °f internal temperature\n\n if you make any of our recipes!',
#   {'entities': [(151, 155, 'INGREDIENT'),
#     (320, 321, 'QUANTITY'),
#     (183, 188, 'INGREDIENT'),
#     (413, 418, 'INGREDIENT'),
#     (448, 449, 'QUANTITY'),
#     (114, 119, 'INGREDIENT'),
#     (330, 335, 'INGREDIENT'),
#     (276, 277, 'QUANTITY'),
#     (100, 105, 'MEASUREMENT'),
#     (136, 142, 'INGREDIENT'),
#     (172, 173, 'QUANTITY'),
#     (98, 99, 'QUANTITY'),
#     (195, 197, 'QUANTITY'),
#     (401, 402, 'QUANTITY')]}),
#  ('avocado quesadillas\ningredients:\n\n 2 corn tortillas\n\n 1 large avocado\n\n 100 gram low-fat melting cheese\n\n pico de gallo to accompany (optional)\n\n salt and ground black pepper to taste\n\n preparation\n\n cut the avocado and add the pulp in a bowl, mix with a little salt and ground black pepper to taste for flavor. you can add a few drops of lemon to prevent it from turning dark.\n\n heat the tortillas on a griddle on both sides and place a little of the cheese to taste on each one. let it gratin a bit.\n\n serve and place the avocado on top, fold in half and accompany with pico de gallo or your sauce to taste if you want to add extra flavor. enjoy some delicious avocado quesadillas, delicious and super easy to make.',
#   {'entities': [(162, 174, 'INGREDIENT'),
#     (663, 670, 'INGREDIENT'),
#     (262, 266, 'INGREDIENT'),
#     (572, 585, 'INGREDIENT'),
#     (452, 458, 'INGREDIENT'),
#     (72, 75, 'QUANTITY'),
#     (35, 36, 'QUANTITY'),
#     (54, 55, 'QUANTITY'),
#     (524, 531, 'INGREDIENT'),
#     (37, 51, 'INGREDIENT'),
#     (339, 344, 'INGREDIENT'),
#     (548, 552, 'QUANTITY'),
#     (62, 69, 'INGREDIENT'),
#     (671, 682, 'INGREDIENT'),
#     (76, 80, 'MEASUREMENT'),
#     (278, 290, 'INGREDIENT'),
#     (146, 150, 'INGREDIENT'),
#     (106, 119, 'INGREDIENT'),
#     (97, 103, 'INGREDIENT')]}),
#  ('start your day with protein intake bright and early with these yummy protein bagels!!\n\nmacros: 300 cal | 27 c | 37 p | 12 f\n\ningredients:\n- everything bagel\n- 2 tablespoon hummus \n- 2 tablespoon low sodium peanut butter\n- 1/2 banana\n- cayenne pepper',
#   {'entities': [(184, 194, 'MEASUREMENT'),
#     (243, 249, 'INGREDIENT'),
#     (112, 114, 'QUANTITY'),
#     (119, 121, 'QUANTITY'),
#     (222, 225, 'QUANTITY'),
#     (105, 107, 'QUANTITY'),
#     (172, 178, 'INGREDIENT'),
#     (161, 171, 'MEASUREMENT'),
#     (182, 183, 'QUANTITY'),
#     (226, 232, 'INGREDIENT'),
#     (95, 98, 'QUANTITY'),
#     (206, 219, 'INGREDIENT'),
#     (159, 160, 'QUANTITY'),
#     (151, 156, 'INGREDIENT')]}),
#  ("𝑵𝒆𝒘 𝑩𝒍𝒐𝒈 𝑹𝒆𝒄𝒊𝒑𝒆! \n\nsummer = aubergines! most of the recipes i know with aubergines are 𝐬𝐮𝐩𝐞𝐫 𝐩𝐚𝐜𝐤𝐞𝐝 𝐰𝐢𝐭𝐡 𝐟𝐥𝐚𝐯𝐨𝐫 𝐚𝐧𝐝 𝐧𝐨𝐮𝐫𝐢𝐬𝐡𝐢𝐧𝐠, and this is one of them! \n\nthis pasta sauce is called norma, it originated in beautiful sicily, and it's made of 3 key ingredients: aubergines, tomatoes and grated cheese! yes, another so simple yet so nice dish \n\nthis version includes a final baking step in the oven to get that gorgeous crust on top for extra crunch! \n\nthe super easy method: \n1 . dice the aubergines and cook in little oil until tender.\n2 . add the tomato sauce and keep cooking for a few minutes.\n3 . cook the pasta of choice until al dente. turn the grill/oven on.\n4 . mix the pasta with the sauce and add some grated cheese (ideally salted ricotta, alternatively a good pecorino will do). adjust seasoning.\n5 . transfer to an oven dish, cover with more cheese and bake until golden. enjoy! \n\ntap the link in bio for the full recipe & method, and to get many more easy & delicious italian recipes! buon appetito!",
#   {'entities': [(72, 82, 'INGREDIENT'),
#     (474, 475, 'QUANTITY'),
#     (272, 280, 'INGREDIENT'),
#     (718, 724, 'INGREDIENT'),
#     (547, 553, 'INGREDIENT'),
#     (292, 298, 'INGREDIENT'),
#     (260, 270, 'INGREDIENT'),
#     (854, 860, 'INGREDIENT'),
#     (487, 497, 'INGREDIENT'),
#     (609, 614, 'INGREDIENT'),
#     (241, 242, 'QUANTITY'),
#     (677, 682, 'INGREDIENT'),
#     (28, 38, 'INGREDIENT'),
#     (596, 597, 'QUANTITY'),
#     (771, 779, 'INGREDIENT'),
#     (535, 536, 'QUANTITY'),
#     (665, 666, 'QUANTITY'),
#     (741, 748, 'INGREDIENT')]}),
#  ('today’s recipe is perfect to go down a treat. topped with fresh juicy plums and swaddled in a sweet, creamy custard topping - a slice of our lovely spiced plum custard cake will leave you wanting more in anytime of the day. the hint of alce nero organic plum jam is simply a cherry on the cake! \n\n a slice of happiness: spiced plum custard cake\n\ningredients: \n- 1 1 /2 cup alce nero organic plum jam\n- 1 cup all-purpose flour\n- 1 tablespoon white sugar\n- 1 tablespoon baking powder\n- 1/2 cup butter- cold, cut into cubes\n- 2 tablespoon heavy cream\n- 1 egg\n- 1 cup plums, pitted and sliced \n- 1/2 teaspoon cinnamon\n- 1/4 teaspoon ground ginger\n- 1/4 teaspoon ground nutmeg\n\nto make custard topping: \n- 1/2 cup heavy cream\n- 1/2 cup white sugar\n- 1 egg\n- 1 teaspoon vanilla extract\n\npreparation: \n1 ) preheat oven to 350 °c. lightly spray an 8 inch springform pan and set aside.\ntoss the plums with the spices and set aside. in a large bowl, stir together flour, sugar and baking powder. add cubes of butter. stir in vanilla, alce nero organic plum jam, heavy cream and egg. continue to stir for a few seconds of until well combined. \n2 ) turn the dough into the bottom of the pan and press in with your fingers. arrange the spiced plums over the dough. bake for 20-25 minutes.\n3 ) while cake is baking prep the custard by whisking together the cream, sugar, vanilla and egg.\n4 ) when the cake is done baking, pour the custard over the plums, and return to the oven, bake for another 20-25 minutes or until the custard has set. serve warm and enjoy! \n\n enjoy making easy and delicious dessert recipes with alce nero organic jams. shop now at: https://linktr.ee/alcenero. link in bio.',
#   {'entities': [(1357, 1364, 'INGREDIENT'),
#     (367, 368, 'QUANTITY'),
#     (596, 604, 'MEASUREMENT'),
#     (737, 742, 'INGREDIENT'),
#     (616, 619, 'QUANTITY'),
#     (954, 959, 'INGREDIENT'),
#     (592, 595, 'QUANTITY'),
#     (402, 403, 'QUANTITY'),
#     (160, 167, 'INGREDIENT'),
#     (362, 363, 'QUANTITY'),
#     (1343, 1348, 'INGREDIENT'),
#     (1350, 1355, 'INGREDIENT'),
#     (1417, 1424, 'INGREDIENT'),
#     (525, 535, 'MEASUREMENT'),
#     (645, 648, 'QUANTITY'),
#     (727, 730, 'MEASUREMENT'),
#     (364, 365, 'QUANTITY'),
#     (764, 779, 'INGREDIENT'),
#     (701, 704, 'QUANTITY'),
#     (1068, 1071, 'INGREDIENT'),
#     (404, 407, 'MEASUREMENT'),
#     (484, 487, 'QUANTITY'),
#     (457, 467, 'MEASUREMENT'),
#     (815, 818, 'QUANTITY'),
#     (447, 452, 'INGREDIENT'),
#     (999, 1005, 'INGREDIENT'),
#     (1482, 1484, 'QUANTITY'),
#     (420, 425, 'INGREDIENT'),
#     (1310, 1317, 'INGREDIENT'),
#     (636, 642, 'INGREDIENT'),
#     (605, 613, 'INGREDIENT'),
#     (108, 115, 'INGREDIENT'),
#     (747, 750, 'INGREDIENT'),
#     (396, 399, 'INGREDIENT'),
#     (745, 746, 'QUANTITY'),
#     (552, 555, 'INGREDIENT'),
#     (560, 563, 'MEASUREMENT'),
#     (332, 339, 'INGREDIENT'),
#     (705, 708, 'MEASUREMENT'),
#     (1374, 1375, 'QUANTITY'),
#     (455, 456, 'QUANTITY'),
#     (1133, 1134, 'QUANTITY'),
#     (1509, 1516, 'INGREDIENT'),
#     (753, 754, 'QUANTITY'),
#     (1058, 1063, 'INGREDIENT'),
#     (901, 907, 'INGREDIENT'),
#     (1369, 1372, 'INGREDIENT'),
#     (649, 657, 'MEASUREMENT'),
#     (961, 966, 'INGREDIENT'),
#     (840, 841, 'QUANTITY'),
#     (550, 551, 'QUANTITY'),
#     (369, 372, 'MEASUREMENT'),
#     (492, 498, 'INGREDIENT'),
#     (755, 763, 'MEASUREMENT'),
#     (1015, 1022, 'INGREDIENT'),
#     (564, 569, 'INGREDIENT'),
#     (1276, 1277, 'QUANTITY'),
#     (715, 720, 'INGREDIENT'),
#     (542, 547, 'INGREDIENT'),
#     (364, 368, 'QUANTITY'),
#     (1485, 1487, 'QUANTITY'),
#     (1264, 1266, 'QUANTITY'),
#     (558, 559, 'QUANTITY'),
#     (523, 524, 'QUANTITY'),
#     (971, 984, 'INGREDIENT'),
#     (723, 726, 'QUANTITY'),
#     (1261, 1263, 'QUANTITY'),
#     (430, 440, 'MEASUREMENT'),
#     (620, 628, 'MEASUREMENT'),
#     (795, 796, 'QUANTITY'),
#     (681, 688, 'INGREDIENT'),
#     (665, 671, 'INGREDIENT'),
#     (488, 491, 'MEASUREMENT'),
#     (428, 429, 'QUANTITY'),
#     (468, 481, 'INGREDIENT')]}),
#  ('whip it up wednesday!! \n\ni made my yummy dish that we like to call in our home chicken chunk!\n\ndo you like to eat it in a variety of ways either with crackers or in a rap not only do we devour it quickly but so did my boys! \n\nhere’s the recipe below try it out and let me know what you think!! \n\ningredients:\n\n2 cup of chopped up rotisserie chicken ( are use the pre-packed pulled apart chicken from costco) \n\n1 chopped serano pepper\n3 chopped stocks of celery\n2 diced tomatoes\n1 small red onion chopped\n\n2 tbs of mayonnaise made with avocado oil ( i use primal kitchen mayo brand) \n\nto taste add sea salt and pepper\n\nmix all ingredients together in bowl for best flavors place in tupperware and set in fridge for overnight or you can eat soon after finished!! \n\nenjoy!!!',
#   {'entities': [(312, 315, 'MEASUREMENT'),
#     (410, 411, 'QUANTITY'),
#     (570, 574, 'INGREDIENT'),
#     (478, 479, 'QUANTITY'),
#     (486, 495, 'INGREDIENT'),
#     (461, 462, 'QUANTITY'),
#     (434, 435, 'QUANTITY'),
#     (610, 616, 'INGREDIENT'),
#     (535, 546, 'INGREDIENT'),
#     (454, 460, 'INGREDIENT'),
#     (507, 510, 'MEASUREMENT'),
#     (150, 158, 'INGREDIENT'),
#     (505, 506, 'QUANTITY'),
#     (469, 477, 'INGREDIENT'),
#     (444, 450, 'MEASUREMENT'),
#     (387, 394, 'INGREDIENT'),
#     (341, 348, 'INGREDIENT'),
#     (601, 605, 'INGREDIENT'),
#     (310, 311, 'QUANTITY'),
#     (79, 86, 'INGREDIENT'),
#     (427, 433, 'INGREDIENT'),
#     (514, 524, 'INGREDIENT')]}),
#  ('black sesame cookies\n\nthese are simple and sweet and such an unique flavor.\n\ningredients:\n1 egg\n1/3 cup oil\n1 teaspoon vanilla \n1/3 cup sugar\n3 tablespoon brown sugar\n1 teaspoon salt\n1 teaspoon baking soda\n1 package of sesame powder\n1/4 cup oil \nsesame seeds\n\ndirections:\npreheat to 350 degrees\nmix solids\nadd in liquids \nput in fridge for 15 minutes\ntake out, roll into balls\nplace on tray\nsprinkle sesame seeds\nbake for 17 minutes\n\n•\n•\n•',
#   {'entities': [(185, 193, 'MEASUREMENT'),
#     (128, 129, 'QUANTITY'),
#     (108, 109, 'QUANTITY'),
#     (233, 236, 'QUANTITY'),
#     (178, 182, 'INGREDIENT'),
#     (98, 99, 'QUANTITY'),
#     (246, 258, 'INGREDIENT'),
#     (130, 131, 'QUANTITY'),
#     (136, 141, 'INGREDIENT'),
#     (128, 131, 'QUANTITY'),
#     (194, 205, 'INGREDIENT'),
#     (144, 154, 'MEASUREMENT'),
#     (208, 215, 'MEASUREMENT'),
#     (161, 166, 'INGREDIENT'),
#     (400, 412, 'INGREDIENT'),
#     (142, 143, 'QUANTITY'),
#     (96, 97, 'QUANTITY'),
#     (183, 184, 'QUANTITY'),
#     (119, 126, 'INGREDIENT'),
#     (206, 207, 'QUANTITY'),
#     (167, 168, 'QUANTITY'),
#     (90, 91, 'QUANTITY'),
#     (100, 103, 'MEASUREMENT'),
#     (104, 107, 'INGREDIENT'),
#     (110, 118, 'MEASUREMENT'),
#     (132, 135, 'MEASUREMENT'),
#     (237, 240, 'MEASUREMENT'),
#     (422, 424, 'QUANTITY'),
#     (169, 177, 'MEASUREMENT'),
#     (219, 232, 'INGREDIENT'),
#     (92, 95, 'INGREDIENT'),
#     (96, 99, 'QUANTITY')]}),
#  ('made fruit triffle \n\ningredients : \nmilk 10 kg \n1 large vanilla custard packet \n1 packet of jelly \nhalf kg sugar (you can adjust according to your taste) \nfew drops of vanilla essence \n4-5 plain cakes \nfruits (apple and banana)',
#   {'entities': [(187, 188, 'QUANTITY'),
#     (48, 49, 'QUANTITY'),
#     (107, 112, 'INGREDIENT'),
#     (82, 88, 'MEASUREMENT'),
#     (41, 43, 'QUANTITY'),
#     (44, 46, 'MEASUREMENT'),
#     (72, 78, 'MEASUREMENT'),
#     (36, 40, 'INGREDIENT'),
#     (64, 71, 'INGREDIENT'),
#     (56, 63, 'INGREDIENT'),
#     (185, 186, 'QUANTITY'),
#     (168, 175, 'INGREDIENT'),
#     (80, 81, 'QUANTITY'),
#     (104, 106, 'MEASUREMENT'),
#     (92, 97, 'INGREDIENT'),
#     (159, 164, 'MEASUREMENT'),
#     (220, 226, 'INGREDIENT'),
#     (99, 103, 'QUANTITY'),
#     (210, 215, 'INGREDIENT')]}),
#  ('my favorite sweet and savory breakfast easy way to curb appetite for those of us who crave all flavors in the morning! start your protein intake bright and early with protein bagels!!\n\nmacros: 300 cal | 27 c | 37 p | 12 f\n\ningredients:\n- everything bagel\n- 2 tablespoon hommus \n- 2 tablespoon low sodium peanut butter \n- 1/2 banana \n- cayenne pepper',
#   {'entities': [(193, 196, 'QUANTITY'),
#     (280, 281, 'QUANTITY'),
#     (203, 205, 'QUANTITY'),
#     (321, 324, 'QUANTITY'),
#     (304, 317, 'INGREDIENT'),
#     (282, 292, 'MEASUREMENT'),
#     (257, 258, 'QUANTITY'),
#     (249, 254, 'INGREDIENT'),
#     (259, 269, 'MEASUREMENT'),
#     (270, 276, 'INGREDIENT'),
#     (325, 331, 'INGREDIENT'),
#     (217, 219, 'QUANTITY'),
#     (210, 212, 'QUANTITY'),
#     (343, 349, 'INGREDIENT')]}),
#  ('this week the weather is hot and getting hotter here in the uk and the thought of a hot drink may be mad to you.\n\nwith your thermomix, you can make such a yummy cappuccino milkshake in just 1 min 30 with the cookidoo recipe \n\njust 4 ingredients:\n\nsugar\ninstant coffee\nice cubes\nwhole milk\n\nmessage me to find out more about what you can make in such a short amount of time\n.\n.\n.\n.\n.\n.\n.\n.\n.\n.\n.\n.',
#   {'entities': [(190, 191, 'QUANTITY'),
#     (284, 288, 'INGREDIENT'),
#     (231, 232, 'QUANTITY'),
#     (268, 271, 'INGREDIENT'),
#     (247, 252, 'INGREDIENT'),
#     (261, 267, 'INGREDIENT'),
#     (196, 198, 'QUANTITY')]})]

# %%
colors = {
    "MEASUREMENT": "#bfeeb7",
    "INGREDIENT": "#feca74",
    "QUANTITY": "#e4e7d2"
}
options = {"ents": list(colors), "colors": colors}

nlp = spacy.blank('en')

for i in range(len(TRAIN_DATA)):
    raw_text = TRAIN_DATA[i][0]
    doc = nlp.make_doc(raw_text)
    spans = TRAIN_DATA[i][1]["entities"]
    ents = []
    for span_start, span_end, label in spans:
        ent = doc.char_span(span_start, span_end, label=label)
        if ent is None:
            continue

        ents.append(ent)
        
    try:
        doc.ents = ents
    except:
        print(f"Error with document")
    #doc.ents = ents
    spacy.displacy.render(doc, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">masala
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br></br>to set the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  why to use cotton / muslin cloth when you can easily set in nyra
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  mould </br></br>tap on the link to buy the product: </br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . buy nyra stainless steel round
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  mould maker with top press lid (set of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  pcs) online at low prices in india - amazon.in</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . nyra stainless steel round
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  mould/ mould press set of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  piece colander price in india - buy nyra stainless steel round
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  mould/ mould press set of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  piece colander online at flipkart.com</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . nyra stainless steel glossy finish round
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  mould/ mould press set of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  - jiomart</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . nyra stainless steel glossy finish round
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  mould/ mould press – set of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  (nyrakitchenware.in)</br></br> ingredients: </br>*
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     litre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     milk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>*
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oregano
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>*
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-r
# Error with document
# /Users/maxkirwan/opt/miniconda3/envs/data_analytics/lib/python3.9/site-packages/spacy/displacy/__init__.py:205: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">warm salad of purple sprouting broccoli, new potatoes and </br></br>ingredients:</br>- 400 gram new potatoes, preferably charlotte</br>- 20 gram hazelnuts, blanched</br>- 200 gram purple sprouting broccoli, trimmed of its thick stalk</br>- 1/2 red onion, thinly sliced (approx. 75 g)</br>- 20 gram parmigiano reggiano</br>- 20 gram flat leaf parsley, leaves picked from the stalk (big handful)</br>- 6 basil leaves (2.5 g)</br>- 1 tarragon sprig, leaves picked (1 g)</br>- 1 small clove garlic</br>- 2 anchovy fillet, from a tin (optional)</br>- 1/2 teaspoon dijon mustard</br>- 1/2 lemon, juiced, the rest kept for garnish</br></br>method:</br>1 . boil the potatoes until cooked, approx. 15 minutes, then drain.</br>2 . make a garlic paste by smashing it with salt with the back of your knife. add to the picked herbs and the anchovies and chop finely. put in a bowl and mix with the mustard, lemon juice, olive oil and black pepper.</br>3 . toast the hazelnuts in a dry pan for a few minutes. use a pestle and mortar or similar to coarsely crush the hazelnuts.</br>4 . heat 2 tablespoon olive oil in the same frying pan. add the broccoli and sliced onion and a splash of water. cover and sauté/steam until broccoli cooked al dente. remove lid and boil off any water left in pan. season and empty into large bowl.</br>5 . thickly slice the potatoes and add to the pan, with a splash more olive oil if needed. fry for a couple of minutes to reheat. season well.</br>6 . add the dressing to the bowl and coat everything.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">if you are looking to bring a yummy
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  salad to the next outdoor summer bbq, try out this amazing grilled ratatouille
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  salad!</br></br>ingredients: </br></br>∙
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  medium
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zucchini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (about
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# .), halved lengthwise</br>∙ about
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  pound adagio eggplants , cut into
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  &quot; wedges</br>∙ 3/4
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  extra-virgin
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     olive oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , divided</br>∙
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# . kosher
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     salt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , divided</br>∙
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# . freshly ground
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     black pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , divided</br>∙
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ounce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  penne or casarecce
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>∙
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  large or
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  medium heirloom or virtuoso beefsteak
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomatoes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (about
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# .), cut into
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">need an easy brunch recipe? this plant-based breakfast casserole is so simple and so tasty! it’s a great vegan recipe for brunch and it feeds at least 8 people. and the key to this dish, is the savory kick from the plant-based loca foods potato queso! it is just such a delicious recipe! so whether or not your guests are vegetarian, vegan, or meat-eaters, they’ll enjoy this dish! </br></br>get these ingredients, and try this recipe for your breakfast tomorrow, it won't disappoint!</br></br>gluten-free plant-based breakfast casserole recipe:</br>ingredients:</br>▢gluten-free nonstick cooking spray</br>▢
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  -ounce)
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     package
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  of frozen gluten-free
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hash browns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>▢
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , diced</br>▢
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  red bell
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , seeded, deveined, and diced</br>▢
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ounce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  sliced
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mushrooms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , baby bellas (cremini), or white</br>▢
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  chopped
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kale
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     spinach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>▢
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     potato queso
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , mild or spicy</br>▢smoked
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paprika
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>us customary - metric</br></br>instructions:</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . preheat the oven to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     350
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  degrees. spray a 9x12 -inch casserole dish with cooking spray.</br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . in a large bowl, combine the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hashbrowns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; bo
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">spicy tuna pancake/gochu-chamchi jeon!(고추참치전) </br></br>sharing another easy and tasty dish you can enjoy any day of the week! recently, you guys may have seen my story photos, i had received a wonderful box of korean products from . it included a nice variety of pantry items from korea: like roasted seaweed, canned tuna, seaweed
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crackers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , nori sheets and more! thanks to them i was able to make this delicious jeon!! recipe below!</br></br>ingredients:</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gochu chamchi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (spicy
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tuna
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# )
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     can
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  c diced
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  t
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     garlic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  minced</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  t
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     scallion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , chopped</br>3/4
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     buchim garoo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (korean pancake mix)</br>
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pinch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     black pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  )open can and drain tuna for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# -
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  min </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  )combine all ingredients into a mixing bowl, without over mixing. </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  )heat pan and cook jeon until golden brown on both sides, in med low heat. drop about
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tablespoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  for each jeon. makes about 9 pc. total. enjoy with favorite dipping sauce!! </br></br>these were super tasty and not fishy at all!! i didn't need to add any
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     salt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  or seasoning since the canned tuna was already seasoned and had a nice savory kick to it! </br></br>and look for these brands if you want to try some high quality korean seafood!!</br>.</br>.</br>.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">prawn taco bowl</br></br>eating keto is simple⁠</br>- less carbs⁠</br>- more healthy fats⁠</br>- easy and delicious recipes⁠</br>- happy and healthy lifestyle choice⁠</br>.</br>if you don't know how to start ketodiet properly or do you want to lose possibly
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# -
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  pound in the first week alone with keto ?? join &quot;custom keto diet&quot;. link in bio .hk</br></br>perfect for a hot summer’s day, this is my spiced prawn bowl with lime
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and homemade guacamole. </br></br>shrimp
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     spices
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# :</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     90
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  raw king
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prawns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>juice of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  lime </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     garlic powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chilli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  powder </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     coriander
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  powder </br>fry for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  minutes until pink. </br></br>simple guacamole:</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     avocado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     red chilli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , diced </br>season to taste with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lime juice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     salt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; bo
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">• lunch (or dinner) idea •</br></br>the most amazing toasted sarnie, yesterday i really didn’t fancy using the oven as it was so hot! so whipped up these
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomato
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  &amp;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mozzarella
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  toasties instead and boy were they good </br></br>ingredients:</br>sourdough
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bread
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pesto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>large
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomatoes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mozzarella
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>roasted
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     red peppers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br></br>method:</br>spread
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pesto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  onto each slice of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bread
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , add one slice of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bread
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  to your george foreman grill, top with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomatoes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mozzarella
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  &amp; peppers then add second slice of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bread
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  &amp; close grill. leave for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# -
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  mins until
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cheese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  has melted &amp;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomatoes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  have softened.</br></br>calories per serving approx: 492 kcals</br></br>i’d love to hear if you give this lunch idea a try and don’t forget to tag me in your foodie pictures </br></br>emma</div></span>
# ...
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     baking soda
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     package
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sesame powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  oil </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em;
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">made fruit triffle </br></br>ingredients : </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     milk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  large
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vanilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     custard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     packet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     packet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jelly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sugar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (you can adjust according to your taste) </br>few
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     drops
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vanilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  essence </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# -
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  plain cakes </br>fruits (
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     banana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# )</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">my favorite sweet and savory breakfast easy way to curb appetite for those of us who crave all flavors in the morning! start your protein intake bright and early with protein bagels!!</br></br>macros:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     300
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  cal |
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  c |
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     37
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  p |
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  f</br></br>ingredients:</br>- everything
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bagel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tablespoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hommus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tablespoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  low sodium
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peanut butter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     banana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>- cayenne
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">this week the weather is hot and getting hotter here in the uk and the thought of a hot drink may be mad to you.</br></br>with your thermomix, you can make such a yummy cappuccino milkshake in just
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  min
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  with the cookidoo recipe </br></br>just
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  ingredients:</br></br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sugar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>instant
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     coffee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  cubes</br>whole
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     milk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br></br>message me to find out more about what you can make in such a short amount of time</br>.</br>.</br>.</br>.</br>.</br>.</br>.</br>.</br>.</br>.</br>.</br>.</div></span>

# %%
colors = {
    "MEASUREMENT": "#bfeeb7",
    "INGREDIENT": "#feca74",
    "QUANTITY": "#e4e7d2"
}
options = {"ents": list(colors), "colors": colors}

nlp = spacy.blank('en')

for i in range(len(test_set)):
    raw_text = test_set[i][0]
    doc = nlp.make_doc(raw_text)
    spans = test_set[i][1]["entities"]
    ents = []
    for span_start, span_end, label in spans:
        ent = doc.char_span(span_start, span_end, label=label)
        if ent is None:
            continue

        ents.append(ent)
        
    try:
        doc.ents = ents
    except:
        print(f"Error with document")
    #doc.ents = ents
    spacy.displacy.render(doc, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">baked
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     potato
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  skins </br></br> prep:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  mins</br> cook:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  hr
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     45
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  mins</br></br>ingredients:</br>・5
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     potatoes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>・3 deli
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , chopped</br>・cheese</br>・olive oil</br>・salt</br>・pepper</br>・parsley</br></br>servings:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">savor the end of summer watermelon season with this delicious watermelon salad! this salad is easy to make and deliciously refreshing! </br></br>save this post! full recipe below! </br>(for printable recipe card and notes: https://www.chewoutloud.com/watermelon-salad-recipe/) </br></br>ingredients: </br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     watermelon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , cubed</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1 /2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  yellow
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     grape
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  or cherry
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomatoes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , halved</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  small
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     red onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , chopped</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  freshly torn
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     basil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  leaves</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  freshly squeezed
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lime juice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  pure
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     honey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>freshly ground
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     black pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  to taste</br></br>instructions: </br></br>combine: in a large bowl, combine all ingredients. use rubber spatula to gently fold together until well combined.</br>cover and chill: cover and chill no more than
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  hour before serving (watermelon salad is best served immediately.)</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">caprese
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  salad i forgot to add in my garden
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     basil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  but this is delicious!</br></br>ingredients:</br>caprese
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chicken
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sausage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>protein
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>cherry
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomatoes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mozzarella
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  pearls</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     olive oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# /balsamic
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vinegar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>seasonings </br>(add
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     basil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  lol)</div></span>
# Error with document
# /Users/maxkirwan/opt/miniconda3/envs/data_analytics/lib/python3.9/site-packages/spacy/displacy/__init__.py:205: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[ad] porridge for a warm winter lunch </br></br>ingredients:</br>1/2 cup oats</br>1 teaspoon chia seeds</br>1 egg white </br>1 heap tablespoon vanilla protein powder</br>1/2 banana mashed</br>1 cup water</br></br>add all ingredients to a pot and cook on low heat for 3-5 min stirring often. </br>serve with a dash of cream</div></span>
# Error with document
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">afternoon tea has never looked this good . </br>this delicious zesty orange cake will melt in your mouth with every bite. we can’t think of a better way to get vitamin c </br></br>happy baking </br></br>zesty orange cake</br></br>ingredients:</br>4 large eggs </br>1 cup castor sugar</br>1 cup oil</br>1 cup fresh orange juice</br>zest of oranges used (reserve half for glaze) </br>2 cup self-raising flour</br>2 teaspoon baking powder</br></br>glaze:</br>2 cup icing sugar </br>70 ml orange juice and reserved zest</br></br>method:</br>1 .preheat oven to 180 ᵒc.</br>2 .whisk eggs well until frothy.</br>3 .add sugar and beat until thick and creamy.</br>4 .add oil and whisk well.</br>5 .add half of juice and zest and blend.</br>6 .sift in flour and baking powder and blend.</br>7 .add rest of the juice and blend.</br>8 .bake in a +/- 22 cm x 13 cm greased, lined baking pan +/- 45 minutes until a skewer comes out clean.</br>9 .allow to cool.</br>10 .drizzle over and smooth the glaze over the cake.</br></br>note: freezes well.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">this interesting flavor combo is brought to you by . i saw the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     carrot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cream cheese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  avo combo and while i’m not an avid
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     carrot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  fan, i had to give it a try! also shocker that i ate it as an actual sandwich and not toast hehe but buying sandwich thins helped take out the extra “bready” feeling ;)</br>•</br>rating: 9/10 (yummy)</br>•</br>ingredients:</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sandwich thins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     butter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br> plain
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cream cheese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     carrots
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (shredded) </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     avocado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br> everything but the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bagel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  seasoning </br></br>i also made a side salad :)</br>•</br>•</br>•</br>•</br>•</br>•</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">upside down pizza hack by </br></br>leave a “” if you love pizza </br></br>ingredients:</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pepperoni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mozzarella
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     marinara
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  sauce</br>low carb
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tortilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>seasonings of your choice </br></br>instructions:</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . add
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pepperoni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mozzarella
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , &amp;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     marinara
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  to a non-stick pan on medium heat. </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . top with low carb tortilla, after
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# -
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  minutes flip, and let the crust crisp up. season, remove from pan &amp; enjoy!</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">a little hearty zesty treat coming your way this recipe wednesday! today’s low-carb
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lemon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chicken
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  features shirataki
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     noodles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# . i mean,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lemon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chicken
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ?? a little zesty surprise for your meal! head on down to see the recipe, that’s good for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  !</br></br>low-carb
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lemon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chicken
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br></br>ingredients:</br></br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  g)
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     package
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  shirataki
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     noodles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pound
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  pastured
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chicken breast
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , cut into bite size piece</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tablespoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  mct
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  or other cooking
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  large
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     clove
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  organic
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     garlic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , minced</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pumpkin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  soup with roasted chickpeas </br></br>ingredients: </br>-
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pumpkin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (i use
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  big
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pumpkin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  or
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  small pumpkins for this recipe)</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     125
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chickpeas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  - canned/cooked </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  x
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     olive oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     garlic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . preheat the oven to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  °c.</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . peal the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pumpkin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and scrape out seeds then cut the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pumpkin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  in to chunks.</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . add
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     olive oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class=
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">* recipe post </br></br>some days you want to indulge in rich, restaurant-like north-indian food but then you don’t want to indulge in the cooking that it calls for! nahi? </br></br>this ‘
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  in cashew &amp; mawa gravy’ is the answer to your dilemma! it’s quick to cook, takes less amount of preps and the outcome? words can’t describe it! you’ll know when you try it!</br></br>some hot sizzling rotis to go with it, and you’re good to go! </br></br>here is the recipe: (perfect for the festive season) </br></br>ingredients:</br></br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     250
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  medium chopped</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     garlic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# -
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     clove
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  chopped</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cashews
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  pcs</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mawa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  grated (50 + 50 ) </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardamom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  pc whole</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cinnamon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  stick
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     clove
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  corns 7-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  pcs</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cumin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-ali
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     snickers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  nice
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cream
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br></br>by </br></br>ingredients:</br>•
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  frozen
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     banana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>• 100
# ...
#     cacao
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  nibs</br>•
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chia seeds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>• soy crispies</br>•
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     blackberries
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </div></span>
# Error with document
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">this delicious and crispy biscotti is the perfect cookie to accompany your morning cup of coffee or tea!️</br>ingredients:</br>2 cup all purpose flour </br>1 teaspoon baking powder </br>1/4 teaspoon baking soda</br>1/4 teaspoon salt</br>1/2 teaspoon cinnamon </br>1/2 teaspoon vanilla extract </br>1 cup granulated sugar</br>1 cup crushed almond and pistachio </br>3 eggs</br>for chocolate ganache:</br>1 cup chocolate chips</br>1/2 tablespoon coconut oil</br>1/2 cup crushed almond and pistachio </br>method:</br> - mix the dry ingredients in a stand mixer, then add the liquid ingredients and mix well until combined </br> - when the dough is formed, add the crushed nuts and mix again </br> - then put parchment paper in a large tray and transfer the dough</br> - shape the dough into a rectangle with 1/2 inch in height, in the middle of the tray without the edges of the dough touching the tray</br> - bake in a preheated oven at 350 °f for 27 minutes</br> - then let it cool for 10 minutes and start cutting into loaves</br> - then spread the biscuits in the tray and bake again at a temperature of 300 °f for 15 minutes</br> - then flip the biscuits over and put them back in the oven for 15 minutes</br> - then let it cool completely</br> - melt the chocolate with the coconut oil in the microwave for 30 seconds, repeating and stirring until melted</br> - dip the biscuits in the chocolate, then sprinkle some crushed nuts and place in the fridge until set</br></br>البسكاتي أو البسكويت الإيطالي </br>هذا البسكوت المقرمش واللذيذ، مغمس بالشوكولاتة والمكسرات، لذيذ وممتع مع كوب من القهوة أو الشاي ️</br>المقادير:</br> 2 كوب طحين </br> 1 ملعقة صغيرة بيكنج بودر</br> 1/4 ملعقة صغيرة بيكنج صودا</br> 1/4 ملعقة صغيرة ملح</br> 1/2 ملعقة صغيرة قرفة</br> 1/2 ملعقة صغيرة ڤانيلا</br> 1 كوب سكر </br> 1 كوب لوز وفستق مجروش</br> 3 بيضات</br> لغناش الشوكولاتة:</br> 1 كوب حبات شوكولاتة</br> 1/2 ملعقة كبيرة زيت جوز الهند</br>وتُزين ب لوز وفستق مجروش</br></br>الطريقة في الكومنت</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  aaloo mix paratha </br></br>ingredients:
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paneer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aaloo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , chopped
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and green
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chilli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     black pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  powder,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chaat masala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , roasted
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jeera powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     salt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     garam masala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     red chilli powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , wheat
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     flour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     soybean
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# .</br></br>serve it with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     butter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     achaar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , enjoy!</br>.</br>.</br>.</br>._.goodness </br>.</br>.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     egg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  pakode </br></br>oh waoo ! now this sounds so interesting </br></br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     egg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  pakode never thought these little
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eggs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  can be eaten like pakodas </br></br>if you havent tried it yet, then what are you waiting for </br></br>so here we go woo hoo </br></br>ingredients: </br>☆ boiled
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eggs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  to fry </br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     besan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# </br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     salt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  to taste</br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ajwain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# </br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jeera
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  </br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     turmeric
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  a
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pinch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  </br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     red chilli powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     coriender
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     water
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chat masala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br></br>quickly quickly tag and share this super tempting recipe with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     egg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  lovers </br></br>♡ </br>♡</br>♡ </br></br>♡</br>♡</br>♡</br>♡</br>♡ </br></br> </br></br>♡</br>♡</br>♡</br>♡</br>do follow</br> for more food recipes</div></span>
