# %% [markdown]
# # Building NER model using annotated dataset
#
# I have annotated ~40 post descriptions. I shall use these to train an NER tagger and analyse the results.

# %%
import json
import random
import pandas as pd
import numpy as np
import inflect

# %%
# Function to load in json file from LightTag
def load_json_to_df(file):
    
    results = json.load(open(file))
    
    # Create list of only those posts which have been annotated
    annotated = []
    for example in results['examples']:
        if example['annotations'] != []:
            annotated.append(example)
            
    return pd.DataFrame(annotated)


# Function to convert data into spacy format
def convert_to_spacy_format(df):
    
    TRAIN_DATA = []
    
    for index, row in df.iterrows():
        
        sentence = row['content']
        annotations_input_list = row['annotations']
        
        annotations_output_list = []
        ing_dict = {}
        
        for annotation in annotations_input_list:
            
            annotations_output_list.append((annotation['start'], annotation['end'], annotation['tag']))
        
        ing_dict['entities'] = annotations_output_list
        TRAIN_DATA.append((sentence, ing_dict))
        
    return TRAIN_DATA

# %%
TRAIN_DATA = convert_to_spacy_format(load_json_to_df('ingredient-tagger_annotations.json'))

# %%
# Splitting into train and dev set
random.seed(23)
random.shuffle(TRAIN_DATA)
split_integer = int(len(TRAIN_DATA)*0.8)
train_set = TRAIN_DATA[:split_integer]
dev_set = TRAIN_DATA[split_integer:]

# %%
# Converting TRAIN_DATA to docbin spacy file

import spacy
from spacy.tokens import DocBin
from tqdm import tqdm

def convert_to_spacy_docbin(dataset, file_location):
    
    nlp = spacy.blank("en") # load a new spacy model
    db = DocBin() # create a DocBin object

    for text, annot in tqdm(dataset):
        doc = nlp.make_doc(text) 
        ents = []
        for start, end, label in annot["entities"]:
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print(f"Skipping entity: {(start,end,label)}")
            else:
                ents.append(span)
        print(ents)
        try:
            doc.ents = ents
        except:
            print(f"Error with document")
        db.add(doc)

    db.to_disk(file_location) # save the docbin object


convert_to_spacy_docbin(train_set, "./train.spacy")
convert_to_spacy_docbin(dev_set, "./dev.spacy")
# Out:
# 100%|██████████████████████████████████████████| 28/28 [00:00<00:00, 135.93it/s]
# Skipping entity: (717, 718, 'QUANTITY')
# Skipping entity: (728, 732, 'INGREDIENT')
# Skipping entity: (786, 791, 'INGREDIENT')
# Skipping entity: (715, 716, 'QUANTITY')
# [5, tablespoon, 2, parmesan, teaspoon, black, 200, fennel seed, teaspoon, 3/4, 2, 3, 1, oil, 1, olive, fennel, 10, yeast, 25, clove, fennel, garlic, parmesan, teaspoon]
# [1/2, 1, block, ricotta, cheese, cheese, salt, 6, container, milk, 2, pasta, 5, 20, boxes, noodles, roll, 2, garlic powder, cheese, 1, italian seasoning, mozzarella, sausage, sausage, 400, tablespoon, basil, 2, jars, 1/2, 4, basil, 20, 1/2, 7, 1, mozzarella, tomato, tablespoon, ricotta, 1, cheese, 3, tablespoon]
# Skipping entity: (367, 368, 'QUANTITY')
# Skipping entity: (492, 498, 'INGREDIENT')
# [vanilla, teaspoon, sugar, 1/4, flour, 1/2, 1, custard, 1, cream, sugar, custard, tablespoon, 1/4, cup, 1, vanilla extract, 1/2, egg, cup, 1/2, tablespoon, 350, sugar, butter, 20, flour, custard, ginger, cinnamon, custard, egg, jam, 1, egg, cup, custard, cup, 4, 1, 2, custard, 1, cream, spices, egg, teaspoon, sugar, 8, 1, cup, teaspoon, vanilla, plums, 3, cream, cream, 1 /2, 25, 25, 1, 2, baking powder, 1/2, 20, tablespoon, teaspoon, 1, custard, nutmeg, cup, 1, baking powder]
# Error with document
# Skipping entity: (128, 129, 'QUANTITY')
# Skipping entity: (98, 99, 'QUANTITY')
# Skipping entity: (130, 131, 'QUANTITY')
# Skipping entity: (96, 97, 'QUANTITY')
# [teaspoon, 1, 1/4, salt, sesame seeds, sugar, 1/3, baking soda, tablespoon, package, sugar, sesame seeds, 3, 1, vanilla, 1, 1, 1, cup, oil, teaspoon, cup, cup, 17, teaspoon, sesame powder, egg, 1/3]
# Skipping entity: (273, 280, 'INGREDIENT')
# Skipping entity: (368, 369, 'QUANTITY')
# Skipping entity: (370, 371, 'QUANTITY')
# [3/4, pepper, flour, 1/2, cauliflower, tablespoon, soy sauce, red onion, 1/2, teaspoon, tablespoon, tablespoon, 1, 2, rice, 1/4, 20, water, 485, pepper, cup, 1, 15, onion, pepper, oil, 25, 10, teaspoon, 1, tablespoon, clove, garlic, cashews, cup, garlic, cup, 1, 1, oil, cauliflower, 2, salt, oil, soy sauce, 4, cauliflower, chilis⁣, sugar, 1/2, 1/4]
# [1, milk, 4, ice, sugar, coffee, 30]
# [ginger, 1, mushrooms, onion, chicken, chicken, 2, spoon, 3, cheese, cheese, 1, milk, spoon, 4, 1, ginger, garlic, oregano, mozzarella, half, oregano, spoon, tomato, butter, spoon, 4, garlic, chilli sauce, spoon, salt, spoon, black pepper, mixed herbs, cheddar, 1, 5, water, 1 .5, spices, half, soya sauce, 3, cheese, mushrooms, spices, 1, 4, onion, spoon, spoon, milk, 1, onion, garlic, half, tomatoes, spoon, olives, cup, chicken, 4, 1, spoon, half, 3, olives, spoon, ketchup, flour, chilli, herbs, oil, kg, butter, flour, oregano, 1, pepper, 4, half, water, salt, spoon, paprika]
# Error with document
# [1/2, cream, 1, onion, cheddar, cheese, onions, 4, 5, 1, 3, 1, ounce, water, cup, 8, water, lettuce, spoon, roll, 1, tomatoes, cheese, cup, 8, 6, cup, cheese, package, 1, cheese, 2, cheese, 1/2, 2]
# [tablespoon, mint, turmeric, ghee, water, 2, green chillies, cup, basmati rice, barista, 2, spices, teaspoon, teaspoon, tablespoon, ginger, 1/2, 1, 1, onion, onion, cup, 1, 1/2, garlic, 1, tablespoon, 1, onion, 1, 1, tablespoon, red chilli powder, salt, water, 1, coriander, cup, tablespoon, paneer, 1, peas, carrot, tablespoon, biryani masala, ghee, half, 1, oil]
# [teaspoon, rice, rice, 10, avocado, 2, 1/2, teaspoon, lime juice, garlic powder, cheese, spices, red chilli, 1/2, 5, 2, salt, coriander, lettuce, pinch, teaspoon, salt, 1/2, 1/2, 1/2, teaspoon, 90, coriander, rice, coriander, 125, 1/2, tomatoes, cucumber, prawns, gram, gram, jalapeños, chilli, 1/4]
# [tablespoon, pepper, 37, 12, 1/2, 27, hummus, tablespoon, 2, banana, 300, peanut butter, 2, bagel]
# [black pepper, avocado, salt, pico de gallo, cheese, 100, 2, 1, avocado, corn tortillas, lemon, half, avocado, quesadillas, gram, black pepper, salt, pico de gallo, cheese]
# [500, 1, pepperoni, 280, lemons, bunch, gram, 5, 2, lemon juice, 8, pasta, lemon juice, 1, pasta, yoghurt, salt, parsley, pasta, 2, gram, parsley, 6, yoghurt, 4, pepperoni, yoghurt, pasta, parsley, pepper, spoon, paprika, water, harissa, harissa, parsley, gram, 7, 2, 3, 75, pepperoni]
# [tomato, few, herbs, 1, baked beans, 3, zucchini, black pepper, tablespoon, cheese, cheese, gram, cheese, zucchini, 1, tomato, herbs, 2, 425, tomatoes, 4, parmesan, black pepper, baked beans, dash, 2, few, dash, 1/4]
# [35, snickers, gram, gram, tofu, banana, 100, blackberries, 200, gram, zucchini, gram, butter, 200, almond butter, flour, soy, cacao, chia seeds]
# Error with document
# [5, 1, sugar, packet, 10, kg, packet, milk, custard, vanilla, 4, vanilla, 1, kg, jelly, drops, banana, half, apple]
# [salt, 3, strip, steak, 5, steak, steak, 2, ounce, pepper, 1, 8, 30, 4]
# [aubergines, 1, tomatoes, cheese, tomato, cheese, aubergines, cheese, aubergines, pasta, 3, pasta, aubergines, 3, pecorino, 2, 4, ricotta]
# Skipping entity: (323, 324, 'QUANTITY')
# Skipping entity: (325, 326, 'QUANTITY')
# Skipping entity: (193, 194, 'QUANTITY')
# Skipping entity: (195, 196, 'QUANTITY')
# [chocolate chips, 1/4, 40, 2, baking powder, coconut milk, teaspoon, flax, salt, maple syrup, teaspoon, cup, 1/3, tablespoon, oats, 2, 1, 1/2, vanilla, 1, 2, pinch, 1, 1, cocoa, peanut butter, milk, cup, 1/3, 350, cup, cup, chocolate chips, 3, cup, butter, cup]
# Error with document
# [pesto, cheese, tomatoes, bread, mozzarella, pesto, red peppers, bread, bread, mozzarella, bread, mozzarella, tomatoes, 2, tomato, 3, tomatoes]
# Skipping entity: (380, 381, 'QUANTITY')
# [handful, 5, 1/2, 1, tablespoon, lemon juice, 1, 2, 1, onion, fillet, olive oil, tarragon, 3, 4, broccoli, salt, black pepper, 1/2, gram, lemon, broccoli, garlic, gram, parsley, hazelnuts, hazelnuts, 400, dijon mustard, 6, 2, garlic, 20, potatoes, 1, basil, broccoli, clove, water, potatoes, anchovy, 2.5, tablespoon, hazelnuts, gram, water, 75, 2, red onion, gram, potatoes, olive oil, broccoli, 20, potatoes, olive oil, teaspoon, parmigiano, 1/2, gram, 200, 20, herbs]
# Error with document
# [olive oil, yeast, half, salt, squash blossoms, flour, tofu, cheese, 4, avocados, tablespoon, 2, salt, tofu, 1, 1, 1, cheese, milk, olive oil, 1, 2, 6, 15, salt, salsa, garlic powder, water, 14, pepper, milk, salt, ounce, ricotta, tofu, 1/2, lemon juice, 10, tablespoon, teaspoon, salt, 1/2, teaspoon, tofu, 2, 10, 4, tablespoon, avocado, tablespoon, 10, tofu, 10, milk, corn tortillas, oat milk, quesadillas, pepper, cheese, corn tortillas, 3, 2, 2, tofu, yeast, lemon, garlic powder]
# Error with document
# [package, 10, rice, 10, rice, black pepper, butter, cup, carrots, brussels sprouts, water, garlic, butter, brussels sprouts, 1, garlic, package, 4, rice, 2, 2, carrots, onion, 1/4, butter, cup, chicken, black pepper, 2, 1/4, rice, water, rice, rice, cup, 5, 1, salt, 1, teaspoon, teaspoon, rice, cup, rice, black pepper, onion, clove]
# Skipping entity: (695, 696, 'QUANTITY')
# Skipping entity: (730, 731, 'QUANTITY')
# Skipping entity: (693, 694, 'QUANTITY')
# Skipping entity: (732, 733, 'QUANTITY')
# [celery, celery, 1, 2, 1/4, 2, 24, celery, avocados, celery, cilantro, tomato, red onion, 1/4, clove, salt, celery, 𝗖𝗘𝗟𝗘𝗥𝗬, garlic, salt, water, jalapeno peppers, 𝗚𝗨𝗔𝗖𝗔𝗠𝗢𝗟𝗘, 1/2, cup, teaspoon]
# [onion, cream, 3, chicken, chicken, rice, chicken, 2, teaspoon, single cream, 200, rice, pinch, chicken, spring onion, ml, pepper, chicken, rice, chicken, garlic, garlic, black pepper, salt, mustard, chicken, chicken breast, pepper, mustard, salt]
# Error with document
# [chili flakes, paneer, 1/2, litre, paneer, 3, paneer, oregano, 3, 1/2, milk, salt, teaspoon, paneer, teaspoon, jeera powder, 3, 3, paneer, 1/2, 3, 1, 4, paneer, 3, paneer, 1, paneer, teaspoon, 2]
# Skipping entity: (455, 456, 'QUANTITY')
# Skipping entity: (325, 326, 'QUANTITY')
# Skipping entity: (346, 347, 'QUANTITY')
# Skipping entity: (453, 454, 'QUANTITY')
# Skipping entity: (323, 324, 'QUANTITY')
# [cornflour, salt, 1, teaspoon, 1, flour, teaspoon, chicken, turmeric, 1/4, cup, 1, chicken, chilli, 1, teaspoon, chicken, garlic powder, g, turmeric, teaspoon, salt, pepper, cup, chilli, beer, pepper, flour, garlic powder, chicken, 1/2, 1/2, 30, 400, oil, teaspoon, cup]
# [eggs, pepper, tomatoes, cheese, cheese, egg, cup, pumpkin, eggs, sage, 1, pepper, ricotta, salt, 20, tomatoes, 6, ricotta, 400, cheese, broccoli, 1, 1/2, cup, tomatoes, 3, cheese, 25, salt, yam]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 81.20it/s]
# [863, feta, tablespoon, feta, cheese, orzo, 200, oregano, 1, 2, salt, feta, 1, teaspoon, garlic, onion, 2, 1, tomato, garlic, 30, feta, tomatoes, cheese, pasta, gram, pepper, clove, tomato, herbs, 4, onions, 4, gram, teaspoon, 863, orzo, pasta, 8, tomatoes, chorizo, cheese, chorizo, 1, cheese, basil]
# Skipping entity: (441, 446, 'INGREDIENT')
# Skipping entity: (328, 333, 'INGREDIENT')
# Skipping entity: (917, 924, 'INGREDIENT')
# Skipping entity: (384, 385, 'QUANTITY')
# Skipping entity: (427, 428, 'QUANTITY')
# Skipping entity: (316, 317, 'QUANTITY')
# Skipping entity: (347, 351, 'INGREDIENT')
# Skipping entity: (1014, 1019, 'INGREDIENT')
# Skipping entity: (382, 383, 'QUANTITY')
# Skipping entity: (526, 536, 'MEASUREMENT')
# Skipping entity: (419, 424, 'INGREDIENT')
# Skipping entity: (429, 430, 'QUANTITY')
# [flour, cup, eggs, teaspoon, 2, flax, teaspoon, cup, 6, tablespoon, oreos, bi carb, flax, water, cup, eggs, butter, 1, cup, 3, oreo, cup, 1, 180, tablespoon, oreos, oreo, eggs, 1, flaxseed, 1, tablespoon, 1, sugar, egg, sugar, 1, vanilla, 10, 1 /2, salt, 2, teaspoon, 2, flour, cup, butter, 25, 1, flax, oreos, 1/2]
# Skipping entity: (263, 264, 'QUANTITY')
# Skipping entity: (265, 266, 'QUANTITY')
# Skipping entity: (308, 309, 'QUANTITY')
# [tablespoon, pepper, vinegar, 2, pasta, zucchini, 1, pasta, pepper, 1/2, ounce, 11/2, pasta, lb, 2, 1, mozzarella, white wine vinegar, thyme, teaspoon, teaspoon, olive oil, salt, 1/4, pasta, basil, 11/2, 1, cheese, pasta, package, teaspoon, teaspoon, 1, teaspoon, tomato, cup, thyme, ounce, cup, eggplant, 1/2, black pepper, lb, cup, 10, tablespoon, 21/2, 1, 1, 2, 1/2, 1, 1, teaspoon, cup, zucchini, tomatoes, 2, 1, salt, 1, 3, basil, salt]
# [chia seeds, 8, 500, milk, 20, pistachio, 1/2, 1, sugar, 1, milk, 1, cup, chia, oats, teaspoon, 1, gram, 1, 1, 3, oats, cardamom seeds, teaspoon, 6, 2, water, tablespoon, pistachios, ml]
# Skipping entity: (587, 592, 'MEASUREMENT')
# [pepper, ounce, 1, 11/2, 2, 8, paprika, 40, kale, onion, 350, mushrooms, 30, package, cup, 1, kale, hash browns, mushrooms, 2, spinach, 1, pepper, onion, jars, 1, hashbrowns, paprika, potato queso, 30]
# [300, 2, 27, 1/2, peanut butter, tablespoon, 2, bagel, tablespoon, hommus, banana, 12, 37, pepper]
# Skipping entity: (534, 535, 'QUANTITY')
# Skipping entity: (536, 537, 'QUANTITY')
# [1, garlic, 2, 2, gochu chamchi, 3, 1/2, salt, black pepper, 5, onion, 2, scallion, 1/2, crackers, buchim garoo, 10, tablespoon, pinch, tuna, can, 1]
# [cup, 1, mayo, 1, red onion, 2, 3, pepper, avocado oil, celery, tbs, crackers, 2, tomatoes, stocks, chicken, chicken, salt, 2, chicken, pepper, mayonnaise]

# %% [markdown]
# ## Running the model

# %%
! python -m spacy init config config.cfg --lang en --pipeline ner --optimize efficiency
# Out:
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: en
# - Pipeline: ner
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
! python -m spacy train config.cfg --output ./ --paths.train ./train.spacy --paths.dev ./dev.spacy
# Out:
# ℹ Saving to output directory: .
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# [2022-08-11 11:08:34,702] [INFO] Set up nlp object from config
# [2022-08-11 11:08:34,721] [INFO] Pipeline: ['tok2vec', 'ner']
# [2022-08-11 11:08:34,736] [INFO] Created vocabulary
# [2022-08-11 11:08:34,737] [INFO] Finished initializing nlp object
# [2022-08-11 11:08:35,757] [INFO] Initialized pipeline components: ['tok2vec', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     62.21    1.18    3.45    0.71    0.01
#   7     200         97.46   3599.58   80.74   84.17   77.58    0.81
#  14     400        112.80    231.63   84.09   89.88   79.00    0.84
#  21     600        133.64    119.79   81.83   84.47   79.36    0.82
#  28     800         87.56     55.46   84.07   87.64   80.78    0.84
#  35    1000         78.46     30.76   81.99   84.79   79.36    0.82
#  43    1200         52.98     15.68   84.79   91.02   79.36    0.85
#  50    1400        115.48     37.91   82.84   87.06   79.00    0.83
#  57    1600        332.15     56.95   81.25   84.03   78.65    0.81
#  64    1800        285.84    103.09   84.73   91.36   79.00    0.85
#  72    2000         83.12     22.03   80.00   81.02   79.00    0.80
#  79    2200         57.04     15.76   83.30   88.10   79.00    0.83
#  87    2400         42.17     10.01   80.51   82.46   78.65    0.81
#  94    2600        113.43     25.38   82.80   88.31   77.94    0.83
# 103    2800        111.65     25.12   81.65   86.17   77.58    0.82
# ✔ Saved pipeline to output directory
# model-last

# %%
nlp_ner = spacy.load("./model-best")

# %%
posts = pd.read_csv('preprocessed_descriptions.csv')

colors = {
    "MEASUREMENT": "#bfeeb7",
    "INGREDIENT": "#feca74",
    "QUANTITY": "#e4e7d2"
}
options = {"ents": list(colors), "colors": colors}

for post in posts['description_preprocessed'][121:130]:
    doc = nlp_ner(post)
    spacy.displacy.render(doc, style="ent", options=options, jupyter=True)
    print("\n------------------------------------------------\n")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">what could be better in summer than a bbq with your favorite people? we've brought you a particularly cool recipe idea for this: pulled pork carnitas with our homemade sour
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cream
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  sauce! </br></br>ingredients:</br>- 250
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  sour
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cream
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  mayonnaise (min. 50 % fat)</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cream
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cheese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     yogurt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  3.2 %</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  smoked
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paprika
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  powder</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chili
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  cayenne</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  ground cumin</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     garlic powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tablespoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1
# ------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">caprese
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  salad i forgot to add in my garden
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     basil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  but this is delicious!</br></br>ingredients:</br>caprese
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chicken
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sausage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>protein
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>cherry
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomatoes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mozzarella
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  pearls</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     olive
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  oil/balsamic vinegar </br>seasonings </br>(add
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     basil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  lol)</div></span>
# ------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sausage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , mushroom &amp; brie
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     egg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  bake</br></br>ingredients:</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ounce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  mild italian
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sausage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  mushroom (sliced)</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  small
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     red onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (diced)</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     clove
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  minced
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     garlic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  spinach</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  brie
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cheese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (cubed)</br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eggs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     milk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  /2
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height:
# ------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">fancy a low cal tiramisu? </br>and you know what? this is prep friendly too!! </br></br>ingredients:</br></br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  cakes (i used
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  )</br></br>(if you feel having something sweeter try chocolate or biscoff covered ones if you have more cals. this recipe is made of plain
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  cakes.)</br></br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vanilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  yogurt (or plain with zero cal
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vanilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  drops ) (160 ml)</br></br>espresso
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     coffee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  ️ </br></br>cacao powder (5
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     g
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# )</br></br>macros for this recipe. </br>protein
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     g
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     carbs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     g
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# </br>fats
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     g
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# </br></br>cals 206 .</br></br>enjoy</div></span>
# ------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">firecracker tofu
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lettuce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  wrap is a quick and simple recipe of tofu tossed in a firecracker sauce served on a bed of crunchy fresh
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lettuce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# .</br>try it today!</br></br>recipe link: https://bit.ly/3 bafl4 f</br></br>ingredients :</br>250
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  diced extra firm tofu</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  finely sliced
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     red onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     inch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ginger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  juliennes</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  finely chopped spring
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  thinly sliced
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peppers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# -
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  white
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sesame seeds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br></br>for the firecracker sauce :</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tablespoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  teriyaki sauce</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tablespoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  vegetarian
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oyster
#     <span
# ------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     egg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  pakode </br></br>oh waoo ! now this sounds so interesting </br></br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     egg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  pakode never thought these little eggs can be eaten like pakodas </br></br>if you havent tried it yet, then what are you waiting for </br></br>so here we go woo hoo </br></br>ingredients: </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ☆
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  boiled
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eggs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  to fry </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ☆
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  besan
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ☆
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     salt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  to taste</br>☆ ajwain
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ☆
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jeera 1/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ☆
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     turmeric
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  a
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pinch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  </br>☆
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     red chilli powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ☆
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  coriender </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ☆
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     water
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>☆ chat masala </br></br>quickly quickly tag and share this super tempting recipe with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     egg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  lovers </br></br>♡ </br>♡</br>♡ </br></br>♡</br>♡</br>♡</br>♡</br>♡ </br></br> </br></br>♡</br>♡</br>♡</br>♡</br>do follow</br> for more food recipes</div></span>
# ------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">who doesn’t love a recipe that is simple and delicious? </br></br>i make this once a week - it’s enough for dinner
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  nights in a row and both of our kiddos *love* it! </br></br>ingredients:</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     •2 pound
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  ground beef (we use 85/15 )</br>•2 medium
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zucchini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (sliced &amp; quartered)</br>•elbow
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ounce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  - i use because it’s gluten free -plus it adds more fiber &amp; protein!)</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     •tomato sauce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (8 oz)</br>•chicken broth (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# )</br>•shredded
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cheddar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cheese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# )</br>•mustard (2 t)</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     •hamburger seasoning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  t)</br>•tobasco (optional - to taste)</br>•salt +
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (to taste)</br></br>how to make it:</br>•pan fry ground beef in a large pot/skillet</br>•when beef is finished, toss in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zucchini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>•once the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zucchini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  is somewhat tender - add in the broth,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomato
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  sauce, mustard, tobasco &amp; seasonings. </br>•simmer until
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  is ready, then fold in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cheese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (iykyk )</br></br>makes 6
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     servings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; m
# ------------------------------------------------
# ...
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  /2 cup lentils</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     -1.5 pound
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  of ground beef</br>-1
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  </br>-1 large
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     carrot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-2 large
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     celery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  stick</br>-1/2
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  curry</br>-1/4
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     turmeric
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-1
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  aleppo
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-2
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  /2
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  dry dill</br>-1/4
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     garlic powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>-1
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  /2
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tablespoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomato
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  paste</br>-1
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     egg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     -salt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  to taste</br></br>preparation: </br>begin by chopping
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  into very small piece or grinding it. start mixing the ground beef, dry ingredients,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomato
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  paste,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     egg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius:
# ------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">kick your immunity into gear with this easy to make
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chicken
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  soup packed full of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     immune
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# -boosting nutrients, you'll want to sip on this all month long! </br></br>get the recipe from below </br></br>ingredients:</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  large
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , chopped</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  spring
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , sliced (be sure to also add the root ends to the soup -- they are extra healing)</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  large
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     carrots
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , peeled and sliced</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     celery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  stalk, sliced</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  large
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     garlic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     clove
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
# , smashed</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  large stick of wakame seaweed (this can be left out, or replaced with spinach)</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1/4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chicken
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  bone broth (this can be substituted with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chicken
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  stock)</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     water
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MEASUREMENT</span>
# </mark>
#  boneless
# <mark class="entity" style="background: #feca74;
# ------------------------------------------------

# %% [markdown]
# ## Determining unique ingredients in each post

# %%
def get_unique_ingredients(text, model):
    
    nlp = spacy.load(model)
    doc = nlp(text)
    
    ingredients = []
    ingredients_singularized = []
    
    for entity in doc.ents:
        if entity.label_ == 'INGREDIENT':
            ingredients.append(entity.text)

    ingredients = np.unique(ingredients)
    
    # Singularizing ingredients using inflect python package
    p = inflect.engine()
    for word in ingredients:
        if p.singular_noun(word):
            ingredients_singularized.append(p.singular_noun(word))
        else:
            ingredients_singularized.append(word)
            
    return np.unique(ingredients_singularized)

# %%
# Adding list of unique ingredients column to dataframe
posts['unique_ingredients'] = posts['description_preprocessed'].apply(get_unique_ingredients)

# %%
def include_unique_ingredients(df, model):
    
    nlp = spacy.load(model)
    
    df['unique_ingredients'] = df['description_preprocessed'].apply(get_unique_ingredients)
    
    return df

# %%
include_unique_ingredients(pd.read_csv('preprocessed_descriptions.csv'), "./model-best")
# Out:
#      Unnamed: 0                           description_preprocessed  \
# 0            81  chocolate fudge protein oatmeal \ningredients:...
# 1           104  ⁣caprese chicken with pesto ⠀\n⠀\nthis dish is...
# 2           169  looking for a fast recipe to make for lunch? t...
# 3           172  sweet & savoury mushroom scones~ this easy and...
# 4           226  paneer tikka recipe\nsave it to try later\n\ni...
# ..          ...                                                ...
# 328        3208  prawn taco bowl\n—————————————————————-\nperfe...
# 329        3389  salmon, butternut squash, sweet potato and kal...
# 330        3463  are you feeling lazy? we have just the recipe ...
# 331        3556  servings: 1 \n⠀ ⠀\ningredients:\n⠀\n1/4 cup sh...
# 332        3558  servings: 1 \n⠀ ⠀\ningredients:\n⠀\n1/4 cup sh...
#
#                                     unique_ingredients
# 0     [banana, milk, oat, peanut butter, sugar, water]
# 1    [basil, breast, cheese, chicken, mozarella, oi...
# 2      [ginger, hemp seed, oil, olive, platter, water]
# 3    [baking powder, butter, cheese, cream, egg, fl...
# 4    [black pepper powder, butter, carom seed, cumi...
# ..                                                 ...
# 328  [avocado, cheese, chilli, coriander, cucumber,...
# 329  [black, garlic powder, oil, paprika, pepper, p...
# 330  [black pepper, bread, butter, cheese, garlic, ...
# 331        [black pepper, cheddar, cheese, egg, flour]
# 332        [black pepper, cheddar, cheese, egg, flour]
#
# [333 rows x 3 columns]
