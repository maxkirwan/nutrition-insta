# %% [markdown]
# # Building an NER tagger
#
# Using the NY Times labelled dataset to train a named entity resolution model to identify tags such as name, quantity and measurement for ingredient phrases.

# %%
import pandas as pd
import numpy as np
import re
import spacy

# %% [markdown]
# **Loading in the training data**

# %%
nyt_data = pd.read_csv("https://raw.githubusercontent.com/mtlynch/ingredient-phrase-tagger/master/nyt-ingredients-snapshot-2015.csv")
nyt_data
# Out:
#          index                                              input  \
# 0            0  1 1/4 cups cooked and pureed fresh butternut s...
# 1            1  1 cup peeled and cooked fresh chestnuts (about...
# 2            2            1 medium-size onion, peeled and chopped
# 3            3                    2 stalks celery, chopped coarse
# 4            4                    1 1/2 tablespoons vegetable oil
# ...        ...                                                ...
# 179202  179202                            3/4 oz. pineapple juice
# 179203  179203                           1 tsp. fresh lemon juice
# 179204  179204                                  Angostura bitters
# 179205  179205                                 Wedge of pineapple
# 179206  179206                                    Brandied cherry
#
#                      name   qty  range_end        unit  \
# 0        butternut squash  1.25        0.0         cup
# 1               chestnuts  1.00        0.0         cup
# 2                   onion  1.00        0.0         NaN
# 3                  celery  2.00        0.0       stalk
# 4           vegetable oil  1.50        0.0  tablespoon
# ...                   ...   ...        ...         ...
# 179202    pineapple juice  0.75        0.0       ounce
# 179203        lemon juice  1.00        0.0    teaspoon
# 179204  Angostura bitters  0.00        0.0         NaN
# 179205          pineapple  1.00        0.0       wedge
# 179206    Brandied cherry  0.00        0.0         NaN
#
#                                                   comment
# 0       cooked and pureed fresh, or 1 10-ounce package...
# 1       peeled and cooked fresh (about 20), or 1 cup c...
# 2                         medium-size, peeled and chopped
# 3                                          chopped coarse
# 4                                                     NaN
# ...                                                   ...
# 179202                                                NaN
# 179203                                              fresh
# 179204                                                NaN
# 179205                                                NaN
# 179206                                                NaN
#
# [179207 rows x 7 columns]

# %% [markdown]
# ### Focusing on ingredient name
#
# Initially, I shall build an NER model which focuses only on 1 entity, the name of the ingredient.
#
# I have decided to do this as the name of the ingredient from the labelled dataset always* corresponds to a string from the input, whereas the quantity and unit do not directly relate to strings from the input. For example:
#
# - Quantity "1 1/4" changed to "1.25" by annotator.
# - Unit "oz.", "tsp." changed to "ounce", "teaspoon" by annotator.

# %% [markdown]
# *There are ~8000 cases where this is not the case. These cases are removed.

# %%
nyt_data[nyt_data.apply(lambda row: str(row['name']) in str(row['input']), axis=1) == False].head(3)
# Out:
#      index                                     input  \
# 5        5                                       NaN
# 123    123  1/2 teaspoon freshly ground black pepper
# 178    178  Chopped fresh parsley leaves for garnish
#
#                                          name  qty  range_end      unit  \
# 5                                       water  0.5        0.0       cup
# 123               Freshly ground black pepper  0.5        0.0  teaspoon
# 178  chopped fresh parsley leaves for garnish  0.0        0.0       NaN
#
#     comment
# 5       NaN
# 123     NaN
# 178     NaN

# %%
nyt_data = nyt_data[nyt_data.apply(lambda row: str(row['name']) in str(row['input']), axis=1)]

# %% [markdown]
# **Edit:** It turns out that most units are also correct, so I could also use units as named entities. This would require some regex to include plurals, e.g. "cup" or "cups"

# %%
no_nans = nyt_data[nyt_data.unit.isna()==False]
no_nans[no_nans.apply(lambda row: str(row['unit']) in str(row['input']), axis=1)]
# Out:
#          index                                              input  \
# 0            0  1 1/4 cups cooked and pureed fresh butternut s...
# 1            1  1 cup peeled and cooked fresh chestnuts (about...
# 3            3                    2 stalks celery, chopped coarse
# 4            4                    1 1/2 tablespoons vegetable oil
# 6            6  2 tablespoons unflavored gelatin, dissolved in...
# ...        ...                                                ...
# 179187  179187       2 cups cherry tomatoes, sliced into quarters
# 179188  179188                                   ½ cup sour cream
# 179189  179189              ½ cup roughly chopped cilantro leaves
# 179195  179195       2 dashes Angostura or Regans’ Orange Bitters
# 179198  179198                                1 strip orange peel
#
#                     name   qty  range_end        unit  \
# 0       butternut squash  1.25        0.0         cup
# 1              chestnuts  1.00        0.0         cup
# 3                 celery  2.00        0.0       stalk
# 4          vegetable oil  1.50        0.0  tablespoon
# 6                gelatin  2.00        0.0  tablespoon
# ...                  ...   ...        ...         ...
# 179187   cherry tomatoes  2.00        0.0         cup
# 179188        sour cream  0.50        0.0         cup
# 179189   cilantro leaves  0.50        0.0         cup
# 179195    Orange Bitters  2.00        0.0        dash
# 179198       orange peel  1.00        0.0       strip
#
#                                                   comment
# 0       cooked and pureed fresh, or 1 10-ounce package...
# 1       peeled and cooked fresh (about 20), or 1 cup c...
# 3                                          chopped coarse
# 4                                                     NaN
# 6                  unflavored, dissolved in 1/2 cup water
# ...                                                   ...
# 179187                             , sliced into quarters
# 179188                                                NaN
# 179189                                    roughly chopped
# 179195                               Angostura or Regans’
# 179198                                                NaN
#
# [119016 rows x 7 columns]

# %% [markdown]
# ### Format for training data
#
# The data for training the custom NER tagger must be of the form:
#
#     TRAIN_DATA = [('3 tablespoons chopped fresh sage',
#                 {'entities': [(28, 32, 'INGREDIENT')]}),
#                 ('1/4 cup brown sugar',
#                 {'entities': [(8, 19, 'INGREDIENT')]}),
#                 ('1 1/2 cups heavy cream',
#                 {'entities': [(11, 22, 'INGREDIENT')]}),
#                 ('1 1/4 cups whole milk',
#                 {'entities': [(11, 21, 'INGREDIENT')]}),
#                 ...
#                 ]

# %% [markdown]
# ***Cleaning NYTimes Dataset***
#
#
# 1. The columns - input, name - are converted to string
# 2. Words to be removed from the name column are identified as sometimes the name column contains descriptive information
# 3. Words are removed from name column if there is additional information present
# 4. Parantheses and text between parantheses is eliminated for name column as it contains additional information
# 5. Drop rows which contain null values for input and name column. This form of imputation is acceptable here as we are utilizing a very small subset of the data and there aren't many null values in the original dataset.

# %%
#convert input and name to string
nyt_data['input'] = nyt_data['input'].astype(str)
nyt_data['name'] = nyt_data['name'].astype(str)
# Out:
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_92016/292912997.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_data['input'] = nyt_data['input'].astype(str)
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_92016/292912997.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_data['name'] = nyt_data['name'].astype(str)

# %%
#clean the name column with these words
remove_words = ['ground','to','taste', 'and', 'or', 'powder','white','red','green','yellow', 'can', 'seed', 'into', 'cut', 'grated',\
                'leaf','package','finely','divided','a','piece','optional','inch','needed','more','drained','for','flake','juice','dry','breast',\
                'extract','yellow','thinly','boneless','skinless','cubed','bell','bunch','cube','slice','pod','beaten','seeded','broth','uncooked',\
                'root','plain','baking','heavy','halved','crumbled','sweet','with','hot','confectioner','room','temperature','trimmed',\
                'all-purpose','sauce','crumb','deveined','bulk','seasoning','jar','food','sundried','italianstyle','if','bag','mix','in',\
                'each','roll','instant','double','such','extra-virgin','frying','thawed','whipping','stock','rinsed','mild','sprig','brown',\
                'freshly','toasted','link','boiling','cooked','basmati','unsalted','container','split','cooking','thin','lengthwise','warm',\
                'softened','thick','quartered','juiced','pitted','chunk','melted','cold','coloring','puree','cored','stewed',\
                'floret','coarsely','the','clarified','blanched','zested','sweetened','powdered','longgrain','garnish','indian','dressing',\
                'soup','at','active','french','lean','chip','sour','condensed','long','smoked','ripe','skinned','fillet','from','stem','flaked',\
                'removed','zest','stalk','unsweetened','baby','cover','crust', 'extra', 'prepared', 'blend', 'of', 'ring','plus','firmly', 'packed',\
                'lightly','level','even','rounded','heaping','heaped','sifted','bushel','peck','stick','chopped','sliced','halves', 'shredded',\
                'slivered','sliced','whole','paste','whole',' fresh', 'peeled', 'diced','mashed','dried','frozen','fresh','peeled','candied',\
                'no', 'pulp','crystallized','canned','crushed','minced','julienned','clove','head', 'small','large','medium', 'good', 'quality', \
                'freshly']

# %%
#drop null 
nyt_data = nyt_data.dropna(axis = 0, subset = ['input', 'name'])

# %%
def clean_nyt_data(df, col, size):
  #clean extra words and brackets
    cleaned_col = []
    for _, row in df.iloc[:size].iterrows():
        #remove text within parantheses along with the parantheses
        row[col] = re.sub("[\(\[].*?[\)\]]", "", row[col])
        row[col] = row[col].replace("-", "")
        curr_row =  row[col].split()
        if len(curr_row) > 1:
            resultwords  = [word for word in curr_row if word.lower() not in remove_words]
            row[col] = ' '.join(resultwords)
        if row[col] == '':
            cleaned_col.append(" ")
        else:
            cleaned_col.append(row[col])
    df.iloc[:size][col] = cleaned_col
    return(df.iloc[:size])

# %%
cleaned_nyt_data = clean_nyt_data(nyt_data, 'name', 1000)
# Out:
# /var/folders/hn/dknbybgs0qv4myljwr8qtf4c0000gn/T/ipykernel_92016/2076217046.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[:size][col] = cleaned_col

# %%
cleaned_nyt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 1045
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      1000 non-null   int64
#  1   input      1000 non-null   object
#  2   name       1000 non-null   object
#  3   qty        1000 non-null   float64
#  4   range_end  1000 non-null   float64
#  5   unit       748 non-null    object
#  6   comment    621 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 62.5+ KB

# %%
# Removing any obviously wrong names, e.g. small red onion, finely diced
cleaned_nyt_data = cleaned_nyt_data[cleaned_nyt_data['name'].str.len()<18]

# %% [markdown]
# ***Transforming the NYTimes Dataset***

# %%
def generateEntity(line, ingredient_list, entity):
    curr_dict = {}
    if len(ingredient_list) == 1:
        ingd_regex = re.compile(ingredient_list[0])
        entity_match = ingd_regex.search(line)
        curr_dict['entities'] = [(entity_match.start(), entity_match.end(), entity)]
        return(curr_dict['entities'])
    else:
        for i in range(len(ingredient_list)):
            ingd_regex = re.compile(ingredient_list[i])
            entity_match = ingd_regex.search(line)
            if i == 0:
                curr_dict['entities'] = [(entity_match.start(), entity_match.end(), entity)]
            else:
                curr_dict['entities'].append((entity_match.start(), entity_match.end(), entity))
    return(curr_dict['entities'])


def generateTrainingData(df, inputCol, ingredientCol, entity):
    TRAIN_DATA = []
    subset = df[[inputCol, ingredientCol]]
    for ix in range(len(df)):
        line = subset.iloc[ix, 0]
        ingd_name = subset.iloc[ix, 1]
        ent_dict = {}
        ingd_list = ingd_name.split()
        flag = 0
        #for each token
        for ingredient in ingd_list:
            if line == 'nan' or ingredient == 'nan':
                flag = 1
                continue
            if ingredient not in line:
                flag = 1
                continue
        if flag == 0:
            ent_dict['entities'] = generateEntity(line, ingd_list, entity)
            TRAIN_DATA.append((line, ent_dict))
            print("\n", "Adding", (line, ent_dict), "to row {0}".format(ix + 1), end = " ")
        else:
            print("\n","Skipping {} row".format(ix + 1), end = " ")
    return(TRAIN_DATA)

# %%
TRAIN_DATA = generateTrainingData(cleaned_nyt_data, "input", 'name', 'INGREDIENT')
# Out:
#  Adding ('1 1/4 cups cooked and pureed fresh butternut squash, or 1 10-ounce package frozen squash, defrosted', {'entities': [(35, 44, 'INGREDIENT'), (45, 51, 'INGREDIENT')]}) to row 1
#  Adding ('1 cup peeled and cooked fresh chestnuts (about 20), or 1 cup canned, unsweetened chestnuts', {'entities': [(30, 39, 'INGREDIENT')]}) to row 2
#  Adding ('1 medium-size onion, peeled and chopped', {'entities': [(14, 19, 'INGREDIENT')]}) to row 3
#  Adding ('2 stalks celery, chopped coarse', {'entities': [(9, 15, 'INGREDIENT')]}) to row 4
#  Adding ('1 1/2 tablespoons vegetable oil', {'entities': [(18, 27, 'INGREDIENT'), (28, 31, 'INGREDIENT')]}) to row 5
#  Adding ('2 tablespoons unflavored gelatin, dissolved in 1/2 cup water', {'entities': [(25, 32, 'INGREDIENT')]}) to row 6
#  Adding ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}) to row 7
#  Adding ('1 cup canned plum tomatoes with juice', {'entities': [(13, 17, 'INGREDIENT'), (18, 26, 'INGREDIENT')]}) to row 8
#  Adding ('6 cups veal or beef stock', {'entities': [(20, 25, 'INGREDIENT')]}) to row 9
#  Adding ('4 bay leaves', {'entities': [(2, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}) to row 10
#  Adding ('6 cloves garlic, crushed and chopped', {'entities': [(9, 15, 'INGREDIENT')]}) to row 11
#  Adding ('2 carrots, peeled and diced', {'entities': [(2, 9, 'INGREDIENT')]}) to row 12
#  Adding ('2 medium onions, diced', {'entities': [(9, 15, 'INGREDIENT')]}) to row 13
#  Adding ('6 tablespoons butter', {'entities': [(14, 20, 'INGREDIENT')]}) to row 14
#  Adding ('1 tablespoon Creole seasoning, or other seasonings of your choice', {'entities': [(13, 19, 'INGREDIENT'), (20, 29, 'INGREDIENT')]}) to row 15
#  Adding ('3 pounds beef brisket', {'entities': [(9, 13, 'INGREDIENT'), (14, 21, 'INGREDIENT')]}) to row 16
#  Adding ('1/2 cup fine dry bread crumbs', {'entities': [(17, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}) to row 17
#  Adding ('Freshly ground black pepper', {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}) to row 18
#  Adding ('3 tablespoons minced scallions', {'entities': [(21, 30, 'INGREDIENT')]}) to row 19
#  Adding ('1 tablespoon flour', {'entities': [(13, 18, 'INGREDIENT')]}) to row 20
#  Adding ('6 ounces button mushrooms, thinly sliced then coarsely chopped', {'entities': [(9, 15, 'INGREDIENT'), (16, 25, 'INGREDIENT')]}) to row 21
#  Adding ('13 tablespoons butter', {'entities': [(15, 21, 'INGREDIENT')]}) to row 22
#  Adding ('4 large artichokes, trimmed', {'entities': [(8, 18, 'INGREDIENT')]}) to row 23
#  Adding ('Juice of 1 lemon', {'entities': [(11, 16, 'INGREDIENT')]}) to row 24
#  Adding ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}) to row 25
#  Adding ('1/4 teaspoon vanilla extract', {'entities': [(13, 20, 'INGREDIENT'), (21, 28, 'INGREDIENT')]}) to row 26
#  Adding ('2 large eggs', {'entities': [(8, 12, 'INGREDIENT')]}) to row 27
#  Adding ('Pinch of freshly grated nutmeg', {'entities': [(24, 30, 'INGREDIENT')]}) to row 28
#  Adding ('2 teaspoons baking powder', {'entities': [(12, 18, 'INGREDIENT'), (19, 25, 'INGREDIENT')]}) to row 29
#  Adding ('1/4 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}) to row 30
#  Adding ('1/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}) to row 31
#  Adding ('6 tablespoons flour', {'entities': [(14, 19, 'INGREDIENT')]}) to row 32
#  Adding ('2 cups cooked medium- or long-grain white rice', {'entities': [(36, 41, 'INGREDIENT'), (42, 46, 'INGREDIENT')]}) to row 33
#  Adding ('Vegetable oil, for deep-frying', {'entities': [(0, 9, 'INGREDIENT'), (10, 13, 'INGREDIENT')]}) to row 34
#  Adding ('pound elbow macaroni', {'entities': [(6, 11, 'INGREDIENT'), (12, 20, 'INGREDIENT')]}) to row 35
#  Adding ('Freshly ground black pepper', {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}) to row 36
#  Adding ('2 teaspoons Dijon mustard', {'entities': [(12, 17, 'INGREDIENT'), (18, 25, 'INGREDIENT')]}) to row 37
#  Adding ('cup heavy cream', {'entities': [(4, 9, 'INGREDIENT'), (10, 15, 'INGREDIENT')]}) to row 38
#  Adding ('2 cups whole milk', {'entities': [(13, 17, 'INGREDIENT')]}) to row 39
#  Adding ('3 tablespoons flour', {'entities': [(14, 19, 'INGREDIENT')]}) to row 40
#  Adding ('5 cups coarsely grated extra-sharp Cheddar', {'entities': [(35, 42, 'INGREDIENT')]}) to row 41
#  Adding ('2 cups panko or coarse dry bread crumbs', {'entities': [(27, 32, 'INGREDIENT'), (33, 39, 'INGREDIENT')]}) to row 42
#  Adding ('5 tablespoons unsalted butter', {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}) to row 43
#  Adding ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}) to row 44
#  Adding ('Sprigs of watercress', {'entities': [(10, 20, 'INGREDIENT')]}) to row 45
#  Adding ('2 tablespoons extra-virgin olive oil', {'entities': [(27, 32, 'INGREDIENT'), (33, 36, 'INGREDIENT')]}) to row 46
#  Adding ('1 2-pound beef tenderloin roast, cut from the large end, trimmed and tied at 1/2 -inch intervals with kitchen twine', {'entities': [(10, 14, 'INGREDIENT'), (15, 25, 'INGREDIENT')]}) to row 47
#  Adding ('1/8 teaspoon ground cinnamon', {'entities': [(20, 28, 'INGREDIENT')]}) to row 48
#  Adding ('1 tablespoon cocoa powder', {'entities': [(13, 18, 'INGREDIENT'), (19, 25, 'INGREDIENT')]}) to row 49
#  Adding ('3 tablespoons medium-roast coffee beans, finely ground', {'entities': [(27, 33, 'INGREDIENT'), (34, 39, 'INGREDIENT')]}) to row 50
#  Adding ('1 teaspoon light-brown sugar', {'entities': [(17, 22, 'INGREDIENT'), (23, 28, 'INGREDIENT')]}) to row 51
#  Adding ('Kosher salt', {'entities': [(7, 11, 'INGREDIENT')]}) to row 52
#  Adding ('1/4 cup heavy cream', {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}) to row 53
#  Adding ('2 1/2 cups chicken stock', {'entities': [(11, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}) to row 54
#  Adding ('4 large cloves garlic', {'entities': [(15, 21, 'INGREDIENT')]}) to row 55
#  Adding ('1 1/2 cups chopped white onion', {'entities': [(25, 30, 'INGREDIENT')]}) to row 56
#  Adding ('3 tablespoons unsalted butter', {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}) to row 57
#  Adding ('2 dried pasilla chilies', {'entities': [(8, 15, 'INGREDIENT'), (16, 23, 'INGREDIENT')]}) to row 58
#  Adding ('2 dashes of Angostura bitters', {'entities': [(12, 21, 'INGREDIENT'), (22, 29, 'INGREDIENT')]}) to row 59
#  Adding ('1/2 ounce apple schnapps', {'entities': [(10, 15, 'INGREDIENT'), (16, 24, 'INGREDIENT')]}) to row 60
#  Adding ('1/2 ounce sweet vermouth', {'entities': [(10, 15, 'INGREDIENT'), (16, 24, 'INGREDIENT')]}) to row 61
#  Adding ('2 ounces applejack', {'entities': [(9, 18, 'INGREDIENT')]}) to row 62
#  Adding ('1 orange slice 1 1/4-inch thick, cut in half', {'entities': [(2, 8, 'INGREDIENT')]}) to row 63
#  Adding ('1 cup sugar', {'entities': [(6, 11, 'INGREDIENT')]}) to row 64
#  Adding ('12 ounces cranberries, washed and picked over', {'entities': [(10, 21, 'INGREDIENT')]}) to row 65
#  Adding ('1 1/2 cups strawberries (about 1 pint), hulled and halved', {'entities': [(11, 23, 'INGREDIENT')]}) to row 66
#  Adding ('3 bananas', {'entities': [(2, 9, 'INGREDIENT')]}) to row 67
#  Adding ('3 tablespoons Triple Sec', {'entities': [(14, 20, 'INGREDIENT'), (21, 24, 'INGREDIENT')]}) to row 68
#  Adding ('3 tablespoons fresh lemon juice', {'entities': [(20, 25, 'INGREDIENT'), (26, 31, 'INGREDIENT')]}) to row 69
#  Adding ('3/4 cup fresh orange juice', {'entities': [(14, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}) to row 70
#  Adding ('3 papayas (1 pound each), peeled and cut into 1-inch chunks (about 4 cups)', {'entities': [(2, 9, 'INGREDIENT')]}) to row 71
#  Adding ('6 kiwis (3 to 4 ounces each), peeled and cut into rounds about 1/4-inch thick', {'entities': [(2, 7, 'INGREDIENT')]}) to row 72
#  Adding ('3 McIntosh apples (8 ounces each), peeled, quartered, cored and cut into thin wedges (about 3 cups)', {'entities': [(2, 10, 'INGREDIENT'), (11, 17, 'INGREDIENT')]}) to row 73
#  Adding ('3 Anjou pears (8 ounces each), peeled, halved, cored and thinly sliced lengthwise (about 3 cups)', {'entities': [(2, 7, 'INGREDIENT'), (8, 13, 'INGREDIENT')]}) to row 74
#  Adding ('1 small pineapple, peeled, cored and cut into 1-inch chunks (about 3 cups)', {'entities': [(8, 17, 'INGREDIENT')]}) to row 75
#  Adding ('9 juice oranges (6 ounces each), peeled and sectioned', {'entities': [(8, 15, 'INGREDIENT')]}) to row 76
#  Adding ('2 small pink grapefruits (12 ounces each) or 1 large pink grapefruit, peeled and sectioned', {'entities': [(13, 24, 'INGREDIENT')]}) to row 77
#  Adding ('3 cups seedless grapes, equal amounts of red and green', {'entities': [(16, 22, 'INGREDIENT')]}) to row 78
#  Adding ('18 kumquats, thinly sliced', {'entities': [(3, 11, 'INGREDIENT')]}) to row 79
#  Adding ('1 cup sifted granulated sugar (optional)', {'entities': [(24, 29, 'INGREDIENT')]}) to row 80
#  Adding ('1 teaspoon pure vanilla extract', {'entities': [(16, 23, 'INGREDIENT'), (24, 31, 'INGREDIENT')]}) to row 81
#  Adding ('1 1/4 cups cake flour', {'entities': [(11, 15, 'INGREDIENT'), (16, 21, 'INGREDIENT')]}) to row 82
#  Adding ('Pinch of kosher salt', {'entities': [(16, 20, 'INGREDIENT')]}) to row 83
#  Adding ('3 egg whites, from Grade A large eggs', {'entities': [(2, 5, 'INGREDIENT')]}) to row 84
#  Adding ('1/2 cup dark brown sugar', {'entities': [(13, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}) to row 85
#  Adding ('3/4 cup unsalted butter, at room temperature', {'entities': [(8, 16, 'INGREDIENT'), (17, 23, 'INGREDIENT')]}) to row 86
#  Adding ('Freshly ground black pepper', {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}) to row 87
#  Adding ('5 tablespoons Pernod', {'entities': [(14, 20, 'INGREDIENT')]}) to row 88
#  Adding ('4 teaspoons kosher salt', {'entities': [(19, 23, 'INGREDIENT')]}) to row 89
#  Adding ('1/4 cup fresh lemon juice', {'entities': [(14, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}) to row 90
#  Adding ('1 cup olive oil', {'entities': [(6, 11, 'INGREDIENT'), (12, 15, 'INGREDIENT')]}) to row 91
#  Adding ('1 cup fresh orange juice', {'entities': [(12, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}) to row 92
#  Adding ('3 heads fennel, tops removed and thinly sliced across the bulb (about 6 cups)', {'entities': [(8, 14, 'INGREDIENT')]}) to row 93
#  Adding ('2 large heads romaine lettuce, torn into small pieces (about 8 cups)', {'entities': [(14, 21, 'INGREDIENT'), (22, 29, 'INGREDIENT')]}) to row 94
#  Adding ('6 bunches watercress (about 12 cups of sprigs)', {'entities': [(10, 20, 'INGREDIENT')]}) to row 95
#  Adding ('2 1/2 pounds bell peppers (about 6 peppers in assorted colors), cut into 2-inch chunks', {'entities': [(13, 17, 'INGREDIENT'), (18, 25, 'INGREDIENT')]}) to row 96
#  Adding ('3/4 pound mushrooms, cut into 1/4-inch slices through the stem (4 cups)', {'entities': [(10, 19, 'INGREDIENT')]}) to row 97
#  Adding ('4 pounds rigatoni', {'entities': [(9, 17, 'INGREDIENT')]}) to row 98
#  Adding ('2 bay leaves', {'entities': [(2, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}) to row 99
#  Adding ('2 tablespoons kosher salt', {'entities': [(21, 25, 'INGREDIENT')]}) to row 100
#  Adding ('5 pounds sweet Italian sausage in casing, cut into 1-inch lengths', {'entities': [(23, 30, 'INGREDIENT')]}) to row 101
#  Adding ('1/2 teaspoon hot red-pepper flakes', {'entities': [(17, 27, 'INGREDIENT'), (28, 34, 'INGREDIENT')]}) to row 102
#  Adding ('1/4 teaspoon freshly ground black pepper', {'entities': [(28, 33, 'INGREDIENT'), (34, 40, 'INGREDIENT')]}) to row 103
#  Adding ('2 tablespoons kosher salt', {'entities': [(21, 25, 'INGREDIENT')]}) to row 104
#  Adding ('1 teaspoon thyme', {'entities': [(11, 16, 'INGREDIENT')]}) to row 105
#  Adding ('1 1/2 teaspoons oregano', {'entities': [(16, 23, 'INGREDIENT')]}) to row 106
#  Adding ('2 28-ounce cans crushed tomatoes', {'entities': [(24, 32, 'INGREDIENT')]}) to row 107
#  Adding ('1/2 cup olive oil', {'entities': [(8, 13, 'INGREDIENT'), (14, 17, 'INGREDIENT')]}) to row 108
#  Adding ('8 cloves garlic, peeled and smashed', {'entities': [(9, 15, 'INGREDIENT')]}) to row 109
#  Adding ('2 cups parsley leaves', {'entities': [(7, 14, 'INGREDIENT'), (15, 21, 'INGREDIENT')]}) to row 110
#  Adding ('4 tablespoons drained and rinsed capers', {'entities': [(33, 39, 'INGREDIENT')]}) to row 111
#  Adding ('1 tablespoon kosher salt', {'entities': [(13, 19, 'INGREDIENT'), (20, 24, 'INGREDIENT')]}) to row 112
#  Adding ('1/2 cup fresh lemon juice', {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}) to row 113
#  Adding ('3/4 pound white onion, quartered and thinly sliced (2 cups)', {'entities': [(16, 21, 'INGREDIENT')]}) to row 114
#  Adding ('8 stalks (about 1 1/2 pounds) celery, peeled and cut diagonally into 1/4-inch slices', {'entities': [(30, 36, 'INGREDIENT')]}) to row 115
#  Adding ('1 teaspoon kosher salt', {'entities': [(11, 17, 'INGREDIENT'), (18, 22, 'INGREDIENT')]}) to row 116
#  Adding ('3 1/4 pounds medium shrimp (20-24 to the pound), shelled', {'entities': [(13, 19, 'INGREDIENT'), (20, 26, 'INGREDIENT')]}) to row 117
#  Adding ('6 1/2 pounds mussels (about 6 dozen), scrubbed and beards removed', {'entities': [(13, 20, 'INGREDIENT')]}) to row 118
#  Adding ('1/2 teaspoon sugar', {'entities': [(13, 18, 'INGREDIENT')]}) to row 119
#  Adding ('1 teaspoon Asian sesame oil', {'entities': [(11, 16, 'INGREDIENT'), (17, 23, 'INGREDIENT'), (24, 27, 'INGREDIENT')]}) to row 120
#  Adding ('10 ounces brussels sprouts', {'entities': [(10, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}) to row 121
#  Adding ('2 scallions', {'entities': [(2, 11, 'INGREDIENT')]}) to row 122
#  Adding ('8 Italian, French or Greek black olives', {'entities': [(27, 32, 'INGREDIENT'), (33, 39, 'INGREDIENT')]}) to row 123
#  Adding ('4 ripe plum tomatoes', {'entities': [(7, 11, 'INGREDIENT'), (12, 20, 'INGREDIENT')]}) to row 124
#  Adding ('1 teaspoon olive oil', {'entities': [(11, 16, 'INGREDIENT'), (17, 20, 'INGREDIENT')]}) to row 125
#  Adding ('8 ounces pork tenderloin', {'entities': [(9, 13, 'INGREDIENT'), (14, 24, 'INGREDIENT')]}) to row 126
#  Adding ('1 clove garlic', {'entities': [(8, 14, 'INGREDIENT')]}) to row 127
#  Adding ('1/2 teaspoon ground ginger', {'entities': [(13, 19, 'INGREDIENT'), (20, 26, 'INGREDIENT')]}) to row 128
#  Adding ('1 teaspoon cumin', {'entities': [(11, 16, 'INGREDIENT')]}) to row 129
#  Adding ('1 teaspoon ground cinnamon', {'entities': [(18, 26, 'INGREDIENT')]}) to row 130
#  Adding ('1 teaspoon ground cloves', {'entities': [(18, 24, 'INGREDIENT')]}) to row 131
#  Adding ('1 teaspoon ground ginger', {'entities': [(18, 24, 'INGREDIENT')]}) to row 132
#  Adding ('2 teaspoons baking soda', {'entities': [(12, 18, 'INGREDIENT'), (19, 23, 'INGREDIENT')]}) to row 133
#  Adding ('1 1/2 teaspoons kosher salt', {'entities': [(23, 27, 'INGREDIENT')]}) to row 134
#  Adding ('2 cups all-purpose flour', {'entities': [(7, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}) to row 135
#  Adding ('1 large egg', {'entities': [(8, 11, 'INGREDIENT')]}) to row 136
#  Adding ('1 cup sugar, plus 1/4 cup for dusting the cookies', {'entities': [(6, 11, 'INGREDIENT')]}) to row 137
#  Adding ('4 tablespoons dark molasses', {'entities': [(19, 27, 'INGREDIENT')]}) to row 138
#  Adding ('3/4 cup bacon fat, cooled (from 1 1/2 to 2 pounds Oscar Mayer bacon)', {'entities': [(8, 13, 'INGREDIENT'), (14, 17, 'INGREDIENT')]}) to row 139
#  Adding ('Maple syrup, optional', {'entities': [(0, 5, 'INGREDIENT'), (6, 11, 'INGREDIENT')]}) to row 140
#  Adding ('1 1/4 cups chopped fresh cranberries', {'entities': [(25, 36, 'INGREDIENT')]}) to row 141
#  Adding ('1 1/2 teaspoons salt', {'entities': [(16, 20, 'INGREDIENT')]}) to row 142
#  Adding ('2 tablespoons plus 2 teaspoons baking powder', {'entities': [(31, 37, 'INGREDIENT'), (38, 44, 'INGREDIENT')]}) to row 143
#  Adding ('2 tablespoons sugar', {'entities': [(14, 19, 'INGREDIENT')]}) to row 144
#  Adding ('1/2 cup yellow cornmeal', {'entities': [(8, 14, 'INGREDIENT'), (15, 23, 'INGREDIENT')]}) to row 145
#  Adding ('2 cups flour', {'entities': [(7, 12, 'INGREDIENT')]}) to row 146
#  Adding ('4 large eggs', {'entities': [(8, 12, 'INGREDIENT')]}) to row 147
#  Adding ('2 cups milk', {'entities': [(7, 11, 'INGREDIENT')]}) to row 148
#  Adding ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}) to row 149
#  Adding ('10 tablespoons butter, cut into chunks, plus more for greasing pan', {'entities': [(15, 21, 'INGREDIENT')]}) to row 150
#  Adding ('1/2 tablespoon butter', {'entities': [(15, 21, 'INGREDIENT')]}) to row 151
#  Adding ('1/2 cup heavy cream', {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}) to row 152
#  Adding ('2 tablespoons sugar', {'entities': [(14, 19, 'INGREDIENT')]}) to row 153
#  Adding ('2 teaspoons cream cheese', {'entities': [(12, 17, 'INGREDIENT'), (18, 24, 'INGREDIENT')]}) to row 154
#  Adding ('2 teaspoons cornstarch', {'entities': [(12, 22, 'INGREDIENT')]}) to row 155
#  Adding ('2 cups apple cider', {'entities': [(7, 12, 'INGREDIENT'), (13, 18, 'INGREDIENT')]}) to row 156
#  Adding ('3/4 teaspoon pumpkin-pie spice', {'entities': [(13, 24, 'INGREDIENT'), (25, 30, 'INGREDIENT')]}) to row 157
#  Adding ('1/2 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}) to row 158
#  Adding ('1/2 cup packed light brown sugar', {'entities': [(15, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT'), (27, 32, 'INGREDIENT')]}) to row 159
#  Adding ('2 gala apples', {'entities': [(2, 6, 'INGREDIENT'), (7, 13, 'INGREDIENT')]}) to row 160
#  Adding ('1 cup mixed good olives', {'entities': [(6, 11, 'INGREDIENT'), (12, 16, 'INGREDIENT'), (17, 23, 'INGREDIENT')]}) to row 161
#  Adding ('1 teaspoon minced garlic', {'entities': [(11, 17, 'INGREDIENT'), (18, 24, 'INGREDIENT')]}) to row 162
#  Adding ('Freshly grated Parmesan', {'entities': [(15, 23, 'INGREDIENT')]}) to row 163
#  Adding ('1/4 cup chopped fresh basil, optional', {'entities': [(22, 27, 'INGREDIENT')]}) to row 164
#  Adding ('1/4 cup chopped fresh parsley', {'entities': [(22, 29, 'INGREDIENT')]}) to row 165
#  Adding ('6 cups stock or water, more as necessary', {'entities': [(7, 12, 'INGREDIENT')]}) to row 166
#  Adding ('2 cups chopped tomatoes (canned are fine; do not drain)', {'entities': [(15, 23, 'INGREDIENT')]}) to row 167
#  Adding ('1 cup dried white beans, soaked for several hours or overnight', {'entities': [(12, 17, 'INGREDIENT'), (18, 23, 'INGREDIENT')]}) to row 168
#  Adding ('1 cup farro, spelt or barley', {'entities': [(6, 11, 'INGREDIENT')]}) to row 169
#  Adding ('1 tablespoon minced garlic', {'entities': [(20, 26, 'INGREDIENT')]}) to row 170
#  Adding ('Salt and pepper', {'entities': [(0, 4, 'INGREDIENT'), (5, 8, 'INGREDIENT'), (9, 15, 'INGREDIENT')]}) to row 171
#  Adding ('2 carrots, peeled and chopped', {'entities': [(2, 9, 'INGREDIENT')]}) to row 172
#  Adding ('2 celery stalks, trimmed and chopped', {'entities': [(2, 8, 'INGREDIENT')]}) to row 173
#  Adding ('1 large onion, sliced', {'entities': [(8, 13, 'INGREDIENT')]}) to row 174
#  Adding ('2 tablespoons extra virgin olive oil', {'entities': [(27, 32, 'INGREDIENT'), (33, 36, 'INGREDIENT')]}) to row 175
#  Adding ('Chopped fresh parsley leaves for garnish', {'entities': [(14, 21, 'INGREDIENT'), (22, 28, 'INGREDIENT')]}) to row 176
#  Adding ('Black pepper', {'entities': [(0, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}) to row 177
#  Adding ('1/3 cup extra virgin olive oil', {'entities': [(21, 26, 'INGREDIENT'), (27, 30, 'INGREDIENT')]}) to row 178
#  Adding ('2 pounds potatoes', {'entities': [(9, 17, 'INGREDIENT')]}) to row 179
#  Adding ('1 1/2 to 2 pounds thick-cut cod, whiting, or hake fillets', {'entities': [(28, 31, 'INGREDIENT')]}) to row 180
#  Adding ('Coarse salt as needed', {'entities': [(7, 11, 'INGREDIENT')]}) to row 181
#  Adding ('1 teaspoon vanilla extract', {'entities': [(11, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}) to row 182
#  Adding ('2 large egg yolks', {'entities': [(2, 7, 'INGREDIENT'), (8, 11, 'INGREDIENT'), (12, 17, 'INGREDIENT')]}) to row 183
#  Adding ('1/4 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}) to row 184
#  Adding ('1 large egg', {'entities': [(2, 7, 'INGREDIENT'), (8, 11, 'INGREDIENT')]}) to row 185
#  Adding ('2 tablespoons cornstarch', {'entities': [(14, 24, 'INGREDIENT')]}) to row 186
#  Adding ('2 tablespoons cocoa', {'entities': [(14, 19, 'INGREDIENT')]}) to row 187
#  Adding ('6 tablespoons sugar', {'entities': [(14, 19, 'INGREDIENT')]}) to row 188
#  Adding ('2 1/4 cups whole milk', {'entities': [(11, 16, 'INGREDIENT'), (17, 21, 'INGREDIENT')]}) to row 189
#  Adding ('3 tablespoons slivered almonds', {'entities': [(23, 30, 'INGREDIENT')]}) to row 190
#  Adding ('Pinch of salt', {'entities': [(9, 13, 'INGREDIENT')]}) to row 191
#  Adding ('1 1/4 teaspoons vanilla extract', {'entities': [(16, 23, 'INGREDIENT'), (24, 31, 'INGREDIENT')]}) to row 192
#  Adding ('7 egg whites', {'entities': [(2, 5, 'INGREDIENT')]}) to row 193
#  Adding ('2/3 cup heavy cream', {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}) to row 194
#  Adding ('4 1/2 tablespoons flour, preferably cake flour', {'entities': [(18, 23, 'INGREDIENT')]}) to row 195
#  Adding ('About 2/3 cup blanched almonds, finely ground', {'entities': [(23, 30, 'INGREDIENT')]}) to row 196
#  Adding ('3/4 cup granulated sugar', {'entities': [(19, 24, 'INGREDIENT')]}) to row 197
#  Adding ('4 egg yolks', {'entities': [(2, 5, 'INGREDIENT')]}) to row 198
#  Adding ('1/3 cup plus 1/4 cup kirsch or dark rum', {'entities': [(36, 39, 'INGREDIENT')]}) to row 199
#  Adding ('2 16-ounce cans dark cherries, pitted', {'entities': [(21, 29, 'INGREDIENT')]}) to row 200
#  Adding ('2 tablespoons chopped parsley', {'entities': [(22, 29, 'INGREDIENT')]}) to row 201
#  Adding ('2 tablespoons chopped parsley', {'entities': [(22, 29, 'INGREDIENT')]}) to row 202
#  Adding ('Freshly ground black pepper', {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}) to row 203
#  Adding ('3 large cloves garlic, smashed', {'entities': [(15, 21, 'INGREDIENT')]}) to row 204
#  Adding ('5 tablespoons tomato paste', {'entities': [(14, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}) to row 205
#  Adding ('6 cups chicken stock', {'entities': [(7, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}) to row 206
#  Adding ('1 cup sliced onion', {'entities': [(13, 18, 'INGREDIENT')]}) to row 207
#  Adding ('1 1/2 pounds hot Italian or Spanish sausage', {'entities': [(36, 43, 'INGREDIENT')]}) to row 208
#  Adding ('2 ducks, about 4 1/2 pounds each', {'entities': [(2, 7, 'INGREDIENT')]}) to row 209
#  Adding ('1 2 1/2-pound chunk of slab bacon', {'entities': [(23, 27, 'INGREDIENT'), (28, 33, 'INGREDIENT')]}) to row 210
#  Adding ('4 medium carrots, peeled and sliced', {'entities': [(9, 16, 'INGREDIENT')]}) to row 211
#  Adding ('1 onion, peeled and stuck with 2 cloves', {'entities': [(2, 7, 'INGREDIENT')]}) to row 212
#  Adding ('Rind from 1/2 pound salt pork', {'entities': [(20, 24, 'INGREDIENT'), (25, 29, 'INGREDIENT')]}) to row 213
#  Adding ('2 pounds (5 1/2 cups) dry white beans (Great Northern)', {'entities': [(32, 37, 'INGREDIENT')]}) to row 214
#  Adding ('Pyrex cups or ramekins, buttered', {'entities': [(0, 5, 'INGREDIENT'), (6, 10, 'INGREDIENT')]}) to row 215
#  Adding ('8 scallop shells, Pyrex cups or ramekins, buttered', {'entities': [(2, 9, 'INGREDIENT'), (10, 16, 'INGREDIENT')]}) to row 216
#  Adding ('3 tablespoons fresh parsley, chopped', {'entities': [(20, 27, 'INGREDIENT')]}) to row 217
#  Adding ('2/3 cup stale bread crumbs, from good bread', {'entities': [(14, 19, 'INGREDIENT'), (20, 26, 'INGREDIENT')]}) to row 218
#  Adding ('1 stick plus 2 tablespoons butter', {'entities': [(27, 33, 'INGREDIENT')]}) to row 219
#  Adding ('About 8 shallots, to yield 1 cup, minced', {'entities': [(8, 16, 'INGREDIENT')]}) to row 220
#  Adding ('Black pepper, freshly ground', {'entities': [(0, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}) to row 221
#  Adding ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}) to row 222
#  Adding ('2 to 3 dozen scallops, to yield 1 pound', {'entities': [(13, 21, 'INGREDIENT')]}) to row 223
#  Adding ('2 tablespoons unsalted butter', {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}) to row 224
#  Adding ('2 cups grated Monterey Jack', {'entities': [(14, 22, 'INGREDIENT'), (23, 27, 'INGREDIENT')]}) to row 225
#  Adding ('2/3 cup corn oil', {'entities': [(8, 12, 'INGREDIENT'), (13, 16, 'INGREDIENT')]}) to row 226
#  Adding ('2 cups buttermilk', {'entities': [(7, 17, 'INGREDIENT')]}) to row 227
#  Adding ('1 teaspoon baking soda', {'entities': [(11, 17, 'INGREDIENT'), (18, 22, 'INGREDIENT')]}) to row 228
#  Adding ('1 teaspoon salt', {'entities': [(11, 15, 'INGREDIENT')]}) to row 229
#  Adding ('4 lightly beaten eggs', {'entities': [(17, 21, 'INGREDIENT')]}) to row 230
#  Adding ('2 cups stone-ground yellow cornmeal', {'entities': [(27, 35, 'INGREDIENT')]}) to row 231
#  Adding ('2 8 1/2-ounce cans, or 2 cups plus 2 tablespoons cream-style corn', {'entities': [(49, 60, 'INGREDIENT'), (61, 65, 'INGREDIENT')]}) to row 232
#  Adding ('4 tablespoons regular or low-fat sour cream', {'entities': [(33, 37, 'INGREDIENT'), (38, 43, 'INGREDIENT')]}) to row 233
#  Adding ('1 tablespoon grated lime rind', {'entities': [(20, 24, 'INGREDIENT'), (25, 29, 'INGREDIENT')]}) to row 234
#  Adding ('4 teaspoons lemon juice', {'entities': [(12, 17, 'INGREDIENT'), (18, 23, 'INGREDIENT')]}) to row 235
#  Adding ('Salt to taste', {'entities': [(0, 4, 'INGREDIENT')]}) to row 236
#  Adding ('1/4 teaspoon ground cloves or to taste', {'entities': [(20, 26, 'INGREDIENT')]}) to row 237
#  Adding ('1 1/4 teaspoon ground cardamom', {'entities': [(22, 30, 'INGREDIENT')]}) to row 238
#  Adding ('3 tablespoons maple syrup', {'entities': [(14, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}) to row 239
#  Adding ('3 eggs', {'entities': [(2, 6, 'INGREDIENT')]}) to row 240
#  Adding ('3 pounds sweet potatoes', {'entities': [(9, 14, 'INGREDIENT'), (15, 23, 'INGREDIENT')]}) to row 241
#  Adding ('1 cup good quality chicken stock (approximately)', {'entities': [(19, 26, 'INGREDIENT'), (27, 32, 'INGREDIENT')]}) to row 242
#  Adding ('2 lightly beaten eggs', {'entities': [(17, 21, 'INGREDIENT')]}) to row 243
#  Adding ('1 cup finely minced celery', {'entities': [(20, 26, 'INGREDIENT')]}) to row 244
#  Adding ('2 large cloves garlic, minced', {'entities': [(15, 21, 'INGREDIENT')]}) to row 245
#  Adding ('2 cups finely chopped onion', {'entities': [(22, 27, 'INGREDIENT')]}) to row 246
#  Adding ('2 tablespoons unsalted butter', {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}) to row 247
#  Adding ('2 hard-cooked eggs, chopped', {'entities': [(14, 18, 'INGREDIENT')]}) to row 248
#  Adding ('5 cups toasted bread cubes', {'entities': [(15, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}) to row 249
#  Adding ('5 cups corn bread cubes', {'entities': [(7, 11, 'INGREDIENT'), (12, 17, 'INGREDIENT'), (18, 23, 'INGREDIENT')]}) to row 250
#  Adding ('2/3 cup coarsely chopped pecans', {'entities': [(25, 31, 'INGREDIENT')]}) to row 251
#  Adding ('6 tablespoons Grand Marnier', {'entities': [(14, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}) to row 252
#  Adding ('1/4 cup orange juice', {'entities': [(8, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}) to row 253
#  Adding ('1/2 to 3/4 cup sugar', {'entities': [(15, 20, 'INGREDIENT')]}) to row 254
#  Adding ('1 pound fresh cranberries', {'entities': [(14, 25, 'INGREDIENT')]}) to row 255
#  Adding ('2 tablespoons coarse sugar like Demerara or turbinado (optional)', {'entities': [(21, 26, 'INGREDIENT')]}) to row 256
#  Adding ('2 sheets frozen puff pastry, thawed overnight in refrigerator', {'entities': [(16, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}) to row 257
#  Adding ('1/8 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}) to row 258
#  Adding ('Flour for rolling out pastry', {'entities': [(0, 5, 'INGREDIENT')]}) to row 259
#  Adding ('1 tablespoon fresh lemon juice', {'entities': [(19, 24, 'INGREDIENT'), (25, 30, 'INGREDIENT')]}) to row 260
#  Adding ('1 cup peeled and grated tart apple, like Granny Smith (about 2 apples)', {'entities': [(24, 28, 'INGREDIENT'), (29, 34, 'INGREDIENT')]}) to row 261
#  Adding ('1/2 teaspoon ground cinnamon', {'entities': [(20, 28, 'INGREDIENT')]}) to row 262
#  Adding ('6 tablespoons granulated sugar', {'entities': [(25, 30, 'INGREDIENT')]}) to row 263
#  Adding ('2/3 cup crumbled amaretti cookies', {'entities': [(17, 25, 'INGREDIENT'), (26, 33, 'INGREDIENT')]}) to row 264
#  Adding ('1/8 teaspoon ground nutmeg, optional', {'entities': [(20, 26, 'INGREDIENT')]}) to row 265
#  Adding ('1/4 teaspoon ground cinnamon, optional', {'entities': [(20, 28, 'INGREDIENT')]}) to row 266
#  Adding ('1/3 cup granulated sugar', {'entities': [(19, 24, 'INGREDIENT')]}) to row 267
#  Adding ('8 egg yolks', {'entities': [(2, 5, 'INGREDIENT')]}) to row 268
#  Adding ('1 vanilla bean, split lengthwise', {'entities': [(2, 9, 'INGREDIENT'), (10, 14, 'INGREDIENT')]}) to row 269
#  Adding ('3 cups heavy cream', {'entities': [(7, 12, 'INGREDIENT'), (13, 18, 'INGREDIENT')]}) to row 270
#  Adding ('1 cup canned pumpkin puree', {'entities': [(13, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}) to row 271
#  Adding ('Freshly ground white pepper', {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}) to row 272
#  Adding ('1/4 teaspoon ground cloves', {'entities': [(20, 26, 'INGREDIENT')]}) to row 273
#  Adding ('1/4 teaspoon ground allspice', {'entities': [(20, 28, 'INGREDIENT')]}) to row 274
#  Adding ('1/4 cup red wine vinegar', {'entities': [(8, 11, 'INGREDIENT'), (12, 16, 'INGREDIENT'), (17, 24, 'INGREDIENT')]}) to row 275
#  Adding ('1/2 cup maple syrup', {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}) to row 276
#  Adding ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}) to row 277
#  Adding ('1 cup heavy cream', {'entities': [(6, 11, 'INGREDIENT'), (12, 17, 'INGREDIENT')]}) to row 278
#  Adding ('1 celery root, about 1 1/2 pounds, peeled and cut in chunks', {'entities': [(2, 8, 'INGREDIENT'), (9, 13, 'INGREDIENT')]}) to row 279
#  Adding ('Sesame oil for drizzling, optional', {'entities': [(0, 6, 'INGREDIENT'), (7, 10, 'INGREDIENT')]}) to row 280
#  Adding ('1/2 cup roasted peanuts, optional', {'entities': [(16, 23, 'INGREDIENT')]}) to row 281
#  Adding ('1/4 cup minced scallions', {'entities': [(15, 24, 'INGREDIENT')]}) to row 282
#  Adding ('1/4 cup crispy cooked bacon, minced, optional', {'entities': [(22, 27, 'INGREDIENT')]}) to row 283
#  Adding ('Soy sauce or salt to taste', {'entities': [(0, 3, 'INGREDIENT'), (4, 9, 'INGREDIENT')]}) to row 284
#  Adding ('1/4 pound slab bacon, optional', {'entities': [(10, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}) to row 285
#  Adding ('1 3-inch piece of ginger, peeled and roughly chopped', {'entities': [(18, 24, 'INGREDIENT')]}) to row 286
#  Adding ('1 cup short-grain rice', {'entities': [(6, 17, 'INGREDIENT'), (18, 22, 'INGREDIENT')]}) to row 287
#  Adding ('2 cups chicken stock, preferably homemade, or water', {'entities': [(7, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}) to row 288
#  Adding ('3 tablespoons extra-virgin olive oil', {'entities': [(27, 32, 'INGREDIENT'), (33, 36, 'INGREDIENT')]}) to row 289
#  Adding ('1 tablespoon chili powder', {'entities': [(13, 18, 'INGREDIENT'), (19, 25, 'INGREDIENT')]}) to row 290
#  Adding ('6 cups cooked pinto or kidney beans, or a mixture', {'entities': [(30, 35, 'INGREDIENT')]}) to row 291
#  Adding ('1/2 cup fresh lime juice', {'entities': [(14, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}) to row 292
#  Adding ('3 ripe Haas avocados', {'entities': [(7, 11, 'INGREDIENT'), (12, 20, 'INGREDIENT')]}) to row 293
#  Adding ('1 fresh jalapeno pepper, seeded and minced', {'entities': [(8, 16, 'INGREDIENT'), (17, 23, 'INGREDIENT')]}) to row 294
#  Adding ('2 medium-size cucumbers, peeled and seeded', {'entities': [(14, 23, 'INGREDIENT')]}) to row 295
#  Adding ('1 large red bell pepper, cored and seeded', {'entities': [(8, 11, 'INGREDIENT'), (12, 16, 'INGREDIENT'), (17, 23, 'INGREDIENT')]}) to row 296
#  Adding ('2 medium-size red onions', {'entities': [(14, 17, 'INGREDIENT'), (18, 24, 'INGREDIENT')]}) to row 297
#  Adding ('3 pints cherry tomatoes', {'entities': [(8, 14, 'INGREDIENT'), (15, 23, 'INGREDIENT')]}) to row 298
#  Adding ('1/2 cup dry red wine', {'entities': [(8, 11, 'INGREDIENT'), (12, 15, 'INGREDIENT'), (16, 20, 'INGREDIENT')]}) to row 299
#  Adding ('3 tablespoons concentrated duck or veal stock (glace de viande)', {'entities': [(40, 45, 'INGREDIENT')]}) to row 300
#  Adding ('3 tablespoons reserved marinade (see note)', {'entities': [(23, 31, 'INGREDIENT')]}) to row 301
#  Adding ('1 tablespoon finely minced fresh ginger', {'entities': [(33, 39, 'INGREDIENT')]}) to row 302
#  Adding ('2 shallots, finely minced', {'entities': [(2, 10, 'INGREDIENT')]}) to row 303
#  Adding ('2 tablespoons fat from cooking duck breasts', {'entities': [(14, 17, 'INGREDIENT')]}) to row 304
#  Adding ('1 tablespoon fresh lemon juice', {'entities': [(19, 24, 'INGREDIENT'), (25, 30, 'INGREDIENT')]}) to row 305
#  Adding ('3 tablespoons light soy sauce', {'entities': [(20, 23, 'INGREDIENT'), (24, 29, 'INGREDIENT')]}) to row 306
#  Adding ('2 tablespoons honey', {'entities': [(14, 19, 'INGREDIENT')]}) to row 307
#  Adding ('3 moulard duck breasts (magret de canard)', {'entities': [(10, 14, 'INGREDIENT'), (15, 22, 'INGREDIENT')]}) to row 308
#  Adding ('4 tablespoons chives, cut into 1-inch-long pieces', {'entities': [(14, 20, 'INGREDIENT')]}) to row 309
#  Adding ('8 cups chicken broth', {'entities': [(7, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}) to row 310
#  Adding ('1 cup diced Spanish onion', {'entities': [(20, 25, 'INGREDIENT')]}) to row 311
#  Adding ('2 tablespoons butter', {'entities': [(14, 20, 'INGREDIENT')]}) to row 312
#  Adding ('2 teaspoons salt', {'entities': [(12, 16, 'INGREDIENT')]}) to row 313
#  Adding ('5 cups peeled and diced eggplant', {'entities': [(24, 32, 'INGREDIENT')]}) to row 314
#  Adding ('Orange zest, for garnish (optional)', {'entities': [(0, 6, 'INGREDIENT')]}) to row 315
#  Adding ('Orange zest, for garnish (optional)', {'entities': [(0, 6, 'INGREDIENT')]}) to row 316
#  Adding ('Agave syrup (or honey) and finely crumbled gingersnap cookies, for rimming the glass', {'entities': [(0, 5, 'INGREDIENT'), (6, 11, 'INGREDIENT')]}) to row 317
#  Adding ('Dash of lemon juice', {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}) to row 318
#  Adding ('2 1/2 ounces apple cider', {'entities': [(13, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}) to row 319
#  Adding ('1 ounce vanilla vodka', {'entities': [(8, 15, 'INGREDIENT'), (16, 21, 'INGREDIENT')]}) to row 320
#  Adding ('1 tablespoon chopped fresh oregano or 1 teaspoon dried', {'entities': [(27, 34, 'INGREDIENT')]}) to row 321
#  Adding ('1 tablespoon chopped fresh basil or 1 teaspoon dried', {'entities': [(27, 32, 'INGREDIENT')]}) to row 322
#  Adding ('1 6-ounce can tomato paste', {'entities': [(14, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}) to row 323
#  Adding ('28 ounces no-salt-added whole tomatoes', {'entities': [(30, 38, 'INGREDIENT')]}) to row 324
#  Adding ('1 pound mushrooms, chopped', {'entities': [(8, 17, 'INGREDIENT')]}) to row 325
#  Adding ('1/2 cup chopped carrots', {'entities': [(16, 23, 'INGREDIENT')]}) to row 326
#  Adding ('2 large cloves of garlic, minced', {'entities': [(18, 24, 'INGREDIENT')]}) to row 327
#  Adding ('3/4 pound chopped onion', {'entities': [(18, 23, 'INGREDIENT')]}) to row 328
#  Adding ('1 tablespoon olive oil', {'entities': [(13, 18, 'INGREDIENT'), (19, 22, 'INGREDIENT')]}) to row 329
#  Adding ('1 pound extra-lean ground beef', {'entities': [(26, 30, 'INGREDIENT')]}) to row 330
#  Adding ('Olive oil for grilling', {'entities': [(0, 5, 'INGREDIENT'), (6, 9, 'INGREDIENT')]}) to row 331
#  Adding ('6 swordfish steaks, 1-inch-thick', {'entities': [(2, 11, 'INGREDIENT')]}) to row 332
#  Adding ('8 anchovy fillets, dried on paper towels', {'entities': [(2, 9, 'INGREDIENT')]}) to row 333
#  Adding ('1/3 cup chopped cornichons', {'entities': [(16, 26, 'INGREDIENT')]}) to row 334
#  Adding ('1 cup diced red onion', {'entities': [(16, 21, 'INGREDIENT')]}) to row 335
#  Adding ('2 tablespoons capers', {'entities': [(14, 20, 'INGREDIENT')]}) to row 336
#  Adding ('1 tablespoon Dijon mustard', {'entities': [(13, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}) to row 337
#  Adding ('Grated rind from 2 lemons', {'entities': [(19, 25, 'INGREDIENT')]}) to row 338
#  Adding ('Juice of 1 lemon', {'entities': [(11, 16, 'INGREDIENT')]}) to row 339
#  Adding ('3/4 cup extra virgin olive oil', {'entities': [(21, 26, 'INGREDIENT'), (27, 30, 'INGREDIENT')]}) to row 340
#  Adding ('1 1/2 large bunches flat-leaf parsley', {'entities': [(30, 37, 'INGREDIENT')]}) to row 341
#  Adding ('30 or more basil leaves', {'entities': [(11, 16, 'INGREDIENT'), (17, 23, 'INGREDIENT')]}) to row 342
#  Adding ('6 cups chicken or vegetable stock', {'entities': [(28, 33, 'INGREDIENT')]}) to row 343
#  Adding ('1 2-pound-3-ounce can best-quality Italian tomatoes', {'entities': [(43, 51, 'INGREDIENT')]}) to row 344
#  Adding ('4 large cloves garlic, crushed', {'entities': [(15, 21, 'INGREDIENT')]}) to row 345
#  Adding ('4 tablespoons extra virgin olive oil, plus additional oil for topping (optional)', {'entities': [(27, 32, 'INGREDIENT'), (33, 36, 'INGREDIENT')]}) to row 346
#  Adding ('1 tablespoon olive oil', {'entities': [(13, 18, 'INGREDIENT'), (19, 22, 'INGREDIENT')]}) to row 347
#  Adding ('4 tablespoons lime juice', {'entities': [(14, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}) to row 348
#  Adding ('3 small ripe avocados, skinned and pitted', {'entities': [(13, 21, 'INGREDIENT')]}) to row 349
#  Adding ('4 tablespoons unsalted butter', {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}) to row 350
#  Adding ('1 tablespoon sesame paste (tahini)', {'entities': [(13, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}) to row 351
#  Adding ('2 garlic cloves, peeled and crushed', {'entities': [(2, 8, 'INGREDIENT')]}) to row 352
#  Adding ('1 1/2 teaspoons ground cumin', {'entities': [(16, 22, 'INGREDIENT'), (23, 28, 'INGREDIENT')]}) to row 353
#  Adding ('2 medium egg yolks', {'entities': [(9, 12, 'INGREDIENT')]}) to row 354
#  Adding ('6 tablespoons whole milk', {'entities': [(20, 24, 'INGREDIENT')]}) to row 355
#  Adding ('4 1/2 ounces bittersweet chocolate, chopped', {'entities': [(25, 34, 'INGREDIENT')]}) to row 356
#  Adding ('Half a vanilla bean, split lengthwise, seeds scraped', {'entities': [(7, 14, 'INGREDIENT'), (15, 19, 'INGREDIENT')]}) to row 357
#  Adding ('3/4 cup heavy cream', {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}) to row 358
#  Adding ('1 small bunch of watercress, to garnish (optional)', {'entities': [(17, 27, 'INGREDIENT')]}) to row 359
#  Adding ('Salt, as needed', {'entities': [(0, 4, 'INGREDIENT')]}) to row 360
#  Adding ('Juice of 1 lemon', {'entities': [(11, 16, 'INGREDIENT')]}) to row 361
#  Adding ('1 2/3 cups white wine', {'entities': [(11, 16, 'INGREDIENT'), (17, 21, 'INGREDIENT')]}) to row 362
#  Adding ('Freshly ground black pepper', {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}) to row 363
#  Adding ('6 tablespoons butter, softened', {'entities': [(14, 20, 'INGREDIENT')]}) to row 364
#  Adding ('1 bunch rosemary', {'entities': [(8, 16, 'INGREDIENT')]}) to row 365
#  Adding ('20 anchovy fillets in oil, drained', {'entities': [(3, 10, 'INGREDIENT')]}) to row 366
#  Adding ('4 large garlic cloves, peeled and sliced lengthwise into thirds', {'entities': [(8, 14, 'INGREDIENT')]}) to row 367
#  Adding ('1 4-pound bone-in leg of lamb', {'entities': [(18, 21, 'INGREDIENT'), (22, 24, 'INGREDIENT'), (25, 29, 'INGREDIENT')]}) to row 368
#  Adding ('6 tablespoons chopped mint plus 6 sprigs mint for serving', {'entities': [(22, 26, 'INGREDIENT')]}) to row 369
#  Adding ('6 cups freshly squeezed tangerine juice', {'entities': [(24, 33, 'INGREDIENT'), (34, 39, 'INGREDIENT')]}) to row 370
#  Adding ('4 dried figs, quartered', {'entities': [(8, 12, 'INGREDIENT')]}) to row 371
#  Adding ('8 dried Turkish apricots, cut in half', {'entities': [(8, 15, 'INGREDIENT'), (16, 24, 'INGREDIENT')]}) to row 372
#  Adding ('1 firm tart apple', {'entities': [(12, 17, 'INGREDIENT')]}) to row 373
#  Adding ('3 firm Bosc pears', {'entities': [(7, 11, 'INGREDIENT'), (12, 17, 'INGREDIENT')]}) to row 374
#  Adding ('2 2-inch long pieces lemon zest (peeled with a vegetable peeler), preferably Meyer lemons', {'entities': [(21, 26, 'INGREDIENT'), (27, 31, 'INGREDIENT')]}) to row 375
#  Adding ('3 star anise', {'entities': [(2, 6, 'INGREDIENT'), (7, 12, 'INGREDIENT')]}) to row 376
#  Adding ('1 plump vanilla bean, split in half lengthwise', {'entities': [(8, 15, 'INGREDIENT'), (16, 20, 'INGREDIENT')]}) to row 377
#  Adding ('1 1/4 cup sugar', {'entities': [(10, 15, 'INGREDIENT')]}) to row 378
#  Adding ('1/4 cup coarsely chopped toasted almonds', {'entities': [(33, 40, 'INGREDIENT')]}) to row 379
#  Adding ('1/4 teaspoon almond extract', {'entities': [(13, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}) to row 380
#  Adding ('1 cup milk', {'entities': [(6, 10, 'INGREDIENT')]}) to row 381
#  Adding ('1/4 cup mascarpone cheese', {'entities': [(8, 18, 'INGREDIENT'), (19, 25, 'INGREDIENT')]}) to row 382
#  Adding ('1 tablespoon peeled and minced ginger', {'entities': [(31, 37, 'INGREDIENT')]}) to row 383
#  Adding ('1/2 cup minced cilantro leaves, plus more for garnish', {'entities': [(15, 23, 'INGREDIENT'), (24, 30, 'INGREDIENT')]}) to row 384
#  Adding ('Freshly ground black pepper to taste', {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}) to row 385
#  Adding ('2 tablespoons peanut or other oil', {'entities': [(30, 33, 'INGREDIENT')]}) to row 386
#  Adding ('Lime wedges', {'entities': [(0, 4, 'INGREDIENT'), (5, 11, 'INGREDIENT')]}) to row 387
#  Adding ('3/4 cup plus 2 tablespoons sugar', {'entities': [(27, 32, 'INGREDIENT')]}) to row 388
#  Adding ('1/4 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}) to row 389
#  Adding ('6 tablespoons butter', {'entities': [(14, 20, 'INGREDIENT')]}) to row 390
#  Adding ('8 eggs', {'entities': [(2, 6, 'INGREDIENT')]}) to row 391
#  Adding ('Salt to taste', {'entities': [(0, 4, 'INGREDIENT')]}) to row 392
#  Adding ('1 1/2 pounds fillet of cod or other mild, delicate white fish', {'entities': [(23, 26, 'INGREDIENT')]}) to row 393
#  Adding ('1 baking potato weighing about 1/2 pound', {'entities': [(9, 15, 'INGREDIENT')]}) to row 394
#  Adding ('Plain yogurt for serving', {'entities': [(6, 12, 'INGREDIENT')]}) to row 395
#  Adding ('3/4 cup diced mango for serving', {'entities': [(14, 19, 'INGREDIENT')]}) to row 396
#  Adding ('3/4 cup diced pineapple or sliced strawberries for serving', {'entities': [(14, 23, 'INGREDIENT')]}) to row 397
#  Adding ('2 tablespoons pomegranate seeds', {'entities': [(14, 25, 'INGREDIENT'), (26, 31, 'INGREDIENT')]}) to row 398
#  Adding ('2 star fruits', {'entities': [(7, 13, 'INGREDIENT')]}) to row 399
#  Adding ('2 bananas, peeled and sliced', {'entities': [(2, 9, 'INGREDIENT')]}) to row 400
#  Adding ('2 cups pure pomegranate juice (see note)', {'entities': [(12, 23, 'INGREDIENT'), (24, 29, 'INGREDIENT')]}) to row 401
#  Adding ('9 sheets (3/4 ounce) leaf gelatin (see note)', {'entities': [(21, 25, 'INGREDIENT'), (26, 33, 'INGREDIENT')]}) to row 402
#  Adding ('1 3/4 ounces (about 1 1/4 cups) dried hibiscus flowers (see note)', {'entities': [(38, 46, 'INGREDIENT'), (47, 54, 'INGREDIENT')]}) to row 403
#  Adding ('1 1/4 cups sugar', {'entities': [(11, 16, 'INGREDIENT')]}) to row 404
#  Adding ('2 cups bottled water', {'entities': [(15, 20, 'INGREDIENT')]}) to row 405
#  Adding ('1 teaspoon vanilla extract', {'entities': [(11, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}) to row 406
#  Adding ('1 cup heavy cream', {'entities': [(6, 11, 'INGREDIENT'), (12, 17, 'INGREDIENT')]}) to row 407
#  Adding ('2 tablespoons Grand Marnier', {'entities': [(14, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}) to row 408
#  Adding ('1 1/2 cups blueberries', {'entities': [(11, 22, 'INGREDIENT')]}) to row 409
#  Adding ('Creme chantilly', {'entities': [(0, 5, 'INGREDIENT'), (6, 15, 'INGREDIENT')]}) to row 410
#  Adding ('4 tablespoons melted butter for brushing', {'entities': [(21, 27, 'INGREDIENT')]}) to row 411
#  Adding ('2 teaspoons vanilla extract', {'entities': [(12, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}) to row 412
#  Adding ('4 tablespoons sweet butter, melted', {'entities': [(20, 26, 'INGREDIENT')]}) to row 413
#  Adding ('1/2 cup cold water', {'entities': [(13, 18, 'INGREDIENT')]}) to row 414
#  Adding ('Pinch of salt', {'entities': [(9, 13, 'INGREDIENT')]}) to row 415
#  Adding ('2 cups low-fat milk', {'entities': [(15, 19, 'INGREDIENT')]}) to row 416
#  Adding ('1/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}) to row 417
#  Adding ('4 eggs', {'entities': [(2, 6, 'INGREDIENT')]}) to row 418
#  Adding ('2 cups fresh raspberries or strawberries', {'entities': [(13, 24, 'INGREDIENT')]}) to row 419
#  Adding ('2 tablespoons Cognac', {'entities': [(14, 20, 'INGREDIENT')]}) to row 420
#  Adding ('28 to 32 store-bought ladyfingers', {'entities': [(22, 33, 'INGREDIENT')]}) to row 421
#  Adding ('1/2 cup chopped marron glace (French candied chestnuts), see note', {'entities': [(16, 22, 'INGREDIENT'), (23, 28, 'INGREDIENT')]}) to row 422
#  Adding ('Creme chantilly', {'entities': [(0, 5, 'INGREDIENT'), (6, 15, 'INGREDIENT')]}) to row 423
#  Adding ('1/4 cup warm water', {'entities': [(13, 18, 'INGREDIENT')]}) to row 424
#  Adding ('1 cup creme de marron (French chestnut puree), see note', {'entities': [(6, 11, 'INGREDIENT'), (12, 14, 'INGREDIENT'), (15, 21, 'INGREDIENT')]}) to row 425
#  Adding ('Pinch of salt', {'entities': [(9, 13, 'INGREDIENT')]}) to row 426
#  Adding ('1 vanilla bean, split in half', {'entities': [(2, 9, 'INGREDIENT'), (10, 14, 'INGREDIENT')]}) to row 427
#  Adding ('10 egg yolks', {'entities': [(3, 6, 'INGREDIENT')]}) to row 428
#  Adding ('1 1/4 cup sugar', {'entities': [(10, 15, 'INGREDIENT')]}) to row 429
#  Adding ('3 cups milk', {'entities': [(7, 11, 'INGREDIENT')]}) to row 430
#  Adding ('12 to 16 ladyfingers, store-bought', {'entities': [(9, 20, 'INGREDIENT')]}) to row 431
#  Adding ('1 can (16 ounces) pears in syrup', {'entities': [(18, 23, 'INGREDIENT')]}) to row 432
#  Adding ('2 tablespoons dark rum', {'entities': [(19, 22, 'INGREDIENT')]}) to row 433
#  Adding ('2 tablespoons water', {'entities': [(14, 19, 'INGREDIENT')]}) to row 434
#  Adding ('1/2 teaspoon vanilla extract', {'entities': [(13, 20, 'INGREDIENT'), (21, 28, 'INGREDIENT')]}) to row 435
#  Adding ('1/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}) to row 436
#  Adding ('Pinch of salt', {'entities': [(9, 13, 'INGREDIENT')]}) to row 437
#  Adding ('Pinch of salt', {'entities': [(9, 13, 'INGREDIENT')]}) to row 438
#  Adding ('1 vanilla bean, split in half', {'entities': [(2, 9, 'INGREDIENT'), (10, 14, 'INGREDIENT')]}) to row 439
#  Adding ('1 1/2 cup milk', {'entities': [(10, 14, 'INGREDIENT')]}) to row 440
#  Adding ('3/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}) to row 441
#  Adding ('5 egg yolks', {'entities': [(2, 5, 'INGREDIENT')]}) to row 442
#  Adding ('1 to 2 cups chicken stock, preferably homemade', {'entities': [(12, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}) to row 443
#  Adding ('2 tablespoons unsalted butter', {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}) to row 444
#  Adding ('1 pound chestnuts, peeled', {'entities': [(8, 17, 'INGREDIENT')]}) to row 445
#  Adding ('2 pounds brussels sprouts', {'entities': [(9, 17, 'INGREDIENT'), (18, 25, 'INGREDIENT')]}) to row 446
#  Adding ('1 lemon, halved', {'entities': [(2, 7, 'INGREDIENT')]}) to row 447
#  Adding ('1 8- to 10-pound goose', {'entities': [(17, 22, 'INGREDIENT')]}) to row 448
#  Adding ('1 pound cooking apples, peeled, cored and chopped', {'entities': [(8, 15, 'INGREDIENT'), (16, 22, 'INGREDIENT')]}) to row 449
#  Adding ('Dash sage', {'entities': [(5, 9, 'INGREDIENT')]}) to row 450
#  Adding ('1/4 teaspoon thyme', {'entities': [(13, 18, 'INGREDIENT')]}) to row 451
#  Adding ('4 tablespoons parsley, chopped', {'entities': [(14, 21, 'INGREDIENT')]}) to row 452
#  Adding ('6 stalks celery, chopped', {'entities': [(9, 15, 'INGREDIENT')]}) to row 453
# ...
#  Adding ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}) to row 786
#  Adding ('1 egg yolk', {'entities': [(2, 5, 'INGREDIENT')]}) to row 787
#  Adding ('20 ounces golden (whitefish) caviar', {'entities': [(29, 35, 'INGREDIENT')]}) to row 788
#  Adding ('1 1/2 pounds angel-hair pasta', {'entities': [(24, 29, 'INGREDIENT')]}) to row 789
#  Adding ('8 tablespoons unsalted butter, softened', {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}) to row 790
#  Adding ('2 bay leaves', {'entities': [(2, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}) to row 791
#  Adding ('1/3 cup Calvados or other brandy', {'entities': [(26, 32, 'INGREDIENT')]}) to row 792
#  Adding ('3 cups créme fraîche', {'entities': [(7, 12, 'INGREDIENT'), (13, 20, 'INGREDIENT')]}) to row 793
#  Adding ('Freshly grated Reggiano Parmesan', {'entities': [(15, 23, 'INGREDIENT'), (24, 32, 'INGREDIENT')]}) to row 794
#  Adding ('About 1 cup heavy cream', {'entities': [(12, 17, 'INGREDIENT'), (18, 23, 'INGREDIENT')]}) to row 795
#  Adding ('1 clove garlic, minced', {'entities': [(8, 14, 'INGREDIENT')]}) to row 796
#  Adding ('3 to 4 tablespoons olive oil', {'entities': [(19, 24, 'INGREDIENT'), (25, 28, 'INGREDIENT')]}) to row 797
#  Adding ('About 24 sage leaves', {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}) to row 798
#  Adding ('4 hot Italian sausages', {'entities': [(6, 13, 'INGREDIENT'), (14, 22, 'INGREDIENT')]}) to row 799
#  Adding ('1 pound fettuccine', {'entities': [(8, 18, 'INGREDIENT')]}) to row 800
#  Adding ('Coarse sea salt to taste', {'entities': [(0, 6, 'INGREDIENT'), (7, 10, 'INGREDIENT'), (11, 15, 'INGREDIENT')]}) to row 801
#  Adding ('About 24 sage leaves', {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}) to row 802
#  Adding ('Freshly ground pepper to taste', {'entities': [(15, 21, 'INGREDIENT')]}) to row 803
#  Adding ('1/2 cup olive oil', {'entities': [(8, 13, 'INGREDIENT'), (14, 17, 'INGREDIENT')]}) to row 804
#  Adding ('2 tablespoons Dijon mustard', {'entities': [(14, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}) to row 805
#  Adding ('2 lemons', {'entities': [(2, 8, 'INGREDIENT')]}) to row 806
#  Adding ('1 salmon fillet, about 1 1/2 to 2 pounds', {'entities': [(2, 8, 'INGREDIENT')]}) to row 807
#  Adding ('1/2 cup grated Reggiano Parmesan, plus extra for garnish', {'entities': [(15, 23, 'INGREDIENT'), (24, 32, 'INGREDIENT')]}) to row 808
#  Adding ('1/2 cup dry white wine', {'entities': [(8, 11, 'INGREDIENT'), (12, 17, 'INGREDIENT'), (18, 22, 'INGREDIENT')]}) to row 809
#  Adding ('2 cups Arborio rice', {'entities': [(7, 14, 'INGREDIENT'), (15, 19, 'INGREDIENT')]}) to row 810
#  Adding ('1 medium onion', {'entities': [(9, 14, 'INGREDIENT')]}) to row 811
#  Adding ('5 1/2 tablespoons unsalted butter', {'entities': [(18, 26, 'INGREDIENT'), (27, 33, 'INGREDIENT')]}) to row 812
#  Adding ('7 to 8 cups chicken stock', {'entities': [(12, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}) to row 813
#  Adding ('About 24 sage leaves', {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}) to row 814
#  Adding ('1 medium butternut squash (about 1 pound)', {'entities': [(9, 18, 'INGREDIENT'), (19, 25, 'INGREDIENT')]}) to row 815
#  Adding ('2 kaffir lime leaves, very thinly shredded', {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}) to row 816
#  Adding ('1 tablespoon or more nam pla (fish sauce)', {'entities': [(21, 24, 'INGREDIENT'), (25, 28, 'INGREDIENT')]}) to row 817
#  Adding ('1/2 cup green onions', {'entities': [(8, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}) to row 818
#  Adding ('1/2 cup very thinly sliced lemon grass', {'entities': [(27, 32, 'INGREDIENT'), (33, 38, 'INGREDIENT')]}) to row 819
#  Adding ('1/2 cup very thinly sliced ginger', {'entities': [(27, 33, 'INGREDIENT')]}) to row 820
#  Adding ('1/2 cup very thinly sliced shallots', {'entities': [(27, 35, 'INGREDIENT')]}) to row 821
#  Adding ('1 tablespoon palm sugar', {'entities': [(18, 23, 'INGREDIENT')]}) to row 822
#  Adding ('2 tablespoons kaffir lime juice', {'entities': [(21, 25, 'INGREDIENT'), (26, 31, 'INGREDIENT')]}) to row 823
#  Adding ('1 tablespoon tamarind paste', {'entities': [(13, 21, 'INGREDIENT'), (22, 27, 'INGREDIENT')]}) to row 824
#  Adding ('4 whole kaffir lime leaves, for garnish', {'entities': [(15, 19, 'INGREDIENT'), (20, 26, 'INGREDIENT')]}) to row 825
#  Adding ('5 sprigs cilantro, washed, dried and chopped', {'entities': [(9, 17, 'INGREDIENT')]}) to row 826
#  Adding ('3 to 4 tablespoons (or more) lime juice', {'entities': [(29, 33, 'INGREDIENT'), (34, 39, 'INGREDIENT')]}) to row 827
#  Adding ('2 to 3 teaspoons nam pla (fish sauce)', {'entities': [(17, 20, 'INGREDIENT'), (21, 24, 'INGREDIENT')]}) to row 828
#  Adding ('8 ounces jumbo shrimp', {'entities': [(9, 14, 'INGREDIENT'), (15, 21, 'INGREDIENT')]}) to row 829
#  Adding ('5 ounces oyster mushrooms, trimmed and quartered', {'entities': [(9, 15, 'INGREDIENT'), (16, 25, 'INGREDIENT')]}) to row 830
#  Adding ('3 kaffir lime leaves, very thinly sliced', {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}) to row 831
#  Adding ('4 cups chicken stock, preferably homemade', {'entities': [(7, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}) to row 832
#  Adding ('3 or 4 stalks lemon grass', {'entities': [(14, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}) to row 833
#  Adding ('8 egg yolks', {'entities': [(2, 5, 'INGREDIENT')]}) to row 834
#  Adding ('1 cup sugar', {'entities': [(6, 11, 'INGREDIENT')]}) to row 835
#  Adding ('4 kaffir lime leaves (see note)', {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}) to row 836
#  Adding ('1 quart plus 5 tablespoons whole milk', {'entities': [(33, 37, 'INGREDIENT')]}) to row 837
#  Adding ('12 stalks lemon grass', {'entities': [(10, 15, 'INGREDIENT'), (16, 21, 'INGREDIENT')]}) to row 838
#  Adding ('Chopped fresh parsley for garnish, optional', {'entities': [(14, 21, 'INGREDIENT')]}) to row 839
#  Adding ('Several sprigs fresh thyme, or 1 teaspoon dried thyme', {'entities': [(21, 26, 'INGREDIENT')]}) to row 840
#  Adding ('1 cup fruity red wine', {'entities': [(13, 16, 'INGREDIENT'), (17, 21, 'INGREDIENT')]}) to row 841
#  Adding ('2 pounds cleaned squid, the bodies cut up if large', {'entities': [(17, 22, 'INGREDIENT')]}) to row 842
#  Adding ('5 cloves garlic, crushed', {'entities': [(9, 15, 'INGREDIENT')]}) to row 843
#  Adding ('3 tablespoons extra virgin olive oil', {'entities': [(27, 32, 'INGREDIENT'), (33, 36, 'INGREDIENT')]}) to row 844
#  Adding ('Tinted sugar for decoration (optional)', {'entities': [(7, 12, 'INGREDIENT')]}) to row 845
#  Adding ('Slivered almonds, slightly crushed, for decoration (optional)', {'entities': [(9, 16, 'INGREDIENT')]}) to row 846
#  Adding ('3 to 3 1/2 cups all-purpose flour, more if cookie cutters are used', {'entities': [(16, 27, 'INGREDIENT'), (28, 33, 'INGREDIENT')]}) to row 847
#  Adding ('1/8 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}) to row 848
#  Adding ('1 teaspoon vanilla extract', {'entities': [(11, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}) to row 849
#  Adding ('1 tablespoon brandy', {'entities': [(13, 19, 'INGREDIENT')]}) to row 850
#  Adding ('3/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}) to row 851
#  Adding ('3 large eggs', {'entities': [(8, 12, 'INGREDIENT')]}) to row 852
#  Adding ('1 cup unsalted butter or margarine', {'entities': [(6, 14, 'INGREDIENT'), (15, 21, 'INGREDIENT')]}) to row 853
#  Adding ('6 eggs, separated', {'entities': [(2, 6, 'INGREDIENT')]}) to row 854
#  Adding ('1 teaspoon vanilla extract', {'entities': [(11, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}) to row 855
#  Adding ('1/2 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}) to row 856
#  Adding ('4 cups milk', {'entities': [(7, 11, 'INGREDIENT')]}) to row 857
#  Adding ('1 cup shelled walnuts, coarsely chopped', {'entities': [(14, 21, 'INGREDIENT')]}) to row 858
#  Adding ('1 cup dried, pitted dates, coarsely chopped', {'entities': [(20, 25, 'INGREDIENT')]}) to row 859
#  Adding ('1 1/2 cups dried pears, cut into 1/2-inch pieces', {'entities': [(17, 22, 'INGREDIENT')]}) to row 860
#  Adding ('1 1/2 cups tawny port', {'entities': [(11, 16, 'INGREDIENT'), (17, 21, 'INGREDIENT')]}) to row 861
#  Adding ('1 cup dried cranberries', {'entities': [(12, 23, 'INGREDIENT')]}) to row 862
#  Adding ('6 cups brioche (approximately 2 large loaves or 4 mini-loaves), cut into 1-inch cubes', {'entities': [(7, 14, 'INGREDIENT')]}) to row 863
#  Adding ('1/8 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}) to row 864
#  Adding ('2 tablespoons sherry', {'entities': [(14, 20, 'INGREDIENT')]}) to row 865
#  Adding ('4 tablespoons unsalted butter, at room temperature', {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}) to row 866
#  Adding ('3/4 cup golden raisins', {'entities': [(8, 14, 'INGREDIENT'), (15, 22, 'INGREDIENT')]}) to row 867
#  Adding ('3/4 cup dried cherries', {'entities': [(14, 22, 'INGREDIENT')]}) to row 868
#  Adding ('1/2 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}) to row 869
#  Adding ('1/2 teaspoon baking soda', {'entities': [(13, 19, 'INGREDIENT'), (20, 24, 'INGREDIENT')]}) to row 870
#  Adding ('2 cups all-purpose flour', {'entities': [(19, 24, 'INGREDIENT')]}) to row 871
#  Adding ('2 teaspoons ground ginger', {'entities': [(19, 25, 'INGREDIENT')]}) to row 872
#  Adding ('1/2 cup milk', {'entities': [(8, 12, 'INGREDIENT')]}) to row 873
#  Adding ('1/2 cup molasses', {'entities': [(8, 16, 'INGREDIENT')]}) to row 874
#  Adding ('2 eggs', {'entities': [(2, 6, 'INGREDIENT')]}) to row 875
#  Adding ('1/2 cup brown sugar', {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}) to row 876
#  Adding ('4 tablespoons unsalted butter, at room temperature', {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}) to row 877
#  Adding ('1 pound dried figs, stemmed', {'entities': [(14, 18, 'INGREDIENT')]}) to row 878
#  Adding ('2 teaspoons dried thyme', {'entities': [(18, 23, 'INGREDIENT')]}) to row 879
#  Adding ('3/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}) to row 880
#  Adding ('3/4 cup honey', {'entities': [(8, 13, 'INGREDIENT')]}) to row 881
#  Adding ('3 cups water', {'entities': [(7, 12, 'INGREDIENT')]}) to row 882
#  Adding ('1/2 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}) to row 883
#  Adding ('1 1/3 cups blanched almonds, toasted and finely ground', {'entities': [(20, 27, 'INGREDIENT')]}) to row 884
#  Adding ('3 tablespoons all-purpose flour', {'entities': [(26, 31, 'INGREDIENT')]}) to row 885
#  Adding ('1 teaspoon vanilla extract', {'entities': [(11, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}) to row 886
#  Adding ('2 eggs', {'entities': [(2, 6, 'INGREDIENT')]}) to row 887
#  Adding ('6 tablespoons unsalted butter, at room temperature', {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}) to row 888
#  Adding ('1 tablespoon water', {'entities': [(13, 18, 'INGREDIENT')]}) to row 889
#  Adding ('1 egg yolk, whisked with 1 tablespoon water', {'entities': [(2, 5, 'INGREDIENT')]}) to row 890
#  Adding ('1/2 cup cold unsalted butter, cut into pieces', {'entities': [(13, 21, 'INGREDIENT'), (22, 28, 'INGREDIENT')]}) to row 891
#  Adding ('1/2 teaspoon ground cinnamon', {'entities': [(20, 28, 'INGREDIENT')]}) to row 892
#  Adding ('1 teaspoon salt', {'entities': [(11, 15, 'INGREDIENT')]}) to row 893
#  Adding ('1/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}) to row 894
#  Adding ('1 1/2 cups all-purpose flour', {'entities': [(23, 28, 'INGREDIENT')]}) to row 895
#  Adding ('3/4 cup Armagnac', {'entities': [(8, 16, 'INGREDIENT')]}) to row 896
#  Adding ('1/2 cup dried Calimyrna figs, quartered', {'entities': [(14, 23, 'INGREDIENT'), (24, 28, 'INGREDIENT')]}) to row 897
#  Adding ('1/2 cup dried apricots, halved', {'entities': [(14, 22, 'INGREDIENT')]}) to row 898
#  Adding ('1/2 cup pitted prunes, quartered', {'entities': [(15, 21, 'INGREDIENT')]}) to row 899
#  Adding ('1/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}) to row 900
#  Adding ('Whipped cream, for garnish', {'entities': [(0, 7, 'INGREDIENT'), (8, 13, 'INGREDIENT')]}) to row 901
#  Adding ('1 cup dried cherries, coarsely chopped', {'entities': [(12, 20, 'INGREDIENT')]}) to row 902
#  Adding ('5 eggs, separated', {'entities': [(2, 6, 'INGREDIENT')]}) to row 903
#  Adding ('1/4 cup heavy cream', {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}) to row 904
#  Adding ('10 tablespoons unsalted butter', {'entities': [(15, 23, 'INGREDIENT'), (24, 30, 'INGREDIENT')]}) to row 905
#  Adding ('2 pounds pitted prunes', {'entities': [(16, 22, 'INGREDIENT')]}) to row 906
#  Adding ('1 cup sugar', {'entities': [(6, 11, 'INGREDIENT')]}) to row 907
#  Adding ('1 750-milliliter bottle merlot', {'entities': [(24, 30, 'INGREDIENT')]}) to row 908
#  Adding ('1/2 cup fresh orange juice', {'entities': [(14, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}) to row 909
#  Adding ('3 tablespoons black peppercorns', {'entities': [(14, 19, 'INGREDIENT'), (20, 31, 'INGREDIENT')]}) to row 910
#  Adding ('Zest of 2 oranges, removed in long strips', {'entities': [(10, 17, 'INGREDIENT')]}) to row 911
#  Adding ('2 tablespoons boiling water', {'entities': [(22, 27, 'INGREDIENT')]}) to row 912
#  Adding ('1 teaspoon baking soda', {'entities': [(11, 17, 'INGREDIENT'), (18, 22, 'INGREDIENT')]}) to row 913
#  Adding ('2 tablespoons grated fresh ginger', {'entities': [(27, 33, 'INGREDIENT')]}) to row 914
#  Adding ('1/2 cup molasses', {'entities': [(8, 16, 'INGREDIENT')]}) to row 915
#  Adding ('3 large eggs', {'entities': [(8, 12, 'INGREDIENT')]}) to row 916
#  Adding ('1/4 cup dark brown sugar, packed', {'entities': [(13, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}) to row 917
#  Adding ('1/4 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}) to row 918
#  Adding ('1/4 teaspoon ground nutmeg', {'entities': [(20, 26, 'INGREDIENT')]}) to row 919
#  Adding ('1/4 teaspoon ground cloves', {'entities': [(20, 26, 'INGREDIENT')]}) to row 920
#  Adding ('1 teaspoon cinnamon', {'entities': [(11, 19, 'INGREDIENT')]}) to row 921
#  Adding ('1 tablespoon ground ginger', {'entities': [(20, 26, 'INGREDIENT')]}) to row 922
#  Adding ('1 cup all-purpose flour', {'entities': [(18, 23, 'INGREDIENT')]}) to row 923
#  Adding ('6 tablespoons Poire William (pear brandy)', {'entities': [(14, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}) to row 924
#  Adding ('4 tablespoons granulated sugar', {'entities': [(25, 30, 'INGREDIENT')]}) to row 925
#  Adding ('2 tablespoons lemon juice', {'entities': [(14, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}) to row 926
#  Adding ('5 large ripe Bartlett pears, peeled, cored and quartered', {'entities': [(13, 21, 'INGREDIENT'), (22, 27, 'INGREDIENT')]}) to row 927
#  Adding ('Freshly ground black pepper', {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}) to row 928
#  Adding ('11 tablespoons butter', {'entities': [(15, 21, 'INGREDIENT')]}) to row 929
#  Adding ('1/4 teaspoon nutmeg, or to taste', {'entities': [(13, 19, 'INGREDIENT')]}) to row 930
#  Adding ('4 tablespoons butter', {'entities': [(14, 20, 'INGREDIENT')]}) to row 931
#  Adding ('6 golden apples, preferably Jona Gold, peeled, cored and cut into large chunks', {'entities': [(9, 15, 'INGREDIENT')]}) to row 932
#  Adding ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}) to row 933
#  Adding ('2 medium celery roots (2 1/2 pounds), peeled and cut into large chunks', {'entities': [(9, 15, 'INGREDIENT'), (16, 21, 'INGREDIENT')]}) to row 934
#  Adding ('1 tablespoon fresh thyme leaves (removed from stems), chopped', {'entities': [(19, 24, 'INGREDIENT'), (25, 31, 'INGREDIENT')]}) to row 935
#  Adding ('2 cups heavy cream', {'entities': [(7, 12, 'INGREDIENT'), (13, 18, 'INGREDIENT')]}) to row 936
#  Adding ('2 quarts chicken stock or canned broth', {'entities': [(9, 16, 'INGREDIENT'), (17, 22, 'INGREDIENT')]}) to row 937
#  Adding ('2 bay leaves', {'entities': [(2, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}) to row 938
#  Adding ('1 1/2 cups cooked wild rice', {'entities': [(18, 22, 'INGREDIENT'), (23, 27, 'INGREDIENT')]}) to row 939

# %%
TRAIN_DATA
# Out:
# [('1 1/4 cups cooked and pureed fresh butternut squash, or 1 10-ounce package frozen squash, defrosted',
#   {'entities': [(35, 44, 'INGREDIENT'), (45, 51, 'INGREDIENT')]}),
#  ('1 cup peeled and cooked fresh chestnuts (about 20), or 1 cup canned, unsweetened chestnuts',
#   {'entities': [(30, 39, 'INGREDIENT')]}),
#  ('1 medium-size onion, peeled and chopped',
#   {'entities': [(14, 19, 'INGREDIENT')]}),
#  ('2 stalks celery, chopped coarse', {'entities': [(9, 15, 'INGREDIENT')]}),
#  ('1 1/2 tablespoons vegetable oil',
#   {'entities': [(18, 27, 'INGREDIENT'), (28, 31, 'INGREDIENT')]}),
#  ('2 tablespoons unflavored gelatin, dissolved in 1/2 cup water',
#   {'entities': [(25, 32, 'INGREDIENT')]}),
#  ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('1 cup canned plum tomatoes with juice',
#   {'entities': [(13, 17, 'INGREDIENT'), (18, 26, 'INGREDIENT')]}),
#  ('6 cups veal or beef stock', {'entities': [(20, 25, 'INGREDIENT')]}),
#  ('4 bay leaves', {'entities': [(2, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}),
#  ('6 cloves garlic, crushed and chopped',
#   {'entities': [(9, 15, 'INGREDIENT')]}),
#  ('2 carrots, peeled and diced', {'entities': [(2, 9, 'INGREDIENT')]}),
#  ('2 medium onions, diced', {'entities': [(9, 15, 'INGREDIENT')]}),
#  ('6 tablespoons butter', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('1 tablespoon Creole seasoning, or other seasonings of your choice',
#   {'entities': [(13, 19, 'INGREDIENT'), (20, 29, 'INGREDIENT')]}),
#  ('3 pounds beef brisket',
#   {'entities': [(9, 13, 'INGREDIENT'), (14, 21, 'INGREDIENT')]}),
#  ('1/2 cup fine dry bread crumbs',
#   {'entities': [(17, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('Freshly ground black pepper',
#   {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('3 tablespoons minced scallions', {'entities': [(21, 30, 'INGREDIENT')]}),
#  ('1 tablespoon flour', {'entities': [(13, 18, 'INGREDIENT')]}),
#  ('6 ounces button mushrooms, thinly sliced then coarsely chopped',
#   {'entities': [(9, 15, 'INGREDIENT'), (16, 25, 'INGREDIENT')]}),
#  ('13 tablespoons butter', {'entities': [(15, 21, 'INGREDIENT')]}),
#  ('4 large artichokes, trimmed', {'entities': [(8, 18, 'INGREDIENT')]}),
#  ('Juice of 1 lemon', {'entities': [(11, 16, 'INGREDIENT')]}),
#  ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('1/4 teaspoon vanilla extract',
#   {'entities': [(13, 20, 'INGREDIENT'), (21, 28, 'INGREDIENT')]}),
#  ('2 large eggs', {'entities': [(8, 12, 'INGREDIENT')]}),
#  ('Pinch of freshly grated nutmeg', {'entities': [(24, 30, 'INGREDIENT')]}),
#  ('2 teaspoons baking powder',
#   {'entities': [(12, 18, 'INGREDIENT'), (19, 25, 'INGREDIENT')]}),
#  ('1/4 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('1/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}),
#  ('6 tablespoons flour', {'entities': [(14, 19, 'INGREDIENT')]}),
#  ('2 cups cooked medium- or long-grain white rice',
#   {'entities': [(36, 41, 'INGREDIENT'), (42, 46, 'INGREDIENT')]}),
#  ('Vegetable oil, for deep-frying',
#   {'entities': [(0, 9, 'INGREDIENT'), (10, 13, 'INGREDIENT')]}),
#  ('pound elbow macaroni',
#   {'entities': [(6, 11, 'INGREDIENT'), (12, 20, 'INGREDIENT')]}),
#  ('Freshly ground black pepper',
#   {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('2 teaspoons Dijon mustard',
#   {'entities': [(12, 17, 'INGREDIENT'), (18, 25, 'INGREDIENT')]}),
#  ('cup heavy cream',
#   {'entities': [(4, 9, 'INGREDIENT'), (10, 15, 'INGREDIENT')]}),
#  ('2 cups whole milk', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('3 tablespoons flour', {'entities': [(14, 19, 'INGREDIENT')]}),
#  ('5 cups coarsely grated extra-sharp Cheddar',
#   {'entities': [(35, 42, 'INGREDIENT')]}),
#  ('2 cups panko or coarse dry bread crumbs',
#   {'entities': [(27, 32, 'INGREDIENT'), (33, 39, 'INGREDIENT')]}),
#  ('5 tablespoons unsalted butter',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('Sprigs of watercress', {'entities': [(10, 20, 'INGREDIENT')]}),
#  ('2 tablespoons extra-virgin olive oil',
#   {'entities': [(27, 32, 'INGREDIENT'), (33, 36, 'INGREDIENT')]}),
#  ('1 2-pound beef tenderloin roast, cut from the large end, trimmed and tied at 1/2 -inch intervals with kitchen twine',
#   {'entities': [(10, 14, 'INGREDIENT'), (15, 25, 'INGREDIENT')]}),
#  ('1/8 teaspoon ground cinnamon', {'entities': [(20, 28, 'INGREDIENT')]}),
#  ('1 tablespoon cocoa powder',
#   {'entities': [(13, 18, 'INGREDIENT'), (19, 25, 'INGREDIENT')]}),
#  ('3 tablespoons medium-roast coffee beans, finely ground',
#   {'entities': [(27, 33, 'INGREDIENT'), (34, 39, 'INGREDIENT')]}),
#  ('1 teaspoon light-brown sugar',
#   {'entities': [(17, 22, 'INGREDIENT'), (23, 28, 'INGREDIENT')]}),
#  ('Kosher salt', {'entities': [(7, 11, 'INGREDIENT')]}),
#  ('1/4 cup heavy cream',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}),
#  ('2 1/2 cups chicken stock',
#   {'entities': [(11, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}),
#  ('4 large cloves garlic', {'entities': [(15, 21, 'INGREDIENT')]}),
#  ('1 1/2 cups chopped white onion', {'entities': [(25, 30, 'INGREDIENT')]}),
#  ('3 tablespoons unsalted butter',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('2 dried pasilla chilies',
#   {'entities': [(8, 15, 'INGREDIENT'), (16, 23, 'INGREDIENT')]}),
#  ('2 dashes of Angostura bitters',
#   {'entities': [(12, 21, 'INGREDIENT'), (22, 29, 'INGREDIENT')]}),
#  ('1/2 ounce apple schnapps',
#   {'entities': [(10, 15, 'INGREDIENT'), (16, 24, 'INGREDIENT')]}),
#  ('1/2 ounce sweet vermouth',
#   {'entities': [(10, 15, 'INGREDIENT'), (16, 24, 'INGREDIENT')]}),
#  ('2 ounces applejack', {'entities': [(9, 18, 'INGREDIENT')]}),
#  ('1 orange slice 1 1/4-inch thick, cut in half',
#   {'entities': [(2, 8, 'INGREDIENT')]}),
#  ('1 cup sugar', {'entities': [(6, 11, 'INGREDIENT')]}),
#  ('12 ounces cranberries, washed and picked over',
#   {'entities': [(10, 21, 'INGREDIENT')]}),
#  ('1 1/2 cups strawberries (about 1 pint), hulled and halved',
#   {'entities': [(11, 23, 'INGREDIENT')]}),
#  ('3 bananas', {'entities': [(2, 9, 'INGREDIENT')]}),
#  ('3 tablespoons Triple Sec',
#   {'entities': [(14, 20, 'INGREDIENT'), (21, 24, 'INGREDIENT')]}),
#  ('3 tablespoons fresh lemon juice',
#   {'entities': [(20, 25, 'INGREDIENT'), (26, 31, 'INGREDIENT')]}),
#  ('3/4 cup fresh orange juice',
#   {'entities': [(14, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}),
#  ('3 papayas (1 pound each), peeled and cut into 1-inch chunks (about 4 cups)',
#   {'entities': [(2, 9, 'INGREDIENT')]}),
#  ('6 kiwis (3 to 4 ounces each), peeled and cut into rounds about 1/4-inch thick',
#   {'entities': [(2, 7, 'INGREDIENT')]}),
#  ('3 McIntosh apples (8 ounces each), peeled, quartered, cored and cut into thin wedges (about 3 cups)',
#   {'entities': [(2, 10, 'INGREDIENT'), (11, 17, 'INGREDIENT')]}),
#  ('3 Anjou pears (8 ounces each), peeled, halved, cored and thinly sliced lengthwise (about 3 cups)',
#   {'entities': [(2, 7, 'INGREDIENT'), (8, 13, 'INGREDIENT')]}),
#  ('1 small pineapple, peeled, cored and cut into 1-inch chunks (about 3 cups)',
#   {'entities': [(8, 17, 'INGREDIENT')]}),
#  ('9 juice oranges (6 ounces each), peeled and sectioned',
#   {'entities': [(8, 15, 'INGREDIENT')]}),
#  ('2 small pink grapefruits (12 ounces each) or 1 large pink grapefruit, peeled and sectioned',
#   {'entities': [(13, 24, 'INGREDIENT')]}),
#  ('3 cups seedless grapes, equal amounts of red and green',
#   {'entities': [(16, 22, 'INGREDIENT')]}),
#  ('18 kumquats, thinly sliced', {'entities': [(3, 11, 'INGREDIENT')]}),
#  ('1 cup sifted granulated sugar (optional)',
#   {'entities': [(24, 29, 'INGREDIENT')]}),
#  ('1 teaspoon pure vanilla extract',
#   {'entities': [(16, 23, 'INGREDIENT'), (24, 31, 'INGREDIENT')]}),
#  ('1 1/4 cups cake flour',
#   {'entities': [(11, 15, 'INGREDIENT'), (16, 21, 'INGREDIENT')]}),
#  ('Pinch of kosher salt', {'entities': [(16, 20, 'INGREDIENT')]}),
#  ('3 egg whites, from Grade A large eggs',
#   {'entities': [(2, 5, 'INGREDIENT')]}),
#  ('1/2 cup dark brown sugar',
#   {'entities': [(13, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}),
#  ('3/4 cup unsalted butter, at room temperature',
#   {'entities': [(8, 16, 'INGREDIENT'), (17, 23, 'INGREDIENT')]}),
#  ('Freshly ground black pepper',
#   {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('5 tablespoons Pernod', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('4 teaspoons kosher salt', {'entities': [(19, 23, 'INGREDIENT')]}),
#  ('1/4 cup fresh lemon juice',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}),
#  ('1 cup olive oil',
#   {'entities': [(6, 11, 'INGREDIENT'), (12, 15, 'INGREDIENT')]}),
#  ('1 cup fresh orange juice',
#   {'entities': [(12, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}),
#  ('3 heads fennel, tops removed and thinly sliced across the bulb (about 6 cups)',
#   {'entities': [(8, 14, 'INGREDIENT')]}),
#  ('2 large heads romaine lettuce, torn into small pieces (about 8 cups)',
#   {'entities': [(14, 21, 'INGREDIENT'), (22, 29, 'INGREDIENT')]}),
#  ('6 bunches watercress (about 12 cups of sprigs)',
#   {'entities': [(10, 20, 'INGREDIENT')]}),
#  ('2 1/2 pounds bell peppers (about 6 peppers in assorted colors), cut into 2-inch chunks',
#   {'entities': [(13, 17, 'INGREDIENT'), (18, 25, 'INGREDIENT')]}),
#  ('3/4 pound mushrooms, cut into 1/4-inch slices through the stem (4 cups)',
#   {'entities': [(10, 19, 'INGREDIENT')]}),
#  ('4 pounds rigatoni', {'entities': [(9, 17, 'INGREDIENT')]}),
#  ('2 bay leaves', {'entities': [(2, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}),
#  ('2 tablespoons kosher salt', {'entities': [(21, 25, 'INGREDIENT')]}),
#  ('5 pounds sweet Italian sausage in casing, cut into 1-inch lengths',
#   {'entities': [(23, 30, 'INGREDIENT')]}),
#  ('1/2 teaspoon hot red-pepper flakes',
#   {'entities': [(17, 27, 'INGREDIENT'), (28, 34, 'INGREDIENT')]}),
#  ('1/4 teaspoon freshly ground black pepper',
#   {'entities': [(28, 33, 'INGREDIENT'), (34, 40, 'INGREDIENT')]}),
#  ('2 tablespoons kosher salt', {'entities': [(21, 25, 'INGREDIENT')]}),
#  ('1 teaspoon thyme', {'entities': [(11, 16, 'INGREDIENT')]}),
#  ('1 1/2 teaspoons oregano', {'entities': [(16, 23, 'INGREDIENT')]}),
#  ('2 28-ounce cans crushed tomatoes', {'entities': [(24, 32, 'INGREDIENT')]}),
#  ('1/2 cup olive oil',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 17, 'INGREDIENT')]}),
#  ('8 cloves garlic, peeled and smashed',
#   {'entities': [(9, 15, 'INGREDIENT')]}),
#  ('2 cups parsley leaves',
#   {'entities': [(7, 14, 'INGREDIENT'), (15, 21, 'INGREDIENT')]}),
#  ('4 tablespoons drained and rinsed capers',
#   {'entities': [(33, 39, 'INGREDIENT')]}),
#  ('1 tablespoon kosher salt',
#   {'entities': [(13, 19, 'INGREDIENT'), (20, 24, 'INGREDIENT')]}),
#  ('1/2 cup fresh lemon juice',
#   {'entities': [(8, 13, 'INGREDIENT'),
#     (14, 19, 'INGREDIENT'),
#     (20, 25, 'INGREDIENT')]}),
#  ('3/4 pound white onion, quartered and thinly sliced (2 cups)',
#   {'entities': [(16, 21, 'INGREDIENT')]}),
#  ('8 stalks (about 1 1/2 pounds) celery, peeled and cut diagonally into 1/4-inch slices',
#   {'entities': [(30, 36, 'INGREDIENT')]}),
#  ('1 teaspoon kosher salt',
#   {'entities': [(11, 17, 'INGREDIENT'), (18, 22, 'INGREDIENT')]}),
#  ('3 1/4 pounds medium shrimp (20-24 to the pound), shelled',
#   {'entities': [(13, 19, 'INGREDIENT'), (20, 26, 'INGREDIENT')]}),
#  ('6 1/2 pounds mussels (about 6 dozen), scrubbed and beards removed',
#   {'entities': [(13, 20, 'INGREDIENT')]}),
#  ('1/2 teaspoon sugar', {'entities': [(13, 18, 'INGREDIENT')]}),
#  ('1 teaspoon Asian sesame oil',
#   {'entities': [(11, 16, 'INGREDIENT'),
#     (17, 23, 'INGREDIENT'),
#     (24, 27, 'INGREDIENT')]}),
#  ('10 ounces brussels sprouts',
#   {'entities': [(10, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}),
#  ('2 scallions', {'entities': [(2, 11, 'INGREDIENT')]}),
#  ('8 Italian, French or Greek black olives',
#   {'entities': [(27, 32, 'INGREDIENT'), (33, 39, 'INGREDIENT')]}),
#  ('4 ripe plum tomatoes',
#   {'entities': [(7, 11, 'INGREDIENT'), (12, 20, 'INGREDIENT')]}),
#  ('1 teaspoon olive oil',
#   {'entities': [(11, 16, 'INGREDIENT'), (17, 20, 'INGREDIENT')]}),
#  ('8 ounces pork tenderloin',
#   {'entities': [(9, 13, 'INGREDIENT'), (14, 24, 'INGREDIENT')]}),
#  ('1 clove garlic', {'entities': [(8, 14, 'INGREDIENT')]}),
#  ('1/2 teaspoon ground ginger',
#   {'entities': [(13, 19, 'INGREDIENT'), (20, 26, 'INGREDIENT')]}),
#  ('1 teaspoon cumin', {'entities': [(11, 16, 'INGREDIENT')]}),
#  ('1 teaspoon ground cinnamon', {'entities': [(18, 26, 'INGREDIENT')]}),
#  ('1 teaspoon ground cloves', {'entities': [(18, 24, 'INGREDIENT')]}),
#  ('1 teaspoon ground ginger', {'entities': [(18, 24, 'INGREDIENT')]}),
#  ('2 teaspoons baking soda',
#   {'entities': [(12, 18, 'INGREDIENT'), (19, 23, 'INGREDIENT')]}),
#  ('1 1/2 teaspoons kosher salt', {'entities': [(23, 27, 'INGREDIENT')]}),
#  ('2 cups all-purpose flour',
#   {'entities': [(7, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}),
#  ('1 large egg', {'entities': [(8, 11, 'INGREDIENT')]}),
#  ('1 cup sugar, plus 1/4 cup for dusting the cookies',
#   {'entities': [(6, 11, 'INGREDIENT')]}),
#  ('4 tablespoons dark molasses', {'entities': [(19, 27, 'INGREDIENT')]}),
#  ('3/4 cup bacon fat, cooled (from 1 1/2 to 2 pounds Oscar Mayer bacon)',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 17, 'INGREDIENT')]}),
#  ('Maple syrup, optional',
#   {'entities': [(0, 5, 'INGREDIENT'), (6, 11, 'INGREDIENT')]}),
#  ('1 1/4 cups chopped fresh cranberries',
#   {'entities': [(25, 36, 'INGREDIENT')]}),
#  ('1 1/2 teaspoons salt', {'entities': [(16, 20, 'INGREDIENT')]}),
#  ('2 tablespoons plus 2 teaspoons baking powder',
#   {'entities': [(31, 37, 'INGREDIENT'), (38, 44, 'INGREDIENT')]}),
#  ('2 tablespoons sugar', {'entities': [(14, 19, 'INGREDIENT')]}),
#  ('1/2 cup yellow cornmeal',
#   {'entities': [(8, 14, 'INGREDIENT'), (15, 23, 'INGREDIENT')]}),
#  ('2 cups flour', {'entities': [(7, 12, 'INGREDIENT')]}),
#  ('4 large eggs', {'entities': [(8, 12, 'INGREDIENT')]}),
#  ('2 cups milk', {'entities': [(7, 11, 'INGREDIENT')]}),
#  ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('10 tablespoons butter, cut into chunks, plus more for greasing pan',
#   {'entities': [(15, 21, 'INGREDIENT')]}),
#  ('1/2 tablespoon butter', {'entities': [(15, 21, 'INGREDIENT')]}),
#  ('1/2 cup heavy cream',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}),
#  ('2 tablespoons sugar', {'entities': [(14, 19, 'INGREDIENT')]}),
#  ('2 teaspoons cream cheese',
#   {'entities': [(12, 17, 'INGREDIENT'), (18, 24, 'INGREDIENT')]}),
#  ('2 teaspoons cornstarch', {'entities': [(12, 22, 'INGREDIENT')]}),
#  ('2 cups apple cider',
#   {'entities': [(7, 12, 'INGREDIENT'), (13, 18, 'INGREDIENT')]}),
#  ('3/4 teaspoon pumpkin-pie spice',
#   {'entities': [(13, 24, 'INGREDIENT'), (25, 30, 'INGREDIENT')]}),
#  ('1/2 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('1/2 cup packed light brown sugar',
#   {'entities': [(15, 20, 'INGREDIENT'),
#     (21, 26, 'INGREDIENT'),
#     (27, 32, 'INGREDIENT')]}),
#  ('2 gala apples',
#   {'entities': [(2, 6, 'INGREDIENT'), (7, 13, 'INGREDIENT')]}),
#  ('1 cup mixed good olives',
#   {'entities': [(6, 11, 'INGREDIENT'),
#     (12, 16, 'INGREDIENT'),
#     (17, 23, 'INGREDIENT')]}),
#  ('1 teaspoon minced garlic',
#   {'entities': [(11, 17, 'INGREDIENT'), (18, 24, 'INGREDIENT')]}),
#  ('Freshly grated Parmesan', {'entities': [(15, 23, 'INGREDIENT')]}),
#  ('1/4 cup chopped fresh basil, optional',
#   {'entities': [(22, 27, 'INGREDIENT')]}),
#  ('1/4 cup chopped fresh parsley', {'entities': [(22, 29, 'INGREDIENT')]}),
#  ('6 cups stock or water, more as necessary',
#   {'entities': [(7, 12, 'INGREDIENT')]}),
#  ('2 cups chopped tomatoes (canned are fine; do not drain)',
#   {'entities': [(15, 23, 'INGREDIENT')]}),
#  ('1 cup dried white beans, soaked for several hours or overnight',
#   {'entities': [(12, 17, 'INGREDIENT'), (18, 23, 'INGREDIENT')]}),
#  ('1 cup farro, spelt or barley', {'entities': [(6, 11, 'INGREDIENT')]}),
#  ('1 tablespoon minced garlic', {'entities': [(20, 26, 'INGREDIENT')]}),
#  ('Salt and pepper',
#   {'entities': [(0, 4, 'INGREDIENT'),
#     (5, 8, 'INGREDIENT'),
#     (9, 15, 'INGREDIENT')]}),
#  ('2 carrots, peeled and chopped', {'entities': [(2, 9, 'INGREDIENT')]}),
#  ('2 celery stalks, trimmed and chopped',
#   {'entities': [(2, 8, 'INGREDIENT')]}),
#  ('1 large onion, sliced', {'entities': [(8, 13, 'INGREDIENT')]}),
#  ('2 tablespoons extra virgin olive oil',
#   {'entities': [(27, 32, 'INGREDIENT'), (33, 36, 'INGREDIENT')]}),
#  ('Chopped fresh parsley leaves for garnish',
#   {'entities': [(14, 21, 'INGREDIENT'), (22, 28, 'INGREDIENT')]}),
#  ('Black pepper', {'entities': [(0, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}),
#  ('1/3 cup extra virgin olive oil',
#   {'entities': [(21, 26, 'INGREDIENT'), (27, 30, 'INGREDIENT')]}),
#  ('2 pounds potatoes', {'entities': [(9, 17, 'INGREDIENT')]}),
#  ('1 1/2 to 2 pounds thick-cut cod, whiting, or hake fillets',
#   {'entities': [(28, 31, 'INGREDIENT')]}),
#  ('Coarse salt as needed', {'entities': [(7, 11, 'INGREDIENT')]}),
#  ('1 teaspoon vanilla extract',
#   {'entities': [(11, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}),
#  ('2 large egg yolks',
#   {'entities': [(2, 7, 'INGREDIENT'),
#     (8, 11, 'INGREDIENT'),
#     (12, 17, 'INGREDIENT')]}),
#  ('1/4 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('1 large egg', {'entities': [(2, 7, 'INGREDIENT'), (8, 11, 'INGREDIENT')]}),
#  ('2 tablespoons cornstarch', {'entities': [(14, 24, 'INGREDIENT')]}),
#  ('2 tablespoons cocoa', {'entities': [(14, 19, 'INGREDIENT')]}),
#  ('6 tablespoons sugar', {'entities': [(14, 19, 'INGREDIENT')]}),
#  ('2 1/4 cups whole milk',
#   {'entities': [(11, 16, 'INGREDIENT'), (17, 21, 'INGREDIENT')]}),
#  ('3 tablespoons slivered almonds', {'entities': [(23, 30, 'INGREDIENT')]}),
#  ('Pinch of salt', {'entities': [(9, 13, 'INGREDIENT')]}),
#  ('1 1/4 teaspoons vanilla extract',
#   {'entities': [(16, 23, 'INGREDIENT'), (24, 31, 'INGREDIENT')]}),
#  ('7 egg whites', {'entities': [(2, 5, 'INGREDIENT')]}),
#  ('2/3 cup heavy cream',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}),
#  ('4 1/2 tablespoons flour, preferably cake flour',
#   {'entities': [(18, 23, 'INGREDIENT')]}),
#  ('About 2/3 cup blanched almonds, finely ground',
#   {'entities': [(23, 30, 'INGREDIENT')]}),
#  ('3/4 cup granulated sugar', {'entities': [(19, 24, 'INGREDIENT')]}),
#  ('4 egg yolks', {'entities': [(2, 5, 'INGREDIENT')]}),
#  ('1/3 cup plus 1/4 cup kirsch or dark rum',
#   {'entities': [(36, 39, 'INGREDIENT')]}),
#  ('2 16-ounce cans dark cherries, pitted',
#   {'entities': [(21, 29, 'INGREDIENT')]}),
#  ('2 tablespoons chopped parsley', {'entities': [(22, 29, 'INGREDIENT')]}),
#  ('2 tablespoons chopped parsley', {'entities': [(22, 29, 'INGREDIENT')]}),
#  ('Freshly ground black pepper',
#   {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('3 large cloves garlic, smashed', {'entities': [(15, 21, 'INGREDIENT')]}),
#  ('5 tablespoons tomato paste',
#   {'entities': [(14, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}),
#  ('6 cups chicken stock',
#   {'entities': [(7, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}),
#  ('1 cup sliced onion', {'entities': [(13, 18, 'INGREDIENT')]}),
#  ('1 1/2 pounds hot Italian or Spanish sausage',
#   {'entities': [(36, 43, 'INGREDIENT')]}),
#  ('2 ducks, about 4 1/2 pounds each', {'entities': [(2, 7, 'INGREDIENT')]}),
#  ('1 2 1/2-pound chunk of slab bacon',
#   {'entities': [(23, 27, 'INGREDIENT'), (28, 33, 'INGREDIENT')]}),
#  ('4 medium carrots, peeled and sliced',
#   {'entities': [(9, 16, 'INGREDIENT')]}),
#  ('1 onion, peeled and stuck with 2 cloves',
#   {'entities': [(2, 7, 'INGREDIENT')]}),
#  ('Rind from 1/2 pound salt pork',
#   {'entities': [(20, 24, 'INGREDIENT'), (25, 29, 'INGREDIENT')]}),
#  ('2 pounds (5 1/2 cups) dry white beans (Great Northern)',
#   {'entities': [(32, 37, 'INGREDIENT')]}),
#  ('Pyrex cups or ramekins, buttered',
#   {'entities': [(0, 5, 'INGREDIENT'), (6, 10, 'INGREDIENT')]}),
#  ('8 scallop shells, Pyrex cups or ramekins, buttered',
#   {'entities': [(2, 9, 'INGREDIENT'), (10, 16, 'INGREDIENT')]}),
#  ('3 tablespoons fresh parsley, chopped',
#   {'entities': [(20, 27, 'INGREDIENT')]}),
#  ('2/3 cup stale bread crumbs, from good bread',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 26, 'INGREDIENT')]}),
#  ('1 stick plus 2 tablespoons butter', {'entities': [(27, 33, 'INGREDIENT')]}),
#  ('About 8 shallots, to yield 1 cup, minced',
#   {'entities': [(8, 16, 'INGREDIENT')]}),
#  ('Black pepper, freshly ground',
#   {'entities': [(0, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}),
#  ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('2 to 3 dozen scallops, to yield 1 pound',
#   {'entities': [(13, 21, 'INGREDIENT')]}),
#  ('2 tablespoons unsalted butter',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('2 cups grated Monterey Jack',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 27, 'INGREDIENT')]}),
#  ('2/3 cup corn oil',
#   {'entities': [(8, 12, 'INGREDIENT'), (13, 16, 'INGREDIENT')]}),
#  ('2 cups buttermilk', {'entities': [(7, 17, 'INGREDIENT')]}),
#  ('1 teaspoon baking soda',
#   {'entities': [(11, 17, 'INGREDIENT'), (18, 22, 'INGREDIENT')]}),
#  ('1 teaspoon salt', {'entities': [(11, 15, 'INGREDIENT')]}),
#  ('4 lightly beaten eggs', {'entities': [(17, 21, 'INGREDIENT')]}),
#  ('2 cups stone-ground yellow cornmeal',
#   {'entities': [(27, 35, 'INGREDIENT')]}),
#  ('2 8 1/2-ounce cans, or 2 cups plus 2 tablespoons cream-style corn',
#   {'entities': [(49, 60, 'INGREDIENT'), (61, 65, 'INGREDIENT')]}),
#  ('4 tablespoons regular or low-fat sour cream',
#   {'entities': [(33, 37, 'INGREDIENT'), (38, 43, 'INGREDIENT')]}),
#  ('1 tablespoon grated lime rind',
#   {'entities': [(20, 24, 'INGREDIENT'), (25, 29, 'INGREDIENT')]}),
#  ('4 teaspoons lemon juice',
#   {'entities': [(12, 17, 'INGREDIENT'), (18, 23, 'INGREDIENT')]}),
#  ('Salt to taste', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('1/4 teaspoon ground cloves or to taste',
#   {'entities': [(20, 26, 'INGREDIENT')]}),
#  ('1 1/4 teaspoon ground cardamom', {'entities': [(22, 30, 'INGREDIENT')]}),
#  ('3 tablespoons maple syrup',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}),
#  ('3 eggs', {'entities': [(2, 6, 'INGREDIENT')]}),
#  ('3 pounds sweet potatoes',
#   {'entities': [(9, 14, 'INGREDIENT'), (15, 23, 'INGREDIENT')]}),
#  ('1 cup good quality chicken stock (approximately)',
#   {'entities': [(19, 26, 'INGREDIENT'), (27, 32, 'INGREDIENT')]}),
#  ('2 lightly beaten eggs', {'entities': [(17, 21, 'INGREDIENT')]}),
#  ('1 cup finely minced celery', {'entities': [(20, 26, 'INGREDIENT')]}),
#  ('2 large cloves garlic, minced', {'entities': [(15, 21, 'INGREDIENT')]}),
#  ('2 cups finely chopped onion', {'entities': [(22, 27, 'INGREDIENT')]}),
#  ('2 tablespoons unsalted butter',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('2 hard-cooked eggs, chopped', {'entities': [(14, 18, 'INGREDIENT')]}),
#  ('5 cups toasted bread cubes',
#   {'entities': [(15, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}),
#  ('5 cups corn bread cubes',
#   {'entities': [(7, 11, 'INGREDIENT'),
#     (12, 17, 'INGREDIENT'),
#     (18, 23, 'INGREDIENT')]}),
#  ('2/3 cup coarsely chopped pecans', {'entities': [(25, 31, 'INGREDIENT')]}),
#  ('6 tablespoons Grand Marnier',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}),
#  ('1/4 cup orange juice',
#   {'entities': [(8, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}),
#  ('1/2 to 3/4 cup sugar', {'entities': [(15, 20, 'INGREDIENT')]}),
#  ('1 pound fresh cranberries', {'entities': [(14, 25, 'INGREDIENT')]}),
#  ('2 tablespoons coarse sugar like Demerara or turbinado (optional)',
#   {'entities': [(21, 26, 'INGREDIENT')]}),
#  ('2 sheets frozen puff pastry, thawed overnight in refrigerator',
#   {'entities': [(16, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('1/8 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('Flour for rolling out pastry', {'entities': [(0, 5, 'INGREDIENT')]}),
#  ('1 tablespoon fresh lemon juice',
#   {'entities': [(19, 24, 'INGREDIENT'), (25, 30, 'INGREDIENT')]}),
#  ('1 cup peeled and grated tart apple, like Granny Smith (about 2 apples)',
#   {'entities': [(24, 28, 'INGREDIENT'), (29, 34, 'INGREDIENT')]}),
#  ('1/2 teaspoon ground cinnamon', {'entities': [(20, 28, 'INGREDIENT')]}),
#  ('6 tablespoons granulated sugar', {'entities': [(25, 30, 'INGREDIENT')]}),
#  ('2/3 cup crumbled amaretti cookies',
#   {'entities': [(17, 25, 'INGREDIENT'), (26, 33, 'INGREDIENT')]}),
#  ('1/8 teaspoon ground nutmeg, optional',
#   {'entities': [(20, 26, 'INGREDIENT')]}),
#  ('1/4 teaspoon ground cinnamon, optional',
#   {'entities': [(20, 28, 'INGREDIENT')]}),
#  ('1/3 cup granulated sugar', {'entities': [(19, 24, 'INGREDIENT')]}),
#  ('8 egg yolks', {'entities': [(2, 5, 'INGREDIENT')]}),
#  ('1 vanilla bean, split lengthwise',
#   {'entities': [(2, 9, 'INGREDIENT'), (10, 14, 'INGREDIENT')]}),
#  ('3 cups heavy cream',
#   {'entities': [(7, 12, 'INGREDIENT'), (13, 18, 'INGREDIENT')]}),
#  ('1 cup canned pumpkin puree',
#   {'entities': [(13, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}),
#  ('Freshly ground white pepper',
#   {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('1/4 teaspoon ground cloves', {'entities': [(20, 26, 'INGREDIENT')]}),
#  ('1/4 teaspoon ground allspice', {'entities': [(20, 28, 'INGREDIENT')]}),
#  ('1/4 cup red wine vinegar',
#   {'entities': [(8, 11, 'INGREDIENT'),
#     (12, 16, 'INGREDIENT'),
#     (17, 24, 'INGREDIENT')]}),
#  ('1/2 cup maple syrup',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}),
#  ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('1 cup heavy cream',
#   {'entities': [(6, 11, 'INGREDIENT'), (12, 17, 'INGREDIENT')]}),
#  ('1 celery root, about 1 1/2 pounds, peeled and cut in chunks',
#   {'entities': [(2, 8, 'INGREDIENT'), (9, 13, 'INGREDIENT')]}),
#  ('Sesame oil for drizzling, optional',
#   {'entities': [(0, 6, 'INGREDIENT'), (7, 10, 'INGREDIENT')]}),
#  ('1/2 cup roasted peanuts, optional', {'entities': [(16, 23, 'INGREDIENT')]}),
#  ('1/4 cup minced scallions', {'entities': [(15, 24, 'INGREDIENT')]}),
#  ('1/4 cup crispy cooked bacon, minced, optional',
#   {'entities': [(22, 27, 'INGREDIENT')]}),
#  ('Soy sauce or salt to taste',
#   {'entities': [(0, 3, 'INGREDIENT'), (4, 9, 'INGREDIENT')]}),
#  ('1/4 pound slab bacon, optional',
#   {'entities': [(10, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}),
#  ('1 3-inch piece of ginger, peeled and roughly chopped',
#   {'entities': [(18, 24, 'INGREDIENT')]}),
#  ('1 cup short-grain rice',
#   {'entities': [(6, 17, 'INGREDIENT'), (18, 22, 'INGREDIENT')]}),
#  ('2 cups chicken stock, preferably homemade, or water',
#   {'entities': [(7, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}),
#  ('3 tablespoons extra-virgin olive oil',
#   {'entities': [(27, 32, 'INGREDIENT'), (33, 36, 'INGREDIENT')]}),
#  ('1 tablespoon chili powder',
#   {'entities': [(13, 18, 'INGREDIENT'), (19, 25, 'INGREDIENT')]}),
#  ('6 cups cooked pinto or kidney beans, or a mixture',
#   {'entities': [(30, 35, 'INGREDIENT')]}),
#  ('1/2 cup fresh lime juice',
#   {'entities': [(14, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}),
#  ('3 ripe Haas avocados',
#   {'entities': [(7, 11, 'INGREDIENT'), (12, 20, 'INGREDIENT')]}),
#  ('1 fresh jalapeno pepper, seeded and minced',
#   {'entities': [(8, 16, 'INGREDIENT'), (17, 23, 'INGREDIENT')]}),
#  ('2 medium-size cucumbers, peeled and seeded',
#   {'entities': [(14, 23, 'INGREDIENT')]}),
#  ('1 large red bell pepper, cored and seeded',
#   {'entities': [(8, 11, 'INGREDIENT'),
#     (12, 16, 'INGREDIENT'),
#     (17, 23, 'INGREDIENT')]}),
#  ('2 medium-size red onions',
#   {'entities': [(14, 17, 'INGREDIENT'), (18, 24, 'INGREDIENT')]}),
#  ('3 pints cherry tomatoes',
#   {'entities': [(8, 14, 'INGREDIENT'), (15, 23, 'INGREDIENT')]}),
#  ('1/2 cup dry red wine',
#   {'entities': [(8, 11, 'INGREDIENT'),
#     (12, 15, 'INGREDIENT'),
#     (16, 20, 'INGREDIENT')]}),
#  ('3 tablespoons concentrated duck or veal stock (glace de viande)',
#   {'entities': [(40, 45, 'INGREDIENT')]}),
#  ('3 tablespoons reserved marinade (see note)',
#   {'entities': [(23, 31, 'INGREDIENT')]}),
#  ('1 tablespoon finely minced fresh ginger',
#   {'entities': [(33, 39, 'INGREDIENT')]}),
#  ('2 shallots, finely minced', {'entities': [(2, 10, 'INGREDIENT')]}),
#  ('2 tablespoons fat from cooking duck breasts',
#   {'entities': [(14, 17, 'INGREDIENT')]}),
#  ('1 tablespoon fresh lemon juice',
#   {'entities': [(19, 24, 'INGREDIENT'), (25, 30, 'INGREDIENT')]}),
#  ('3 tablespoons light soy sauce',
#   {'entities': [(20, 23, 'INGREDIENT'), (24, 29, 'INGREDIENT')]}),
#  ('2 tablespoons honey', {'entities': [(14, 19, 'INGREDIENT')]}),
#  ('3 moulard duck breasts (magret de canard)',
#   {'entities': [(10, 14, 'INGREDIENT'), (15, 22, 'INGREDIENT')]}),
#  ('4 tablespoons chives, cut into 1-inch-long pieces',
#   {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('8 cups chicken broth',
#   {'entities': [(7, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}),
#  ('1 cup diced Spanish onion', {'entities': [(20, 25, 'INGREDIENT')]}),
#  ('2 tablespoons butter', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('2 teaspoons salt', {'entities': [(12, 16, 'INGREDIENT')]}),
#  ('5 cups peeled and diced eggplant', {'entities': [(24, 32, 'INGREDIENT')]}),
#  ('Orange zest, for garnish (optional)', {'entities': [(0, 6, 'INGREDIENT')]}),
#  ('Orange zest, for garnish (optional)', {'entities': [(0, 6, 'INGREDIENT')]}),
#  ('Agave syrup (or honey) and finely crumbled gingersnap cookies, for rimming the glass',
#   {'entities': [(0, 5, 'INGREDIENT'), (6, 11, 'INGREDIENT')]}),
#  ('Dash of lemon juice',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}),
#  ('2 1/2 ounces apple cider',
#   {'entities': [(13, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}),
#  ('1 ounce vanilla vodka',
#   {'entities': [(8, 15, 'INGREDIENT'), (16, 21, 'INGREDIENT')]}),
#  ('1 tablespoon chopped fresh oregano or 1 teaspoon dried',
#   {'entities': [(27, 34, 'INGREDIENT')]}),
#  ('1 tablespoon chopped fresh basil or 1 teaspoon dried',
#   {'entities': [(27, 32, 'INGREDIENT')]}),
#  ('1 6-ounce can tomato paste',
#   {'entities': [(14, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}),
#  ('28 ounces no-salt-added whole tomatoes',
#   {'entities': [(30, 38, 'INGREDIENT')]}),
#  ('1 pound mushrooms, chopped', {'entities': [(8, 17, 'INGREDIENT')]}),
#  ('1/2 cup chopped carrots', {'entities': [(16, 23, 'INGREDIENT')]}),
#  ('2 large cloves of garlic, minced', {'entities': [(18, 24, 'INGREDIENT')]}),
#  ('3/4 pound chopped onion', {'entities': [(18, 23, 'INGREDIENT')]}),
#  ('1 tablespoon olive oil',
#   {'entities': [(13, 18, 'INGREDIENT'), (19, 22, 'INGREDIENT')]}),
#  ('1 pound extra-lean ground beef', {'entities': [(26, 30, 'INGREDIENT')]}),
#  ('Olive oil for grilling',
#   {'entities': [(0, 5, 'INGREDIENT'), (6, 9, 'INGREDIENT')]}),
#  ('6 swordfish steaks, 1-inch-thick', {'entities': [(2, 11, 'INGREDIENT')]}),
#  ('8 anchovy fillets, dried on paper towels',
#   {'entities': [(2, 9, 'INGREDIENT')]}),
#  ('1/3 cup chopped cornichons', {'entities': [(16, 26, 'INGREDIENT')]}),
#  ('1 cup diced red onion', {'entities': [(16, 21, 'INGREDIENT')]}),
#  ('2 tablespoons capers', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('1 tablespoon Dijon mustard',
#   {'entities': [(13, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}),
#  ('Grated rind from 2 lemons', {'entities': [(19, 25, 'INGREDIENT')]}),
#  ('Juice of 1 lemon', {'entities': [(11, 16, 'INGREDIENT')]}),
#  ('3/4 cup extra virgin olive oil',
#   {'entities': [(21, 26, 'INGREDIENT'), (27, 30, 'INGREDIENT')]}),
#  ('1 1/2 large bunches flat-leaf parsley',
#   {'entities': [(30, 37, 'INGREDIENT')]}),
#  ('30 or more basil leaves',
#   {'entities': [(11, 16, 'INGREDIENT'), (17, 23, 'INGREDIENT')]}),
#  ('6 cups chicken or vegetable stock', {'entities': [(28, 33, 'INGREDIENT')]}),
#  ('1 2-pound-3-ounce can best-quality Italian tomatoes',
#   {'entities': [(43, 51, 'INGREDIENT')]}),
#  ('4 large cloves garlic, crushed', {'entities': [(15, 21, 'INGREDIENT')]}),
#  ('4 tablespoons extra virgin olive oil, plus additional oil for topping (optional)',
#   {'entities': [(27, 32, 'INGREDIENT'), (33, 36, 'INGREDIENT')]}),
#  ('1 tablespoon olive oil',
#   {'entities': [(13, 18, 'INGREDIENT'), (19, 22, 'INGREDIENT')]}),
#  ('4 tablespoons lime juice',
#   {'entities': [(14, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}),
#  ('3 small ripe avocados, skinned and pitted',
#   {'entities': [(13, 21, 'INGREDIENT')]}),
#  ('4 tablespoons unsalted butter',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('1 tablespoon sesame paste (tahini)',
#   {'entities': [(13, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}),
#  ('2 garlic cloves, peeled and crushed', {'entities': [(2, 8, 'INGREDIENT')]}),
#  ('1 1/2 teaspoons ground cumin',
#   {'entities': [(16, 22, 'INGREDIENT'), (23, 28, 'INGREDIENT')]}),
#  ('2 medium egg yolks', {'entities': [(9, 12, 'INGREDIENT')]}),
#  ('6 tablespoons whole milk', {'entities': [(20, 24, 'INGREDIENT')]}),
#  ('4 1/2 ounces bittersweet chocolate, chopped',
#   {'entities': [(25, 34, 'INGREDIENT')]}),
#  ('Half a vanilla bean, split lengthwise, seeds scraped',
#   {'entities': [(7, 14, 'INGREDIENT'), (15, 19, 'INGREDIENT')]}),
#  ('3/4 cup heavy cream',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}),
#  ('1 small bunch of watercress, to garnish (optional)',
#   {'entities': [(17, 27, 'INGREDIENT')]}),
#  ('Salt, as needed', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('Juice of 1 lemon', {'entities': [(11, 16, 'INGREDIENT')]}),
#  ('1 2/3 cups white wine',
#   {'entities': [(11, 16, 'INGREDIENT'), (17, 21, 'INGREDIENT')]}),
#  ('Freshly ground black pepper',
#   {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('6 tablespoons butter, softened', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('1 bunch rosemary', {'entities': [(8, 16, 'INGREDIENT')]}),
#  ('20 anchovy fillets in oil, drained', {'entities': [(3, 10, 'INGREDIENT')]}),
#  ('4 large garlic cloves, peeled and sliced lengthwise into thirds',
#   {'entities': [(8, 14, 'INGREDIENT')]}),
#  ('1 4-pound bone-in leg of lamb',
#   {'entities': [(18, 21, 'INGREDIENT'),
#     (22, 24, 'INGREDIENT'),
#     (25, 29, 'INGREDIENT')]}),
#  ('6 tablespoons chopped mint plus 6 sprigs mint for serving',
#   {'entities': [(22, 26, 'INGREDIENT')]}),
#  ('6 cups freshly squeezed tangerine juice',
#   {'entities': [(24, 33, 'INGREDIENT'), (34, 39, 'INGREDIENT')]}),
#  ('4 dried figs, quartered', {'entities': [(8, 12, 'INGREDIENT')]}),
#  ('8 dried Turkish apricots, cut in half',
#   {'entities': [(8, 15, 'INGREDIENT'), (16, 24, 'INGREDIENT')]}),
#  ('1 firm tart apple', {'entities': [(12, 17, 'INGREDIENT')]}),
#  ('3 firm Bosc pears',
#   {'entities': [(7, 11, 'INGREDIENT'), (12, 17, 'INGREDIENT')]}),
#  ('2 2-inch long pieces lemon zest (peeled with a vegetable peeler), preferably Meyer lemons',
#   {'entities': [(21, 26, 'INGREDIENT'), (27, 31, 'INGREDIENT')]}),
#  ('3 star anise', {'entities': [(2, 6, 'INGREDIENT'), (7, 12, 'INGREDIENT')]}),
#  ('1 plump vanilla bean, split in half lengthwise',
#   {'entities': [(8, 15, 'INGREDIENT'), (16, 20, 'INGREDIENT')]}),
#  ('1 1/4 cup sugar', {'entities': [(10, 15, 'INGREDIENT')]}),
#  ('1/4 cup coarsely chopped toasted almonds',
#   {'entities': [(33, 40, 'INGREDIENT')]}),
#  ('1/4 teaspoon almond extract',
#   {'entities': [(13, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}),
#  ('1 cup milk', {'entities': [(6, 10, 'INGREDIENT')]}),
#  ('1/4 cup mascarpone cheese',
#   {'entities': [(8, 18, 'INGREDIENT'), (19, 25, 'INGREDIENT')]}),
#  ('1 tablespoon peeled and minced ginger',
#   {'entities': [(31, 37, 'INGREDIENT')]}),
#  ('1/2 cup minced cilantro leaves, plus more for garnish',
#   {'entities': [(15, 23, 'INGREDIENT'), (24, 30, 'INGREDIENT')]}),
#  ('Freshly ground black pepper to taste',
#   {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('2 tablespoons peanut or other oil', {'entities': [(30, 33, 'INGREDIENT')]}),
#  ('Lime wedges', {'entities': [(0, 4, 'INGREDIENT'), (5, 11, 'INGREDIENT')]}),
#  ('3/4 cup plus 2 tablespoons sugar', {'entities': [(27, 32, 'INGREDIENT')]}),
#  ('1/4 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('6 tablespoons butter', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('8 eggs', {'entities': [(2, 6, 'INGREDIENT')]}),
#  ('Salt to taste', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('1 1/2 pounds fillet of cod or other mild, delicate white fish',
#   {'entities': [(23, 26, 'INGREDIENT')]}),
#  ('1 baking potato weighing about 1/2 pound',
#   {'entities': [(9, 15, 'INGREDIENT')]}),
#  ('Plain yogurt for serving', {'entities': [(6, 12, 'INGREDIENT')]}),
#  ('3/4 cup diced mango for serving', {'entities': [(14, 19, 'INGREDIENT')]}),
#  ('3/4 cup diced pineapple or sliced strawberries for serving',
#   {'entities': [(14, 23, 'INGREDIENT')]}),
#  ('2 tablespoons pomegranate seeds',
#   {'entities': [(14, 25, 'INGREDIENT'), (26, 31, 'INGREDIENT')]}),
#  ('2 star fruits', {'entities': [(7, 13, 'INGREDIENT')]}),
#  ('2 bananas, peeled and sliced', {'entities': [(2, 9, 'INGREDIENT')]}),
#  ('2 cups pure pomegranate juice (see note)',
#   {'entities': [(12, 23, 'INGREDIENT'), (24, 29, 'INGREDIENT')]}),
#  ('9 sheets (3/4 ounce) leaf gelatin (see note)',
#   {'entities': [(21, 25, 'INGREDIENT'), (26, 33, 'INGREDIENT')]}),
#  ('1 3/4 ounces (about 1 1/4 cups) dried hibiscus flowers (see note)',
#   {'entities': [(38, 46, 'INGREDIENT'), (47, 54, 'INGREDIENT')]}),
#  ('1 1/4 cups sugar', {'entities': [(11, 16, 'INGREDIENT')]}),
#  ('2 cups bottled water', {'entities': [(15, 20, 'INGREDIENT')]}),
#  ('1 teaspoon vanilla extract',
#   {'entities': [(11, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}),
#  ('1 cup heavy cream',
#   {'entities': [(6, 11, 'INGREDIENT'), (12, 17, 'INGREDIENT')]}),
#  ('2 tablespoons Grand Marnier',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}),
#  ('1 1/2 cups blueberries', {'entities': [(11, 22, 'INGREDIENT')]}),
#  ('Creme chantilly',
#   {'entities': [(0, 5, 'INGREDIENT'), (6, 15, 'INGREDIENT')]}),
#  ('4 tablespoons melted butter for brushing',
#   {'entities': [(21, 27, 'INGREDIENT')]}),
#  ('2 teaspoons vanilla extract',
#   {'entities': [(12, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}),
#  ('4 tablespoons sweet butter, melted',
#   {'entities': [(20, 26, 'INGREDIENT')]}),
#  ('1/2 cup cold water', {'entities': [(13, 18, 'INGREDIENT')]}),
#  ('Pinch of salt', {'entities': [(9, 13, 'INGREDIENT')]}),
#  ('2 cups low-fat milk', {'entities': [(15, 19, 'INGREDIENT')]}),
#  ('1/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}),
#  ('4 eggs', {'entities': [(2, 6, 'INGREDIENT')]}),
#  ('2 cups fresh raspberries or strawberries',
#   {'entities': [(13, 24, 'INGREDIENT')]}),
#  ('2 tablespoons Cognac', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('28 to 32 store-bought ladyfingers', {'entities': [(22, 33, 'INGREDIENT')]}),
#  ('1/2 cup chopped marron glace (French candied chestnuts), see note',
#   {'entities': [(16, 22, 'INGREDIENT'), (23, 28, 'INGREDIENT')]}),
#  ('Creme chantilly',
#   {'entities': [(0, 5, 'INGREDIENT'), (6, 15, 'INGREDIENT')]}),
#  ('1/4 cup warm water', {'entities': [(13, 18, 'INGREDIENT')]}),
#  ('1 cup creme de marron (French chestnut puree), see note',
#   {'entities': [(6, 11, 'INGREDIENT'),
#     (12, 14, 'INGREDIENT'),
#     (15, 21, 'INGREDIENT')]}),
#  ('Pinch of salt', {'entities': [(9, 13, 'INGREDIENT')]}),
#  ('1 vanilla bean, split in half',
#   {'entities': [(2, 9, 'INGREDIENT'), (10, 14, 'INGREDIENT')]}),
#  ('10 egg yolks', {'entities': [(3, 6, 'INGREDIENT')]}),
#  ('1 1/4 cup sugar', {'entities': [(10, 15, 'INGREDIENT')]}),
#  ('3 cups milk', {'entities': [(7, 11, 'INGREDIENT')]}),
#  ('12 to 16 ladyfingers, store-bought', {'entities': [(9, 20, 'INGREDIENT')]}),
#  ('1 can (16 ounces) pears in syrup', {'entities': [(18, 23, 'INGREDIENT')]}),
#  ('2 tablespoons dark rum', {'entities': [(19, 22, 'INGREDIENT')]}),
#  ('2 tablespoons water', {'entities': [(14, 19, 'INGREDIENT')]}),
#  ('1/2 teaspoon vanilla extract',
#   {'entities': [(13, 20, 'INGREDIENT'), (21, 28, 'INGREDIENT')]}),
#  ('1/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}),
#  ('Pinch of salt', {'entities': [(9, 13, 'INGREDIENT')]}),
#  ('Pinch of salt', {'entities': [(9, 13, 'INGREDIENT')]}),
#  ('1 vanilla bean, split in half',
#   {'entities': [(2, 9, 'INGREDIENT'), (10, 14, 'INGREDIENT')]}),
#  ('1 1/2 cup milk', {'entities': [(10, 14, 'INGREDIENT')]}),
#  ('3/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}),
#  ('5 egg yolks', {'entities': [(2, 5, 'INGREDIENT')]}),
#  ('1 to 2 cups chicken stock, preferably homemade',
#   {'entities': [(12, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}),
#  ('2 tablespoons unsalted butter',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('1 pound chestnuts, peeled', {'entities': [(8, 17, 'INGREDIENT')]}),
#  ('2 pounds brussels sprouts',
#   {'entities': [(9, 17, 'INGREDIENT'), (18, 25, 'INGREDIENT')]}),
#  ('1 lemon, halved', {'entities': [(2, 7, 'INGREDIENT')]}),
#  ('1 8- to 10-pound goose', {'entities': [(17, 22, 'INGREDIENT')]}),
#  ('1 pound cooking apples, peeled, cored and chopped',
#   {'entities': [(8, 15, 'INGREDIENT'), (16, 22, 'INGREDIENT')]}),
#  ('Dash sage', {'entities': [(5, 9, 'INGREDIENT')]}),
#  ('1/4 teaspoon thyme', {'entities': [(13, 18, 'INGREDIENT')]}),
#  ('4 tablespoons parsley, chopped', {'entities': [(14, 21, 'INGREDIENT')]}),
#  ('6 stalks celery, chopped', {'entities': [(9, 15, 'INGREDIENT')]}),
#  ('2 cloves garlic, minced', {'entities': [(9, 15, 'INGREDIENT')]}),
#  ('1 medium onion, chopped', {'entities': [(9, 14, 'INGREDIENT')]}),
#  ('2 tablespoons unsalted butter',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('1 cup port or madeira', {'entities': [(6, 10, 'INGREDIENT')]}),
#  ('1 pound prunes, pitted', {'entities': [(8, 14, 'INGREDIENT')]}),
#  ('Lemon juice to taste',
#   {'entities': [(0, 5, 'INGREDIENT'), (6, 11, 'INGREDIENT')]}),
#  ('Coarse salt to taste', {'entities': [(7, 11, 'INGREDIENT')]}),
#  ('1/2 teaspoon powdered ginger', {'entities': [(22, 28, 'INGREDIENT')]}),
#  ('Cayenne pepper to taste',
#   {'entities': [(0, 7, 'INGREDIENT'), (8, 14, 'INGREDIENT')]}),
#  ('Dash freshly grated nutmeg', {'entities': [(20, 26, 'INGREDIENT')]}),
#  ('1 teaspoon ground mace', {'entities': [(18, 22, 'INGREDIENT')]}),
#  ('1 clove garlic, crushed', {'entities': [(8, 14, 'INGREDIENT')]}),
#  ('1 pound small shrimp, shelled', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('1/2 pound unsalted butter',
#   {'entities': [(10, 18, 'INGREDIENT'), (19, 25, 'INGREDIENT')]}),
#  ('1 medium-size red onion, about 1/2 pound, cut into thin rings',
#   {'entities': [(18, 23, 'INGREDIENT')]}),
#  ('2 medium-size tomatoes, about 3/4 pound, cored and cut into small wedges',
#   {'entities': [(14, 22, 'INGREDIENT')]}),
#  ('1 whole cucumber, about 1/2 pound, peeled and cut into thin rounds',
#   {'entities': [(8, 16, 'INGREDIENT')]}),
#  ('1 cup coarsely chopped, trimmed scallions, green part and all',
#   {'entities': [(32, 41, 'INGREDIENT')]}),
#  ('8 cups reasonably packed romaine lettuce leaves broken into fairly large, bite-size pieces',
#   {'entities': [(33, 40, 'INGREDIENT'), (41, 47, 'INGREDIENT')]}),
#  ('1/2 teaspoon dried hot red-pepper flakes',
#   {'entities': [(23, 33, 'INGREDIENT'), (34, 40, 'INGREDIENT')]}),
#  ('8 sprigs fresh coriander with stems and leaves',
#   {'entities': [(15, 24, 'INGREDIENT')]}),
#  ('1 tablespoon finely minced garlic', {'entities': [(27, 33, 'INGREDIENT')]}),
#  ('1/2 cup fish sauce',
#   {'entities': [(8, 12, 'INGREDIENT'), (13, 18, 'INGREDIENT')]}),
#  ('1 cup freshly squeezed lime juice',
#   {'entities': [(23, 27, 'INGREDIENT'), (28, 33, 'INGREDIENT')]}),
#  ('2 tablespoons corn, peanut or vegetable oil',
#   {'entities': [(40, 43, 'INGREDIENT')]}),
#  ('1/2 pound lean, tender beef, preferably fillet of beef',
#   {'entities': [(23, 27, 'INGREDIENT')]}),
#  ('2 pounds pears (or apples), peeled, cored and sliced',
#   {'entities': [(9, 14, 'INGREDIENT')]}),
#  ('1 tablespoon vinegar (sherry, Champagne or white wine vinegar)',
#   {'entities': [(13, 20, 'INGREDIENT')]}),
#  ('A few thyme sprigs', {'entities': [(6, 11, 'INGREDIENT')]}),
#  ('4 bay leaves', {'entities': [(2, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}),
#  ('2 large onions, roughly chopped',
#   {'entities': [(2, 7, 'INGREDIENT'), (8, 14, 'INGREDIENT')]}),
#  ('1 goose, cut into serving pieces, excess fat removed',
#   {'entities': [(2, 7, 'INGREDIENT')]}),
#  ('8 tablespoons unsalted butter',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('1/8 teaspoon vanilla extract',
#   {'entities': [(13, 20, 'INGREDIENT'), (21, 28, 'INGREDIENT')]}),
#  ('1/2 cup milk', {'entities': [(8, 12, 'INGREDIENT')]}),
#  ('1/2 cup all-purpose flour',
#   {'entities': [(8, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}),
#  ('3 large eggs', {'entities': [(8, 12, 'INGREDIENT')]}),
#  ('1/2 teaspoon ground cinnamon', {'entities': [(20, 28, 'INGREDIENT')]}),
#  ('Scant 1/2 cup sugar plus 1 1/2 tablespoons sugar',
#   {'entities': [(14, 19, 'INGREDIENT')]}),
#  ('1 teaspoon garam masala (optional)',
#   {'entities': [(11, 16, 'INGREDIENT'), (17, 23, 'INGREDIENT')]}),
#  ('2 pinches cayenne', {'entities': [(10, 17, 'INGREDIENT')]}),
#  ('2 tablespoons lemon juice',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}),
#  ('2 teaspoons salt', {'entities': [(12, 16, 'INGREDIENT')]}),
#  ('2 onions, halved and thinly sliced crosswise',
#   {'entities': [(2, 8, 'INGREDIENT')]}),
#  ('2 teaspoons sesame seeds',
#   {'entities': [(12, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}),
#  ('1 tablespoon cumin or caraway seeds',
#   {'entities': [(30, 35, 'INGREDIENT')]}),
#  ('6 tablespoons vegetable oil',
#   {'entities': [(14, 23, 'INGREDIENT'), (24, 27, 'INGREDIENT')]}),
#  ('1 large head green cabbage', {'entities': [(19, 26, 'INGREDIENT')]}),
#  ('2 cloves garlic, crushed', {'entities': [(9, 15, 'INGREDIENT')]}),
#  ('1/4 cup olive oil',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 17, 'INGREDIENT')]}),
#  ('4 pounds chard, red or green', {'entities': [(9, 14, 'INGREDIENT')]}),
#  ('Salt and pepper',
#   {'entities': [(0, 4, 'INGREDIENT'),
#     (5, 8, 'INGREDIENT'),
#     (9, 15, 'INGREDIENT')]}),
#  ('2 teaspoons black or mixed peppercorns, bruised; more for garnish',
#   {'entities': [(27, 38, 'INGREDIENT')]}),
#  ('1 tablespoon sugar', {'entities': [(13, 18, 'INGREDIENT')]}),
#  ('1/2 teaspoon red pepper flakes',
#   {'entities': [(13, 16, 'INGREDIENT'),
#     (17, 23, 'INGREDIENT'),
#     (24, 30, 'INGREDIENT')]}),
#  ('4 thyme sprigs', {'entities': [(2, 7, 'INGREDIENT')]}),
#  ('2 bay leaves', {'entities': [(2, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}),
#  ('2 large red onions, peeled and sliced into thick rings, rings separated',
#   {'entities': [(12, 18, 'INGREDIENT')]}),
#  ('Salt and pepper',
#   {'entities': [(0, 4, 'INGREDIENT'),
#     (5, 8, 'INGREDIENT'),
#     (9, 15, 'INGREDIENT')]}),
#  ('2 teaspoons fresh thyme leaves, plus more for garnish',
#   {'entities': [(18, 23, 'INGREDIENT'), (24, 30, 'INGREDIENT')]}),
#  ('2 shallots, diced', {'entities': [(2, 10, 'INGREDIENT')]}),
#  ('3 tablespoons butter', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('40 radishes (green tops optional)', {'entities': [(3, 11, 'INGREDIENT')]}),
#  ('4 medium-size garlic cloves, minced',
#   {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('1/4 cup minced fresh ginger (about 6 inches ginger root, peeled)',
#   {'entities': [(21, 27, 'INGREDIENT')]}),
#  ('4 tablespoons vegetable oil',
#   {'entities': [(14, 23, 'INGREDIENT'), (24, 27, 'INGREDIENT')]}),
#  ('2 1/2 pounds string beans (French-style slim haricots verts work especially well), trimmed',
#   {'entities': [(13, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}),
#  ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('Salt and pepper to taste',
#   {'entities': [(0, 4, 'INGREDIENT'),
#     (5, 8, 'INGREDIENT'),
#     (9, 15, 'INGREDIENT')]}),
#  ('1/4 cup dry white wine or vermouth',
#   {'entities': [(8, 11, 'INGREDIENT'),
#     (12, 17, 'INGREDIENT'),
#     (18, 22, 'INGREDIENT')]}),
#  ('2 tablespoons black mustard seeds, cumin seeds, or poppy seeds',
#   {'entities': [(28, 33, 'INGREDIENT')]}),
#  ('3 garlic cloves, minced', {'entities': [(2, 8, 'INGREDIENT')]}),
#  ('2 tablespoons butter', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('2 tablespoons olive oil',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 23, 'INGREDIENT')]}),
#  ('2 to 3 pounds brussels sprouts',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 30, 'INGREDIENT')]}),
#  ('Grated zest of 1 lemon', {'entities': [(17, 22, 'INGREDIENT')]}),
#  ('2 tablespoons freshly squeezed lemon juice, more to taste',
#   {'entities': [(31, 36, 'INGREDIENT'), (37, 42, 'INGREDIENT')]}),
#  ('Flour for dredging', {'entities': [(0, 5, 'INGREDIENT')]}),
#  ('2 tablespoons unsalted butter ', {'entities': [(23, 29, 'INGREDIENT')]}),
#  ('1 clove garlic, minced ', {'entities': [(8, 14, 'INGREDIENT')]}),
#  ('1/2 pound chanterelles', {'entities': [(10, 22, 'INGREDIENT')]}),
#  ('3 tablespoons creme fraiche',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}),
# ...
#   {'entities': [(23, 28, 'INGREDIENT')]}),
#  ('2 tablespoons vegetable oil, plus more for greasing the pan',
#   {'entities': [(14, 23, 'INGREDIENT'), (24, 27, 'INGREDIENT')]}),
#  ('2 cups Greek or whole milk yogurt',
#   {'entities': [(22, 26, 'INGREDIENT'), (27, 33, 'INGREDIENT')]}),
#  ('2 cups (one 12-ounce bag) frozen raspberries',
#   {'entities': [(33, 44, 'INGREDIENT')]}),
#  ('4 large eggs', {'entities': [(8, 12, 'INGREDIENT')]}),
#  ('1/4 cup tomato ketchup, more if desired',
#   {'entities': [(8, 14, 'INGREDIENT'), (15, 22, 'INGREDIENT')]}),
#  ('1 cup grated cheddar cheese',
#   {'entities': [(13, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('1/4 teaspoon mace', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('1 1/2 cups whole milk', {'entities': [(17, 21, 'INGREDIENT')]}),
#  ('10 slices (6 ounces) bacon', {'entities': [(21, 26, 'INGREDIENT')]}),
#  ('Butter for baking dish', {'entities': [(0, 6, 'INGREDIENT')]}),
#  ('2 cups granola', {'entities': [(7, 14, 'INGREDIENT')]}),
#  ('1/3 cup vegetable oil',
#   {'entities': [(8, 17, 'INGREDIENT'), (18, 21, 'INGREDIENT')]}),
#  ("3/4 cup Golden Baker's natural cane sugar or other light brown sugar",
#   {'entities': [(31, 35, 'INGREDIENT'), (36, 41, 'INGREDIENT')]}),
#  ('1 large egg', {'entities': [(8, 11, 'INGREDIENT')]}),
#  ('1/4 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('1 teaspoon baking soda',
#   {'entities': [(11, 17, 'INGREDIENT'), (18, 22, 'INGREDIENT')]}),
#  ('1 1/2 cups all-purpose flour',
#   {'entities': [(11, 22, 'INGREDIENT'), (23, 28, 'INGREDIENT')]}),
#  ('Pinch salt', {'entities': [(6, 10, 'INGREDIENT')]}),
#  ('1/4 cup granulated sugar', {'entities': [(19, 24, 'INGREDIENT')]}),
#  ('5 tablespoons frozen lemonade concentrate, thawed',
#   {'entities': [(21, 29, 'INGREDIENT')]}),
#  ('5 eggs, separated', {'entities': [(2, 6, 'INGREDIENT')]}),
#  ('Butter for greasing the dish', {'entities': [(0, 6, 'INGREDIENT')]}),
#  ('Freshly ground black pepper',
#   {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('2 shallots, minced', {'entities': [(2, 10, 'INGREDIENT')]}),
#  ('1/2 cup brut Champagne', {'entities': [(13, 22, 'INGREDIENT')]}),
#  ('1 teaspoon olive oil',
#   {'entities': [(11, 16, 'INGREDIENT'), (17, 20, 'INGREDIENT')]}),
#  ('2 filet mignons, at least 6 ounces each',
#   {'entities': [(2, 7, 'INGREDIENT'), (8, 15, 'INGREDIENT')]}),
#  ('2 tablespoons plus 1 teaspoon butter',
#   {'entities': [(30, 36, 'INGREDIENT')]}),
#  ('Freshly ground black pepper',
#   {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('1 egg yolk', {'entities': [(2, 5, 'INGREDIENT')]}),
#  ('20 ounces golden (whitefish) caviar',
#   {'entities': [(29, 35, 'INGREDIENT')]}),
#  ('1 1/2 pounds angel-hair pasta', {'entities': [(24, 29, 'INGREDIENT')]}),
#  ('8 tablespoons unsalted butter, softened',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('2 bay leaves', {'entities': [(2, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}),
#  ('1/3 cup Calvados or other brandy', {'entities': [(26, 32, 'INGREDIENT')]}),
#  ('3 cups créme fraîche',
#   {'entities': [(7, 12, 'INGREDIENT'), (13, 20, 'INGREDIENT')]}),
#  ('Freshly grated Reggiano Parmesan',
#   {'entities': [(15, 23, 'INGREDIENT'), (24, 32, 'INGREDIENT')]}),
#  ('About 1 cup heavy cream',
#   {'entities': [(12, 17, 'INGREDIENT'), (18, 23, 'INGREDIENT')]}),
#  ('1 clove garlic, minced', {'entities': [(8, 14, 'INGREDIENT')]}),
#  ('3 to 4 tablespoons olive oil',
#   {'entities': [(19, 24, 'INGREDIENT'), (25, 28, 'INGREDIENT')]}),
#  ('About 24 sage leaves',
#   {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}),
#  ('4 hot Italian sausages',
#   {'entities': [(6, 13, 'INGREDIENT'), (14, 22, 'INGREDIENT')]}),
#  ('1 pound fettuccine', {'entities': [(8, 18, 'INGREDIENT')]}),
#  ('Coarse sea salt to taste',
#   {'entities': [(0, 6, 'INGREDIENT'),
#     (7, 10, 'INGREDIENT'),
#     (11, 15, 'INGREDIENT')]}),
#  ('About 24 sage leaves',
#   {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}),
#  ('Freshly ground pepper to taste', {'entities': [(15, 21, 'INGREDIENT')]}),
#  ('1/2 cup olive oil',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 17, 'INGREDIENT')]}),
#  ('2 tablespoons Dijon mustard',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}),
#  ('2 lemons', {'entities': [(2, 8, 'INGREDIENT')]}),
#  ('1 salmon fillet, about 1 1/2 to 2 pounds',
#   {'entities': [(2, 8, 'INGREDIENT')]}),
#  ('1/2 cup grated Reggiano Parmesan, plus extra for garnish',
#   {'entities': [(15, 23, 'INGREDIENT'), (24, 32, 'INGREDIENT')]}),
#  ('1/2 cup dry white wine',
#   {'entities': [(8, 11, 'INGREDIENT'),
#     (12, 17, 'INGREDIENT'),
#     (18, 22, 'INGREDIENT')]}),
#  ('2 cups Arborio rice',
#   {'entities': [(7, 14, 'INGREDIENT'), (15, 19, 'INGREDIENT')]}),
#  ('1 medium onion', {'entities': [(9, 14, 'INGREDIENT')]}),
#  ('5 1/2 tablespoons unsalted butter',
#   {'entities': [(18, 26, 'INGREDIENT'), (27, 33, 'INGREDIENT')]}),
#  ('7 to 8 cups chicken stock',
#   {'entities': [(12, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}),
#  ('About 24 sage leaves',
#   {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}),
#  ('1 medium butternut squash (about 1 pound)',
#   {'entities': [(9, 18, 'INGREDIENT'), (19, 25, 'INGREDIENT')]}),
#  ('2 kaffir lime leaves, very thinly shredded',
#   {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}),
#  ('1 tablespoon or more nam pla (fish sauce)',
#   {'entities': [(21, 24, 'INGREDIENT'), (25, 28, 'INGREDIENT')]}),
#  ('1/2 cup green onions',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}),
#  ('1/2 cup very thinly sliced lemon grass',
#   {'entities': [(27, 32, 'INGREDIENT'), (33, 38, 'INGREDIENT')]}),
#  ('1/2 cup very thinly sliced ginger', {'entities': [(27, 33, 'INGREDIENT')]}),
#  ('1/2 cup very thinly sliced shallots',
#   {'entities': [(27, 35, 'INGREDIENT')]}),
#  ('1 tablespoon palm sugar', {'entities': [(18, 23, 'INGREDIENT')]}),
#  ('2 tablespoons kaffir lime juice',
#   {'entities': [(21, 25, 'INGREDIENT'), (26, 31, 'INGREDIENT')]}),
#  ('1 tablespoon tamarind paste',
#   {'entities': [(13, 21, 'INGREDIENT'), (22, 27, 'INGREDIENT')]}),
#  ('4 whole kaffir lime leaves, for garnish',
#   {'entities': [(15, 19, 'INGREDIENT'), (20, 26, 'INGREDIENT')]}),
#  ('5 sprigs cilantro, washed, dried and chopped',
#   {'entities': [(9, 17, 'INGREDIENT')]}),
#  ('3 to 4 tablespoons (or more) lime juice',
#   {'entities': [(29, 33, 'INGREDIENT'), (34, 39, 'INGREDIENT')]}),
#  ('2 to 3 teaspoons nam pla (fish sauce)',
#   {'entities': [(17, 20, 'INGREDIENT'), (21, 24, 'INGREDIENT')]}),
#  ('8 ounces jumbo shrimp',
#   {'entities': [(9, 14, 'INGREDIENT'), (15, 21, 'INGREDIENT')]}),
#  ('5 ounces oyster mushrooms, trimmed and quartered',
#   {'entities': [(9, 15, 'INGREDIENT'), (16, 25, 'INGREDIENT')]}),
#  ('3 kaffir lime leaves, very thinly sliced',
#   {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}),
#  ('4 cups chicken stock, preferably homemade',
#   {'entities': [(7, 14, 'INGREDIENT'), (15, 20, 'INGREDIENT')]}),
#  ('3 or 4 stalks lemon grass',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}),
#  ('8 egg yolks', {'entities': [(2, 5, 'INGREDIENT')]}),
#  ('1 cup sugar', {'entities': [(6, 11, 'INGREDIENT')]}),
#  ('4 kaffir lime leaves (see note)',
#   {'entities': [(9, 13, 'INGREDIENT'), (14, 20, 'INGREDIENT')]}),
#  ('1 quart plus 5 tablespoons whole milk',
#   {'entities': [(33, 37, 'INGREDIENT')]}),
#  ('12 stalks lemon grass',
#   {'entities': [(10, 15, 'INGREDIENT'), (16, 21, 'INGREDIENT')]}),
#  ('Chopped fresh parsley for garnish, optional',
#   {'entities': [(14, 21, 'INGREDIENT')]}),
#  ('Several sprigs fresh thyme, or 1 teaspoon dried thyme',
#   {'entities': [(21, 26, 'INGREDIENT')]}),
#  ('1 cup fruity red wine',
#   {'entities': [(13, 16, 'INGREDIENT'), (17, 21, 'INGREDIENT')]}),
#  ('2 pounds cleaned squid, the bodies cut up if large',
#   {'entities': [(17, 22, 'INGREDIENT')]}),
#  ('5 cloves garlic, crushed', {'entities': [(9, 15, 'INGREDIENT')]}),
#  ('3 tablespoons extra virgin olive oil',
#   {'entities': [(27, 32, 'INGREDIENT'), (33, 36, 'INGREDIENT')]}),
#  ('Tinted sugar for decoration (optional)',
#   {'entities': [(7, 12, 'INGREDIENT')]}),
#  ('Slivered almonds, slightly crushed, for decoration (optional)',
#   {'entities': [(9, 16, 'INGREDIENT')]}),
#  ('3 to 3 1/2 cups all-purpose flour, more if cookie cutters are used',
#   {'entities': [(16, 27, 'INGREDIENT'), (28, 33, 'INGREDIENT')]}),
#  ('1/8 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('1 teaspoon vanilla extract',
#   {'entities': [(11, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}),
#  ('1 tablespoon brandy', {'entities': [(13, 19, 'INGREDIENT')]}),
#  ('3/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}),
#  ('3 large eggs', {'entities': [(8, 12, 'INGREDIENT')]}),
#  ('1 cup unsalted butter or margarine',
#   {'entities': [(6, 14, 'INGREDIENT'), (15, 21, 'INGREDIENT')]}),
#  ('6 eggs, separated', {'entities': [(2, 6, 'INGREDIENT')]}),
#  ('1 teaspoon vanilla extract',
#   {'entities': [(11, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}),
#  ('1/2 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}),
#  ('4 cups milk', {'entities': [(7, 11, 'INGREDIENT')]}),
#  ('1 cup shelled walnuts, coarsely chopped',
#   {'entities': [(14, 21, 'INGREDIENT')]}),
#  ('1 cup dried, pitted dates, coarsely chopped',
#   {'entities': [(20, 25, 'INGREDIENT')]}),
#  ('1 1/2 cups dried pears, cut into 1/2-inch pieces',
#   {'entities': [(17, 22, 'INGREDIENT')]}),
#  ('1 1/2 cups tawny port',
#   {'entities': [(11, 16, 'INGREDIENT'), (17, 21, 'INGREDIENT')]}),
#  ('1 cup dried cranberries', {'entities': [(12, 23, 'INGREDIENT')]}),
#  ('6 cups brioche (approximately 2 large loaves or 4 mini-loaves), cut into 1-inch cubes',
#   {'entities': [(7, 14, 'INGREDIENT')]}),
#  ('1/8 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('2 tablespoons sherry', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('4 tablespoons unsalted butter, at room temperature',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('3/4 cup golden raisins',
#   {'entities': [(8, 14, 'INGREDIENT'), (15, 22, 'INGREDIENT')]}),
#  ('3/4 cup dried cherries', {'entities': [(14, 22, 'INGREDIENT')]}),
#  ('1/2 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('1/2 teaspoon baking soda',
#   {'entities': [(13, 19, 'INGREDIENT'), (20, 24, 'INGREDIENT')]}),
#  ('2 cups all-purpose flour', {'entities': [(19, 24, 'INGREDIENT')]}),
#  ('2 teaspoons ground ginger', {'entities': [(19, 25, 'INGREDIENT')]}),
#  ('1/2 cup milk', {'entities': [(8, 12, 'INGREDIENT')]}),
#  ('1/2 cup molasses', {'entities': [(8, 16, 'INGREDIENT')]}),
#  ('2 eggs', {'entities': [(2, 6, 'INGREDIENT')]}),
#  ('1/2 cup brown sugar',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}),
#  ('4 tablespoons unsalted butter, at room temperature',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('1 pound dried figs, stemmed', {'entities': [(14, 18, 'INGREDIENT')]}),
#  ('2 teaspoons dried thyme', {'entities': [(18, 23, 'INGREDIENT')]}),
#  ('3/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}),
#  ('3/4 cup honey', {'entities': [(8, 13, 'INGREDIENT')]}),
#  ('3 cups water', {'entities': [(7, 12, 'INGREDIENT')]}),
#  ('1/2 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('1 1/3 cups blanched almonds, toasted and finely ground',
#   {'entities': [(20, 27, 'INGREDIENT')]}),
#  ('3 tablespoons all-purpose flour', {'entities': [(26, 31, 'INGREDIENT')]}),
#  ('1 teaspoon vanilla extract',
#   {'entities': [(11, 18, 'INGREDIENT'), (19, 26, 'INGREDIENT')]}),
#  ('2 eggs', {'entities': [(2, 6, 'INGREDIENT')]}),
#  ('6 tablespoons unsalted butter, at room temperature',
#   {'entities': [(14, 22, 'INGREDIENT'), (23, 29, 'INGREDIENT')]}),
#  ('1 tablespoon water', {'entities': [(13, 18, 'INGREDIENT')]}),
#  ('1 egg yolk, whisked with 1 tablespoon water',
#   {'entities': [(2, 5, 'INGREDIENT')]}),
#  ('1/2 cup cold unsalted butter, cut into pieces',
#   {'entities': [(13, 21, 'INGREDIENT'), (22, 28, 'INGREDIENT')]}),
#  ('1/2 teaspoon ground cinnamon', {'entities': [(20, 28, 'INGREDIENT')]}),
#  ('1 teaspoon salt', {'entities': [(11, 15, 'INGREDIENT')]}),
#  ('1/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}),
#  ('1 1/2 cups all-purpose flour', {'entities': [(23, 28, 'INGREDIENT')]}),
#  ('3/4 cup Armagnac', {'entities': [(8, 16, 'INGREDIENT')]}),
#  ('1/2 cup dried Calimyrna figs, quartered',
#   {'entities': [(14, 23, 'INGREDIENT'), (24, 28, 'INGREDIENT')]}),
#  ('1/2 cup dried apricots, halved', {'entities': [(14, 22, 'INGREDIENT')]}),
#  ('1/2 cup pitted prunes, quartered', {'entities': [(15, 21, 'INGREDIENT')]}),
#  ('1/4 cup sugar', {'entities': [(8, 13, 'INGREDIENT')]}),
#  ('Whipped cream, for garnish',
#   {'entities': [(0, 7, 'INGREDIENT'), (8, 13, 'INGREDIENT')]}),
#  ('1 cup dried cherries, coarsely chopped',
#   {'entities': [(12, 20, 'INGREDIENT')]}),
#  ('5 eggs, separated', {'entities': [(2, 6, 'INGREDIENT')]}),
#  ('1/4 cup heavy cream',
#   {'entities': [(8, 13, 'INGREDIENT'), (14, 19, 'INGREDIENT')]}),
#  ('10 tablespoons unsalted butter',
#   {'entities': [(15, 23, 'INGREDIENT'), (24, 30, 'INGREDIENT')]}),
#  ('2 pounds pitted prunes', {'entities': [(16, 22, 'INGREDIENT')]}),
#  ('1 cup sugar', {'entities': [(6, 11, 'INGREDIENT')]}),
#  ('1 750-milliliter bottle merlot', {'entities': [(24, 30, 'INGREDIENT')]}),
#  ('1/2 cup fresh orange juice',
#   {'entities': [(14, 20, 'INGREDIENT'), (21, 26, 'INGREDIENT')]}),
#  ('3 tablespoons black peppercorns',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 31, 'INGREDIENT')]}),
#  ('Zest of 2 oranges, removed in long strips',
#   {'entities': [(10, 17, 'INGREDIENT')]}),
#  ('2 tablespoons boiling water', {'entities': [(22, 27, 'INGREDIENT')]}),
#  ('1 teaspoon baking soda',
#   {'entities': [(11, 17, 'INGREDIENT'), (18, 22, 'INGREDIENT')]}),
#  ('2 tablespoons grated fresh ginger', {'entities': [(27, 33, 'INGREDIENT')]}),
#  ('1/2 cup molasses', {'entities': [(8, 16, 'INGREDIENT')]}),
#  ('3 large eggs', {'entities': [(8, 12, 'INGREDIENT')]}),
#  ('1/4 cup dark brown sugar, packed',
#   {'entities': [(13, 18, 'INGREDIENT'), (19, 24, 'INGREDIENT')]}),
#  ('1/4 teaspoon salt', {'entities': [(13, 17, 'INGREDIENT')]}),
#  ('1/4 teaspoon ground nutmeg', {'entities': [(20, 26, 'INGREDIENT')]}),
#  ('1/4 teaspoon ground cloves', {'entities': [(20, 26, 'INGREDIENT')]}),
#  ('1 teaspoon cinnamon', {'entities': [(11, 19, 'INGREDIENT')]}),
#  ('1 tablespoon ground ginger', {'entities': [(20, 26, 'INGREDIENT')]}),
#  ('1 cup all-purpose flour', {'entities': [(18, 23, 'INGREDIENT')]}),
#  ('6 tablespoons Poire William (pear brandy)',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 27, 'INGREDIENT')]}),
#  ('4 tablespoons granulated sugar', {'entities': [(25, 30, 'INGREDIENT')]}),
#  ('2 tablespoons lemon juice',
#   {'entities': [(14, 19, 'INGREDIENT'), (20, 25, 'INGREDIENT')]}),
#  ('5 large ripe Bartlett pears, peeled, cored and quartered',
#   {'entities': [(13, 21, 'INGREDIENT'), (22, 27, 'INGREDIENT')]}),
#  ('Freshly ground black pepper',
#   {'entities': [(15, 20, 'INGREDIENT'), (21, 27, 'INGREDIENT')]}),
#  ('11 tablespoons butter', {'entities': [(15, 21, 'INGREDIENT')]}),
#  ('1/4 teaspoon nutmeg, or to taste', {'entities': [(13, 19, 'INGREDIENT')]}),
#  ('4 tablespoons butter', {'entities': [(14, 20, 'INGREDIENT')]}),
#  ('6 golden apples, preferably Jona Gold, peeled, cored and cut into large chunks',
#   {'entities': [(9, 15, 'INGREDIENT')]}),
#  ('Salt', {'entities': [(0, 4, 'INGREDIENT')]}),
#  ('2 medium celery roots (2 1/2 pounds), peeled and cut into large chunks',
#   {'entities': [(9, 15, 'INGREDIENT'), (16, 21, 'INGREDIENT')]}),
#  ('1 tablespoon fresh thyme leaves (removed from stems), chopped',
#   {'entities': [(19, 24, 'INGREDIENT'), (25, 31, 'INGREDIENT')]}),
#  ('2 cups heavy cream',
#   {'entities': [(7, 12, 'INGREDIENT'), (13, 18, 'INGREDIENT')]}),
#  ('2 quarts chicken stock or canned broth',
#   {'entities': [(9, 16, 'INGREDIENT'), (17, 22, 'INGREDIENT')]}),
#  ('2 bay leaves', {'entities': [(2, 5, 'INGREDIENT'), (6, 12, 'INGREDIENT')]}),
#  ('1 1/2 cups cooked wild rice',
#   {'entities': [(18, 22, 'INGREDIENT'), (23, 27, 'INGREDIENT')]})]

# %%
print(f'Our training set has {len(TRAIN_DATA)} observations')
# Out:
# Our training set has 939 observations

# %%
def train_spacy(data,iterations):
    TRAIN_DATA = data
    nlp = spacy.load('en_core_web_sm')
    ner = nlp.get_pipe("ner")
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
    # add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])
    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Statring iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update(
                    [text],  # batch of texts
                    [annotations],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
            print(losses)
    return nlp

# %%
ner_model = train_spacy(TRAIN_DATA, 25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <module>
# ----> 1 ner_model = train_spacy(TRAIN_DATA, 25)
#
# Input In [24], in train_spacy(data, iterations)
#      13 other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
#      14 with nlp.disable_pipes(*other_pipes):  # only train NER
# ---> 15     optimizer = nlp.begin_training()
#      16     for itn in range(iterations):
#      17         print("Statring iteration " + str(itn))
#
# File ~/opt/miniconda3/envs/data_analytics/lib/python3.9/site-packages/spacy/language.py:1258, in Language.begin_training(self, get_examples, sgd)
#    1251 def begin_training(
#    1252     self,
#    1253     get_examples: Optional[Callable[[], Iterable[Example]]] = None,
#    1254     *,
#    1255     sgd: Optional[Optimizer] = None,
#    1256 ) -> Optimizer:
#    1257     warnings.warn(Warnings.W089, DeprecationWarning)
# -> 1258     return self.initialize(get_examples, sgd=sgd)
#
# File ~/opt/miniconda3/envs/data_analytics/lib/python3.9/site-packages/spacy/language.py:1290, in Language.initialize(self, get_examples, sgd)
#    1288 config = self.config.interpolate()
#    1289 # These are the settings provided in the [initialize] block in the config
# -> 1290 I = registry.resolve(config["initialize"], schema=ConfigSchemaInit)
#    1291 before_init = I["before_init"]
#    1292 if before_init is not None:
#
# File ~/opt/miniconda3/envs/data_analytics/lib/python3.9/site-packages/thinc/config.py:747, in registry.resolve(cls, config, schema, overrides, validate)
#     738 @classmethod
#     739 def resolve(
#     740     cls,
#    (...)
#     745     validate: bool = True,
#     746 ) -> Dict[str, Any]:
# --> 747     resolved, _ = cls._make(
#     748         config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     749     )
#     750     return resolved
#
# File ~/opt/miniconda3/envs/data_analytics/lib/python3.9/site-packages/thinc/config.py:796, in registry._make(cls, config, schema, overrides, resolve, validate)
#     794 if not is_interpolated:
#     795     config = Config(orig_config).interpolate()
# --> 796 filled, _, resolved = cls._fill(
#     797     config, schema, validate=validate, overrides=overrides, resolve=resolve
#     798 )
#     799 filled = Config(filled, section_order=section_order)
#     800 # Check that overrides didn't include invalid properties not in config
#
# File ~/opt/miniconda3/envs/data_analytics/lib/python3.9/site-packages/thinc/config.py:868, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     865     getter = cls.get(reg_name, func_name)
#     866     # We don't want to try/except this and raise our own error
#     867     # here, because we want the traceback if the function fails.
# --> 868     getter_result = getter(*args, **kwargs)
#     869 else:
#     870     # We're not resolving and calling the function, so replace
#     871     # the getter_result with a Promise class
#     872     getter_result = Promise(
#     873         registry=reg_name, name=func_name, args=args, kwargs=kwargs
#     874     )
#
# File ~/opt/miniconda3/envs/data_analytics/lib/python3.9/site-packages/spacy/language.py:108, in load_lookups_data(lang, tables)
#     105 @registry.misc("spacy.LookupsDataLoader.v1")
#     106 def load_lookups_data(lang, tables):
#     107     util.logger.debug(f"Loading lookups from spacy-lookups-data: {tables}")
# --> 108     lookups = load_lookups(lang=lang, tables=tables)
#     109     return lookups
#
# File ~/opt/miniconda3/envs/data_analytics/lib/python3.9/site-packages/spacy/lookups.py:30, in load_lookups(lang, tables, strict)
#      28 if lang not in registry.lookups:
#      29     if strict and len(tables) > 0:
# ---> 30         raise ValueError(Errors.E955.format(table=", ".join(tables), lang=lang))
#      31     return lookups
#      32 data = registry.lookups.get(lang)
#
# ValueError: [E955] Can't find table(s) lexeme_norm for language 'en' in spacy-lookups-data. Make sure you have the package installed or provide your own lookup tables if no default lookups are available for your language.
