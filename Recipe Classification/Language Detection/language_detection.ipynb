# %% [markdown]
# # Language Detection
#
# This notebook aims to identify the best method for filtering out non-English posts.

# %%
import pandas as pd
from datetime import datetime

# %%
posts = pd.read_csv("/Users/maxkirwan/Desktop/Uni/Data Science MSc/Data Science Project/nutrition-insta/Instagram Data Scraping/Phantom Buster/recipe_posts.csv")
posts.head(2)
# Out:
#                                     postUrl  \
# 0  https://www.instagram.com/p/CgWcU2fss5n/
# 1  https://www.instagram.com/p/CgckMjTpSPs/
#
#                                 profileUrl       username  \
# 0     https://www.instagram.com/jadesbites     jadesbites
# 1  https://www.instagram.com/sweettreatsyt  sweettreatsyt
#
#                 fullName  commentCount  likeCount                   pubDate  \
# 0  JADE | Recipes & Food            47       1648  2022-07-23T10:00:53.000Z
# 1     Ania | SweetTreats             4          3  2022-07-25T19:05:06.000Z
#
#                                          description          location  \
# 0  🧄 ~ A G L I O ~ E ~ O L I O ~ 🧄\n\nSimply mean...         Liverpool
# 1  NEW! Condensed Milk Brownies. These brownies a...  Toronto, Ontario
#
#                                               imgUrl               postId  \
# 0  https://scontent-lhr8-2.cdninstagram.com/v/t51...  2888620789210467943
# 1  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2890344253083689964
#
#       ownerId      type            query                 timestamp  isSidecar  \
# 0  3656910377     Photo  #recipeoftheday  2022-07-26T08:27:52.635Z      False
# 1   633730791  Carousel  #recipeoftheday  2022-07-26T08:27:52.635Z       True
#
#    sidecarMedias videoUrl  viewCount
# 0            NaN      NaN        NaN
# 1            3.0      NaN        NaN

# %% [markdown]
# ### Using SpaCy's language detector

# %%
import spacy
from spacy.language import Language
from spacy_langdetect import LanguageDetector

@Language.factory("language_detector")
def get_lang_detector(nlp, name):
    return LanguageDetector()

nlp = spacy.load("en_core_web_sm")
nlp.add_pipe('language_detector', last=True)
print(nlp("This is an english text.")._.language)
# Out:
# {'language': 'en', 'score': 0.9999981485694562}

# %%
def detect_language(post):
    lang_dict = nlp(str(post))._.language
    return pd.Series([lang_dict['language'], lang_dict['score']])

# %%
now = datetime.now()
posts[['language', 'score']] = posts['description'].apply(detect_language)
print(f"Completed!\nTime taken: {datetime.now()-now}")
# Out:
# Completed!
# Time taken: 0:00:56.144062

# %% [markdown]
# ### Analysis of results

# %%
# Different languages in dataset
posts['language'].unique()
# Out:
# array(['en', 'fr', 'tr', 'it', 'de', 'hu', 'nl', 'ro', 'id', 'ja', 'pl',
#        'ko', 'th', 'hr', 'ar', 'cs', 'es', 'mk', 'tl', 'bg', 'et', 'lt',
#        'el', 'ru', 'sl', 'sv', 'sq', 'da', 'pt'], dtype=object)

# %%
# Lets look at some posts with low confidence scores. These are mainly posts that are in multiple languages.
for index, post in posts[posts['score']<0.6].iterrows():
    print(post['description'], "\n\n", post['language'], post['score'])
# Out:
# Auntie Kai’s Coco Pipinu (Cucumber Coco) 😋🔥❤️
#
# #nettycee #auntiekaiscucumbercoco #cocorecipe #coco #cucumber #cocopipinu #recipe #easyrecipe #easyrecipes #saipan #cnmi #marianas #themarianas #pickledcucumber #foodie #tiktokfoodie
#
#  ro 0.5714267746615391
# #brownies #homemade#chocolate #delicious #2022 #easyrecipes
#
#  en 0.5714268193276484
# Sabudana Vada 🥰 Tag your bestie 😍
# Follow @foodbook_by_aditi
#
# #sabudanavada #meduvada #vadapav #pakoda #easyrecipes #quickrecipes #recipe #recipes
#
#  es 0.5654219400703555
# Niku-maki bento ! 🍱(veggies wrapped in pork) ✿豚の肉巻き弁当✿！
#
# Bento main:
# -Veggies, shiso and cheese wrapped in pork 🥕🐷
# -Brown rice
#
# Bento sides:
# -Broccoli dressed in sesame 🥦
# -Bell pepper, tomato and basil salad 🍅🌿
# -Hard boiled egg 🥚
#
# ✿豚の肉巻き弁当✿
# ◎豚の肉巻き (にんじん、インゲン、チーズ、大葉入り)
# ◎玄米
# ◎ブロッコリーの胡麻和え
# ◎ピーマン、トマトとバジルのサラダ
# ◎ゆで卵
#
# Reel coming soon 😊▶️
# .
# .
# .
#
# #mizuseats#cooking#food#foodstagram #easyrecipes##自炊#自炊記録 #bentobox#bento#本日のお弁当#お弁当#弁当#japanese弁当 #肉巻き#lunch##recipes#簡単レシピ #簡単料理 #肉巻き弁当#豚の肉巻き#弁当記録#japanesecooking#japanesefood#japan#japanfood#japanesecooking#healthy#healthyfood#foodie#japantravel
#
#  en 0.5714273300557413
# 🌱Malzemeler son postta! Ingredients in last post!
#
# 🌷Beys tarif:
#
# 1. Reyhanları bir tencere içine yerleştiriniz.
# 2. 2 yemek kaşığı şeker ekleyiniz.
# 3. 3-4 tane limon tuzu ekleyiniz.
# 4. Kaynamış 1 litre suyu tencereye dökünüz ve kapağını kapatıp 15-20 dk demlenmesini bekleyiniz.
# 5. Suyun rengi değiştikten sonra reyhanları çıkarınız ve soğumaya bırakınız. İçine buz, nane vb şeyler katarak içebilirsiniz. Afiyet olsun!
#
# 🌷Beys recipe:
#
# 1. Place the basil in a saucepan.
# 2. Add 2 tbsp of sugar.
# 3. Add 3-4 sour salt.
# 4. Pour 1 lit. of boiled water into the pot and close the lid and wait for it to brew for 15-20 min.
# 5. After the color of the water changes, take out the basil and let it cool. You can drink it by adding ice, mint etc. Bon appetit!
#
# #easyrecipes#colddrinks#drinkrecipes#kolaytarifler#soğukiçeçekler#cocktailrecipes#recipeshare#applecocktail#health#recipeideas#tarifler#içecektarifleri#sağlık#vegantarifler#plantbased#aesthetic#drinks#homemade#cooking#healthylifestyle#healthyrecipes
#
#  tr 0.5714291282461511
# Frukost: kefir, kanel, havregryn, nektarinbitar, blåbär 🫐 🍑
# .
# .
# .
# .
# .
# .
# .
# #kefir #havregryn #healthy #oats #fruktochbär #foodart #goodfood  #breakfastbowl #breakfast #frukost #fruit #berries #foodblogger  #delicious #mattips #lovefood #foodtography #oatbowl #recipeideas  #foodstagram #ibs
#
#  sv 0.5714271161219189
# 💚 CHEESECAKE VEGANA ALLE ALBICOCCHE 💚 (English below)
#
# ☀️ Voi amate l'estate?
#
# 🍑🍒 A noi piace soprattutto per la grande varietà di frutta che si trova. Se siete come noi dovete per forza provare questa cheesecake alle albicocche!
#
# INGREDIENTI DEL RIPIENO:
#
# 400 g tofu vellutato
# 80 g latte di avena
# 240 g panna vegana
# 3 g agar agar
# 3 albicocche mature
#
# 👉 La ricetta completa la trovate su www.twinsfoodlab.com, oppure cliccando sul link in bio!
#
# ~~~
#
# 💚 APRICOTS VEGAN CHEESECAKE 💚
#
# ☀️ Do you love summer?
#
# 🍑🍒 We like it beacause of the great variety of fruit that can be found. If you are the same as us, you must try this apricot cheesecake!
#
# FILLING INGREDIENTS:
#
# 400 g silken tofu
# 80 g oat milk
# 240 g vegan whipped cream
# 3 g agar agar
# 3 ripe apricots
#
# 👉 The complete recipe can be found on www.twinsfoodlab.com, or by clicking the link in bio!
#
# ~~~
#
# #twinsfoodlab #dolcivegani #dolcivegan #cheesecake #vegancheesecake #ricettevegane #ricettevegan #cucinavegana #dolcisani #healthyrecipes #ricettesane #bergamo #albicocche #cheesecakevegana #cheesecakevegan #iomangiosano #veganok #veganitalia #veganitaly #senzaburro #senzauova #senzalattosio #dolcifattiincasa #veganpastrychef #veganpastry
#
#  en 0.5714288910175669
# Healthy eating is not boring 🤤
#
# Αυγόφετες
#
# •σε αντικολλητικό τηγάνι με 1κ.γ ελαιόλαδο
# •Πρόσθεσα μέλι και μαρμελάδα με λιγότερες θερμίδες 🍯🍒
#
# •Περίπου 300 θερμίδες•
#
# #healthylifestyle #healthyliving #healthyhabits #healthybodyhealthymind #healthybody #healthychoices #healthy #health #healthyrecipes #healthyfood #healthyeating #bodyfitness #bodyacceptance  #bodymindsoul #food #foodlover #υγιεινηδιατροφη #υγεια #υγεία #διατροφή #διατροφη #αυγοφετες
#
#  en 0.5714249947885427
# Breakfast
# سموذي الموز
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# #healthyrecipes #healthyfood #healthybreakfast #healthysmoothies #healthysmoothie #smoothie #smothiebowl #سموذي #سموذي_صحي #سموذي_بول #سموذي_بالموز_والشوفان #اكل_صحي #حياة_صحية #دايت_ورياضة #نظام_غذائي #نظام_صحي #اكسبلور #explore #instagram
#
#  en 0.5714270807313108
# Pirinčani griz bez kuvanja 😍
# Sastojci:
# 40 gr pirinčanih pahuljica
# 1 kašičica čia semenki
# 1 merica proteina
# 100 ml provrele vode
# 50-ak ml biljnog mleka
# 1 kašičica kikiriki putera
# Zasladjivac po želji ukoliko volite sladje
# Priprema:
# Samleti pahuljice I čia semenke dodati postepeno provrelu vodu do željene gustine,konstantno mesati(ja potrošim odprilike 100ml),zatim dodati protein i razmutiti ga sa mlekom!Dekorisati željenim voćem i zero prelivom!Uživati u laganom i ukusnom doručku ili uzini!
# #healthyproo#healthylifestyle #helathyfood #helathylife #healthyblogger #healthyeating #healthyrecipes #healthychoices #healthy #zdravoproo #zdravaishrana #zdravirecepti#zdravauzina #zdravobrok #zdravahrana#nosugar #novisad #instafood #instahealth #instablogger #instagram #foodblog #foodblogger #foodstagram #foodphotography #foodporn #foodinstagram
#
#  hr 0.5708338794242274
# Wie immer …
# #gutenmorgen #goodmorning
# #täglichgrüsstdasmurmeltier #petmüsli #iloveit #oatmeal #fruit #nibs #müsli #morningvibes #morning #meal #breakfast #vegan #veganfood #veganfoodporn #veganfoodlovers #healthyfood #healthyrecipes #getreidekaffee #kaffee #kaffeeliebe #foodblogger #foodlover #summervibes #summer #juli #july
#
#  da 0.5125635894934101
# TROPICAL DIET SMOOTHIE 🍍🥭🥥
#
# Нещо тропическо, свежо и идеално за лятото.
# Тази диетична протеинова бленда съдържа много полезни съставки, а именно:
# ✨Глюкоманан-диетични фибри
# ✨Витамин B5
# ✨Смес от ензими, които спомагат за по-бързото разбиване на протеина до аминокиселини
# ✨Екстракт от канела
# ✨CLA powder - естествено срещаща се мастна киселина от шафраново масло
# ✨Матча зелен чай на прах
# ✨Хюлин - помага за преобразуването на мазнини в енергия
#
# 🌴А също така една доза съдържа само 1,3г мазнини и 3,9г въглехидрати.
#
# ✨Препоръчвам ви да го пробвате, вкусът е уникален, съчетан с плодове под формата на смути. А в сайта на @myproteinbg може да използвате кода ми 𝐒𝐈𝐋𝐕𝐈𝐘𝐀𝐌𝐏 за допълнителна отстъпка! ✨
#
# Ето какво ви трябва за смутито 🥥
# ▪️50 г боровинки
# ▪️50 г манго
# ▪️50 г ананас
# ▪️50 г морков
# ▪️300 мл прясно мляко / овесено мляко
# ▪️1 доза диетичен протеин ягодов милкшейк @myproteinbg
#
# За украса
# ▪️кокосов сироп
# .
# .
# .
# .
# 🇺🇸TROPICAL DIET SMOOTHIE 🍍🥭🥥
#
# Something tropical, fresh and perfect for summer.
# This diet protein blend contains many beneficial ingredients, namely:
# ✨Glucomannan-dietary fiber
# ✨Vitamin B5
# ✨Mixture of enzymes that help break down protein into amino acids faster
# ✨Cinnamon extract
# ✨CLA powder - a naturally occurring fatty acid from safflower oil
# ✨Matcha green tea powder
# ✨Hyulin - helps convert fat into energy
#
# 🌴And also one dose contains only 1.3g of fat and 3.9g of carbohydrates.
#
# ✨I recommend you to try it, the taste is unique, combined with fruit in the form of a smoothie. And on the site of @myproteinbg you can use my code SILVIYAMP for an additional discount! ✨
#
# Here's what you need for the smoothie 🥥
# ▪️50 g of blueberries
# ▪️50 g of mango
# ▪️50 g of pineapple
# ▪️50 g carrot
# ▪️300 ml fresh milk / oat milk
# ▪️1 dose of diet protein strawberry milkshake @myproteinbg
#
# For decoration
# ▪️coconut syrup
# .
# .
# .
# .
# .
# #myprotein #teammyp #fuelyourambition #youdoyou #myproteinkitchen #protein #smoothie #food #foodblogfeed #foodblogger #foodphotography #foodpic #blogger #photooftheday #healthy #healthyfood #healthyeating #healthyrecipes #healthyideas #healthylifestyle #eatclean #goodfood #eatgoodfeelgood #nutrition #fit #fitfood #summer
#
#  en 0.5714280728106628
# Tulunad Special Menthe Ganji 😋
#
# Fenugreek Seeds Porridge
#
# #healthyfood #healthyrecipes #mentheganji #aati #aatiamavasya #tulunad #mangalorespecial #karanataka #karnatakafood #karnatakafoodies #mangalorefood #foodgasm #foodiesofkarnataka #karnatakafoodadda #karnatakafoodbloggers #karnatakafoodlovers #foodlovers #udupifood
#
#  et 0.42857179507101417
# Vous aimez manger sainement ? 🌿😋
# Nos produits sont sans additifs, sans conservateurs et sans gluten.
# Le riz et les légumes utilisés sont bio et les poissons sont issus exclusivement de pêche durable et labellisés MSC. 🎣💙
# .
# .
# .
# .
# .
# .
# .
# .
# #organic #vegan #healthy #instagood #biology
# #homemade #crueltyfree #sushilover #yummy
# #MadeInFrance #sansgluten #passionfood #france
# #delicious #instalike #summer #yummyfood #japon
# #food #japanesefood #japanesefoodstreet #foodporn #healthyrecipes #healthyeating #bio #foodlover #foodies #deliciousfood #eatclean #food
#
#  fr 0.571429207591107
# Prosciutto/mozza salade 🥗 #summer #salade #salad #fresh #healthyfood #sain #mangersain #prosciutto #mozzarella #été #warm #mangersainement #easymeals #diner
#
#  it 0.571426562932605
# Why is canned tuna so cheap when fresh tuna is so expensive?
#
# Tuna salad:
# - Tuna+mayo+salt+yogurt+lime
# - Red coral lettuce
# - Baby cos lettuce
# - Butterhead lettuce
# - Fresh shallots
# - Goji berries
# - Spring onions
# - Hard boiled egg
#
# Well it basically comes down to what is described as "sushinomics". Tuna that is canned are species that reproduce quickly creating a vast supply (albacore, yellowtail etc.) But are considered less tasty. The ones that are used for sashimi and sushi are the Bluefin tuna which not only require more efforts in catch but are also low in supply. With the fish only reaching reproductive at 8 years and only having a life span of around 40 years, there aren't much to go around. Overfishing has also greatly contributed to the decline in supply of bluefins as they are being caught before being able to reproduce. Lack in regulation will likely lead to extinction of these tasty swimmers. Luckily there are efforts being put forward and the status of bluefin have been reduce from endangered to least concern. Which is great but it needs to be continued because they taste so good 🥺.
#
# Oh and side note: if you dont want to add alot of mayo to your tuna; sub with unsweetened yogurt, lime and salt. Gives it a fresh taste and adds a 'lil probiotics to you diet.
#
# ทำไมทูน่ากระป๋องกับแบบซาชิมิถึงราคาต่างกันราวฟ้ากับเหว
#
# สลัด:
# - ทูน่าผสม มายองเนส โยเกิร์ต เกลือ มะนาว
# - ผักเรดคอรัล
# - เบบี้คอส
# - บัตรเตอร์เฮด
# - หอมแดง
# - ต้นหอม
# - โกจิเบอร์รี่
# - ไข่ต้ม
#
# คือราคามันก็ขึ้นอยู่กับอุปสงค์อุปทานแหละ ตัวชนิดแลาที่เอามาทำทูน่ากระป๋องเป็นพันธุ์ที่โตไวและออกลูกง่ายเลยมีให้จับได้ล้นเหลือ ส่วนพันธุ์ที่เอามาทำเป็นซาชิมินั้นนิยมเป็นพันธุ์บลูฟิน ซึ่งกว่าจะโตถึงไวเพาะพันธุ์ก็ ตั้ง8ปี แล้วแถมยังอยู่น้ำลึกจับยากอีก เนื่องจากมีดารจับปลาบลูฟินที่เร็วเกินกว่ามันจะขยายพันธ์ได้ก็ทำให้จำนวนนั้นลดลงไปเรื่อยๆ มิหนำซ้ำชาวประมงเริ่มจับปลาที่มีขนาดเล็กลงซึ่งอาจจะอายุน้อยกว่า 8ปี ทำให้ปลาเหลือน้อยยิ่งไปอีกเพราะยังไม่ได้ทันออกลูกก็ถูกจับไปกินสะแล้ว
#
# ปล. ใครไม่อยากใช้มายองเนสผสมปลาเยอะให้เปลี่ยนมาเป็นโยเกิร์ตไม่หวานผสมเกลือกับมะนาวนะ หลดไขมันได้เยอะเลยแถมยังเพิ่มโปรไบโอติกอีก
#
#  en 0.5714285168892246
# Tomato sauce spaghetti and roasted broccoli. I made a quick supper and fed my son and brought him to his soccer game but it got cancelled because of thunder storm 😵‍💫
# .
# .
# .
# トマトソーススパゲッティとローストブロッコリー。息子のサッカーの試合があるからと、慌てて作って食べさせて試合に連れて行ったけど、雷雨で中止に🙄
# .
# .
# .
# .
# .
# .
#
# #veganrecipes #vegetarianrecipes #tomatosaucespaghetti #spaghettitomatosauce #tomatosaucepasta #simplepasta #airfryerbroccoli #airfriedbroccoli #simplecooking #quickmeals #easymeals #healthymeals #ビーガンレシピ #ベジタリアンレシピ #トマトソーススパゲッティ #スパゲッティトマトソース #トマトソースパスタ #シンプルパスタ #ノンフライヤーレシピ #エアフライヤーレシピ #おうちごはん #晩ごはん #シンプルごはん #簡単ごはん #ヘルシーごはん
#
#  ja 0.571428542322404

# %%
# Looking at posts which have been classified as english but with low confidence scores.
for index, post in posts[(posts['score']<0.95) & (posts['language']=='en')].iterrows():
    print(post['description'], "\n\n", post['score'])
# Out:
# Tried this Creamy burger steak version 🥰
#
# Follow on:
# Tiktok: @mjkevsvlog
# Instagram: @mjkevss
# YT: MJKevss
#
# #burgersteak #jollibeeburgersteak #foodlover #food #foodstagram #foodie #mjkevss #recipe #recipeoftheday #fyp
#
#  0.8571390987604018
# Spicy chikan Tika mecroni |colourful mecroni
#
# Ingredients
#
# #chikan
# #alo
# #gajar
# #mecroni
# #tikamasla
# #chatmasla
# #kalimirch powder
# #namak
# #soyasauce
# #sirka
# #chilisauce
# #sabaz mirch
#
# #tikamecroni#chikanmecroni#colorful
# #mecroni #spicy #tikamasla #chikan #alo #gajar #soyasauce #chilisauce #reels #instgram #recipe #recipeoftheday #vedio #foodinstgram
#
#  0.8571413169423909
# Meat Balls With Zucchini Zoodles & Veges 🍝🥕🧄🧅🍅
#
# Recipe now up over at @saharskitchenette
#
#  0.8571404725726666
# A good day starts with a good breakfast 🥰♥️🥰
#
# صباح الخير و السعادة 🌹
#
# طبق سهل متوازن سعراته قليله 🥗✅✅.
#
# —————————————————————#healthyfood #healthylifestyle #nutrition #diet #balanceddiet #eggs#wheyprotein #explore #shake #pumkinseeds#easyrecipes #happy#دايت #تغذیه #سمنه#نحافه #تصويري #اكسبلور #وصفات #فطار #دايت_صحي #افكار #egypt #ksa #iraq #love
#
#  0.7142837321148233
# #brownies #homemade#chocolate #delicious #2022 #easyrecipes
#
#  0.5714268193276484
# Soft tacos for dinner #gerry #keto #tacos #taranaki #easyrecipes
#
#  0.7142830939286486
# Malai kofta
# Full recipe link in bio @sukirtisfoodmagic
#
# #indianfood #vegcurry #vegetariancurry #vegfood  #indianrecipes #maincourse #malaikofta #restaurant #restaurantstyle #quickrecipe #easyrecipes #recipeshare #homemaderecipes #homemadefood #vegetarianrecipes #vegetarianrecipes
#
#  0.7142835143987214
# 5 minute easy and quick snack recipe potato cubes
# .
# .
# .
# .
# .
# #easyrecipes #potatocubes #yummy #delicious #easy #tasty #snacks
#
#  0.8571404451530068
# Dasi ghee nikalnay ka asan tariqa #mishivlog #desighee #food #easyrecipes #homemadeghee #foryoupage #foryou #pakistanibloggers
#
#  0.7142831766922526
# Instant Sambhar preparation || #food #foodie #foodblogger #easyrecipes #homemadefood #sambhar #trending #viral #viralvideos #creator #dailyvlogs
#
#  0.8571407032451295
# Why is canned tuna so cheap when fresh tuna is so expensive?
#
# Tuna salad:
# - Tuna+mayo+salt+yogurt+lime
# - Red coral lettuce
# - Baby cos lettuce
# - Butterhead lettuce
# - Fresh shallots
# - Goji berries
# - Spring onions
# - Hard boiled egg
#
# Well it basically comes down to what is described as "sushinomics". Tuna that is canned are species that reproduce quickly creating a vast supply (albacore, yellowtail etc.) But are considered less tasty. The ones that are used for sashimi and sushi are the Bluefin tuna which not only require more efforts in catch but are also low in supply. With the fish only reaching reproductive at 8 years and only having a life span of around 40 years, there aren't much to go around. Overfishing has also greatly contributed to the decline in supply of bluefins as they are being caught before being able to reproduce. Lack in regulation will likely lead to extinction of these tasty swimmers. Luckily there are efforts being put forward and the status of bluefin have been reduce from endangered to least concern. Which is great but it needs to be continued because they taste so good 🥺.
#
# Oh and side note: if you dont want to add alot of mayo to your tuna; sub with unsweetened yogurt, lime and salt. Gives it a fresh taste and adds a 'lil probiotics to you diet.
#
# ทำไมทูน่ากระป๋องกับแบบซาชิมิถึงราคาต่างกันราวฟ้ากับเหว
#
# สลัด:
# - ทูน่าผสม มายองเนส โยเกิร์ต เกลือ มะนาว
# - ผักเรดคอรัล
# - เบบี้คอส
# - บัตรเตอร์เฮด
# - หอมแดง
# - ต้นหอม
# - โกจิเบอร์รี่
# - ไข่ต้ม
#
# คือราคามันก็ขึ้นอยู่กับอุปสงค์อุปทานแหละ ตัวชนิดแลาที่เอามาทำทูน่ากระป๋องเป็นพันธุ์ที่โตไวและออกลูกง่ายเลยมีให้จับได้ล้นเหลือ ส่วนพันธุ์ที่เอามาทำเป็นซาชิมินั้นนิยมเป็นพันธุ์บลูฟิน ซึ่งกว่าจะโตถึงไวเพาะพันธุ์ก็ ตั้ง8ปี แล้วแถมยังอยู่น้ำลึกจับยากอีก เนื่องจากมีดารจับปลาบลูฟินที่เร็วเกินกว่ามันจะขยายพันธ์ได้ก็ทำให้จำนวนนั้นลดลงไปเรื่อยๆ มิหนำซ้ำชาวประมงเริ่มจับปลาที่มีขนาดเล็กลงซึ่งอาจจะอายุน้อยกว่า 8ปี ทำให้ปลาเหลือน้อยยิ่งไปอีกเพราะยังไม่ได้ทันออกลูกก็ถูกจับไปกินสะแล้ว
#
# ปล. ใครไม่อยากใช้มายองเนสผสมปลาเยอะให้เปลี่ยนมาเป็นโยเกิร์ตไม่หวานผสมเกลือกับมะนาวนะ หลดไขมันได้เยอะเลยแถมยังเพิ่มโปรไบโอติกอีก
#
#  0.7142839689821255
# Niku-maki bento ! 🍱(veggies wrapped in pork) ✿豚の肉巻き弁当✿！
#
# Bento main:
# -Veggies, shiso and cheese wrapped in pork 🥕🐷
# -Brown rice
#
# Bento sides:
# -Broccoli dressed in sesame 🥦
# -Bell pepper, tomato and basil salad 🍅🌿
# -Hard boiled egg 🥚
#
# ✿豚の肉巻き弁当✿
# ◎豚の肉巻き (にんじん、インゲン、チーズ、大葉入り)
# ◎玄米
# ◎ブロッコリーの胡麻和え
# ◎ピーマン、トマトとバジルのサラダ
# ◎ゆで卵
#
# Reel coming soon 😊▶️
# .
# .
# .
#
# #mizuseats#cooking#food#foodstagram #easyrecipes##自炊#自炊記録 #bentobox#bento#本日のお弁当#お弁当#弁当#japanese弁当 #肉巻き#lunch##recipes#簡単レシピ #簡単料理 #肉巻き弁当#豚の肉巻き#弁当記録#japanesecooking#japanesefood#japan#japanfood#japanesecooking#healthy#healthyfood#foodie#japantravel
#
#  0.5714273300557413
# 💗 pizza & salad
# flatbread from Aldi & an air fryer = pizza in less than 10 minutes 👌🏻 bon appetit
# #flatbreadpizza #pizzalover #foodiefun #airfryer #airfryerpizza #pizza  #kitchenadventures #easyrecipes #foodiefun #goodeats
#
#  0.8571410489427772
# #whatsfordinner - Seafood Salad Tostadas! I made this easy seafood salad and fresh guacamole, then layered the guacamole and salad on baked tostadas. Fresh, light, and delicious for a hot summer night. ☀️
# Recipe: https://www.dinneratthezoo.com/seafood-salad/
#
# #seafood #shrimp #shrimptostadas #guacamole #crab #crabsalad #seafoodsalad #bakedtostadas #tostadas #summerdinner #easydinner #easydinners #easyrecipes #dinnerideas #dinnerrecipes #dinner
#
#  0.857140795132363
# Silky Zucchini soup with olive oil and zucchini blossoms.
# .
# .
# #pickedtoday #freshlypicked #harvest #summergarden #zucchinirecipes #zucchinisoup #vegetablegarden #freshisbest #easydinner #easyrecipes #soupfordinner #dinnertime #cookingathome #homecooking
#
#  0.85713859076059
# Hey Foodies! Ako lang ba? Pero ang sarap talaga ng combination ng tokwa at kangkong, lalo na kung smoked tofu ang isasahog! Tara kain! 😊
#
# #smokedtofu #smokedtokwa #tokwa #kangkong #waterspinach #veggies #breakfast #breakfastbowl #flexitarian #flexitarianrecipe #photooftheday #recipeshare #igfoodieph #igfoodies #igphotoworld #instagram #ph #healthymeals #healthyfoodieph #homecooking #channel #igph #ig #instagram #recipeideas #yummyph #chibogtayoph #instafood #foodstagram #foodtripbakamo #masarapba
#
#  0.71428373287976
# CALIFORNIA FIG BANANA BREAD. Read about it in today’s Blog: aimeebrabant.wixsite.com/aimeescorner #recipes #recipe #recipeoftheday #recipeshare #recipeideas #recipesharing #recipeidea #healthyrecipe #easyrecipe #recipeblog #recipepost #recipeinspo #simplerecipe #foodrecipe #dessertrecipe #quickrecipe #breadrecipe #bananabreadrecipe #bananabreadmuffins
#
#  0.7142826870004163
# Tortellini, olive oil, lemon, chilli flakes, basil, pecorino.
#
# #hkfoodie #instafoodies #manchesterfood #homecooked  #yummyinmytummy #foodphotograph #homecooking #recipeideas #yummyfood  #ukfoodblogger #manchesterfoodie #manchesterfood  #ukfoodblog #foodbloguk #ukfoodie #londonfoodie #mcrfood #mcrfoodie #homecookedmeal #nomnomnom #pastalovers   #ilovepasta  #unami #tortellini
#
#  0.8571405898389092
# [🇬🇧 below]
#
# 🇪🇸 Obleas de arroz fritas con verduras, langostinos y salsa sate. Montalos como más te gusta y ponle mucha salsa como yo.
#
# 👉 He usado verduras crunch: zanahoria, col lombarda, pepino y cilantro.
#
# 👉 Los langostinos son hervidos y los fideos de arroz finos se preparan como indica el paquete.
#
# 👉 Las obleas de arroz se fríen en aceite y empieza a montar!
# .
# .
# .
# .
# .
# 🇬🇧 Fried rice papers with vegetables, prawns and satay sauce. Create them using the ingredients you like and have them with lots of sauce like me.
#
# 👉 I used crunchy veggies: cucumber, red cabbage, carrots and coriander.
#
# 👉 The prawns have been boiled and the thin rice noodles prepared as indicated on the package.
#
# 👉 Fry the rice papers in oil and start stacking!
# .
# .
# .
# .
# .
# #ricepaper #obleasdearroz #peanutsauce #salsadecacahuetes #lunch #yummylunch #delicioso #langostinos #recetaasiatica #recetafacil #instafood #instareceta #mallorcacooking #mallorcacocina #recipeideas #sataysauce #ideasparacocinar
#
#  0.8571404823975376
# وصفة جديدة في قناتي كملو الالبوم وخلولي رايكم
#
# #biskra #gateauxalgeriens #gateauchocolat #femme #femmealgerienne #summer #قاطو_العيد #قاطو_بريستيج #قاطو_جزائري #قاطو_الاعراس #قاطوالحلويات_الجزائرية #المرأة
# #food #foodporn #foodstylist #foodphotography #foodblogger #foodpics #foodie #foodlover #foodgram #foodinstagram #foodshooting #instagram #instagramfood #recipe #recipeideas #easyrecipes  #اكلات_سريعه #اكلات_سهله
#
#  0.8571365591132148
# S.O.S! Or shall I say, sauce? 😂
#
# What do you do when you need to find new recipes? Share some details about your favourite new dinner below, or send us a link to your favourite recipe pages. 🍑🥓🍟
#
# #dinnerideas #recipe #recipes #dinnerecipe #dinnerecipes #Pinterestrecipe #recipeideas
#
#  0.8571395116169318
# 💚 CHEESECAKE VEGANA ALLE ALBICOCCHE 💚 (English below)
#
# ☀️ Voi amate l'estate?
#
# 🍑🍒 A noi piace soprattutto per la grande varietà di frutta che si trova. Se siete come noi dovete per forza provare questa cheesecake alle albicocche!
#
# INGREDIENTI DEL RIPIENO:
#
# 400 g tofu vellutato
# 80 g latte di avena
# 240 g panna vegana
# 3 g agar agar
# 3 albicocche mature
#
# 👉 La ricetta completa la trovate su www.twinsfoodlab.com, oppure cliccando sul link in bio!
#
# ~~~
#
# 💚 APRICOTS VEGAN CHEESECAKE 💚
#
# ☀️ Do you love summer?
#
# 🍑🍒 We like it beacause of the great variety of fruit that can be found. If you are the same as us, you must try this apricot cheesecake!
#
# FILLING INGREDIENTS:
#
# 400 g silken tofu
# 80 g oat milk
# 240 g vegan whipped cream
# 3 g agar agar
# 3 ripe apricots
#
# 👉 The complete recipe can be found on www.twinsfoodlab.com, or by clicking the link in bio!
#
# ~~~
#
# #twinsfoodlab #dolcivegani #dolcivegan #cheesecake #vegancheesecake #ricettevegane #ricettevegan #cucinavegana #dolcisani #healthyrecipes #ricettesane #bergamo #albicocche #cheesecakevegana #cheesecakevegan #iomangiosano #veganok #veganitalia #veganitaly #senzaburro #senzauova #senzalattosio #dolcifattiincasa #veganpastrychef #veganpastry
#
#  0.5714288910175669
# Healthy eating is not boring 🤤
#
# Αυγόφετες
#
# •σε αντικολλητικό τηγάνι με 1κ.γ ελαιόλαδο
# •Πρόσθεσα μέλι και μαρμελάδα με λιγότερες θερμίδες 🍯🍒
#
# •Περίπου 300 θερμίδες•
#
# #healthylifestyle #healthyliving #healthyhabits #healthybodyhealthymind #healthybody #healthychoices #healthy #health #healthyrecipes #healthyfood #healthyeating #bodyfitness #bodyacceptance  #bodymindsoul #food #foodlover #υγιεινηδιατροφη #υγεια #υγεία #διατροφή #διατροφη #αυγοφετες
#
#  0.5714249947885427
# Breakfast
# سموذي الموز
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# #healthyrecipes #healthyfood #healthybreakfast #healthysmoothies #healthysmoothie #smoothie #smothiebowl #سموذي #سموذي_صحي #سموذي_بول #سموذي_بالموز_والشوفان #اكل_صحي #حياة_صحية #دايت_ورياضة #نظام_غذائي #نظام_صحي #اكسبلور #explore #instagram
#
#  0.5714270807313108
# Buon martedí 💛
# •Weetabix
# •Yogurt gredo bianco 0%
# •Marmellata di fragole senza zuccheri
# •Burro di arachidi 100%
# .
# .
# .
# .
# .
#
# .
# .
# .
# .
# .
#
# #healthyfood #healthylifestyle #foodblogger #fooddiary #healthyrecipes #healthylife #cibosano #delicious #dietasana #diet  #food #foodphotography #foodpics  #ciboitaliano #instafood #foodlovers #italianfood  #goodfood  #cappuccino #breakfast  #breakfastlover #colazione #colazionesana #healthybreakfast  #healthybreakfastideas #lovebreakfast #dietfood #eathealthy
# #alimentazionesana #weetabix
#
#  0.7142822823927912
# #Repost @wawa.draishahbeau with @let.repost
# • • • • • •
# After so long wawa tak update, but still have to work hard for myself !! Been busy working and jalankan tugas sebagai seorang isteri. My friend ni dah repeat second box sebab betul2 nak tengok result after consume @d.va_ofc
# 🍓
# 🍓
# Long lost friend 3tahun tak jumpa ni tauu !! Alhamdulillah dia yakin and trust the process of consuming this product, lagi2 kita yg built career as empowering woman ni kan haaa gituu 🫶🏻🥰
# .
# #dva #rahsiakebahagiaanwanita #quotesdva #skincare #beautyproduct #supplements #beautyandhealth #beautytips #healthyrecipes #healthylifestyle #healthyhabits #beautycare #beautyhacks #beautytips #cantiksihat #tipscantik #sihatdancantik #resepisihat #sihatmalaysia #dietsihat #jomsihatdancantik #sihatdalamancantikluaran #tipssihat #sihatbertenaga #readytodrink #vitality #tranquil #agentdva #dropshipdva
#
#  0.7142843583354065
# The simplicity of pizza makes it a year round favourite and summer is no exception. But here at our kitchen we like to spice things up so how about an easy and decadent croque Madame made with turkey and Gruyère? Give it a shot and thank us later
#
# تعتبر البيتزا بمكوناتها البسيطة مفضلة لدي الجميع على مدار العام بما في ذلك موسم الصيف. لكن هنا في مطبخنا، نضيف لمساتنا الإبداعية الخاصة عند إعداد الوصفات، لذلك ما رأيكم بتجربة وصفة كروك مدام بطريقة سهلة ومميزة باستخدام شرائح من الديك الرومي، وجبنة غرويير؟ جربوها، واستمتعوا بالطعم المميز.
#
# #oliveoil #alwaziroliveoil #healthy #oliveoiltasting #healthylife #easyrecipes #healthyrecipes #meal #foodies #cookingtime #cookingtips #ksa #UAE
# #زيت_زيتون #الوزير #صحي #طبيعي #وصفات #وصفات_صحية #وصفات_سهلة #وجبات #شهية #لذيذة #السعودية #الامارات
#
#  0.7142835037237721
# TROPICAL DIET SMOOTHIE 🍍🥭🥥
#
# Нещо тропическо, свежо и идеално за лятото.
# Тази диетична протеинова бленда съдържа много полезни съставки, а именно:
# ✨Глюкоманан-диетични фибри
# ✨Витамин B5
# ✨Смес от ензими, които спомагат за по-бързото разбиване на протеина до аминокиселини
# ✨Екстракт от канела
# ✨CLA powder - естествено срещаща се мастна киселина от шафраново масло
# ✨Матча зелен чай на прах
# ✨Хюлин - помага за преобразуването на мазнини в енергия
#
# 🌴А също така една доза съдържа само 1,3г мазнини и 3,9г въглехидрати.
#
# ✨Препоръчвам ви да го пробвате, вкусът е уникален, съчетан с плодове под формата на смути. А в сайта на @myproteinbg може да използвате кода ми 𝐒𝐈𝐋𝐕𝐈𝐘𝐀𝐌𝐏 за допълнителна отстъпка! ✨
#
# Ето какво ви трябва за смутито 🥥
# ▪️50 г боровинки
# ▪️50 г манго
# ▪️50 г ананас
# ▪️50 г морков
# ▪️300 мл прясно мляко / овесено мляко
# ▪️1 доза диетичен протеин ягодов милкшейк @myproteinbg
#
# За украса
# ▪️кокосов сироп
# .
# .
# .
# .
# 🇺🇸TROPICAL DIET SMOOTHIE 🍍🥭🥥
#
# Something tropical, fresh and perfect for summer.
# This diet protein blend contains many beneficial ingredients, namely:
# ✨Glucomannan-dietary fiber
# ✨Vitamin B5
# ✨Mixture of enzymes that help break down protein into amino acids faster
# ✨Cinnamon extract
# ✨CLA powder - a naturally occurring fatty acid from safflower oil
# ✨Matcha green tea powder
# ✨Hyulin - helps convert fat into energy
#
# 🌴And also one dose contains only 1.3g of fat and 3.9g of carbohydrates.
#
# ✨I recommend you to try it, the taste is unique, combined with fruit in the form of a smoothie. And on the site of @myproteinbg you can use my code SILVIYAMP for an additional discount! ✨
#
# Here's what you need for the smoothie 🥥
# ▪️50 g of blueberries
# ▪️50 g of mango
# ▪️50 g of pineapple
# ▪️50 g carrot
# ▪️300 ml fresh milk / oat milk
# ▪️1 dose of diet protein strawberry milkshake @myproteinbg
#
# For decoration
# ▪️coconut syrup
# .
# .
# .
# .
# .
# #myprotein #teammyp #fuelyourambition #youdoyou #myproteinkitchen #protein #smoothie #food #foodblogfeed #foodblogger #foodphotography #foodpic #blogger #photooftheday #healthy #healthyfood #healthyeating #healthyrecipes #healthyideas #healthylifestyle #eatclean #goodfood #eatgoodfeelgood #nutrition #fit #fitfood #summer
#
#  0.5714280728106628
# Good food always wins.
# .
# Always prefer a good diet.
# .
# #healthydiet #healthyindiandiet #diethealthy #healthyvegandiet #healthyfooddiet #mealprep #healthyliving #healthyfood #nutrition #healthylifestyle #healthyeating #healthyfats #healthyrecipes #fitfood #nutritioncoaching #foodfitness #nutritions #healthyeat #healthyfoodideas #heathy #heathyfood #dietcoach #proteindrink #eatcleaning #myhealthylife #healthydietfood #everydaycafeinfaridabad
#
#  0.714285580422056
# 🍳 poached egg (I attempted) and home made avocado on toast, 🥑 yum
#
#  0.8571413619806103
# BLUEBERRY COCONUT OATS 🥥🫐 (English below 👇🏻)
#
# 🇩🇪Heute wieder ein leckeres Porridge Rezept für euch. 🥥🫐 Heidelbeeren kombiniert mit Kokos Geschmack, so startet es sich gut in den Dienstag oder?
#
# 2 Portionen ➡️
#
# - 90g Haferflocken
# - 20g Kokosnuss Protein
# - 5g Chia Samen
# - 150-200ml Kokosdrink
# - Süße nach Wahl (z.B. Kokosblütenzucker
# - 60g gefrorene Heidelbeeren
#
# Toppings: Heidelbeeren, Himbeeren, Papaya, Pfirsich, Nussmus
#
# Zubereitung ➡️
#
# Alles bis auf die gefrorenen Beeren und Toppings im Topf bei mittlerer Hitze circa 10min cremig kochen. Heidelbeeren unterheben und weitere 3min köcheln. Auf Schüsseln verteilen, toppen und schmecken lassen. 😊
#
# •
# •
#
# BLUEBERRY COCONUT OATS 🥥 🫐
#
# 🇬🇧Today another delicious porridge recipe for you. 🥥  Blueberries combined with coconut flavor, that's a good way to start Tuesday, right?
#
# 2 Portions ➡️
#
# - 90g oats
# - 20g coconut protein
# - 5g of chia seeds
# - 150-200ml coconut drink
# - Sweetener of your choice (e.g. coconut blossom sugar
# - 60g frozen blueberries
#
# Toppings: blueberries, raspberries, papaya, peach, nut butter
#
# Preparation ➡️
#
# Cook everything except the frozen berries and toppings in a saucepan over medium heat for about 10 minutes until creamy. Fold in the blueberries and simmer for another 3 minutes. Pour into bowls, top and enjoy. 😊
#
# •
# •
# •
#
# #breakfast #breakfastbowl #haferflocken #oats #blueberries #porridge #oatmeal  #veganfrühstück #veganessen #veganeküche #coconutbowls #nourishbowl #nutbutter #breakfastrecipes #wellnessfood #vegan #plantbasedrecipes #healthyfood #healthyrecipes #foodismedicine  #veganbreakfast #plantbased #veganfoodshare #wellnessjourney #workoutfuel #gesundeernährung #vegangermany #discoverunder5k #berryseason #theflavoursomekitchen
#
#  0.7142832313863865
# ⛓️🍂🗣️柳太既住家靚餸👀‼️
#
# 玻璃生菜🥬
# 冬菇黑木耳燜雞🥰
#
# 〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️〰️
# #foodie #foodies #foodieforlife #foodiepics #foodielife #foodiesofinstagram #foodiehk #foodiecanada #homemade #homemadefood #homemadevinegar #homemadeveganfood #green #greenliving #healthyfood #healthylifestyle #healthyrecipes
#
#  0.8571394744105552
# Dinner last night was cheese and tomato on gluten free toast. Xxx
#
# #weightloss #weightlossvlogger #slimmingyoutuber #healthyrecipes #healthyfood #intuitiveeating
#
#  0.8571387787628346
# #fruitartist #myfruitdecor #fruitfarmacy #drmassimospattini #fruitonly #freshfruits #drfilippoongaro #foodblogger #fruitforbreakfast #fruitcreation #fruttafresca #fruitporn #drjoedispenza #colazione #lamiafrutta
# #solocosebelle #everyday #foodblogger #salute #healthyfood #healthybreakfastideas #healthylifestyle
# #healthyrecipes #saluteebenessere #salus #salutebenessere #salus #saluteebenessere
# #lasitua #cosebrutteimpaginatebelle
#
#  0.7142840637130353
# Homemade Paneer Burger 🍔
#
# #paneerburger #homadeburger #homcooking
#  #homecookingshow #jackfrooteats #wannabechef #cookingself #healthyrecipes
# #homefoodie #burger
#
#  0.8571389734049846
# کوکوی عدس🧆
# عدس( خیس خورده از قبل)
# آب یک فنجان
# جو دو سر پرک یک قاشق
# سبزی های معطر دلخواه
# ادویه های دلخواه
# همه ی مواد و با هم میکس کنین
# سبزی های خورد شده رو بهش اضافه کنین. ماهیتابه رو با روغن کنجد یا زیتون چرب کنین و بزارین روی حرارت تا داغ بشه.
# دو تا سه دقیقه به هر طرف زمان بدین تا بپزه. یه تخم مرغ با روغن خیلی کم نیمرو کنین و ازش لذت ببرین.
# .
# Lentils cuckoo🥙
# Lentils
# 1cup water
# 1spoon oats
# Fave vegetables
# Fave spices
# Mix all of ingredients.add vegetables. Hit the pan with sesame or olive oil. Pour your mixed ingredients onto pan and wait 2,3 mins for each side. Serve it with egg 🍳 enjoy❤️
# #diet #healthyfood #health #healthy #healthyrecipes #healthylifestyle #fitness #fit #gym #fitnesslife #motivation #breakfast #breakfastideas #lunch #mealplan #meal #mealprep
#
#  0.7142832642554694
# Follow 👉@beautyremedies.ig For More HEALTH, BEAUTY & FITNESS Information.
# -
# -
# -
# -
# .
# .
# #easyfood #lessfat #eatfoodfeelgood #fatness #nutritionplan #foodgoals #fitmeal #leanmeals #easymeals #eatbetter #healthyfoods #cleanfoodcrush #instantpot #easydinner #eatcleantraindirty #healthyfoodlove #iifymfood #quickandeasyfood #gymfood #painreleif #tastyrecipes #iifymrecipes #eatcolorful #healthynutrition #foodrevolution #healthyfoodie #fitfoods #proteinmeal #reduceinflammation
#
#  0.8571379688868043
# Why is canned tuna so cheap when fresh tuna is so expensive?
#
# Tuna salad:
# - Tuna+mayo+salt+yogurt+lime
# - Red coral lettuce
# - Baby cos lettuce
# - Butterhead lettuce
# - Fresh shallots
# - Goji berries
# - Spring onions
# - Hard boiled egg
#
# Well it basically comes down to what is described as "sushinomics". Tuna that is canned are species that reproduce quickly creating a vast supply (albacore, yellowtail etc.) But are considered less tasty. The ones that are used for sashimi and sushi are the Bluefin tuna which not only require more efforts in catch but are also low in supply. With the fish only reaching reproductive at 8 years and only having a life span of around 40 years, there aren't much to go around. Overfishing has also greatly contributed to the decline in supply of bluefins as they are being caught before being able to reproduce. Lack in regulation will likely lead to extinction of these tasty swimmers. Luckily there are efforts being put forward and the status of bluefin have been reduce from endangered to least concern. Which is great but it needs to be continued because they taste so good 🥺.
#
# Oh and side note: if you dont want to add alot of mayo to your tuna; sub with unsweetened yogurt, lime and salt. Gives it a fresh taste and adds a 'lil probiotics to you diet.
#
# ทำไมทูน่ากระป๋องกับแบบซาชิมิถึงราคาต่างกันราวฟ้ากับเหว
#
# สลัด:
# - ทูน่าผสม มายองเนส โยเกิร์ต เกลือ มะนาว
# - ผักเรดคอรัล
# - เบบี้คอส
# - บัตรเตอร์เฮด
# - หอมแดง
# - ต้นหอม
# - โกจิเบอร์รี่
# - ไข่ต้ม
#
# คือราคามันก็ขึ้นอยู่กับอุปสงค์อุปทานแหละ ตัวชนิดแลาที่เอามาทำทูน่ากระป๋องเป็นพันธุ์ที่โตไวและออกลูกง่ายเลยมีให้จับได้ล้นเหลือ ส่วนพันธุ์ที่เอามาทำเป็นซาชิมินั้นนิยมเป็นพันธุ์บลูฟิน ซึ่งกว่าจะโตถึงไวเพาะพันธุ์ก็ ตั้ง8ปี แล้วแถมยังอยู่น้ำลึกจับยากอีก เนื่องจากมีดารจับปลาบลูฟินที่เร็วเกินกว่ามันจะขยายพันธ์ได้ก็ทำให้จำนวนนั้นลดลงไปเรื่อยๆ มิหนำซ้ำชาวประมงเริ่มจับปลาที่มีขนาดเล็กลงซึ่งอาจจะอายุน้อยกว่า 8ปี ทำให้ปลาเหลือน้อยยิ่งไปอีกเพราะยังไม่ได้ทันออกลูกก็ถูกจับไปกินสะแล้ว
#
# ปล. ใครไม่อยากใช้มายองเนสผสมปลาเยอะให้เปลี่ยนมาเป็นโยเกิร์ตไม่หวานผสมเกลือกับมะนาวนะ หลดไขมันได้เยอะเลยแถมยังเพิ่มโปรไบโอติกอีก
#
#  0.5714285168892246
# Tonight we had panzanella which was super duper yummy and not hard to cook. I added kalamata olives, garlic, basil, pine nuts, spinach, tomatoes, balsamic dressing, olive oil, mozzarella and ricotta salata.
#
# #vegetarian #panzanella #yummy #easymeals
#
#  0.8571390835694299
# Spaghetti Bolognaise 🧡
#
# #slimmingworld #slimmingworlduk #slimmingworldfollowers #slimmingworldfood #slimmingworldinsta #slimmingworlddinner #slimmingworlddinners #sw #swuk #swfood #swinspo #swideas #swdinner #swdinnerideas #healthyeating #healthyrecipes #healthymeals #healthydinner #healthylifestyle #dinner #food #foodie #foodstagram #spagbol #tagliatelle #weightloss #easymeals #quickrecipes #diet
#
#  0.857139933550764

# %% [markdown]
# From the above analysis it seems appropriate to remove all such posts:
#
# 1. Any posts not classified as english.
#
# 2. Any posts classified as english but with confidence scores less than 0.95. This is because these posts are likely to contain multiple languages.

# %%
def get_english_posts(df, language='en', confidence=0.95):
    
    print("Detecting language of each post...")
    now = datetime.now()
    
    df[['language', 'score']] = df['description'].apply(detect_language)
    
    print(f"Language detection complete.\nTime taken: {datetime.now()-now}")
    
    return df[(df['score']>0.95) & (df['language']=='en')]

# %%
get_english_posts(posts)
# Out:
# Detecting language of each post...
# Language detection complete./nTime taken: 0:01:04.993261
#                                        postUrl  \
# 0     https://www.instagram.com/p/CgWcU2fss5n/
# 1     https://www.instagram.com/p/CgckMjTpSPs/
# 3     https://www.instagram.com/p/Cgdy9wBjeYl/
# 4     https://www.instagram.com/p/Cgdp-q1vao_/
# 6     https://www.instagram.com/p/CgRpagzj1in/
# ...                                        ...
# 1266  https://www.instagram.com/p/CgcTdXLI0Dd/
# 1267  https://www.instagram.com/p/CgcS-dFJRmx/
# 1268  https://www.instagram.com/p/CgcSs3GjRSE/
# 1269  https://www.instagram.com/p/CgcStMdv2vK/
# 1270  https://www.instagram.com/p/CgcSuw8oVL2/
#
#                                              profileUrl  \
# 0                  https://www.instagram.com/jadesbites
# 1               https://www.instagram.com/sweettreatsyt
# 3                https://www.instagram.com/nicolejcooks
# 4             https://www.instagram.com/its_shreyajoshi
# 6        https://www.instagram.com/alwayshungryinlondon
# ...                                                 ...
# 1266  https://www.instagram.com/liz_sw_weightloss_jo...
# 1267             https://www.instagram.com/_nanny_gram_
# 1268          https://www.instagram.com/goodiesfoodhall
# 1269           https://www.instagram.com/smoothie.smart
# 1270         https://www.instagram.com/keto.diet.pro___
#
#                        username                       fullName  commentCount  \
# 0                    jadesbites          JADE | Recipes & Food            47
# 1                 sweettreatsyt             Ania | SweetTreats             4
# 3                  nicolejcooks                    Nicole Jain             4
# 4               its_shreyajoshi                   Food Blogger             7
# 6          alwayshungryinlondon                      𝐇𝐚𝐧𝐧𝐚𝐡 𝐃𝐉            62
# ...                         ...                            ...           ...
# 1266  liz_sw_weightloss_journey                            NaN             1
# 1267               _nanny_gram_                        Felicia             0
# 1268            goodiesfoodhall              Goodies Food Hall             2
# 1269             smoothie.smart  Smoothies | Weight Los | Diet             3
# 1270           keto.diet.pro___            KETO DIET PLANNER 🔥             4
#
#       likeCount                   pubDate  \
# 0          1648  2022-07-23T10:00:53.000Z
# 1             3  2022-07-25T19:05:06.000Z
# 3            46  2022-07-26T06:33:24.000Z
# 4             3  2022-07-26T05:14:53.000Z
# 6          2821  2022-07-21T13:19:03.000Z
# ...         ...                       ...
# 1266         13  2022-07-25T16:38:51.000Z
# 1267          3  2022-07-25T16:34:38.000Z
# 1268         18  2022-07-25T16:32:14.000Z
# 1269          3  2022-07-25T16:32:16.000Z
# 1270         36  2022-07-25T16:32:29.000Z
#
#                                             description          location  \
# 0     🧄 ~ A G L I O ~ E ~ O L I O ~ 🧄\n\nSimply mean...         Liverpool
# 1     NEW! Condensed Milk Brownies. These brownies a...  Toronto, Ontario
# 3     HOT & COLD\n.\nRoasted peppers & tomatoes pair...               NaN
# 4     Chocolate Bar\n\n#chocolate #recipes #recipeof...               NaN
# 6     Roasted Vegetable Lentil Bowl\n———————————————...    United Kingdom
# ...                                                 ...               ...
# 1266  Fancied burger pasta tonight but without the p...               NaN
# 1267  Nothing better than starting a Monday with one...               NaN
# 1268  Happy summer holidays! 🌞🎉 We hope you survived...     Pulham Market
# 1269  AMAZING tranformation results from a customer ...               NaN
# 1270  Double tap if you love it.\n\nFor recipe just ...               USA
#
#                                                  imgUrl  ...      ownerId  \
# 0     https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...   3656910377
# 1     https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...    633730791
# 3     https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...  10645378983
# 4     https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...  40803727237
# 6     https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...   4204503727
# ...                                                 ...  ...          ...
# 1266  https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...  34220359606
# 1267  https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...  54519380490
# 1268  https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...   2680681440
# 1269  https://scontent-lhr8-1.cdninstagram.com/v/t51...  ...  31927134756
# 1270  https://scontent-lhr8-2.cdninstagram.com/v/t51...  ...  51693160062
#
#           type            query                 timestamp isSidecar  \
# 0        Photo  #recipeoftheday  2022-07-26T08:27:52.635Z     False
# 1     Carousel  #recipeoftheday  2022-07-26T08:27:52.635Z      True
# 3     Carousel  #recipeoftheday  2022-07-26T08:27:52.635Z      True
# 4     Carousel  #recipeoftheday  2022-07-26T08:27:52.635Z      True
# 6        Photo  #recipeoftheday  2022-07-26T08:27:52.635Z     False
# ...        ...              ...                       ...       ...
# 1266     Photo       #easymeals  2022-07-26T08:31:32.893Z     False
# 1267     Photo       #easymeals  2022-07-26T08:31:32.893Z     False
# 1268  Carousel       #easymeals  2022-07-26T08:31:32.893Z      True
# 1269  Carousel       #easymeals  2022-07-26T08:31:32.893Z      True
# 1270     Photo       #easymeals  2022-07-26T08:31:32.893Z     False
#
#       sidecarMedias  videoUrl viewCount  language     score
# 0               NaN       NaN       NaN        en  0.999995
# 1               3.0       NaN       NaN        en  0.999996
# 3               5.0       NaN       NaN        en  0.999997
# 4               2.0       NaN       NaN        en  0.999997
# 6               NaN       NaN       NaN        en  0.999995
# ...             ...       ...       ...       ...       ...
# 1266            NaN       NaN       NaN        en  0.999997
# 1267            NaN       NaN       NaN        en  0.999997
# 1268            3.0       NaN       NaN        en  0.999997
# 1269            2.0       NaN       NaN        en  0.999997
# 1270            NaN       NaN       NaN        en  0.999996
#
# [1043 rows x 21 columns]
