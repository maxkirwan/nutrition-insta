# %% [markdown]
# # Language Detection
#
# This notebook aims to identify the best method for filtering out non-English posts.

# %%
import pandas as pd
from datetime import datetime

# %%
posts = pd.read_csv("/Users/maxkirwan/Desktop/Uni/Data Science MSc/Data Science Project/nutrition-insta/Instagram Data Scraping/Phantom Buster/recipe_posts.csv")
posts.head(2)
# Out:
#                                     postUrl  \
# 0  https://www.instagram.com/p/CgWcU2fss5n/
# 1  https://www.instagram.com/p/CgckMjTpSPs/
#
#                                 profileUrl       username  \
# 0     https://www.instagram.com/jadesbites     jadesbites
# 1  https://www.instagram.com/sweettreatsyt  sweettreatsyt
#
#                 fullName  commentCount  likeCount                   pubDate  \
# 0  JADE | Recipes & Food            47       1648  2022-07-23T10:00:53.000Z
# 1     Ania | SweetTreats             4          3  2022-07-25T19:05:06.000Z
#
#                                          description          location  \
# 0  🧄 ~ A G L I O ~ E ~ O L I O ~ 🧄\n\nSimply mean...         Liverpool
# 1  NEW! Condensed Milk Brownies. These brownies a...  Toronto, Ontario
#
#                                               imgUrl               postId  \
# 0  https://scontent-lhr8-2.cdninstagram.com/v/t51...  2888620789210467943
# 1  https://scontent-lhr8-1.cdninstagram.com/v/t51...  2890344253083689964
#
#       ownerId      type            query                 timestamp  isSidecar  \
# 0  3656910377     Photo  #recipeoftheday  2022-07-26T08:27:52.635Z      False
# 1   633730791  Carousel  #recipeoftheday  2022-07-26T08:27:52.635Z       True
#
#    sidecarMedias videoUrl  viewCount
# 0            NaN      NaN        NaN
# 1            3.0      NaN        NaN

# %% [markdown]
# ### Using SpaCy's language detector

# %%
import spacy
from spacy.language import Language
from spacy_langdetect import LanguageDetector

@Language.factory("language_detector")
def get_lang_detector(nlp, name):
    return LanguageDetector()

nlp = spacy.load("en_core_web_sm")
nlp.add_pipe('language_detector', last=True)
print(nlp("This is an english text.")._.language)
# Out:
# {'language': 'en', 'score': 0.9999981485694562}

# %%
def detect_language(post):
    lang_dict = nlp(str(post))._.language
    return pd.Series([lang_dict['language'], lang_dict['score']])

# %%
from datetime import datetime
import time
now = datetime.now()
time.sleep(5)
print(f"Time taken: {datetime.now()-now}")
# Out:
# Time taken: 0:00:05.000990

# %%
now = datetime.now()
posts[['language', 'score']] = posts['description'].apply(detect_language)
print(f"Completed!\nTime taken: {datetime.now()-now}")
# Out:
# Completed!
# Time taken: 0:00:56.144062

# %%
# Different languages in dataset
posts['language'].unique()
# Out:
# array(['en', 'fr', 'tr', 'it', 'de', 'hu', 'nl', 'ro', 'id', 'ja', 'pl',
#        'ko', 'th', 'hr', 'ar', 'cs', 'es', 'mk', 'tl', 'bg', 'et', 'lt',
#        'el', 'ru', 'sl', 'sv', 'sq', 'da', 'pt'], dtype=object)

# %%
# Lets look at some posts with low scores. These are mainly posts that are in multiple languages.
for index, post in posts[posts['score']<0.6].iterrows():
    print(post['description'], "\n\n", post['language'], post['score'])
# Out:
# Auntie Kai’s Coco Pipinu (Cucumber Coco) 😋🔥❤️
#
# #nettycee #auntiekaiscucumbercoco #cocorecipe #coco #cucumber #cocopipinu #recipe #easyrecipe #easyrecipes #saipan #cnmi #marianas #themarianas #pickledcucumber #foodie #tiktokfoodie
#
#  ro 0.5714267746615391
# #brownies #homemade#chocolate #delicious #2022 #easyrecipes
#
#  en 0.5714268193276484
# Sabudana Vada 🥰 Tag your bestie 😍
# Follow @foodbook_by_aditi
#
# #sabudanavada #meduvada #vadapav #pakoda #easyrecipes #quickrecipes #recipe #recipes
#
#  es 0.5654219400703555
# Niku-maki bento ! 🍱(veggies wrapped in pork) ✿豚の肉巻き弁当✿！
#
# Bento main:
# -Veggies, shiso and cheese wrapped in pork 🥕🐷
# -Brown rice
#
# Bento sides:
# -Broccoli dressed in sesame 🥦
# -Bell pepper, tomato and basil salad 🍅🌿
# -Hard boiled egg 🥚
#
# ✿豚の肉巻き弁当✿
# ◎豚の肉巻き (にんじん、インゲン、チーズ、大葉入り)
# ◎玄米
# ◎ブロッコリーの胡麻和え
# ◎ピーマン、トマトとバジルのサラダ
# ◎ゆで卵
#
# Reel coming soon 😊▶️
# .
# .
# .
#
# #mizuseats#cooking#food#foodstagram #easyrecipes##自炊#自炊記録 #bentobox#bento#本日のお弁当#お弁当#弁当#japanese弁当 #肉巻き#lunch##recipes#簡単レシピ #簡単料理 #肉巻き弁当#豚の肉巻き#弁当記録#japanesecooking#japanesefood#japan#japanfood#japanesecooking#healthy#healthyfood#foodie#japantravel
#
#  en 0.5714273300557413
# 🌱Malzemeler son postta! Ingredients in last post!
#
# 🌷Beys tarif:
#
# 1. Reyhanları bir tencere içine yerleştiriniz.
# 2. 2 yemek kaşığı şeker ekleyiniz.
# 3. 3-4 tane limon tuzu ekleyiniz.
# 4. Kaynamış 1 litre suyu tencereye dökünüz ve kapağını kapatıp 15-20 dk demlenmesini bekleyiniz.
# 5. Suyun rengi değiştikten sonra reyhanları çıkarınız ve soğumaya bırakınız. İçine buz, nane vb şeyler katarak içebilirsiniz. Afiyet olsun!
#
# 🌷Beys recipe:
#
# 1. Place the basil in a saucepan.
# 2. Add 2 tbsp of sugar.
# 3. Add 3-4 sour salt.
# 4. Pour 1 lit. of boiled water into the pot and close the lid and wait for it to brew for 15-20 min.
# 5. After the color of the water changes, take out the basil and let it cool. You can drink it by adding ice, mint etc. Bon appetit!
#
# #easyrecipes#colddrinks#drinkrecipes#kolaytarifler#soğukiçeçekler#cocktailrecipes#recipeshare#applecocktail#health#recipeideas#tarifler#içecektarifleri#sağlık#vegantarifler#plantbased#aesthetic#drinks#homemade#cooking#healthylifestyle#healthyrecipes
#
#  tr 0.5714291282461511
# Frukost: kefir, kanel, havregryn, nektarinbitar, blåbär 🫐 🍑
# .
# .
# .
# .
# .
# .
# .
# #kefir #havregryn #healthy #oats #fruktochbär #foodart #goodfood  #breakfastbowl #breakfast #frukost #fruit #berries #foodblogger  #delicious #mattips #lovefood #foodtography #oatbowl #recipeideas  #foodstagram #ibs
#
#  sv 0.5714271161219189
# 💚 CHEESECAKE VEGANA ALLE ALBICOCCHE 💚 (English below)
#
# ☀️ Voi amate l'estate?
#
# 🍑🍒 A noi piace soprattutto per la grande varietà di frutta che si trova. Se siete come noi dovete per forza provare questa cheesecake alle albicocche!
#
# INGREDIENTI DEL RIPIENO:
#
# 400 g tofu vellutato
# 80 g latte di avena
# 240 g panna vegana
# 3 g agar agar
# 3 albicocche mature
#
# 👉 La ricetta completa la trovate su www.twinsfoodlab.com, oppure cliccando sul link in bio!
#
# ~~~
#
# 💚 APRICOTS VEGAN CHEESECAKE 💚
#
# ☀️ Do you love summer?
#
# 🍑🍒 We like it beacause of the great variety of fruit that can be found. If you are the same as us, you must try this apricot cheesecake!
#
# FILLING INGREDIENTS:
#
# 400 g silken tofu
# 80 g oat milk
# 240 g vegan whipped cream
# 3 g agar agar
# 3 ripe apricots
#
# 👉 The complete recipe can be found on www.twinsfoodlab.com, or by clicking the link in bio!
#
# ~~~
#
# #twinsfoodlab #dolcivegani #dolcivegan #cheesecake #vegancheesecake #ricettevegane #ricettevegan #cucinavegana #dolcisani #healthyrecipes #ricettesane #bergamo #albicocche #cheesecakevegana #cheesecakevegan #iomangiosano #veganok #veganitalia #veganitaly #senzaburro #senzauova #senzalattosio #dolcifattiincasa #veganpastrychef #veganpastry
#
#  en 0.5714288910175669
# Healthy eating is not boring 🤤
#
# Αυγόφετες
#
# •σε αντικολλητικό τηγάνι με 1κ.γ ελαιόλαδο
# •Πρόσθεσα μέλι και μαρμελάδα με λιγότερες θερμίδες 🍯🍒
#
# •Περίπου 300 θερμίδες•
#
# #healthylifestyle #healthyliving #healthyhabits #healthybodyhealthymind #healthybody #healthychoices #healthy #health #healthyrecipes #healthyfood #healthyeating #bodyfitness #bodyacceptance  #bodymindsoul #food #foodlover #υγιεινηδιατροφη #υγεια #υγεία #διατροφή #διατροφη #αυγοφετες
#
#  en 0.5714249947885427
# Breakfast
# سموذي الموز
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# #healthyrecipes #healthyfood #healthybreakfast #healthysmoothies #healthysmoothie #smoothie #smothiebowl #سموذي #سموذي_صحي #سموذي_بول #سموذي_بالموز_والشوفان #اكل_صحي #حياة_صحية #دايت_ورياضة #نظام_غذائي #نظام_صحي #اكسبلور #explore #instagram
#
#  en 0.5714270807313108
# Pirinčani griz bez kuvanja 😍
# Sastojci:
# 40 gr pirinčanih pahuljica
# 1 kašičica čia semenki
# 1 merica proteina
# 100 ml provrele vode
# 50-ak ml biljnog mleka
# 1 kašičica kikiriki putera
# Zasladjivac po želji ukoliko volite sladje
# Priprema:
# Samleti pahuljice I čia semenke dodati postepeno provrelu vodu do željene gustine,konstantno mesati(ja potrošim odprilike 100ml),zatim dodati protein i razmutiti ga sa mlekom!Dekorisati željenim voćem i zero prelivom!Uživati u laganom i ukusnom doručku ili uzini!
# #healthyproo#healthylifestyle #helathyfood #helathylife #healthyblogger #healthyeating #healthyrecipes #healthychoices #healthy #zdravoproo #zdravaishrana #zdravirecepti#zdravauzina #zdravobrok #zdravahrana#nosugar #novisad #instafood #instahealth #instablogger #instagram #foodblog #foodblogger #foodstagram #foodphotography #foodporn #foodinstagram
#
#  hr 0.5708338794242274
# Wie immer …
# #gutenmorgen #goodmorning
# #täglichgrüsstdasmurmeltier #petmüsli #iloveit #oatmeal #fruit #nibs #müsli #morningvibes #morning #meal #breakfast #vegan #veganfood #veganfoodporn #veganfoodlovers #healthyfood #healthyrecipes #getreidekaffee #kaffee #kaffeeliebe #foodblogger #foodlover #summervibes #summer #juli #july
#
#  da 0.5125635894934101
# TROPICAL DIET SMOOTHIE 🍍🥭🥥
#
# Нещо тропическо, свежо и идеално за лятото.
# Тази диетична протеинова бленда съдържа много полезни съставки, а именно:
# ✨Глюкоманан-диетични фибри
# ✨Витамин B5
# ✨Смес от ензими, които спомагат за по-бързото разбиване на протеина до аминокиселини
# ✨Екстракт от канела
# ✨CLA powder - естествено срещаща се мастна киселина от шафраново масло
# ✨Матча зелен чай на прах
# ✨Хюлин - помага за преобразуването на мазнини в енергия
#
# 🌴А също така една доза съдържа само 1,3г мазнини и 3,9г въглехидрати.
#
# ✨Препоръчвам ви да го пробвате, вкусът е уникален, съчетан с плодове под формата на смути. А в сайта на @myproteinbg може да използвате кода ми 𝐒𝐈𝐋𝐕𝐈𝐘𝐀𝐌𝐏 за допълнителна отстъпка! ✨
#
# Ето какво ви трябва за смутито 🥥
# ▪️50 г боровинки
# ▪️50 г манго
# ▪️50 г ананас
# ▪️50 г морков
# ▪️300 мл прясно мляко / овесено мляко
# ▪️1 доза диетичен протеин ягодов милкшейк @myproteinbg
#
# За украса
# ▪️кокосов сироп
# .
# .
# .
# .
# 🇺🇸TROPICAL DIET SMOOTHIE 🍍🥭🥥
#
# Something tropical, fresh and perfect for summer.
# This diet protein blend contains many beneficial ingredients, namely:
# ✨Glucomannan-dietary fiber
# ✨Vitamin B5
# ✨Mixture of enzymes that help break down protein into amino acids faster
# ✨Cinnamon extract
# ✨CLA powder - a naturally occurring fatty acid from safflower oil
# ✨Matcha green tea powder
# ✨Hyulin - helps convert fat into energy
#
# 🌴And also one dose contains only 1.3g of fat and 3.9g of carbohydrates.
#
# ✨I recommend you to try it, the taste is unique, combined with fruit in the form of a smoothie. And on the site of @myproteinbg you can use my code SILVIYAMP for an additional discount! ✨
#
# Here's what you need for the smoothie 🥥
# ▪️50 g of blueberries
# ▪️50 g of mango
# ▪️50 g of pineapple
# ▪️50 g carrot
# ▪️300 ml fresh milk / oat milk
# ▪️1 dose of diet protein strawberry milkshake @myproteinbg
#
# For decoration
# ▪️coconut syrup
# .
# .
# .
# .
# .
# #myprotein #teammyp #fuelyourambition #youdoyou #myproteinkitchen #protein #smoothie #food #foodblogfeed #foodblogger #foodphotography #foodpic #blogger #photooftheday #healthy #healthyfood #healthyeating #healthyrecipes #healthyideas #healthylifestyle #eatclean #goodfood #eatgoodfeelgood #nutrition #fit #fitfood #summer
#
#  en 0.5714280728106628
# Tulunad Special Menthe Ganji 😋
#
# Fenugreek Seeds Porridge
#
# #healthyfood #healthyrecipes #mentheganji #aati #aatiamavasya #tulunad #mangalorespecial #karanataka #karnatakafood #karnatakafoodies #mangalorefood #foodgasm #foodiesofkarnataka #karnatakafoodadda #karnatakafoodbloggers #karnatakafoodlovers #foodlovers #udupifood
#
#  et 0.42857179507101417
# Vous aimez manger sainement ? 🌿😋
# Nos produits sont sans additifs, sans conservateurs et sans gluten.
# Le riz et les légumes utilisés sont bio et les poissons sont issus exclusivement de pêche durable et labellisés MSC. 🎣💙
# .
# .
# .
# .
# .
# .
# .
# .
# #organic #vegan #healthy #instagood #biology
# #homemade #crueltyfree #sushilover #yummy
# #MadeInFrance #sansgluten #passionfood #france
# #delicious #instalike #summer #yummyfood #japon
# #food #japanesefood #japanesefoodstreet #foodporn #healthyrecipes #healthyeating #bio #foodlover #foodies #deliciousfood #eatclean #food
#
#  fr 0.571429207591107
# Prosciutto/mozza salade 🥗 #summer #salade #salad #fresh #healthyfood #sain #mangersain #prosciutto #mozzarella #été #warm #mangersainement #easymeals #diner
#
#  it 0.571426562932605
# Why is canned tuna so cheap when fresh tuna is so expensive?
#
# Tuna salad:
# - Tuna+mayo+salt+yogurt+lime
# - Red coral lettuce
# - Baby cos lettuce
# - Butterhead lettuce
# - Fresh shallots
# - Goji berries
# - Spring onions
# - Hard boiled egg
#
# Well it basically comes down to what is described as "sushinomics". Tuna that is canned are species that reproduce quickly creating a vast supply (albacore, yellowtail etc.) But are considered less tasty. The ones that are used for sashimi and sushi are the Bluefin tuna which not only require more efforts in catch but are also low in supply. With the fish only reaching reproductive at 8 years and only having a life span of around 40 years, there aren't much to go around. Overfishing has also greatly contributed to the decline in supply of bluefins as they are being caught before being able to reproduce. Lack in regulation will likely lead to extinction of these tasty swimmers. Luckily there are efforts being put forward and the status of bluefin have been reduce from endangered to least concern. Which is great but it needs to be continued because they taste so good 🥺.
#
# Oh and side note: if you dont want to add alot of mayo to your tuna; sub with unsweetened yogurt, lime and salt. Gives it a fresh taste and adds a 'lil probiotics to you diet.
#
# ทำไมทูน่ากระป๋องกับแบบซาชิมิถึงราคาต่างกันราวฟ้ากับเหว
#
# สลัด:
# - ทูน่าผสม มายองเนส โยเกิร์ต เกลือ มะนาว
# - ผักเรดคอรัล
# - เบบี้คอส
# - บัตรเตอร์เฮด
# - หอมแดง
# - ต้นหอม
# - โกจิเบอร์รี่
# - ไข่ต้ม
#
# คือราคามันก็ขึ้นอยู่กับอุปสงค์อุปทานแหละ ตัวชนิดแลาที่เอามาทำทูน่ากระป๋องเป็นพันธุ์ที่โตไวและออกลูกง่ายเลยมีให้จับได้ล้นเหลือ ส่วนพันธุ์ที่เอามาทำเป็นซาชิมินั้นนิยมเป็นพันธุ์บลูฟิน ซึ่งกว่าจะโตถึงไวเพาะพันธุ์ก็ ตั้ง8ปี แล้วแถมยังอยู่น้ำลึกจับยากอีก เนื่องจากมีดารจับปลาบลูฟินที่เร็วเกินกว่ามันจะขยายพันธ์ได้ก็ทำให้จำนวนนั้นลดลงไปเรื่อยๆ มิหนำซ้ำชาวประมงเริ่มจับปลาที่มีขนาดเล็กลงซึ่งอาจจะอายุน้อยกว่า 8ปี ทำให้ปลาเหลือน้อยยิ่งไปอีกเพราะยังไม่ได้ทันออกลูกก็ถูกจับไปกินสะแล้ว
#
# ปล. ใครไม่อยากใช้มายองเนสผสมปลาเยอะให้เปลี่ยนมาเป็นโยเกิร์ตไม่หวานผสมเกลือกับมะนาวนะ หลดไขมันได้เยอะเลยแถมยังเพิ่มโปรไบโอติกอีก
#
#  en 0.5714285168892246
# Tomato sauce spaghetti and roasted broccoli. I made a quick supper and fed my son and brought him to his soccer game but it got cancelled because of thunder storm 😵‍💫
# .
# .
# .
# トマトソーススパゲッティとローストブロッコリー。息子のサッカーの試合があるからと、慌てて作って食べさせて試合に連れて行ったけど、雷雨で中止に🙄
# .
# .
# .
# .
# .
# .
#
# #veganrecipes #vegetarianrecipes #tomatosaucespaghetti #spaghettitomatosauce #tomatosaucepasta #simplepasta #airfryerbroccoli #airfriedbroccoli #simplecooking #quickmeals #easymeals #healthymeals #ビーガンレシピ #ベジタリアンレシピ #トマトソーススパゲッティ #スパゲッティトマトソース #トマトソースパスタ #シンプルパスタ #ノンフライヤーレシピ #エアフライヤーレシピ #おうちごはん #晩ごはん #シンプルごはん #簡単ごはん #ヘルシーごはん
#
#  ja 0.571428542322404
